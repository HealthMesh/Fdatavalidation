# %%
import os

# %%
base_dir = os.getcwd()

base_dir = os.path.join(base_dir, '../')

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # DATA VALIDATION FRAMEWORK

# %% [markdown]
# ![title](demo_images/Prototype.png)

# %% [markdown]
# The Data Validation Framework is intented to be used in federated enviorments such as federated repositories and data spaces. In the above figure, the different components, roles and workflows are represented.
#
# Roles:
#
#     - Data Owners (i.e, Providers)
#     - Data Consumers
#     - Federated Team (i.e. Federator)
#
# Components:
#
#     - Data Platform Layer: Acts as interface for the different roles to interact with the framework.
#     - Semantic Data Model $\Delta$: Graph-based construct with all the metadata of the federation acting as a backbone to operacionalize processes.
#     - Data Validation Workflow includes the following:
#         - Parser: Generates Policy Checkers
#         - Translator: Generates UDFs for data validation
#         - Graph Transformation rules: Used to generate Policy Checkers
#         - Code metadata: Used to generate UDFs
#
# Wokflows:
#
#     - Data federation population (Blue Arrows)
#     - Data Validation Workflow (Orange Arrows)

# %% [markdown]
# ## GRAPH-BASED DATA FEDERATION

# %% [markdown]
# ### Global Definitions and Policies

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:16<00:00,  1.09s/cell]
# {'cells': [{'id': '784ffabe',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.235600',
#      'end_time': '2024-11-24T07:57:32.258211',
#      'duration': 0.022611,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.239115Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.239601Z',
#      'iopub.status.idle': '2024-11-24T07:57:32.254306Z',
#      'shell.execute_reply': '2024-11-24T07:57:32.252519Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.263373',
#      'end_time': '2024-11-24T07:57:32.282847',
#      'duration': 0.019474,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.267833Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.268561Z',
#      'iopub.status.idle': '2024-11-24T07:57:32.278832Z',
#      'shell.execute_reply': '2024-11-24T07:57:32.276345Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.283172',
#      'end_time': '2024-11-24T07:57:32.284144',
#      'duration': 0.000972,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.284461',
#      'end_time': '2024-11-24T07:57:32.434730',
#      'duration': 0.150269,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.287211Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.287806Z',
#      'iopub.status.idle': '2024-11-24T07:57:32.430369Z',
#      'shell.execute_reply': '2024-11-24T07:57:32.428883Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.437015',
#      'end_time': '2024-11-24T07:57:32.476262',
#      'duration': 0.039247,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.440050Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.441080Z',
#      'shell.execute_reply': '2024-11-24T07:57:32.471086Z',
#      'iopub.status.idle': '2024-11-24T07:57:32.472686Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.476607',
#      'end_time': '2024-11-24T07:57:32.477249',
#      'duration': 0.000642,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.477631',
#      'end_time': '2024-11-24T07:57:32.495207',
#      'duration': 0.017576,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.480257Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.481246Z',
#      'iopub.status.idle': '2024-11-24T07:57:32.491256Z',
#      'shell.execute_reply': '2024-11-24T07:57:32.489496Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:32.495561',
#      'end_time': '2024-11-24T07:57:37.026270',
#      'duration': 4.530709,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:32.497715Z',
#      'iopub.execute_input': '2024-11-24T07:57:32.498634Z',
#      'iopub.status.idle': '2024-11-24T07:57:37.023728Z',
#      'shell.execute_reply': '2024-11-24T07:57:37.022216Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.1.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.027752',
#      'end_time': '2024-11-24T07:57:37.028584',
#      'duration': 0.000832,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Common Data Models',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.028912',
#      'end_time': '2024-11-24T07:57:37.042079',
#      'duration': 0.013167,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:37.030608Z',
#      'iopub.execute_input': '2024-11-24T07:57:37.031486Z',
#      'shell.execute_reply': '2024-11-24T07:57:37.036960Z',
#      'iopub.status.idle': '2024-11-24T07:57:37.038532Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/common_data_models.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.042281',
#      'end_time': '2024-11-24T07:57:37.068051',
#      'duration': 0.02577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:37.043864Z',
#      'iopub.execute_input': '2024-11-24T07:57:37.044189Z',
#      'iopub.status.idle': '2024-11-24T07:57:37.064318Z',
#      'shell.execute_reply': '2024-11-24T07:57:37.063159Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.068426',
#      'end_time': '2024-11-24T07:57:37.068810',
#      'duration': 0.000384,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.069186',
#      'end_time': '2024-11-24T07:57:37.107948',
#      'duration': 0.038762,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:37.070952Z',
#      'iopub.execute_input': '2024-11-24T07:57:37.071777Z',
#      'shell.execute_reply': '2024-11-24T07:57:37.102889Z',
#      'iopub.status.idle': '2024-11-24T07:57:37.104378Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.108300',
#      'end_time': '2024-11-24T07:57:37.108659',
#      'duration': 0.000359,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:37.108983',
#      'end_time': '2024-11-24T07:57:37.150611',
#      'duration': 0.041628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:37.110883Z',
#      'iopub.execute_input': '2024-11-24T07:57:37.111550Z',
#      'iopub.status.idle': '2024-11-24T07:57:37.146712Z',
#      'shell.execute_reply': '2024-11-24T07:57:37.145357Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8a7acbb7f7a94918a2a344e644420842 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-24T07:57:21.181249',
#    'end_time': '2024-11-24T07:57:37.475507',
#    'duration': 16.294258,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### Data product Registration

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# #### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 11/11 [00:21<00:00,  1.97s/cell]
# {'cells': [{'id': '3fa87afb',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:48.939974',
#      'end_time': '2024-11-24T07:57:48.999538',
#      'duration': 0.059564,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:48.945484Z',
#      'iopub.execute_input': '2024-11-24T07:57:48.948426Z',
#      'iopub.status.idle': '2024-11-24T07:57:48.986610Z',
#      'shell.execute_reply': '2024-11-24T07:57:48.982809Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-10-25T14:11:00.245095Z',
#      'start_time': '2024-10-25T14:10:48.071834Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:49.013631',
#      'end_time': '2024-11-24T07:57:57.685417',
#      'duration': 8.671786,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:49.024180Z',
#      'iopub.execute_input': '2024-11-24T07:57:49.029883Z',
#      'shell.execute_reply': '2024-11-24T07:57:57.681752Z',
#      'iopub.status.idle': '2024-11-24T07:57:57.683104Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.1.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (1.5.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: python-dateutil>=2.8.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: numpy>=1.21.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.23.4)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.261824Z',
#      'start_time': '2024-10-25T14:11:00.255390Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:57.686372',
#      'end_time': '2024-11-24T07:57:57.696920',
#      'duration': 0.010548,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:57.688046Z',
#      'iopub.execute_input': '2024-11-24T07:57:57.688365Z',
#      'iopub.status.idle': '2024-11-24T07:57:57.693501Z',
#      'shell.execute_reply': '2024-11-24T07:57:57.692535Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.351533Z',
#      'start_time': '2024-10-25T14:11:00.320406Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:57.697239',
#      'end_time': '2024-11-24T07:57:57.769344',
#      'duration': 0.072105,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:57.698769Z',
#      'iopub.execute_input': '2024-11-24T07:57:57.699415Z',
#      'shell.execute_reply': '2024-11-24T07:57:57.766086Z',
#      'iopub.status.idle': '2024-11-24T07:57:57.767058Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:57.769519',
#      'end_time': '2024-11-24T07:57:58.680413',
#      'duration': 0.910894,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:57.771070Z',
#      'iopub.execute_input': '2024-11-24T07:57:57.771443Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.676058Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.677049Z'}},
#    'cell_type': 'code',
#    'outputs': [],
#    'execution_count': 5,
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.sour ...
#    'id': 'e77fc103b819f2e6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.466088Z',
#      'start_time': '2024-10-25T14:11:00.459873Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.681601',
#      'end_time': '2024-11-24T07:57:58.693216',
#      'duration': 0.011615,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:58.683661Z',
#      'iopub.execute_input': '2024-11-24T07:57:58.684368Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.689585Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.690535Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.524701Z',
#      'start_time': '2024-10-25T14:11:00.507714Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.693386',
#      'end_time': '2024-11-24T07:57:58.711570',
#      'duration': 0.018184,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:58.694735Z',
#      'iopub.execute_input': '2024-11-24T07:57:58.694990Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.707156Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.708325Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.567706Z',
#      'start_time': '2024-10-25T14:11:00.562378Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.711869',
#      'end_time': '2024-11-24T07:57:58.721755',
#      'duration': 0.009886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:58.713844Z',
#      'iopub.execute_input': '2024-11-24T07:57:58.714300Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.719461Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.718280Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.722004',
#      'end_time': '2024-11-24T07:57:58.722306',
#      'duration': 0.000302,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.653276Z',
#      'start_time': '2024-10-25T14:11:00.613474Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.722488',
#      'end_time': '2024-11-24T07:57:58.748033',
#      'duration': 0.025545,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:58.723886Z',
#      'iopub.execute_input': '2024-11-24T07:57:58.724376Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.743741Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.744824Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.739277Z',
#      'start_time': '2024-10-25T14:11:00.679709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:57:58.748348',
#      'end_time': '2024-11-24T07:57:58.820837',
#      'duration': 0.072489,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:57:58.750119Z',
#      'iopub.execute_input': '2024-11-24T07:57:58.750983Z',
#      'shell.execute_reply': '2024-11-24T07:57:58.814216Z',
#      'iopub.status.idle': '2024-11-24T07:57:58.816485Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1d318de3451c47d498a7174b7a708476 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-24T07:57:37.660116',
#    'end_time': '2024-11-24T07:57:59.361595',
#    'duration': 21.701479,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# #### DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 11/11 [00:21<00:00,  1.99s/cell]
# {'cells': [{'id': '1fd3c01a',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:10.516293',
#      'end_time': '2024-11-24T07:58:10.531434',
#      'duration': 0.015141,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:10.517789Z',
#      'iopub.execute_input': '2024-11-24T07:58:10.518065Z',
#      'shell.execute_reply': '2024-11-24T07:58:10.525796Z',
#      'iopub.status.idle': '2024-11-24T07:58:10.526974Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-10-25T14:11:00.245095Z',
#      'start_time': '2024-10-25T14:10:48.071834Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:10.532556',
#      'end_time': '2024-11-24T07:58:20.104930',
#      'duration': 9.572374,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:10.534430Z',
#      'iopub.execute_input': '2024-11-24T07:58:10.534925Z',
#      'iopub.status.idle': '2024-11-24T07:58:20.095916Z',
#      'shell.execute_reply': '2024-11-24T07:58:20.091315Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.1.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (1.5.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: python-dateutil>=2.8.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: numpy>=1.21.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.23.4)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.261824Z',
#      'start_time': '2024-10-25T14:11:00.255390Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:20.108587',
#      'end_time': '2024-11-24T07:58:20.143331',
#      'duration': 0.034744,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:20.116326Z',
#      'iopub.execute_input': '2024-11-24T07:58:20.117808Z',
#      'shell.execute_reply': '2024-11-24T07:58:20.133584Z',
#      'iopub.status.idle': '2024-11-24T07:58:20.136109Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.351533Z',
#      'start_time': '2024-10-25T14:11:00.320406Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:20.144080',
#      'end_time': '2024-11-24T07:58:20.270373',
#      'duration': 0.126293,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:20.149091Z',
#      'iopub.execute_input': '2024-11-24T07:58:20.151238Z',
#      'iopub.status.idle': '2024-11-24T07:58:20.268480Z',
#      'shell.execute_reply': '2024-11-24T07:58:20.267620Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:20.271283',
#      'end_time': '2024-11-24T07:58:21.003197',
#      'duration': 0.731914,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:20.273260Z',
#      'iopub.execute_input': '2024-11-24T07:58:20.273608Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.000231Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.001247Z'}},
#    'cell_type': 'code',
#    'outputs': [],
#    'execution_count': 5,
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.sour ...
#    'id': 'e77fc103b819f2e6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.466088Z',
#      'start_time': '2024-10-25T14:11:00.459873Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.004079',
#      'end_time': '2024-11-24T07:58:21.012783',
#      'duration': 0.008704,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:21.006121Z',
#      'iopub.execute_input': '2024-11-24T07:58:21.006472Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.010721Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.010018Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.524701Z',
#      'start_time': '2024-10-25T14:11:00.507714Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.012926',
#      'end_time': '2024-11-24T07:58:21.032930',
#      'duration': 0.020004,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:21.014015Z',
#      'iopub.execute_input': '2024-11-24T07:58:21.014244Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.031279Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.030553Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.567706Z',
#      'start_time': '2024-10-25T14:11:00.562378Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.033202',
#      'end_time': '2024-11-24T07:58:21.040400',
#      'duration': 0.007198,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:21.034219Z',
#      'iopub.execute_input': '2024-11-24T07:58:21.034445Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.037003Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.037836Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.040573',
#      'end_time': '2024-11-24T07:58:21.040816',
#      'duration': 0.000243,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.653276Z',
#      'start_time': '2024-10-25T14:11:00.613474Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.040942',
#      'end_time': '2024-11-24T07:58:21.069963',
#      'duration': 0.029021,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:21.042250Z',
#      'iopub.execute_input': '2024-11-24T07:58:21.042486Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.067155Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.068051Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.739277Z',
#      'start_time': '2024-10-25T14:11:00.679709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:21.070105',
#      'end_time': '2024-11-24T07:58:21.114348',
#      'duration': 0.044243,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:21.071367Z',
#      'iopub.execute_input': '2024-11-24T07:58:21.071655Z',
#      'shell.execute_reply': '2024-11-24T07:58:21.111500Z',
#      'iopub.status.idle': '2024-11-24T07:58:21.112365Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc4a50caa338e48c4af1475aeae82aad0 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-24T07:57:59.592871',
#    'end_time': '2024-11-24T07:58:21.536997',
#    'duration': 21.944126,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:26<00:00,  1.58s/cell]
# {'cells': [{'id': '76afa74b',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:32.556127',
#      'end_time': '2024-11-24T07:58:32.580924',
#      'duration': 0.024797,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:32.559687Z',
#      'iopub.execute_input': '2024-11-24T07:58:32.561152Z',
#      'shell.execute_reply': '2024-11-24T07:58:32.577081Z',
#      'iopub.status.idle': '2024-11-24T07:58:32.578299Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:32.582090',
#      'end_time': '2024-11-24T07:58:47.913618',
#      'duration': 15.331528,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:32.584309Z',
#      'iopub.execute_input': '2024-11-24T07:58:32.585246Z',
#      'shell.execute_reply': '2024-11-24T07:58:47.905582Z',
#      'iopub.status.idle': '2024-11-24T07:58:47.907768Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:47.915538',
#      'end_time': '2024-11-24T07:58:47.928746',
#      'duration': 0.013208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:47.918694Z',
#      'iopub.execute_input': '2024-11-24T07:58:47.919234Z',
#      'shell.execute_reply': '2024-11-24T07:58:47.924826Z',
#      'iopub.status.idle': '2024-11-24T07:58:47.926341Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:47.929175',
#      'end_time': '2024-11-24T07:58:48.002200',
#      'duration': 0.073025,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:47.930797Z',
#      'iopub.execute_input': '2024-11-24T07:58:47.931137Z',
#      'iopub.status.idle': '2024-11-24T07:58:47.999646Z',
#      'shell.execute_reply': '2024-11-24T07:58:47.998843Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.002353',
#      'end_time': '2024-11-24T07:58:48.009906',
#      'duration': 0.007553,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.003566Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.003786Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.008121Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.007202Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.010111',
#      'end_time': '2024-11-24T07:58:48.024853',
#      'duration': 0.014742,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.011295Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.011768Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.021079Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.020220Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.026415',
#      'end_time': '2024-11-24T07:58:48.027181',
#      'duration': 0.000766,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.027469',
#      'end_time': '2024-11-24T07:58:48.027804',
#      'duration': 0.000335,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.028040',
#      'end_time': '2024-11-24T07:58:48.060690',
#      'duration': 0.03265,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.029712Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.030139Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.057237Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.058091Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.060842',
#      'end_time': '2024-11-24T07:58:48.061068',
#      'duration': 0.000226,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.061217',
#      'end_time': '2024-11-24T07:58:48.069516',
#      'duration': 0.008299,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.062345Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.062576Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.066351Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.067271Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.069658',
#      'end_time': '2024-11-24T07:58:48.076942',
#      'duration': 0.007284,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.070930Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.071165Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.075039Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.074053Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.077077',
#      'end_time': '2024-11-24T07:58:48.084204',
#      'duration': 0.007127,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.078139Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.078431Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.082460Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.081424Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.084339',
#      'end_time': '2024-11-24T07:58:48.092603',
#      'duration': 0.008264,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.085602Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.085963Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.089399Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.090278Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.092757',
#      'end_time': '2024-11-24T07:58:48.100058',
#      'duration': 0.007301,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.094025Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.094256Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.096976Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.097929Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.100206',
#      'end_time': '2024-11-24T07:58:48.100463',
#      'duration': 0.000257,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:48.100603',
#      'end_time': '2024-11-24T07:58:48.157927',
#      'duration': 0.057324,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:48.101635Z',
#      'iopub.execute_input': '2024-11-24T07:58:48.101950Z',
#      'shell.execute_reply': '2024-11-24T07:58:48.154540Z',
#      'iopub.status.idle': '2024-11-24T07:58:48.155146Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3ef1ca634fc94a02843f6a16604928de (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-24T07:58:21.627268',
#    'end_time': '2024-11-24T07:58:48.480848',
#    'duration': 26.85358,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:24<00:00,  1.43s/cell]
# {'cells': [{'id': 'e520f7e4',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:59.690892',
#      'end_time': '2024-11-24T07:58:59.762689',
#      'duration': 0.071797,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:59.697417Z',
#      'iopub.execute_input': '2024-11-24T07:58:59.702635Z',
#      'iopub.status.idle': '2024-11-24T07:58:59.748054Z',
#      'shell.execute_reply': '2024-11-24T07:58:59.743025Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:58:59.770785',
#      'end_time': '2024-11-24T07:59:12.253253',
#      'duration': 12.482468,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:58:59.776122Z',
#      'iopub.execute_input': '2024-11-24T07:58:59.777016Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.247953Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.249766Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.254653',
#      'end_time': '2024-11-24T07:59:12.265959',
#      'duration': 0.011306,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.257479Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.257849Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.263807Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.262637Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.266124',
#      'end_time': '2024-11-24T07:59:12.336469',
#      'duration': 0.070345,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.267637Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.268058Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.334439Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.333488Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.336608',
#      'end_time': '2024-11-24T07:59:12.347089',
#      'duration': 0.010481,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.338142Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.338945Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.344802Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.343628Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.347237',
#      'end_time': '2024-11-24T07:59:12.364141',
#      'duration': 0.016904,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.348658Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.349016Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.361610Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.360834Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.365253',
#      'end_time': '2024-11-24T07:59:12.365905',
#      'duration': 0.000652,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.366059',
#      'end_time': '2024-11-24T07:59:12.366275',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.366398',
#      'end_time': '2024-11-24T07:59:12.398234',
#      'duration': 0.031836,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.367439Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.367666Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.395627Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.396431Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.398423',
#      'end_time': '2024-11-24T07:59:12.398692',
#      'duration': 0.000269,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.398834',
#      'end_time': '2024-11-24T07:59:12.412170',
#      'duration': 0.013336,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.399944Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.400324Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.410016Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.408985Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.412460',
#      'end_time': '2024-11-24T07:59:12.419465',
#      'duration': 0.007005,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.413871Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.414229Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.416708Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.417539Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.419667',
#      'end_time': '2024-11-24T07:59:12.428326',
#      'duration': 0.008659,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.420951Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.421521Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.425225Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.426383Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.428552',
#      'end_time': '2024-11-24T07:59:12.437245',
#      'duration': 0.008693,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.429788Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.430101Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.432783Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.433764Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.437540',
#      'end_time': '2024-11-24T07:59:12.456496',
#      'duration': 0.018956,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.439403Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.444509Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.452527Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.453663Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.456664',
#      'end_time': '2024-11-24T07:59:12.456946',
#      'duration': 0.000282,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-24T07:59:12.457111',
#      'end_time': '2024-11-24T07:59:12.516761',
#      'duration': 0.05965,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-24T07:59:12.458826Z',
#      'iopub.execute_input': '2024-11-24T07:59:12.459770Z',
#      'iopub.status.idle': '2024-11-24T07:59:12.515004Z',
#      'shell.execute_reply': '2024-11-24T07:59:12.514215Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N519dc9077ef3413a853fe42283d6bccd (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-24T07:58:48.560285',
#    'end_time': '2024-11-24T07:59:12.848066',
#    'duration': 24.287781,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA VALIDATION WORKFLOW

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# Avaliable Common Data Models

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:CommonDataModel .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %% [markdown]
# The user selects a common data model for analysis

# %%
#dp = input("SELECT NAME OF THE COMMON DATA MODEL: ")
dp = "Patient_Data"

# %% [markdown]
# We retrive the data products that are mapped to the selected common data model through their data contracts

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:prohibition|odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


data_products = [row.dataset.split("#")[1] for row in qres]

data_products = set(data_products)
data_products
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ### PARSER

# %% [markdown]
# The parser generates a set of policy checkers $C$ for each data product $DP$ that is mapped to the selected common data model

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in data_products:
    print("DP", dp)
    pm.execute_notebook(
        os.path.join(base_dir, 'Connector/ValidationFramework/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'Connector/ValidationFramework/parser/'),
            'dp': dp
        },
        log_output=False
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP UPENN-GBM_clinical_info_v21csv
# Executing: 100%|██████████| 15/15 [00:23<00:00,  1.55s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP 0002DCM
# Executing: 100%|██████████| 15/15 [00:21<00:00,  1.42s/cell]

# %% [markdown]
# ### TRANSLATOR

# %% [markdown]
# The translator takes a $pc$ and generates a UDF to scrutinize $DP$

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# First we need to retrive all $pc \in C$ for each $DP$

# %%
def queryPC(dp):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?dp .
        FILTER (?dp = ab:{dp})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %% [markdown]
# Execute the translator for each $pc \in C$

# %%
for dp in data_products:
    pcs = queryPC(dp)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'Connector/ValidationFramework/translator/translator.ipynb'),None, parameters={
                'folder': '../Connector/ValidationFramework/translator/',
                'pc' : pc.split("#")[1],
            },
            log_output=False
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 3ccba773-8b25-408b-949d-2448fa66d626
# Executing: 100%|██████████| 18/18 [00:25<00:00,  1.39s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 3ea66814-5414-4382-9c94-0e8eb73e986d
# Executing: 100%|██████████| 18/18 [00:24<00:00,  1.36s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# b4fba6e2-473a-48d6-a1eb-e9ab011d19c2
# Executing: 100%|██████████| 18/18 [00:25<00:00,  1.40s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# ce77d01d-b1ba-4445-97f1-fc18431460ff
# Executing: 100%|██████████| 18/18 [00:26<00:00,  1.45s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0344f4df-2ab7-4848-bb63-100e4c8fbd16
# Executing: 100%|██████████| 18/18 [00:25<00:00,  1.40s/cell]

# %% [markdown]
# ## DATA VALIDATION REPORTS

# %% [markdown]
# Since all the data validation metadata is stored in $\Delta$ it can be retrived through SPARQL queries

# %% [markdown]
# ### VALIDATION RESULT

# %% [markdown]
# The results for each DP and its associated policies can be retrived through the following query

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = """
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?dp ?p ?pc ?result
WHERE {
    # ?pc a tb:PolicyChecker .
    # ?pc tb:validates ?dp .
    # ?pc tb:accordingTo ?p .
    # ?pc tb:nextStep+ ?rep .
    # ?rep a tb:Report .
    # ?rep tb:result ?result .
}
"""

res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "Report",row["result"])
# Out:
# DP 0002DCM P p1 Report false
# DP UPENN-GBM_clinical_info_v21csv P p4 Report True
# DP UPENN-GBM_clinical_info_v21csv P p1 Report False
# DP UPENN-GBM_clinical_info_v21csv P p3 Report true
# DP UPENN-GBM_clinical_info_v21csv P p2 Report True

# %% [markdown]
# ### CLARITY QUERIES

# %% [markdown]
# The user can query the metadata to retrive more details on how a Policy has been validated both logically and algorithmically

# %%
policy = "p2"

# %%
query = f"""
SELECT ?dp ?p ?pc ?op ?code
WHERE {{
     # ?pc a tb:PolicyChecker . 
     # ?pc tb:validates ?dp . 
     # ?pc tb:accordingTo ?p . 
     FILTER (?p = ab:{policy})
     # ?pc tb:nextStep+ ?op . 
     # ?op tb:hasTranslation ?imp . 
     # ?imp tb:hasCode ?codeclass . 
     # ?codeclass tb:code ?code . 
}}
"""


res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "OP", row["op"].split("#")[1], "Code", row["code"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 27d83a5e-6cd1-4bf9-979e-b112fee238f4 Code pandas.read_csv(p)
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 3e5c0b78-6025-4fc2-9c3f-da3f0372e4ab Code (data[attr].count()/len(data))*100
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 71df25a2-c6fa-4767-975b-a7bbd789697c Code data >= ro
