# %%
import os

# %%
base_dir = os.getcwd()

base_dir = os.path.join(base_dir, '../')

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # DATA VALIDATION FRAMEWORK

# %% [markdown]
# ![title](demo_images/Prototype.png)

# %% [markdown]
# The Data Validation Framework is intented to be used in federated enviorments such as federated repositories and data spaces. In the above figure, the different components, roles and workflows are represented.
#
# Roles:
#
#     - Data Owners (i.e, Providers)
#     - Data Consumers
#     - Federated Team (i.e. Federator)
#
# Components:
#
#     - Data Platform Layer: Acts as interface for the different roles to interact with the framework.
#     - Semantic Data Model $\Delta$: Graph-based construct with all the metadata of the federation acting as a backbone to operacionalize processes.
#     - Data Validation Workflow includes the following:
#         - Parser: Generates Policy Checkers
#         - Translator: Generates UDFs for data validation
#         - Graph Transformation rules: Used to generate Policy Checkers
#         - Code metadata: Used to generate UDFs
#
# Wokflows:
#
#     - Data federation population (Blue Arrows)
#     - Data Validation Workflow (Orange Arrows)

# %% [markdown]
# ## GRAPH-BASED DATA FEDERATION

# %% [markdown]
# ### Global Definitions and Policies

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'cells': [{'id': '2616241d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.734377',
#      'end_time': '2024-12-15T21:38:35.769460',
#      'duration': 0.035083,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.739167Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.741269Z',
#      'iopub.status.idle': '2024-12-15T21:38:35.765327Z',
#      'shell.execute_reply': '2024-12-15T21:38:35.763619Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.770818',
#      'end_time': '2024-12-15T21:38:35.780644',
#      'duration': 0.009826,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.773299Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.773595Z',
#      'shell.execute_reply': '2024-12-15T21:38:35.777754Z',
#      'iopub.status.idle': '2024-12-15T21:38:35.778725Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.780848',
#      'end_time': '2024-12-15T21:38:35.781175',
#      'duration': 0.000327,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.781360',
#      'end_time': '2024-12-15T21:38:35.893851',
#      'duration': 0.112491,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.782493Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.783261Z',
#      'shell.execute_reply': '2024-12-15T21:38:35.891132Z',
#      'iopub.status.idle': '2024-12-15T21:38:35.891910Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.894537',
#      'end_time': '2024-12-15T21:38:35.914685',
#      'duration': 0.020148,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.895885Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.896295Z',
#      'shell.execute_reply': '2024-12-15T21:38:35.911378Z',
#      'iopub.status.idle': '2024-12-15T21:38:35.912126Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.914951',
#      'end_time': '2024-12-15T21:38:35.915211',
#      'duration': 0.00026,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.915354',
#      'end_time': '2024-12-15T21:38:35.923268',
#      'duration': 0.007914,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.916500Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.916759Z',
#      'shell.execute_reply': '2024-12-15T21:38:35.920161Z',
#      'iopub.status.idle': '2024-12-15T21:38:35.920847Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:35.923541',
#      'end_time': '2024-12-15T21:38:38.564612',
#      'duration': 2.641071,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:35.924798Z',
#      'iopub.execute_input': '2024-12-15T21:38:35.925051Z',
#      'iopub.status.idle': '2024-12-15T21:38:38.556178Z',
#      'shell.execute_reply': '2024-12-15T21:38:38.551644Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.567331',
#      'end_time': '2024-12-15T21:38:38.569971',
#      'duration': 0.00264,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Common Data Models',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.570585',
#      'end_time': '2024-12-15T21:38:38.590291',
#      'duration': 0.019706,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:38.577402Z',
#      'iopub.execute_input': '2024-12-15T21:38:38.578602Z',
#      'shell.execute_reply': '2024-12-15T21:38:38.586025Z',
#      'iopub.status.idle': '2024-12-15T21:38:38.587515Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/common_data_models.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.590686',
#      'end_time': '2024-12-15T21:38:38.605036',
#      'duration': 0.01435,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:38.592240Z',
#      'iopub.execute_input': '2024-12-15T21:38:38.592581Z',
#      'shell.execute_reply': '2024-12-15T21:38:38.602190Z',
#      'iopub.status.idle': '2024-12-15T21:38:38.603026Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.605216',
#      'end_time': '2024-12-15T21:38:38.605528',
#      'duration': 0.000312,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.605689',
#      'end_time': '2024-12-15T21:38:38.622248',
#      'duration': 0.016559,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:38.606901Z',
#      'iopub.execute_input': '2024-12-15T21:38:38.607155Z',
#      'shell.execute_reply': '2024-12-15T21:38:38.619911Z',
#      'iopub.status.idle': '2024-12-15T21:38:38.620666Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.622516',
#      'end_time': '2024-12-15T21:38:38.622833',
#      'duration': 0.000317,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:38.623051',
#      'end_time': '2024-12-15T21:38:38.644531',
#      'duration': 0.02148,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:38.624177Z',
#      'iopub.execute_input': '2024-12-15T21:38:38.624405Z',
#      'iopub.status.idle': '2024-12-15T21:38:38.642948Z',
#      'shell.execute_reply': '2024-12-15T21:38:38.642266Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N336877d9fa7f49b6861020d15c3de8d2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:38:34.626811',
#    'end_time': '2024-12-15T21:38:38.863062',
#    'duration': 4.236251,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### Data product Registration

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# #### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': 'ae76253e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:39.808608',
#      'end_time': '2024-12-15T21:38:39.831770',
#      'duration': 0.023162,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:39.812327Z',
#      'iopub.execute_input': '2024-12-15T21:38:39.813184Z',
#      'shell.execute_reply': '2024-12-15T21:38:39.828231Z',
#      'iopub.status.idle': '2024-12-15T21:38:39.829258Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:39.832703',
#      'end_time': '2024-12-15T21:38:47.641398',
#      'duration': 7.808695,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:39.834322Z',
#      'iopub.execute_input': '2024-12-15T21:38:39.834611Z',
#      'shell.execute_reply': '2024-12-15T21:38:47.632066Z',
#      'iopub.status.idle': '2024-12-15T21:38:47.635204Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:47.643668',
#      'end_time': '2024-12-15T21:38:47.852302',
#      'duration': 0.208634,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:47.650247Z',
#      'iopub.execute_input': '2024-12-15T21:38:47.651111Z',
#      'shell.execute_reply': '2024-12-15T21:38:47.850205Z',
#      'iopub.status.idle': '2024-12-15T21:38:47.850864Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:47.853259',
#      'end_time': '2024-12-15T21:38:47.918214',
#      'duration': 0.064955,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:47.854582Z',
#      'iopub.execute_input': '2024-12-15T21:38:47.854898Z',
#      'iopub.status.idle': '2024-12-15T21:38:47.916684Z',
#      'shell.execute_reply': '2024-12-15T21:38:47.915967Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:47.918441',
#      'end_time': '2024-12-15T21:38:48.393479',
#      'duration': 0.475038,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:47.919425Z',
#      'iopub.execute_input': '2024-12-15T21:38:47.919651Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.391120Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.391828Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.394137',
#      'end_time': '2024-12-15T21:38:48.400820',
#      'duration': 0.006683,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.395279Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.395654Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.398551Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.399421Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.400972',
#      'end_time': '2024-12-15T21:38:48.407063',
#      'duration': 0.006091,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.401954Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.402169Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.404897Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.405649Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.407215',
#      'end_time': '2024-12-15T21:38:48.419453',
#      'duration': 0.012238,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.408087Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.408334Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.417156Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.417865Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.419657',
#      'end_time': '2024-12-15T21:38:48.425427',
#      'duration': 0.00577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.420579Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.420812Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.423451Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.423997Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.425565',
#      'end_time': '2024-12-15T21:38:48.425775',
#      'duration': 0.00021,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.425892',
#      'end_time': '2024-12-15T21:38:48.445821',
#      'duration': 0.019929,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.426799Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.427038Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.443705Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.442722Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:48.445965',
#      'end_time': '2024-12-15T21:38:48.478967',
#      'duration': 0.033002,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:48.446987Z',
#      'iopub.execute_input': '2024-12-15T21:38:48.447220Z',
#      'shell.execute_reply': '2024-12-15T21:38:48.476407Z',
#      'iopub.status.idle': '2024-12-15T21:38:48.477250Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf402ba735cde44fbad7ca53e14fdb081 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:38:38.993374',
#    'end_time': '2024-12-15T21:38:48.802204',
#    'duration': 9.80883,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# #### DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': 'b077df96',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:49.705374',
#      'end_time': '2024-12-15T21:38:49.742624',
#      'duration': 0.03725,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:49.709663Z',
#      'iopub.execute_input': '2024-12-15T21:38:49.710537Z',
#      'shell.execute_reply': '2024-12-15T21:38:49.737343Z',
#      'iopub.status.idle': '2024-12-15T21:38:49.739233Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:49.744447',
#      'end_time': '2024-12-15T21:38:57.657584',
#      'duration': 7.913137,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:49.747403Z',
#      'iopub.execute_input': '2024-12-15T21:38:49.748387Z',
#      'shell.execute_reply': '2024-12-15T21:38:57.648233Z',
#      'iopub.status.idle': '2024-12-15T21:38:57.651367Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:57.660323',
#      'end_time': '2024-12-15T21:38:57.867763',
#      'duration': 0.20744,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:57.664810Z',
#      'iopub.execute_input': '2024-12-15T21:38:57.665629Z',
#      'iopub.status.idle': '2024-12-15T21:38:57.866255Z',
#      'shell.execute_reply': '2024-12-15T21:38:57.865580Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:57.868439',
#      'end_time': '2024-12-15T21:38:57.938011',
#      'duration': 0.069572,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:57.870511Z',
#      'iopub.execute_input': '2024-12-15T21:38:57.870986Z',
#      'shell.execute_reply': '2024-12-15T21:38:57.935591Z',
#      'iopub.status.idle': '2024-12-15T21:38:57.936295Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:57.938155',
#      'end_time': '2024-12-15T21:38:58.403920',
#      'duration': 0.465765,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:57.939409Z',
#      'iopub.execute_input': '2024-12-15T21:38:57.939635Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.401817Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.400849Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.404625',
#      'end_time': '2024-12-15T21:38:58.411929',
#      'duration': 0.007304,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.406137Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.406756Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.409258Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.410371Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.412162',
#      'end_time': '2024-12-15T21:38:58.421073',
#      'duration': 0.008911,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.413583Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.414371Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.417729Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.418653Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.421221',
#      'end_time': '2024-12-15T21:38:58.437270',
#      'duration': 0.016049,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.422295Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.422561Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.434265Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.434986Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.437413',
#      'end_time': '2024-12-15T21:38:58.444451',
#      'duration': 0.007038,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.438449Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.438671Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.441349Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.442139Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.444737',
#      'end_time': '2024-12-15T21:38:58.444993',
#      'duration': 0.000256,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.445145',
#      'end_time': '2024-12-15T21:38:58.469436',
#      'duration': 0.024291,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.446347Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.446738Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.466265Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.467225Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:58.469576',
#      'end_time': '2024-12-15T21:38:58.510319',
#      'duration': 0.040743,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:58.470742Z',
#      'iopub.execute_input': '2024-12-15T21:38:58.470967Z',
#      'iopub.status.idle': '2024-12-15T21:38:58.508030Z',
#      'shell.execute_reply': '2024-12-15T21:38:58.507118Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N2446df7ef0144295869c8805b3b62833 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:38:48.930458',
#    'end_time': '2024-12-15T21:38:58.830461',
#    'duration': 9.900003,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ![title](demo_images/SDM.png)

# %% [markdown]
# #### DP1 (ML Model)

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': '4e588e1b',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:59.823218',
#      'end_time': '2024-12-15T21:38:59.859028',
#      'duration': 0.03581,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:59.828794Z',
#      'iopub.execute_input': '2024-12-15T21:38:59.830072Z',
#      'shell.execute_reply': '2024-12-15T21:38:59.854249Z',
#      'iopub.status.idle': '2024-12-15T21:38:59.855394Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:38:59.859999',
#      'end_time': '2024-12-15T21:39:08.735494',
#      'duration': 8.875495,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:38:59.863239Z',
#      'iopub.execute_input': '2024-12-15T21:38:59.863768Z',
#      'shell.execute_reply': '2024-12-15T21:39:08.724777Z',
#      'iopub.status.idle': '2024-12-15T21:39:08.728926Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:08.738384',
#      'end_time': '2024-12-15T21:39:08.936904',
#      'duration': 0.19852,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:08.743915Z',
#      'iopub.execute_input': '2024-12-15T21:39:08.745166Z',
#      'iopub.status.idle': '2024-12-15T21:39:08.935209Z',
#      'shell.execute_reply': '2024-12-15T21:39:08.934313Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:08.937553',
#      'end_time': '2024-12-15T21:39:09.008482',
#      'duration': 0.070929,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:08.938968Z',
#      'iopub.execute_input': '2024-12-15T21:39:08.939479Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.005494Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.006172Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.008623',
#      'end_time': '2024-12-15T21:39:09.475726',
#      'duration': 0.467103,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.009925Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.010136Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.473080Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.473963Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.476398',
#      'end_time': '2024-12-15T21:39:09.484220',
#      'duration': 0.007822,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.477843Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.478188Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.481070Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.481811Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.484372',
#      'end_time': '2024-12-15T21:39:09.492005',
#      'duration': 0.007633,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.485605Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.485824Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.489590Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.488809Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.492255',
#      'end_time': '2024-12-15T21:39:09.503751',
#      'duration': 0.011496,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.493283Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.493515Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.501404Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.502103Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'OTHERFIle /home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv\n'}],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.503993',
#      'end_time': '2024-12-15T21:39:09.510153',
#      'duration': 0.00616,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.504892Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.505165Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.508096Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.507534Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.510297',
#      'end_time': '2024-12-15T21:39:09.510622',
#      'duration': 0.000325,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.510760',
#      'end_time': '2024-12-15T21:39:09.537960',
#      'duration': 0.0272,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.511765Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.511984Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.535208Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.535927Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:09.538103',
#      'end_time': '2024-12-15T21:39:09.589959',
#      'duration': 0.051856,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:09.539342Z',
#      'iopub.execute_input': '2024-12-15T21:39:09.539591Z',
#      'shell.execute_reply': '2024-12-15T21:39:09.587739Z',
#      'iopub.status.idle': '2024-12-15T21:39:09.588442Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N076f64e705b442f5913f1578ea3bcfbb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:38:58.950339',
#    'end_time': '2024-12-15T21:39:09.909477',
#    'duration': 10.959138,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': '97bca1a3',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:10.886769',
#      'end_time': '2024-12-15T21:39:10.903487',
#      'duration': 0.016718,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:10.888600Z',
#      'iopub.execute_input': '2024-12-15T21:39:10.889087Z',
#      'shell.execute_reply': '2024-12-15T21:39:10.899522Z',
#      'iopub.status.idle': '2024-12-15T21:39:10.900857Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:10.904856',
#      'end_time': '2024-12-15T21:39:19.161154',
#      'duration': 8.256298,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:10.907668Z',
#      'iopub.execute_input': '2024-12-15T21:39:10.908280Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.157102Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.154694Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.162835',
#      'end_time': '2024-12-15T21:39:19.364076',
#      'duration': 0.201241,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.166223Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.166815Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.361852Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.362504Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.364711',
#      'end_time': '2024-12-15T21:39:19.432176',
#      'duration': 0.067465,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.366435Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.367050Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.429745Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.428942Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.432421',
#      'end_time': '2024-12-15T21:39:19.894536',
#      'duration': 0.462115,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.433713Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.434007Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.892573Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.891277Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.895963',
#      'end_time': '2024-12-15T21:39:19.904229',
#      'duration': 0.008266,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.897688Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.898083Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.902139Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.901102Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.904431',
#      'end_time': '2024-12-15T21:39:19.916856',
#      'duration': 0.012425,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.906434Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.906786Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.913022Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.911194Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.917179',
#      'end_time': '2024-12-15T21:39:19.934265',
#      'duration': 0.017086,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.919011Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.919498Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.931429Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.930292Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.934514',
#      'end_time': '2024-12-15T21:39:19.943890',
#      'duration': 0.009376,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.936372Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.936791Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.941512Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.940321Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.944186',
#      'end_time': '2024-12-15T21:39:19.944507',
#      'duration': 0.000321,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.944810',
#      'end_time': '2024-12-15T21:39:19.981273',
#      'duration': 0.036463,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.946500Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.947438Z',
#      'shell.execute_reply': '2024-12-15T21:39:19.977909Z',
#      'iopub.status.idle': '2024-12-15T21:39:19.978824Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:19.981517',
#      'end_time': '2024-12-15T21:39:20.031711',
#      'duration': 0.050194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:19.982599Z',
#      'iopub.execute_input': '2024-12-15T21:39:19.982833Z',
#      'iopub.status.idle': '2024-12-15T21:39:20.029612Z',
#      'shell.execute_reply': '2024-12-15T21:39:20.028709Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf2d8031dc3dd40c8a1fdbf974fbffab3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:39:10.011848',
#    'end_time': '2024-12-15T21:39:20.351213',
#    'duration': 10.339365,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## Integration

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '9ed37adc',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:21.476213',
#      'end_time': '2024-12-15T21:39:21.515859',
#      'duration': 0.039646,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:21.480373Z',
#      'iopub.execute_input': '2024-12-15T21:39:21.483826Z',
#      'iopub.status.idle': '2024-12-15T21:39:21.509136Z',
#      'shell.execute_reply': '2024-12-15T21:39:21.506302Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:21.518571',
#      'end_time': '2024-12-15T21:39:31.979892',
#      'duration': 10.461321,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:21.523645Z',
#      'iopub.execute_input': '2024-12-15T21:39:21.525078Z',
#      'shell.execute_reply': '2024-12-15T21:39:31.970689Z',
#      'iopub.status.idle': '2024-12-15T21:39:31.973701Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:31.982214',
#      'end_time': '2024-12-15T21:39:32.011869',
#      'duration': 0.029655,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:31.988024Z',
#      'iopub.execute_input': '2024-12-15T21:39:31.989884Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.003785Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.006220Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.012446',
#      'end_time': '2024-12-15T21:39:32.099214',
#      'duration': 0.086768,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.016832Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.017836Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.096901Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.097630Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.099850',
#      'end_time': '2024-12-15T21:39:32.107485',
#      'duration': 0.007635,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.100967Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.101306Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.105984Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.105184Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.107613',
#      'end_time': '2024-12-15T21:39:32.118998',
#      'duration': 0.011385,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.108539Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.109097Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.116763Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.117496Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.119132',
#      'end_time': '2024-12-15T21:39:32.119368',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.119479',
#      'end_time': '2024-12-15T21:39:32.119713',
#      'duration': 0.000234,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.119840',
#      'end_time': '2024-12-15T21:39:32.147867',
#      'duration': 0.028027,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.120706Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.120902Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.145453Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.144762Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.148004',
#      'end_time': '2024-12-15T21:39:32.148249',
#      'duration': 0.000245,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.148375',
#      'end_time': '2024-12-15T21:39:32.156076',
#      'duration': 0.007701,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.149407Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.149633Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.152980Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.153817Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.156210',
#      'end_time': '2024-12-15T21:39:32.162822',
#      'duration': 0.006612,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.157136Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.157339Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.160732Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.159834Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.162954',
#      'end_time': '2024-12-15T21:39:32.169123',
#      'duration': 0.006169,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.163892Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.164166Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.167703Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.167003Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.169255',
#      'end_time': '2024-12-15T21:39:32.175392',
#      'duration': 0.006137,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.170160Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.170349Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.173171Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.173787Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.175529',
#      'end_time': '2024-12-15T21:39:32.183593',
#      'duration': 0.008064,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.176636Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.176988Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.180583Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.181276Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.183732',
#      'end_time': '2024-12-15T21:39:32.183921',
#      'duration': 0.000189,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:32.184049',
#      'end_time': '2024-12-15T21:39:32.232036',
#      'duration': 0.047987,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:32.184883Z',
#      'iopub.execute_input': '2024-12-15T21:39:32.185097Z',
#      'iopub.status.idle': '2024-12-15T21:39:32.230705Z',
#      'shell.execute_reply': '2024-12-15T21:39:32.230062Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf4714b7892c44d498503a652fb40a103 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:39:20.433503',
#    'end_time': '2024-12-15T21:39:32.456530',
#    'duration': 12.023027,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '82460c21',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:33.573446',
#      'end_time': '2024-12-15T21:39:33.600423',
#      'duration': 0.026977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:33.576312Z',
#      'iopub.execute_input': '2024-12-15T21:39:33.576981Z',
#      'shell.execute_reply': '2024-12-15T21:39:33.591995Z',
#      'iopub.status.idle': '2024-12-15T21:39:33.594553Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:33.602073',
#      'end_time': '2024-12-15T21:39:44.165774',
#      'duration': 10.563701,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:33.604442Z',
#      'iopub.execute_input': '2024-12-15T21:39:33.605565Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.159798Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.156708Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.168227',
#      'end_time': '2024-12-15T21:39:44.189947',
#      'duration': 0.02172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.175730Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.177781Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.184424Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.186137Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.190308',
#      'end_time': '2024-12-15T21:39:44.290339',
#      'duration': 0.100031,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.192694Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.193235Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.288040Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.288775Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.290999',
#      'end_time': '2024-12-15T21:39:44.299174',
#      'duration': 0.008175,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.293082Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.293447Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.296828Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.297644Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.299319',
#      'end_time': '2024-12-15T21:39:44.310347',
#      'duration': 0.011028,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.300309Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.300525Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.308740Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.307948Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.310490',
#      'end_time': '2024-12-15T21:39:44.310737',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.310875',
#      'end_time': '2024-12-15T21:39:44.311074',
#      'duration': 0.000199,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.311197',
#      'end_time': '2024-12-15T21:39:44.339619',
#      'duration': 0.028422,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.312114Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.312325Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.336641Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.337322Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.339753',
#      'end_time': '2024-12-15T21:39:44.339937',
#      'duration': 0.000184,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.340045',
#      'end_time': '2024-12-15T21:39:44.346507',
#      'duration': 0.006462,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.340918Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.341179Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.344401Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.345137Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.346641',
#      'end_time': '2024-12-15T21:39:44.352868',
#      'duration': 0.006227,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.347563Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.347767Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.350815Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.350264Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.353089',
#      'end_time': '2024-12-15T21:39:44.358805',
#      'duration': 0.005716,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.353997Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.354186Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.356661Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.357312Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.358932',
#      'end_time': '2024-12-15T21:39:44.364820',
#      'duration': 0.005888,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.359818Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.360017Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.362588Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.363273Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.364997',
#      'end_time': '2024-12-15T21:39:44.371491',
#      'duration': 0.006494,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.366032Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.366236Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.369378Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.368642Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.371629',
#      'end_time': '2024-12-15T21:39:44.371852',
#      'duration': 0.000223,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:44.371980',
#      'end_time': '2024-12-15T21:39:44.423967',
#      'duration': 0.051987,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:44.372950Z',
#      'iopub.execute_input': '2024-12-15T21:39:44.373252Z',
#      'iopub.status.idle': '2024-12-15T21:39:44.422603Z',
#      'shell.execute_reply': '2024-12-15T21:39:44.421715Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5599634bd1784666bff2907b93bb6264 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:39:32.539860',
#    'end_time': '2024-12-15T21:39:44.643696',
#    'duration': 12.103836,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp3.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': 'a511ed61',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:45.838620',
#      'end_time': '2024-12-15T21:39:45.871569',
#      'duration': 0.032949,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:45.842974Z',
#      'iopub.execute_input': '2024-12-15T21:39:45.843738Z',
#      'shell.execute_reply': '2024-12-15T21:39:45.863632Z',
#      'iopub.status.idle': '2024-12-15T21:39:45.866379Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp3.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:45.874102',
#      'end_time': '2024-12-15T21:39:56.994895',
#      'duration': 11.120793,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:45.879496Z',
#      'iopub.execute_input': '2024-12-15T21:39:45.880275Z',
#      'shell.execute_reply': '2024-12-15T21:39:56.989845Z',
#      'iopub.status.idle': '2024-12-15T21:39:56.991538Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:56.996362',
#      'end_time': '2024-12-15T21:39:57.018570',
#      'duration': 0.022208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:56.999516Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.000278Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.011427Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.010185Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.018906',
#      'end_time': '2024-12-15T21:39:57.153372',
#      'duration': 0.134466,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.025201Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.030382Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.150756Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.149862Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.154390',
#      'end_time': '2024-12-15T21:39:57.162699',
#      'duration': 0.008309,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.155538Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.156144Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.160324Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.159507Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.162884',
#      'end_time': '2024-12-15T21:39:57.175258',
#      'duration': 0.012374,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.164453Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.164872Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.172870Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.173556Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.175400',
#      'end_time': '2024-12-15T21:39:57.175591',
#      'duration': 0.000191,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.175710',
#      'end_time': '2024-12-15T21:39:57.175908',
#      'duration': 0.000198,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.176021',
#      'end_time': '2024-12-15T21:39:57.214755',
#      'duration': 0.038734,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.177070Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.177295Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.212498Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.211590Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.214901',
#      'end_time': '2024-12-15T21:39:57.215137',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.215271',
#      'end_time': '2024-12-15T21:39:57.222530',
#      'duration': 0.007259,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.216561Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.217210Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.221070Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.220455Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.222678',
#      'end_time': '2024-12-15T21:39:57.228662',
#      'duration': 0.005984,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.223564Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.223810Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.226791Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.227333Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.228798',
#      'end_time': '2024-12-15T21:39:57.234423',
#      'duration': 0.005625,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.229657Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.229855Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.232948Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.232446Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.234556',
#      'end_time': '2024-12-15T21:39:57.240735',
#      'duration': 0.006179,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.235441Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.235640Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.239265Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.238704Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.240986',
#      'end_time': '2024-12-15T21:39:57.247168',
#      'duration': 0.006182,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.241910Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.242167Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.244529Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.245316Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.247432',
#      'end_time': '2024-12-15T21:39:57.247740',
#      'duration': 0.000308,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-15T21:39:57.247926',
#      'end_time': '2024-12-15T21:39:57.302059',
#      'duration': 0.054133,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-15T21:39:57.249259Z',
#      'iopub.execute_input': '2024-12-15T21:39:57.249488Z',
#      'iopub.status.idle': '2024-12-15T21:39:57.300568Z',
#      'shell.execute_reply': '2024-12-15T21:39:57.299929Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N72e1793977214236a3f83c769c906728 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp3.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-15T21:39:44.717088',
#    'end_time': '2024-12-15T21:39:57.623569',
#    'duration': 12.906481,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA VALIDATION WORKFLOW

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# Avaliable Common Data Models

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:CommonDataModel .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %% [markdown]
# The user selects a common data model for analysis

# %%
#dp = input("SELECT NAME OF THE COMMON DATA MODEL: ")
dp = "Patient_Data"

# %% [markdown]
# We retrive the data products that are mapped to the selected common data model through their data contracts

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:prohibition|odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


data_products = [row.dataset.split("#")[1] for row in qres]

data_products = set(data_products)
data_products
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv', 'modelpkl'}

# %% [markdown]
# ### PARSER

# %% [markdown]
# The parser generates a set of policy checkers $C$ for each data product $DP$ that is mapped to the selected common data model

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in data_products:
    print("DP", dp)
    pm.execute_notebook(
        os.path.join(base_dir, 'Connector/ValidationFramework/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'Connector/ValidationFramework/parser/'),
            'dp': dp
        },
        log_output=False
    )
# Out:
# DP modelpkl
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP UPENN-GBM_clinical_info_v21csv
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP 0002DCM
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ### TRANSLATOR

# %% [markdown]
# The translator takes a $pc$ and generates a UDF to scrutinize $DP$

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# First we need to retrive all $pc \in C$ for each $DP$

# %%
def queryPC(dp):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?dp .
        FILTER (?dp = ab:{dp})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %% [markdown]
# Execute the translator for each $pc \in C$

# %%
for dp in data_products:
    pcs = queryPC(dp)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'Connector/ValidationFramework/translator/translator.ipynb'),None, parameters={
                'folder': '../Connector/ValidationFramework/translator/',
                'pc' : pc.split("#")[1],
            },
            log_output=False
        )
# Out:
# fdf95c15-2202-4dc9-930c-7b0deec2defe
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 1dd1ae97-0d62-4d95-a3e4-506ab13b5b52
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 2112ab84-df68-4efd-a502-fc30934ac082
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 49f69d0d-e825-443f-8333-e9fc088f0c55
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 96a14798-59c9-49d4-99c5-e4c0fd6c773e
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# cccfd5b1-dda5-42ed-974b-689cae37b5cf
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# db5a7e2a-3839-4098-b744-a53c58d2f428
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]

# %% [markdown]
# ## DATA VALIDATION REPORTS

# %% [markdown]
# Since all the data validation metadata is stored in $\Delta$ it can be retrived through SPARQL queries

# %% [markdown]
# ### VALIDATION RESULT

# %% [markdown]
# The results for each DP and its associated policies can be retrived through the following query

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = """
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?dp ?p ?pc ?result
WHERE {
    # ?pc a tb:PolicyChecker .
    # ?pc tb:validates ?dp .
    # ?pc tb:accordingTo ?p .
    # ?pc tb:nextStep+ ?rep .
    # ?rep a tb:Report .
    # ?rep tb:result ?result .
}
"""

res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "Report",row["result"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p5 Report True
# DP UPENN-GBM_clinical_info_v21csv P p1v2 Report false
# DP UPENN-GBM_clinical_info_v21csv P p2 Report True
# DP UPENN-GBM_clinical_info_v21csv P p1 Report False
# DP UPENN-GBM_clinical_info_v21csv P p3 Report true
# DP 0002DCM P p1 Report false
# DP modelpkl P p4 Report False

# %% [markdown]
# ### CLARITY QUERIES

# %% [markdown]
# The user can query the metadata to retrive more details on how a Policy has been validated both logically and algorithmically

# %%
policy = "p2"

# %%
query = f"""
SELECT ?dp ?p ?pc ?op ?code
WHERE {{
     # ?pc a tb:PolicyChecker . 
     # ?pc tb:validates ?dp . 
     # ?pc tb:accordingTo ?p . 
     FILTER (?p = ab:{policy})
     # ?pc tb:nextStep+ ?op . 
     # ?op tb:hasTranslation ?imp . 
     # ?imp tb:hasCode ?codeclass . 
     # ?codeclass tb:code ?code . 
}}
"""


res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "OP", row["op"].split("#")[1], "Code", row["code"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 99143ba9-48eb-4af9-a9a8-150728c35276 Code pandas.read_csv(p)
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 494fe9f8-642f-45fb-9405-f4f31f34b235 Code (data[attr].count()/len(data))*100
# DP UPENN-GBM_clinical_info_v21csv P p2 OP a11b8664-03e0-47a5-ac84-a794e04d855f Code data >= ro
# DP UPENN-GBM_clinical_info_v21csv P p2 OP a11b8664-03e0-47a5-ac84-a794e04d855f Code data if not (data[attr] >= ro).all() else (data[attr] >= ro).all()
