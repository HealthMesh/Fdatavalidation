# %%
import os

# %%
base_dir = os.getcwd()

base_dir = os.path.join(base_dir, '../')

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:13<00:00,  1.08cell/s]
# {'cells': [{'id': 'fa93e13e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.554360',
#      'end_time': '2024-11-09T15:58:33.567482',
#      'duration': 0.013122,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.555864Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.556409Z',
#      'shell.execute_reply': '2024-11-09T15:58:33.563358Z',
#      'iopub.status.idle': '2024-11-09T15:58:33.564258Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.568473',
#      'end_time': '2024-11-09T15:58:33.578386',
#      'duration': 0.009913,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.570569Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.570923Z',
#      'shell.execute_reply': '2024-11-09T15:58:33.575209Z',
#      'iopub.status.idle': '2024-11-09T15:58:33.576386Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.578568',
#      'end_time': '2024-11-09T15:58:33.578870',
#      'duration': 0.000302,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.579047',
#      'end_time': '2024-11-09T15:58:33.653364',
#      'duration': 0.074317,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.580118Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.580380Z',
#      'shell.execute_reply': '2024-11-09T15:58:33.650840Z',
#      'iopub.status.idle': '2024-11-09T15:58:33.651493Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.653519',
#      'end_time': '2024-11-09T15:58:33.673153',
#      'duration': 0.019634,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.654822Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.655503Z',
#      'shell.execute_reply': '2024-11-09T15:58:33.670277Z',
#      'iopub.status.idle': '2024-11-09T15:58:33.670994Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.674010',
#      'end_time': '2024-11-09T15:58:33.674766',
#      'duration': 0.000756,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.674923',
#      'end_time': '2024-11-09T15:58:33.684159',
#      'duration': 0.009236,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.676213Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.676982Z',
#      'shell.execute_reply': '2024-11-09T15:58:33.681993Z',
#      'iopub.status.idle': '2024-11-09T15:58:33.682607Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:33.684410',
#      'end_time': '2024-11-09T15:58:35.936480',
#      'duration': 2.25207,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:33.685411Z',
#      'iopub.execute_input': '2024-11-09T15:58:33.685640Z',
#      'shell.execute_reply': '2024-11-09T15:58:35.932282Z',
#      'iopub.status.idle': '2024-11-09T15:58:35.933531Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.936666',
#      'end_time': '2024-11-09T15:58:35.936946',
#      'duration': 0.00028,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.937908',
#      'end_time': '2024-11-09T15:58:35.948077',
#      'duration': 0.010169,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:35.939816Z',
#      'iopub.execute_input': '2024-11-09T15:58:35.940409Z',
#      'iopub.status.idle': '2024-11-09T15:58:35.945161Z',
#      'shell.execute_reply': '2024-11-09T15:58:35.944161Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.948403',
#      'end_time': '2024-11-09T15:58:35.962401',
#      'duration': 0.013998,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:35.949651Z',
#      'iopub.execute_input': '2024-11-09T15:58:35.949925Z',
#      'shell.execute_reply': '2024-11-09T15:58:35.959234Z',
#      'iopub.status.idle': '2024-11-09T15:58:35.960196Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.962581',
#      'end_time': '2024-11-09T15:58:35.962888',
#      'duration': 0.000307,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.963072',
#      'end_time': '2024-11-09T15:58:35.978845',
#      'duration': 0.015773,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:35.964401Z',
#      'iopub.execute_input': '2024-11-09T15:58:35.964758Z',
#      'shell.execute_reply': '2024-11-09T15:58:35.975878Z',
#      'iopub.status.idle': '2024-11-09T15:58:35.976753Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.979024',
#      'end_time': '2024-11-09T15:58:35.979290',
#      'duration': 0.000266,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:35.979439',
#      'end_time': '2024-11-09T15:58:36.001859',
#      'duration': 0.02242,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:35.980555Z',
#      'iopub.execute_input': '2024-11-09T15:58:35.980814Z',
#      'shell.execute_reply': '2024-11-09T15:58:35.999545Z',
#      'iopub.status.idle': '2024-11-09T15:58:36.000276Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nbe3cc77a0d5c4fdf8b2b9754688958c1 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-09T15:58:22.374912',
#    'end_time': '2024-11-09T15:58:36.220209',
#    'duration': 13.845297,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 11/11 [00:18<00:00,  1.70s/cell]
# {'cells': [{'id': '781b78f3',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:47.472545',
#      'end_time': '2024-11-09T15:58:47.506551',
#      'duration': 0.034006,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:47.476590Z',
#      'iopub.execute_input': '2024-11-09T15:58:47.479178Z',
#      'shell.execute_reply': '2024-11-09T15:58:47.500809Z',
#      'iopub.status.idle': '2024-11-09T15:58:47.503018Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-10-25T14:11:00.245095Z',
#      'start_time': '2024-10-25T14:10:48.071834Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:47.507952',
#      'end_time': '2024-11-09T15:58:54.004499',
#      'duration': 6.496547,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:47.510613Z',
#      'iopub.execute_input': '2024-11-09T15:58:47.510944Z',
#      'shell.execute_reply': '2024-11-09T15:58:53.998199Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.000119Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.261824Z',
#      'start_time': '2024-10-25T14:11:00.255390Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.005593',
#      'end_time': '2024-11-09T15:58:54.015427',
#      'duration': 0.009834,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.007971Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.008690Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.012484Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.013405Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.351533Z',
#      'start_time': '2024-10-25T14:11:00.320406Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.015622',
#      'end_time': '2024-11-09T15:58:54.089095',
#      'duration': 0.073473,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.017020Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.017709Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.086773Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.087487Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.089241',
#      'end_time': '2024-11-09T15:58:54.599742',
#      'duration': 0.510501,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.090407Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.090641Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.596695Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.597551Z'}},
#    'cell_type': 'code',
#    'outputs': [],
#    'execution_count': 5,
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.sour ...
#    'id': 'e77fc103b819f2e6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.466088Z',
#      'start_time': '2024-10-25T14:11:00.459873Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.600571',
#      'end_time': '2024-11-09T15:58:54.607744',
#      'duration': 0.007173,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.601909Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.602551Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.605282Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.606122Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.524701Z',
#      'start_time': '2024-10-25T14:11:00.507714Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.607889',
#      'end_time': '2024-11-09T15:58:54.621502',
#      'duration': 0.013613,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.609119Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.609443Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.619132Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.619857Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.567706Z',
#      'start_time': '2024-10-25T14:11:00.562378Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.621734',
#      'end_time': '2024-11-09T15:58:54.628357',
#      'duration': 0.006623,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.623017Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.623519Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.626625Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.626029Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.628582',
#      'end_time': '2024-11-09T15:58:54.628851',
#      'duration': 0.000269,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.653276Z',
#      'start_time': '2024-10-25T14:11:00.613474Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.629134',
#      'end_time': '2024-11-09T15:58:54.648342',
#      'duration': 0.019208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.630162Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.630427Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.645095Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.645890Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.739277Z',
#      'start_time': '2024-10-25T14:11:00.679709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:58:54.648505',
#      'end_time': '2024-11-09T15:58:54.680043',
#      'duration': 0.031538,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:58:54.649777Z',
#      'iopub.execute_input': '2024-11-09T15:58:54.650008Z',
#      'shell.execute_reply': '2024-11-09T15:58:54.676782Z',
#      'iopub.status.idle': '2024-11-09T15:58:54.677592Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd6ac00d81cf340fe8c9cdaf6b20d9489 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-09T15:58:36.346851',
#    'end_time': '2024-11-09T15:58:55.000035',
#    'duration': 18.653184,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 11/11 [00:18<00:00,  1.69s/cell]
# {'cells': [{'id': 'd81564de',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:06.011147',
#      'end_time': '2024-11-09T15:59:06.022658',
#      'duration': 0.011511,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:06.012333Z',
#      'iopub.execute_input': '2024-11-09T15:59:06.012694Z',
#      'shell.execute_reply': '2024-11-09T15:59:06.019997Z',
#      'iopub.status.idle': '2024-11-09T15:59:06.020839Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-10-25T14:11:00.245095Z',
#      'start_time': '2024-10-25T14:10:48.071834Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:06.023399',
#      'end_time': '2024-11-09T15:59:12.700607',
#      'duration': 6.677208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:06.024834Z',
#      'iopub.execute_input': '2024-11-09T15:59:06.025149Z',
#      'shell.execute_reply': '2024-11-09T15:59:12.695545Z',
#      'iopub.status.idle': '2024-11-09T15:59:12.697178Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.261824Z',
#      'start_time': '2024-10-25T14:11:00.255390Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:12.702221',
#      'end_time': '2024-11-09T15:59:12.717628',
#      'duration': 0.015407,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:12.706672Z',
#      'iopub.execute_input': '2024-11-09T15:59:12.707311Z',
#      'shell.execute_reply': '2024-11-09T15:59:12.713555Z',
#      'iopub.status.idle': '2024-11-09T15:59:12.714789Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.351533Z',
#      'start_time': '2024-10-25T14:11:00.320406Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:12.718046',
#      'end_time': '2024-11-09T15:59:12.807714',
#      'duration': 0.089668,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:12.720022Z',
#      'iopub.execute_input': '2024-11-09T15:59:12.720613Z',
#      'shell.execute_reply': '2024-11-09T15:59:12.805386Z',
#      'iopub.status.idle': '2024-11-09T15:59:12.806102Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:12.808609',
#      'end_time': '2024-11-09T15:59:13.309065',
#      'duration': 0.500456,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:12.810469Z',
#      'iopub.execute_input': '2024-11-09T15:59:12.810706Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.306697Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.307393Z'}},
#    'cell_type': 'code',
#    'outputs': [],
#    'execution_count': 5,
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.sour ...
#    'id': 'e77fc103b819f2e6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.466088Z',
#      'start_time': '2024-10-25T14:11:00.459873Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.309306',
#      'end_time': '2024-11-09T15:59:13.315645',
#      'duration': 0.006339,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:13.310318Z',
#      'iopub.execute_input': '2024-11-09T15:59:13.310607Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.313192Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.313997Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.524701Z',
#      'start_time': '2024-10-25T14:11:00.507714Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.316735',
#      'end_time': '2024-11-09T15:59:13.333152',
#      'duration': 0.016417,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:13.317894Z',
#      'iopub.execute_input': '2024-11-09T15:59:13.318148Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.330214Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.331222Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.567706Z',
#      'start_time': '2024-10-25T14:11:00.562378Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.333310',
#      'end_time': '2024-11-09T15:59:13.339723',
#      'duration': 0.006413,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:13.334504Z',
#      'iopub.execute_input': '2024-11-09T15:59:13.334781Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.337403Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.338051Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.339883',
#      'end_time': '2024-11-09T15:59:13.340107',
#      'duration': 0.000224,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.653276Z',
#      'start_time': '2024-10-25T14:11:00.613474Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.340228',
#      'end_time': '2024-11-09T15:59:13.362867',
#      'duration': 0.022639,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:13.341273Z',
#      'iopub.execute_input': '2024-11-09T15:59:13.341534Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.359113Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.360109Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-10-25T14:11:00.739277Z',
#      'start_time': '2024-10-25T14:11:00.679709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:13.363113',
#      'end_time': '2024-11-09T15:59:13.405697',
#      'duration': 0.042584,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:13.364640Z',
#      'iopub.execute_input': '2024-11-09T15:59:13.365040Z',
#      'shell.execute_reply': '2024-11-09T15:59:13.403459Z',
#      'iopub.status.idle': '2024-11-09T15:59:13.404187Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne6dabbcd476d4180861206517bebc5f9 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-09T15:58:55.118561',
#    'end_time': '2024-11-09T15:59:13.728353',
#    'duration': 18.609792,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:20<00:00,  1.19s/cell]
# {'cells': [{'id': '2df2f5ae',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:24.701898',
#      'end_time': '2024-11-09T15:59:24.715705',
#      'duration': 0.013807,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:24.703477Z',
#      'iopub.execute_input': '2024-11-09T15:59:24.703959Z',
#      'shell.execute_reply': '2024-11-09T15:59:24.712737Z',
#      'iopub.status.idle': '2024-11-09T15:59:24.713717Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:24.716687',
#      'end_time': '2024-11-09T15:59:33.336680',
#      'duration': 8.619993,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:24.718291Z',
#      'iopub.execute_input': '2024-11-09T15:59:24.718954Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.333606Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.332334Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.337906',
#      'end_time': '2024-11-09T15:59:33.352129',
#      'duration': 0.014223,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.340367Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.341170Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.347644Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.348907Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.352324',
#      'end_time': '2024-11-09T15:59:33.485380',
#      'duration': 0.133056,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.354016Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.354441Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.481015Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.482265Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.486380',
#      'end_time': '2024-11-09T15:59:33.497121',
#      'duration': 0.010741,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.488798Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.489343Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.494418Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.493216Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.497402',
#      'end_time': '2024-11-09T15:59:33.514368',
#      'duration': 0.016966,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.499146Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.499880Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.510216Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.511475Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.514735',
#      'end_time': '2024-11-09T15:59:33.515158',
#      'duration': 0.000423,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.515386',
#      'end_time': '2024-11-09T15:59:33.515745',
#      'duration': 0.000359,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.515941',
#      'end_time': '2024-11-09T15:59:33.556795',
#      'duration': 0.040854,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.517420Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.518577Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.553864Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.552882Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.557054',
#      'end_time': '2024-11-09T15:59:33.557318',
#      'duration': 0.000264,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.557464',
#      'end_time': '2024-11-09T15:59:33.569063',
#      'duration': 0.011599,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.559269Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.559763Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.565920Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.564585Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.569266',
#      'end_time': '2024-11-09T15:59:33.579073',
#      'duration': 0.009807,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.570939Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.571478Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.576306Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.575052Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.579418',
#      'end_time': '2024-11-09T15:59:33.591253',
#      'duration': 0.011835,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.581303Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.581867Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.588084Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.586828Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.592464',
#      'end_time': '2024-11-09T15:59:33.604129',
#      'duration': 0.011665,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.595018Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.595399Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.601187Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.599903Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.604408',
#      'end_time': '2024-11-09T15:59:33.614498',
#      'duration': 0.01009,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.605893Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.606187Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.611250Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.609737Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.614814',
#      'end_time': '2024-11-09T15:59:33.615122',
#      'duration': 0.000308,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:33.615364',
#      'end_time': '2024-11-09T15:59:33.688516',
#      'duration': 0.073152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:33.617309Z',
#      'iopub.execute_input': '2024-11-09T15:59:33.617703Z',
#      'iopub.status.idle': '2024-11-09T15:59:33.684948Z',
#      'shell.execute_reply': '2024-11-09T15:59:33.683604Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb5357e59cff845669d54821d4339ac60 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-09T15:59:13.811608',
#    'end_time': '2024-11-09T15:59:34.012077',
#    'duration': 20.200469,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:21<00:00,  1.24s/cell]
# {'cells': [{'id': '48b6b602',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:45.154532',
#      'end_time': '2024-11-09T15:59:45.169898',
#      'duration': 0.015366,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:45.156027Z',
#      'iopub.execute_input': '2024-11-09T15:59:45.156331Z',
#      'shell.execute_reply': '2024-11-09T15:59:45.165562Z',
#      'iopub.status.idle': '2024-11-09T15:59:45.166826Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:45.171087',
#      'end_time': '2024-11-09T15:59:54.663954',
#      'duration': 9.492867,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:45.173276Z',
#      'iopub.execute_input': '2024-11-09T15:59:45.173618Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.660452Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.661423Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.664853',
#      'end_time': '2024-11-09T15:59:54.673893',
#      'duration': 0.00904,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.666571Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.667001Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.671792Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.670957Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.674038',
#      'end_time': '2024-11-09T15:59:54.752084',
#      'duration': 0.078046,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.675082Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.675322Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.749674Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.747960Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.752228',
#      'end_time': '2024-11-09T15:59:54.759975',
#      'duration': 0.007747,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.753469Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.753703Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.756800Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.757704Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.760190',
#      'end_time': '2024-11-09T15:59:54.777611',
#      'duration': 0.017421,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.761738Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.761996Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.773044Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.774752Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.779225',
#      'end_time': '2024-11-09T15:59:54.779560',
#      'duration': 0.000335,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.779810',
#      'end_time': '2024-11-09T15:59:54.780116',
#      'duration': 0.000306,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.780477',
#      'end_time': '2024-11-09T15:59:54.817492',
#      'duration': 0.037015,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.781858Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.782141Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.814666Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.815647Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.817655',
#      'end_time': '2024-11-09T15:59:54.817887',
#      'duration': 0.000232,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.818088',
#      'end_time': '2024-11-09T15:59:54.826823',
#      'duration': 0.008735,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.819506Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.820291Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.824697Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.823684Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.826972',
#      'end_time': '2024-11-09T15:59:54.835781',
#      'duration': 0.008809,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.828208Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.828471Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.831702Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.832882Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.836049',
#      'end_time': '2024-11-09T15:59:54.845622',
#      'duration': 0.009573,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.837442Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.837803Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.842990Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.842108Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.845837',
#      'end_time': '2024-11-09T15:59:54.854951',
#      'duration': 0.009114,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.847618Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.848022Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.852131Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.853109Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.855108',
#      'end_time': '2024-11-09T15:59:54.862738',
#      'duration': 0.00763,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.856324Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.856889Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.859912Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.860800Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.862889',
#      'end_time': '2024-11-09T15:59:54.863088',
#      'duration': 0.000199,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-11-09T15:59:54.863216',
#      'end_time': '2024-11-09T15:59:54.914182',
#      'duration': 0.050966,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-11-09T15:59:54.864380Z',
#      'iopub.execute_input': '2024-11-09T15:59:54.864783Z',
#      'shell.execute_reply': '2024-11-09T15:59:54.911975Z',
#      'iopub.status.idle': '2024-11-09T15:59:54.912638Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd70b0e1b508047dfb8b25e45a133af62 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-11-09T15:59:34.083532',
#    'end_time': '2024-11-09T15:59:55.133859',
#    'duration': 21.050327,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:CommonDataModel .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF THE COMMON DATA MODEL: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


data_products = [row.dataset.split("#")[1] for row in qres]

data_products = set(data_products)
data_products
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in data_products:
    print("DP", dp)
    pm.execute_notebook(
        os.path.join(base_dir, 'Connector/ValidationFramework/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'Connector/ValidationFramework/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP 0002DCM
# Executing: 100%|██████████| 15/15 [00:18<00:00,  1.24s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP UPENN-GBM_clinical_info_v21csv
# Executing: 100%|██████████| 15/15 [00:18<00:00,  1.25s/cell]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(dp):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?dp .
        FILTER (?dp = ab:{dp})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for dp in data_products:
    pcs = queryPC(dp)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'Connector/ValidationFramework/translator/translator_new.ipynb'),None, parameters={
                'folder': '../Connector/ValidationFramework/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# f00b4c8c-9ceb-4183-8874-eee888294f52
# Executing: 100%|██████████| 18/18 [00:20<00:00,  1.15s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 9cd7f82e-7e25-4a97-9894-e6deacb2d74b
# Executing: 100%|██████████| 18/18 [00:21<00:00,  1.17s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# f4d6aa22-9add-4e82-aad5-4e6807cf7871
# Executing: 100%|██████████| 18/18 [00:20<00:00,  1.16s/cell]

# %% [markdown]
# # Reports

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = """
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?dp ?p ?pc ?result
WHERE {
    # ?pc a tb:PolicyChecker .
    # ?pc tb:validates ?dp .
    # ?pc tb:accordingTo ?p .
    # ?pc tb:nextStep+ ?rep .
    # ?rep a tb:Report .
    # ?rep tb:result ?result .
}
"""

res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "Report",row["result"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p2 Report True
# DP 0002DCM P p1 Report false
# DP UPENN-GBM_clinical_info_v21csv P p1 Report False
