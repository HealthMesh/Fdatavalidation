# %%
import os

# %%
base_dir = os.getcwd()

base_dir = os.path.join(base_dir, '../')

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # DATA VALIDATION FRAMEWORK

# %% [markdown]
# ![title](demo_images/Prototype.png)

# %% [markdown]
# The Data Validation Framework is intented to be used in federated enviorments such as federated repositories and data spaces. In the above figure, the different components, roles and workflows are represented.
#
# Roles:
#
#     - Data Owners (i.e, Providers)
#     - Data Consumers
#     - Federated Team (i.e. Federator)
#
# Components:
#
#     - Data Platform Layer: Acts as interface for the different roles to interact with the framework.
#     - Semantic Data Model $\Delta$: Graph-based construct with all the metadata of the federation acting as a backbone to operacionalize processes.
#     - Data Validation Workflow includes the following:
#         - Parser: Generates Policy Checkers
#         - Translator: Generates UDFs for data validation
#         - Graph Transformation rules: Used to generate Policy Checkers
#         - Code metadata: Used to generate UDFs
#
# Wokflows:
#
#     - Data federation population (Blue Arrows)
#     - Data Validation Workflow (Orange Arrows)

# %% [markdown]
# ## GRAPH-BASED DATA FEDERATION

# %% [markdown]
# ### Global Definitions and Policies

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# {'cells': [{'id': '97e2ff0b',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.741898',
#      'end_time': '2024-12-18T12:32:59.778825',
#      'duration': 0.036927,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.745816Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.746590Z',
#      'shell.execute_reply': '2024-12-18T12:32:59.769988Z',
#      'iopub.status.idle': '2024-12-18T12:32:59.772539Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.782137',
#      'end_time': '2024-12-18T12:32:59.808957',
#      'duration': 0.02682,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.787404Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.788988Z',
#      'iopub.status.idle': '2024-12-18T12:32:59.804470Z',
#      'shell.execute_reply': '2024-12-18T12:32:59.801479Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.809437',
#      'end_time': '2024-12-18T12:32:59.809973',
#      'duration': 0.000536,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.810242',
#      'end_time': '2024-12-18T12:32:59.810657',
#      'duration': 0.000415,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load Ontology ',
#    'id': '5cecd1fd2c0c4b19'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.810974',
#      'end_time': '2024-12-18T12:32:59.893431',
#      'duration': 0.082457,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.812923Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.813255Z',
#      'shell.execute_reply': '2024-12-18T12:32:59.890766Z',
#      'iopub.status.idle': '2024-12-18T12:32:59.891501Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.894152',
#      'end_time': '2024-12-18T12:32:59.918696',
#      'duration': 0.024544,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.896000Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.896502Z',
#      'iopub.status.idle': '2024-12-18T12:32:59.915784Z',
#      'shell.execute_reply': '2024-12-18T12:32:59.914892Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.918934',
#      'end_time': '2024-12-18T12:32:59.919193',
#      'duration': 0.000259,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.919407',
#      'end_time': '2024-12-18T12:32:59.919632',
#      'duration': 0.000225,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Util function for populating ABOX',
#    'id': '23fdcd90e902db2c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.919838',
#      'end_time': '2024-12-18T12:32:59.928102',
#      'duration': 0.008264,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.921107Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.921533Z',
#      'iopub.status.idle': '2024-12-18T12:32:59.925540Z',
#      'shell.execute_reply': '2024-12-18T12:32:59.924719Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:32:59.928396',
#      'end_time': '2024-12-18T12:33:02.707180',
#      'duration': 2.778784,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:32:59.929655Z',
#      'iopub.execute_input': '2024-12-18T12:32:59.930348Z',
#      'shell.execute_reply': '2024-12-18T12:33:02.703067Z',
#      'iopub.status.idle': '2024-12-18T12:33:02.704141Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.707988',
#      'end_time': '2024-12-18T12:33:02.708567',
#      'duration': 0.000579,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Common Data Models',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.708728',
#      'end_time': '2024-12-18T12:33:02.709073',
#      'duration': 0.000345,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'These simulate domain data models enriched semantically.',
#    'id': '9b9c9367222bf1ad'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.709227',
#      'end_time': '2024-12-18T12:33:02.719899',
#      'duration': 0.010672,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:02.711389Z',
#      'iopub.execute_input': '2024-12-18T12:33:02.712036Z',
#      'shell.execute_reply': '2024-12-18T12:33:02.716685Z',
#      'iopub.status.idle': '2024-12-18T12:33:02.717868Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/common_data_models.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.720215',
#      'end_time': '2024-12-18T12:33:02.738409',
#      'duration': 0.018194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:02.721773Z',
#      'iopub.execute_input': '2024-12-18T12:33:02.722232Z',
#      'iopub.status.idle': '2024-12-18T12:33:02.735960Z',
#      'shell.execute_reply': '2024-12-18T12:33:02.734946Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.738647',
#      'end_time': '2024-12-18T12:33:02.738910',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.739130',
#      'end_time': '2024-12-18T12:33:02.739367',
#      'duration': 0.000237,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'These represent data policies.',
#    'id': 'f6a687b032ca6be'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.739576',
#      'end_time': '2024-12-18T12:33:02.756520',
#      'duration': 0.016944,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:02.740695Z',
#      'iopub.execute_input': '2024-12-18T12:33:02.741072Z',
#      'iopub.status.idle': '2024-12-18T12:33:02.754768Z',
#      'shell.execute_reply': '2024-12-18T12:33:02.753794Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.756775',
#      'end_time': '2024-12-18T12:33:02.757034',
#      'duration': 0.000259,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:02.757274',
#      'end_time': '2024-12-18T12:33:02.781162',
#      'duration': 0.023888,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:02.758506Z',
#      'iopub.execute_input': '2024-12-18T12:33:02.759095Z',
#      'iopub.status.idle': '2024-12-18T12:33:02.779395Z',
#      'shell.execute_reply': '2024-12-18T12:33:02.778445Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nda2fe5ff079f4652b5c56de6637737dd (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:32:58.832823',
#    'end_time': '2024-12-18T12:33:03.005297',
#    'duration': 4.172474,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### Data product Registration

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# #### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/13 [00:00<?, ?cell/s]
# {'cells': [{'id': 'a4516f23',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:04.068557',
#      'end_time': '2024-12-18T12:33:04.106308',
#      'duration': 0.037751,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:04.072782Z',
#      'iopub.execute_input': '2024-12-18T12:33:04.073639Z',
#      'shell.execute_reply': '2024-12-18T12:33:04.099554Z',
#      'iopub.status.idle': '2024-12-18T12:33:04.102307Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:04.107630',
#      'end_time': '2024-12-18T12:33:12.763462',
#      'duration': 8.655832,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:04.110215Z',
#      'iopub.execute_input': '2024-12-18T12:33:04.110775Z',
#      'shell.execute_reply': '2024-12-18T12:33:12.753550Z',
#      'iopub.status.idle': '2024-12-18T12:33:12.757221Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:12.767252',
#      'end_time': '2024-12-18T12:33:12.974644',
#      'duration': 0.207392,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:12.772800Z',
#      'iopub.execute_input': '2024-12-18T12:33:12.773720Z',
#      'shell.execute_reply': '2024-12-18T12:33:12.972367Z',
#      'iopub.status.idle': '2024-12-18T12:33:12.973130Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:12.975276',
#      'end_time': '2024-12-18T12:33:13.049827',
#      'duration': 0.074551,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:12.976444Z',
#      'iopub.execute_input': '2024-12-18T12:33:12.976886Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.047266Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.046517Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.050064',
#      'end_time': '2024-12-18T12:33:13.050310',
#      'duration': 0.000246,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'The Profiler is a process which simulates a semi-automatic tools to extract metadata from different data assets. Thus, for tabular data assets the schema is extracted and for Images in DICOM, we extract Header Metadata.',
#    'id': 'b526dc73679d7564'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.050537',
#      'end_time': '2024-12-18T12:33:13.547237',
#      'duration': 0.4967,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.052045Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.052414Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.544793Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.545570Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    #DTT\n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n     ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.548364',
#      'end_time': '2024-12-18T12:33:13.556185',
#      'duration': 0.007821,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.549941Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.550416Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.554013Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.554784Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.556325',
#      'end_time': '2024-12-18T12:33:13.563348',
#      'duration': 0.007023,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.557481Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.557712Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.561772Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.560968Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.563482',
#      'end_time': '2024-12-18T12:33:13.576727',
#      'duration': 0.013245,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.564601Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.564899Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.574383Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.575057Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.576861',
#      'end_time': '2024-12-18T12:33:13.584297',
#      'duration': 0.007436,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.577856Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.578255Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.581030Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.581915Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.584477',
#      'end_time': '2024-12-18T12:33:13.584762',
#      'duration': 0.000285,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.584938',
#      'end_time': '2024-12-18T12:33:13.604644',
#      'duration': 0.019706,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.586017Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.586463Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.602139Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.602904Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:13.604783',
#      'end_time': '2024-12-18T12:33:13.639080',
#      'duration': 0.034297,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:13.605857Z',
#      'iopub.execute_input': '2024-12-18T12:33:13.606088Z',
#      'shell.execute_reply': '2024-12-18T12:33:13.636777Z',
#      'iopub.status.idle': '2024-12-18T12:33:13.637514Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne950702a8dcd4fa0a364fc3eb7684c5b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:33:03.141447',
#    'end_time': '2024-12-18T12:33:13.967086',
#    'duration': 10.825639,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# #### DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/13 [00:00<?, ?cell/s]
# {'cells': [{'id': '909255f1',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:15.032393',
#      'end_time': '2024-12-18T12:33:15.046509',
#      'duration': 0.014116,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:15.033923Z',
#      'iopub.execute_input': '2024-12-18T12:33:15.034613Z',
#      'shell.execute_reply': '2024-12-18T12:33:15.043620Z',
#      'iopub.status.idle': '2024-12-18T12:33:15.044581Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:15.047403',
#      'end_time': '2024-12-18T12:33:23.206938',
#      'duration': 8.159535,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:15.049705Z',
#      'iopub.execute_input': '2024-12-18T12:33:15.050260Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.196791Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.200951Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.208976',
#      'end_time': '2024-12-18T12:33:23.421905',
#      'duration': 0.212929,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.214155Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.216652Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.419643Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.420276Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.422518',
#      'end_time': '2024-12-18T12:33:23.497869',
#      'duration': 0.075351,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.423650Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.424015Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.495469Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.496270Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.498115',
#      'end_time': '2024-12-18T12:33:23.498364',
#      'duration': 0.000249,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'The Profiler is a process which simulates a semi-automatic tools to extract metadata from different data assets. Thus, for tabular data assets the schema is extracted and for Images in DICOM, we extract Header Metadata.',
#    'id': 'b526dc73679d7564'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.498591',
#      'end_time': '2024-12-18T12:33:23.971589',
#      'duration': 0.472998,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.500511Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.500997Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.969020Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.969831Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    #DTT\n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n     ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.972430',
#      'end_time': '2024-12-18T12:33:23.980634',
#      'duration': 0.008204,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.974275Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.975270Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.978872Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.977866Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.980779',
#      'end_time': '2024-12-18T12:33:23.988253',
#      'duration': 0.007474,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.981799Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.982028Z',
#      'shell.execute_reply': '2024-12-18T12:33:23.985231Z',
#      'iopub.status.idle': '2024-12-18T12:33:23.985968Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:23.988397',
#      'end_time': '2024-12-18T12:33:24.004567',
#      'duration': 0.01617,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:23.989509Z',
#      'iopub.execute_input': '2024-12-18T12:33:23.989867Z',
#      'shell.execute_reply': '2024-12-18T12:33:24.001265Z',
#      'iopub.status.idle': '2024-12-18T12:33:24.002057Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:24.004713',
#      'end_time': '2024-12-18T12:33:24.011729',
#      'duration': 0.007016,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:24.005826Z',
#      'iopub.execute_input': '2024-12-18T12:33:24.006049Z',
#      'shell.execute_reply': '2024-12-18T12:33:24.008566Z',
#      'iopub.status.idle': '2024-12-18T12:33:24.009427Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:24.011930',
#      'end_time': '2024-12-18T12:33:24.012186',
#      'duration': 0.000256,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:24.012324',
#      'end_time': '2024-12-18T12:33:24.034813',
#      'duration': 0.022489,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:24.013350Z',
#      'iopub.execute_input': '2024-12-18T12:33:24.014051Z',
#      'shell.execute_reply': '2024-12-18T12:33:24.032320Z',
#      'iopub.status.idle': '2024-12-18T12:33:24.033102Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:24.034954',
#      'end_time': '2024-12-18T12:33:24.078239',
#      'duration': 0.043285,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:24.035865Z',
#      'iopub.execute_input': '2024-12-18T12:33:24.036080Z',
#      'shell.execute_reply': '2024-12-18T12:33:24.075830Z',
#      'iopub.status.idle': '2024-12-18T12:33:24.076678Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N16717d19b8474f6eb0eb33cd36011a05 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:33:14.106165',
#    'end_time': '2024-12-18T12:33:24.398287',
#    'duration': 10.292122,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ![title](demo_images/SDM.png)

# %% [markdown]
# #### DP1 (ML Model)

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/13 [00:00<?, ?cell/s]
# {'cells': [{'id': '90dc020b',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:25.396466',
#      'end_time': '2024-12-18T12:33:25.410169',
#      'duration': 0.013703,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:25.397937Z',
#      'iopub.execute_input': '2024-12-18T12:33:25.398222Z',
#      'iopub.status.idle': '2024-12-18T12:33:25.407415Z',
#      'shell.execute_reply': '2024-12-18T12:33:25.406403Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:25.411009',
#      'end_time': '2024-12-18T12:33:33.544826',
#      'duration': 8.133817,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:25.412940Z',
#      'iopub.execute_input': '2024-12-18T12:33:25.414075Z',
#      'shell.execute_reply': '2024-12-18T12:33:33.534025Z',
#      'iopub.status.idle': '2024-12-18T12:33:33.537722Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:33.547791',
#      'end_time': '2024-12-18T12:33:33.758977',
#      'duration': 0.211186,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:33.553611Z',
#      'iopub.execute_input': '2024-12-18T12:33:33.556645Z',
#      'shell.execute_reply': '2024-12-18T12:33:33.756392Z',
#      'iopub.status.idle': '2024-12-18T12:33:33.757134Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:33.759970',
#      'end_time': '2024-12-18T12:33:33.835162',
#      'duration': 0.075192,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:33.761767Z',
#      'iopub.execute_input': '2024-12-18T12:33:33.762735Z',
#      'shell.execute_reply': '2024-12-18T12:33:33.832180Z',
#      'iopub.status.idle': '2024-12-18T12:33:33.832894Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:33.835289',
#      'end_time': '2024-12-18T12:33:33.835468',
#      'duration': 0.000179,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'The Profiler is a process which simulates a semi-automatic tools to extract metadata from different data assets. Thus, for tabular data assets the schema is extracted and for Images in DICOM, we extract Header Metadata.',
#    'id': 'b526dc73679d7564'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:33.835584',
#      'end_time': '2024-12-18T12:33:34.322669',
#      'duration': 0.487085,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:33.836986Z',
#      'iopub.execute_input': '2024-12-18T12:33:33.837326Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.320164Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.321058Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    #DTT\n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n     ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.323676',
#      'end_time': '2024-12-18T12:33:34.332072',
#      'duration': 0.008396,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.325853Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.326805Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.330017Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.329340Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.332252',
#      'end_time': '2024-12-18T12:33:34.339672',
#      'duration': 0.00742,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.333259Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.333488Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.337241Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.336332Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.339943',
#      'end_time': '2024-12-18T12:33:34.363538',
#      'duration': 0.023595,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.341284Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.342066Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.360288Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.361199Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'OTHERFIle /home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv\n'}],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.363688',
#      'end_time': '2024-12-18T12:33:34.371246',
#      'duration': 0.007558,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.365135Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.365512Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.368426Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.369423Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.371399',
#      'end_time': '2024-12-18T12:33:34.371596',
#      'duration': 0.000197,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.371720',
#      'end_time': '2024-12-18T12:33:34.398594',
#      'duration': 0.026874,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.372926Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.373146Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.396232Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.397031Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:34.398735',
#      'end_time': '2024-12-18T12:33:34.440771',
#      'duration': 0.042036,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:34.399612Z',
#      'iopub.execute_input': '2024-12-18T12:33:34.399817Z',
#      'shell.execute_reply': '2024-12-18T12:33:34.438986Z',
#      'iopub.status.idle': '2024-12-18T12:33:34.439457Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7be56a4e208643a0abea65c59b9e56f3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:33:24.517553',
#    'end_time': '2024-12-18T12:33:34.760699',
#    'duration': 10.243146,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/13 [00:00<?, ?cell/s]
# {'cells': [{'id': 'ebbe5986',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:35.957406',
#      'end_time': '2024-12-18T12:33:35.975403',
#      'duration': 0.017997,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:35.959430Z',
#      'iopub.execute_input': '2024-12-18T12:33:35.960328Z',
#      'iopub.status.idle': '2024-12-18T12:33:35.972191Z',
#      'shell.execute_reply': '2024-12-18T12:33:35.970578Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:35.976741',
#      'end_time': '2024-12-18T12:33:44.131056',
#      'duration': 8.154315,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:35.979335Z',
#      'iopub.execute_input': '2024-12-18T12:33:35.980761Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.122236Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.119146Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.133416',
#      'end_time': '2024-12-18T12:33:44.348501',
#      'duration': 0.215085,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.139637Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.141387Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.346371Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.347078Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.349457',
#      'end_time': '2024-12-18T12:33:44.420991',
#      'duration': 0.071534,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.350537Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.350812Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.418384Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.419106Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.421124',
#      'end_time': '2024-12-18T12:33:44.421370',
#      'duration': 0.000246,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'The Profiler is a process which simulates a semi-automatic tools to extract metadata from different data assets. Thus, for tabular data assets the schema is extracted and for Images in DICOM, we extract Header Metadata.',
#    'id': 'b526dc73679d7564'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.421496',
#      'end_time': '2024-12-18T12:33:44.882094',
#      'duration': 0.460598,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.422464Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.422668Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.878866Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.879631Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    #DTT\n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n     ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.882773',
#      'end_time': '2024-12-18T12:33:44.891060',
#      'duration': 0.008287,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.883995Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.884397Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.887566Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.888617Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.891316',
#      'end_time': '2024-12-18T12:33:44.898890',
#      'duration': 0.007574,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.892593Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.892822Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.895738Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.896583Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.899143',
#      'end_time': '2024-12-18T12:33:44.910472',
#      'duration': 0.011329,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.900215Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.900474Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.907214Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.908013Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.910725',
#      'end_time': '2024-12-18T12:33:44.917749',
#      'duration': 0.007024,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.911842Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.912062Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.914749Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.915600Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.918007',
#      'end_time': '2024-12-18T12:33:44.918252',
#      'duration': 0.000245,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.918486',
#      'end_time': '2024-12-18T12:33:44.948427',
#      'duration': 0.029941,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.919853Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.920273Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.945283Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.945981Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:44.948574',
#      'end_time': '2024-12-18T12:33:44.992979',
#      'duration': 0.044405,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:44.949582Z',
#      'iopub.execute_input': '2024-12-18T12:33:44.950270Z',
#      'iopub.status.idle': '2024-12-18T12:33:44.991444Z',
#      'shell.execute_reply': '2024-12-18T12:33:44.990736Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nfc7e9c19b2a541cc8af8a5b1a536f11f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:33:34.889127',
#    'end_time': '2024-12-18T12:33:45.312526',
#    'duration': 10.423399,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## Integration

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '0f98eb28',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:46.448730',
#      'end_time': '2024-12-18T12:33:46.481470',
#      'duration': 0.03274,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:46.452442Z',
#      'iopub.execute_input': '2024-12-18T12:33:46.453228Z',
#      'iopub.status.idle': '2024-12-18T12:33:46.475841Z',
#      'shell.execute_reply': '2024-12-18T12:33:46.473227Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:46.483846',
#      'end_time': '2024-12-18T12:33:59.690986',
#      'duration': 13.20714,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:46.490238Z',
#      'iopub.execute_input': '2024-12-18T12:33:46.491626Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.680268Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.683643Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.695504',
#      'end_time': '2024-12-18T12:33:59.719946',
#      'duration': 0.024442,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.703373Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.706336Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.715487Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.716745Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.720382',
#      'end_time': '2024-12-18T12:33:59.805324',
#      'duration': 0.084942,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.722407Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.722929Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.802282Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.803071Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.806014',
#      'end_time': '2024-12-18T12:33:59.814964',
#      'duration': 0.00895,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.807472Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.807839Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.812654Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.813464Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.815176',
#      'end_time': '2024-12-18T12:33:59.826899',
#      'duration': 0.011723,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.816275Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.816598Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.824592Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.825367Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.827036',
#      'end_time': '2024-12-18T12:33:59.827237',
#      'duration': 0.000201,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.827363',
#      'end_time': '2024-12-18T12:33:59.827542',
#      'duration': 0.000179,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.827666',
#      'end_time': '2024-12-18T12:33:59.855814',
#      'duration': 0.028148,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.828767Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.828990Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.853273Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.854014Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.855948',
#      'end_time': '2024-12-18T12:33:59.856182',
#      'duration': 0.000234,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.856301',
#      'end_time': '2024-12-18T12:33:59.879473',
#      'duration': 0.023172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.857213Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.857442Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.870307Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.873328Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.879942',
#      'end_time': '2024-12-18T12:33:59.896655',
#      'duration': 0.016713,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.883070Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.883954Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.893302Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.891489Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.896907',
#      'end_time': '2024-12-18T12:33:59.906753',
#      'duration': 0.009846,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.898698Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.899093Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.902859Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.904296Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.908423',
#      'end_time': '2024-12-18T12:33:59.919114',
#      'duration': 0.010691,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.910534Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.911014Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.915200Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.916260Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.919383',
#      'end_time': '2024-12-18T12:33:59.926384',
#      'duration': 0.007001,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.920679Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.921464Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.923831Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.924755Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.926537',
#      'end_time': '2024-12-18T12:33:59.926742',
#      'duration': 0.000205,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:33:59.926883',
#      'end_time': '2024-12-18T12:33:59.985998',
#      'duration': 0.059115,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:33:59.927820Z',
#      'iopub.execute_input': '2024-12-18T12:33:59.928183Z',
#      'shell.execute_reply': '2024-12-18T12:33:59.982801Z',
#      'iopub.status.idle': '2024-12-18T12:33:59.983577Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N893bb2c44c004e60a1109cceca826b36 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:33:45.382639',
#    'end_time': '2024-12-18T12:34:00.204760',
#    'duration': 14.822121,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '493cfa7d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:01.155516',
#      'end_time': '2024-12-18T12:34:01.168017',
#      'duration': 0.012501,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:01.157212Z',
#      'iopub.execute_input': '2024-12-18T12:34:01.157543Z',
#      'shell.execute_reply': '2024-12-18T12:34:01.165154Z',
#      'iopub.status.idle': '2024-12-18T12:34:01.166036Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:01.169390',
#      'end_time': '2024-12-18T12:34:12.080590',
#      'duration': 10.9112,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:01.171479Z',
#      'iopub.execute_input': '2024-12-18T12:34:01.172475Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.076649Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.077854Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.081404',
#      'end_time': '2024-12-18T12:34:12.093059',
#      'duration': 0.011655,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.083268Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.083939Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.090668Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.089557Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.093239',
#      'end_time': '2024-12-18T12:34:12.181334',
#      'duration': 0.088095,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.094815Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.095240Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.179493Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.178499Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.182032',
#      'end_time': '2024-12-18T12:34:12.191557',
#      'duration': 0.009525,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.183430Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.183879Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.189007Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.188163Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.191710',
#      'end_time': '2024-12-18T12:34:12.203680',
#      'duration': 0.01197,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.192969Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.193199Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.202162Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.201531Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.203902',
#      'end_time': '2024-12-18T12:34:12.204149',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.204341',
#      'end_time': '2024-12-18T12:34:12.204557',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.204743',
#      'end_time': '2024-12-18T12:34:12.243455',
#      'duration': 0.038712,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.205875Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.206255Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.240771Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.239402Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.243711',
#      'end_time': '2024-12-18T12:34:12.244000',
#      'duration': 0.000289,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.244243',
#      'end_time': '2024-12-18T12:34:12.261905',
#      'duration': 0.017662,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.245850Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.246376Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.259319Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.258343Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.262157',
#      'end_time': '2024-12-18T12:34:12.270602',
#      'duration': 0.008445,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.263635Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.264096Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.267167Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.268282Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.270859',
#      'end_time': '2024-12-18T12:34:12.278206',
#      'duration': 0.007347,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.271951Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.272236Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.275829Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.275204Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.278462',
#      'end_time': '2024-12-18T12:34:12.286812',
#      'duration': 0.00835,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.279605Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.279944Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.283363Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.284103Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.287983',
#      'end_time': '2024-12-18T12:34:12.296640',
#      'duration': 0.008657,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.289827Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.290674Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.293995Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.294860Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.296938',
#      'end_time': '2024-12-18T12:34:12.297239',
#      'duration': 0.000301,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:12.297487',
#      'end_time': '2024-12-18T12:34:12.358426',
#      'duration': 0.060939,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:12.298835Z',
#      'iopub.execute_input': '2024-12-18T12:34:12.299069Z',
#      'shell.execute_reply': '2024-12-18T12:34:12.355863Z',
#      'iopub.status.idle': '2024-12-18T12:34:12.356560Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N52462497fa614c72897f8ed2d75c49de (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:34:00.273215',
#    'end_time': '2024-12-18T12:34:12.576333',
#    'duration': 12.303118,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp3.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '7fff7e16',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:13.517236',
#      'end_time': '2024-12-18T12:34:13.540094',
#      'duration': 0.022858,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:13.519957Z',
#      'iopub.execute_input': '2024-12-18T12:34:13.520521Z',
#      'shell.execute_reply': '2024-12-18T12:34:13.533759Z',
#      'iopub.status.idle': '2024-12-18T12:34:13.536057Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp3.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:13.541800',
#      'end_time': '2024-12-18T12:34:24.645472',
#      'duration': 11.103672,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:13.544563Z',
#      'iopub.execute_input': '2024-12-18T12:34:13.545233Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.636519Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.639722Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.647958',
#      'end_time': '2024-12-18T12:34:24.678556',
#      'duration': 0.030598,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.655165Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.656592Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.669619Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.672159Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.679033',
#      'end_time': '2024-12-18T12:34:24.774901',
#      'duration': 0.095868,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.682805Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.684959Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.772374Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.773185Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.775532',
#      'end_time': '2024-12-18T12:34:24.784073',
#      'duration': 0.008541,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.777029Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.777286Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.781190Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.782141Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.784255',
#      'end_time': '2024-12-18T12:34:24.796605',
#      'duration': 0.01235,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.785573Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.785913Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.795132Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.794415Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.796767',
#      'end_time': '2024-12-18T12:34:24.797031',
#      'duration': 0.000264,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.797170',
#      'end_time': '2024-12-18T12:34:24.797434',
#      'duration': 0.000264,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.797573',
#      'end_time': '2024-12-18T12:34:24.828004',
#      'duration': 0.030431,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.798702Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.798938Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.824974Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.824303Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.828178',
#      'end_time': '2024-12-18T12:34:24.828407',
#      'duration': 0.000229,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.828539',
#      'end_time': '2024-12-18T12:34:24.836200',
#      'duration': 0.007661,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.829628Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.830267Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.834604Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.833825Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.836345',
#      'end_time': '2024-12-18T12:34:24.842544',
#      'duration': 0.006199,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.837488Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.837728Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.840273Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.841043Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.842680',
#      'end_time': '2024-12-18T12:34:24.850214',
#      'duration': 0.007534,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.843615Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.843808Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.848650Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.847719Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.850465',
#      'end_time': '2024-12-18T12:34:24.857473',
#      'duration': 0.007008,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.851451Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.851729Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.854698Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.855503Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.857646',
#      'end_time': '2024-12-18T12:34:24.864156',
#      'duration': 0.00651,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.858777Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.859068Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.861679Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.862551Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.864410',
#      'end_time': '2024-12-18T12:34:24.864663',
#      'duration': 0.000253,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-18T12:34:24.864904',
#      'end_time': '2024-12-18T12:34:24.919215',
#      'duration': 0.054311,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-18T12:34:24.866059Z',
#      'iopub.execute_input': '2024-12-18T12:34:24.866339Z',
#      'shell.execute_reply': '2024-12-18T12:34:24.916552Z',
#      'iopub.status.idle': '2024-12-18T12:34:24.917223Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ned2c038cfffc43ef921f8e62553e5680 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/dp3.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/demo/../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-18T12:34:12.644325',
#    'end_time': '2024-12-18T12:34:25.138581',
#    'duration': 12.494256,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA VALIDATION WORKFLOW

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# Avaliable Common Data Models

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:CommonDataModel .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %% [markdown]
# The user selects a common data model for analysis

# %%
#dp = input("SELECT NAME OF THE COMMON DATA MODEL: ")
dp = "Patient_Data"

# %% [markdown]
# We retrive the data products that are mapped to the selected common data model through their data contracts

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:prohibition|odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


data_products = [row.dataset.split("#")[1] for row in qres]

data_products = set(data_products)
data_products
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv', 'modelpkl'}

# %% [markdown]
# ### PARSER

# %% [markdown]
# The parser generates a set of policy checkers $C$ for each data product $DP$ that is mapped to the selected common data model

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in data_products:
    print("DP", dp)
    pm.execute_notebook(
        os.path.join(base_dir, 'Connector/ValidationFramework/planner/planner.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'Connector/ValidationFramework/planner/'),
            'dp': dp
        },
        log_output=False
    )
# Out:
# DP modelpkl
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP UPENN-GBM_clinical_info_v21csv
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP 0002DCM
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ### TRANSLATOR

# %% [markdown]
# The translator takes a $pc$ and generates a UDF to scrutinize $DP$

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# First we need to retrive all $pc \in C$ for each $DP$

# %%
def queryPC(dp):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?dp .
        FILTER (?dp = ab:{dp})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %% [markdown]
# Execute the translator for each $pc \in C$

# %%
for dp in data_products:
    pcs = queryPC(dp)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'Connector/ValidationFramework/translator/executor.ipynb'),None, parameters={
                'folder': '../Connector/ValidationFramework/translator/',
                'pc' : pc.split("#")[1],
            },
            log_output=False
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# 4c3f50bb-762b-4565-8e32-b7694710996a
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 18823858-49d9-43fd-a1f7-a9cae4fa91db
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 1b729a2d-7c7c-46ca-bfe9-eff9c77af836
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 5211bccf-109b-46d7-aa26-d5fe24510ea1
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c22d531e-4e60-4dd7-9519-5874d5c87e4f
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# fe0247bc-6aed-46d9-bcfe-c11b0ed76416
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 00018601-0c61-461a-b7eb-a99067e1ab92
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]

# %% [markdown]
# ## DATA VALIDATION REPORTS

# %% [markdown]
# Since all the data validation metadata is stored in $\Delta$ it can be retrived through SPARQL queries

# %% [markdown]
# ### VALIDATION RESULT

# %% [markdown]
# The results for each DP and its associated policies can be retrived through the following query

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = """
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?dp ?p ?pc ?result
WHERE {
    # ?pc a tb:PolicyChecker .
    # ?pc tb:validates ?dp .
    # ?pc tb:accordingTo ?p .
    # ?pc tb:nextStep+ ?rep .
    # ?rep a tb:Report .
    # ?rep tb:result ?result .
}
"""

res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "Report",row["result"])
# Out:
# DP 0002DCM P p1 Report false
# DP UPENN-GBM_clinical_info_v21csv P p1 Report False
# DP UPENN-GBM_clinical_info_v21csv P p2 Report True
# DP modelpkl P p4 Report False
# DP UPENN-GBM_clinical_info_v21csv P p5 Report True
# DP UPENN-GBM_clinical_info_v21csv P p1v2 Report true
# DP UPENN-GBM_clinical_info_v21csv P p3 Report true

# %% [markdown]
# ### CLARITY QUERIES

# %% [markdown]
# The user can query the metadata to retrive more details on how a Policy has been validated both logically and algorithmically

# %%
policy = "p2"

# %%
query = f"""
SELECT ?dp ?p ?pc ?op ?code
WHERE {{
     # ?pc a tb:PolicyChecker . 
     # ?pc tb:validates ?dp . 
     # ?pc tb:accordingTo ?p . 
     FILTER (?p = ab:{policy})
     # ?pc tb:nextStep+ ?op . 
     # ?op tb:hasTranslation ?imp . 
     # ?imp tb:hasCode ?codeclass . 
     # ?codeclass tb:code ?code . 
}}
"""


res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "OP", row["op"].split("#")[1], "Code", row["code"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p2 OP dc785128-f418-46b6-a784-ab36259da541 Code pandas.read_csv(p)
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 699ca02e-0838-4e4e-a7f7-bcfbb67afc8b Code (data[attr].count()/len(data))*100
# DP UPENN-GBM_clinical_info_v21csv P p2 OP b95562ec-89a4-4d87-abb9-659f30daef12 Code data >= ro
# DP UPENN-GBM_clinical_info_v21csv P p2 OP b95562ec-89a4-4d87-abb9-659f30daef12 Code data if not (data[attr] >= ro).all() else (data[attr] >= ro).all()
