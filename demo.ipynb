# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm
import os   
from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': 'e4c49b35',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.666820',
#      'end_time': '2024-05-27T10:09:35.680661',
#      'duration': 0.013841,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.668623Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.669351Z',
#      'shell.execute_reply': '2024-05-27T10:09:35.676990Z',
#      'iopub.status.idle': '2024-05-27T10:09:35.677985Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.681819',
#      'end_time': '2024-05-27T10:09:35.693549',
#      'duration': 0.01173,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.683610Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.684536Z',
#      'shell.execute_reply': '2024-05-27T10:09:35.688835Z',
#      'iopub.status.idle': '2024-05-27T10:09:35.690111Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.693898',
#      'end_time': '2024-05-27T10:09:35.694245',
#      'duration': 0.000347,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.694582',
#      'end_time': '2024-05-27T10:09:35.756454',
#      'duration': 0.061872,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.696156Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.697008Z',
#      'shell.execute_reply': '2024-05-27T10:09:35.754102Z',
#      'iopub.status.idle': '2024-05-27T10:09:35.754619Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.756610',
#      'end_time': '2024-05-27T10:09:35.774512',
#      'duration': 0.017902,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.757566Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.757740Z',
#      'shell.execute_reply': '2024-05-27T10:09:35.772489Z',
#      'iopub.status.idle': '2024-05-27T10:09:35.773061Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.774655',
#      'end_time': '2024-05-27T10:09:35.774840',
#      'duration': 0.000185,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.774960',
#      'end_time': '2024-05-27T10:09:35.775143',
#      'duration': 0.000183,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.775255',
#      'end_time': '2024-05-27T10:09:35.780883',
#      'duration': 0.005628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.776179Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.776350Z',
#      'shell.execute_reply': '2024-05-27T10:09:35.779078Z',
#      'iopub.status.idle': '2024-05-27T10:09:35.779649Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:35.781441',
#      'end_time': '2024-05-27T10:09:37.503886',
#      'duration': 1.722445,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:35.782473Z',
#      'iopub.execute_input': '2024-05-27T10:09:35.782976Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.495650Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.498505Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.504640',
#      'end_time': '2024-05-27T10:09:37.505249',
#      'duration': 0.000609,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.505808',
#      'end_time': '2024-05-27T10:09:37.526079',
#      'duration': 0.020271,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.509729Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.511065Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.521154Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.519056Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.526685',
#      'end_time': '2024-05-27T10:09:37.558728',
#      'duration': 0.032043,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.529592Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.530264Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.553802Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.555247Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.559032',
#      'end_time': '2024-05-27T10:09:37.559344',
#      'duration': 0.000312,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.560593',
#      'end_time': '2024-05-27T10:09:37.570702',
#      'duration': 0.010109,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.562798Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.563245Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.567138Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.568192Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.570966',
#      'end_time': '2024-05-27T10:09:37.579521',
#      'duration': 0.008555,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.572215Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.572489Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.577113Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.577820Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.579676',
#      'end_time': '2024-05-27T10:09:37.579893',
#      'duration': 0.000217,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.580040',
#      'end_time': '2024-05-27T10:09:37.585825',
#      'duration': 0.005785,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.580929Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.581161Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.583246Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.583892Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.585987',
#      'end_time': '2024-05-27T10:09:37.592746',
#      'duration': 0.006759,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.587412Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.587706Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.591040Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.590307Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.592900',
#      'end_time': '2024-05-27T10:09:37.593099',
#      'duration': 0.000199,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.593244',
#      'end_time': '2024-05-27T10:09:37.599121',
#      'duration': 0.005877,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.594182Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.594373Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.596462Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.597183Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.599277',
#      'end_time': '2024-05-27T10:09:37.599473',
#      'duration': 0.000196,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:37.599616',
#      'end_time': '2024-05-27T10:09:37.612873',
#      'duration': 0.013257,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:37.600487Z',
#      'iopub.execute_input': '2024-05-27T10:09:37.600676Z',
#      'iopub.status.idle': '2024-05-27T10:09:37.611514Z',
#      'shell.execute_reply': '2024-05-27T10:09:37.611007Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd47bb2f16a7e452598571ecc23b58884 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T10:09:34.761423',
#    'end_time': '2024-05-27T10:09:37.830671',
#    'duration': 3.069248,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T10:09:37.888369',
#    'end_time': '2024-05-27T10:09:43.316907',
#    'duration': 5.428538,
#    'exception': None}},
#  'cells': [{'id': 'f0e1e188',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:38.611351',
#      'end_time': '2024-05-27T10:09:38.639976',
#      'duration': 0.028625,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:38.614592Z',
#      'iopub.execute_input': '2024-05-27T10:09:38.615239Z',
#      'iopub.status.idle': '2024-05-27T10:09:38.633908Z',
#      'shell.execute_reply': '2024-05-27T10:09:38.631834Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:38.642335',
#      'end_time': '2024-05-27T10:09:38.660758',
#      'duration': 0.018423,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:38.647192Z',
#      'iopub.execute_input': '2024-05-27T10:09:38.649411Z',
#      'iopub.status.idle': '2024-05-27T10:09:38.658163Z',
#      'shell.execute_reply': '2024-05-27T10:09:38.656962Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '318d8388'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:38.661033',
#      'end_time': '2024-05-27T10:09:38.668789',
#      'duration': 0.007756,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:38.662558Z',
#      'iopub.execute_input': '2024-05-27T10:09:38.662898Z',
#      'shell.execute_reply': '2024-05-27T10:09:38.666190Z',
#      'iopub.status.idle': '2024-05-27T10:09:38.667077Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '1c34ed80'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:38.668972',
#      'end_time': '2024-05-27T10:09:42.473244',
#      'duration': 3.804272,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:38.669998Z',
#      'iopub.execute_input': '2024-05-27T10:09:38.670576Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.469169Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.467181Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': 'ad0d55db'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.474590',
#      'end_time': '2024-05-27T10:09:42.475144',
#      'duration': 0.000554,
#      'status': 'completed'}},
#    'id': '195c1e85'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.475492',
#      'end_time': '2024-05-27T10:09:42.489898',
#      'duration': 0.014406,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.477807Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.478398Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.486352Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.487194Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': '8ef13a9f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.490155',
#      'end_time': '2024-05-27T10:09:42.490387',
#      'duration': 0.000232,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'ac94515d'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.490610',
#      'end_time': '2024-05-27T10:09:42.903715',
#      'duration': 0.413105,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.492000Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.492392Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.901689Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.902244Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '2c796fd6'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.904264',
#      'end_time': '2024-05-27T10:09:42.921424',
#      'duration': 0.01716,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.905843Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.906257Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.918799Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.919508Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  670 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '930b12ac'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.921640',
#      'end_time': '2024-05-27T10:09:42.921844',
#      'duration': 0.000204,
#      'status': 'completed'}},
#    'id': 'd8a1ecc9'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.921972',
#      'end_time': '2024-05-27T10:09:42.922114',
#      'duration': 0.000142,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '5216950a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.922233',
#      'end_time': '2024-05-27T10:09:42.927795',
#      'duration': 0.005562,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.923263Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.923629Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.926409Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.925781Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'ad82b5c0'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.927942',
#      'end_time': '2024-05-27T10:09:42.935587',
#      'duration': 0.007645,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.928783Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.929205Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.933598Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.934190Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': 'd28f207c'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.935733',
#      'end_time': '2024-05-27T10:09:42.935954',
#      'duration': 0.000221,
#      'status': 'completed'}},
#    'id': 'ee48cdc8'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.936095',
#      'end_time': '2024-05-27T10:09:42.945546',
#      'duration': 0.009451,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.936990Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.937495Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.943762Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.943063Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '5853ae16'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.945789',
#      'end_time': '2024-05-27T10:09:42.945956',
#      'duration': 0.000167,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '11f6caf0'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.946082',
#      'end_time': '2024-05-27T10:09:42.953343',
#      'duration': 0.007261,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.946960Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.947323Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.951522Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.952066Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N71f0d89c6fe742398925b20476048b3e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': 'efb643df'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.953486',
#      'end_time': '2024-05-27T10:09:42.953669',
#      'duration': 0.000183,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'a6802e94'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.953821',
#      'end_time': '2024-05-27T10:09:42.959985',
#      'duration': 0.006164,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.954621Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.954801Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.958783Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.958285Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '4086b6e6'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.960140',
#      'end_time': '2024-05-27T10:09:42.960305',
#      'duration': 0.000165,
#      'status': 'completed'}},
#    'id': '0fbf6a09'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.960445',
#      'end_time': '2024-05-27T10:09:42.960668',
#      'duration': 0.000223,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '545599af'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.960809',
#      'end_time': '2024-05-27T10:09:42.967792',
#      'duration': 0.006983,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.961593Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.961770Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.966062Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.965335Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '8068b79d'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.967953',
#      'end_time': '2024-05-27T10:09:42.975345',
#      'duration': 0.007392,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.968925Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.969291Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.973555Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.973010Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N71f0d89c6fe742398925b20476048b3e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'c5221cfb'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.975516',
#      'end_time': '2024-05-27T10:09:42.975717',
#      'duration': 0.000201,
#      'status': 'completed'}},
#    'id': '74a5c51c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.975855',
#      'end_time': '2024-05-27T10:09:42.983740',
#      'duration': 0.007885,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.976713Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.977140Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.981527Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.982118Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N71f0d89c6fe742398925b20476048b3e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '0614fa12'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.983878',
#      'end_time': '2024-05-27T10:09:42.984054',
#      'duration': 0.000176,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '0eeb5f23'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:42.984184',
#      'end_time': '2024-05-27T10:09:42.994190',
#      'duration': 0.010006,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:42.984969Z',
#      'iopub.execute_input': '2024-05-27T10:09:42.985176Z',
#      'iopub.status.idle': '2024-05-27T10:09:42.992506Z',
#      'shell.execute_reply': '2024-05-27T10:09:42.991809Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N71f0d89c6fe742398925b20476048b3e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': 'e2bb42e9'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T10:09:43.371396',
#    'end_time': '2024-05-27T10:09:50.421677',
#    'duration': 7.050281,
#    'exception': None}},
#  'cells': [{'id': '946e017b',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:44.284750',
#      'end_time': '2024-05-27T10:09:44.301451',
#      'duration': 0.016701,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:44.286572Z',
#      'iopub.execute_input': '2024-05-27T10:09:44.287430Z',
#      'shell.execute_reply': '2024-05-27T10:09:44.296789Z',
#      'iopub.status.idle': '2024-05-27T10:09:44.297829Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:44.302910',
#      'end_time': '2024-05-27T10:09:44.315042',
#      'duration': 0.012132,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:44.304968Z',
#      'iopub.execute_input': '2024-05-27T10:09:44.306078Z',
#      'shell.execute_reply': '2024-05-27T10:09:44.311034Z',
#      'iopub.status.idle': '2024-05-27T10:09:44.312027Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '82699dbd'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:44.315321',
#      'end_time': '2024-05-27T10:09:48.933937',
#      'duration': 4.618616,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:44.316864Z',
#      'iopub.execute_input': '2024-05-27T10:09:44.317296Z',
#      'shell.execute_reply': '2024-05-27T10:09:48.931140Z',
#      'iopub.status.idle': '2024-05-27T10:09:48.931978Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '4542f214'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:48.934661',
#      'end_time': '2024-05-27T10:09:48.944881',
#      'duration': 0.01022,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:48.936362Z',
#      'iopub.execute_input': '2024-05-27T10:09:48.936837Z',
#      'iopub.status.idle': '2024-05-27T10:09:48.942176Z',
#      'shell.execute_reply': '2024-05-27T10:09:48.941102Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': 'a87da5a8'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:48.945073',
#      'end_time': '2024-05-27T10:09:48.945316',
#      'duration': 0.000243,
#      'status': 'completed'}},
#    'id': 'd52d8d34'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:48.945518',
#      'end_time': '2024-05-27T10:09:48.958130',
#      'duration': 0.012612,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:48.947040Z',
#      'iopub.execute_input': '2024-05-27T10:09:48.947334Z',
#      'shell.execute_reply': '2024-05-27T10:09:48.954740Z',
#      'iopub.status.idle': '2024-05-27T10:09:48.955812Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '87fd9e1e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:48.958336',
#      'end_time': '2024-05-27T10:09:48.958583',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'bd8de6cd'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:48.958847',
#      'end_time': '2024-05-27T10:09:49.474538',
#      'duration': 0.515691,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:48.960539Z',
#      'iopub.execute_input': '2024-05-27T10:09:48.960983Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.471893Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.472548Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': '4742a7ae'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.475778',
#      'end_time': '2024-05-27T10:09:49.769358',
#      'duration': 0.29358,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.477269Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.477719Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.762390Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.765253Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'fc91995f'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.771118',
#      'end_time': '2024-05-27T10:09:49.809594',
#      'duration': 0.038476,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.773294Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.774134Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.804307Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.806069Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': 'f4825f96'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.809949',
#      'end_time': '2024-05-27T10:09:49.810211',
#      'duration': 0.000262,
#      'status': 'completed'}},
#    'id': 'c0dd1dd8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.810552',
#      'end_time': '2024-05-27T10:09:49.811051',
#      'duration': 0.000499,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'd90bf630'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.811411',
#      'end_time': '2024-05-27T10:09:49.825144',
#      'duration': 0.013733,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.815737Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.817059Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.822575Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.821664Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': '6adec45c'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.825459',
#      'end_time': '2024-05-27T10:09:49.854255',
#      'duration': 0.028796,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.827838Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.828287Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.846240Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.844113Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '32f3afef'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.855340',
#      'end_time': '2024-05-27T10:09:49.856076',
#      'duration': 0.000736,
#      'status': 'completed'}},
#    'id': '6cc9bf56'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.856524',
#      'end_time': '2024-05-27T10:09:49.882658',
#      'duration': 0.026134,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.858661Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.859356Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.876656Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.877684Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': 'f7fc49d6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.884273',
#      'end_time': '2024-05-27T10:09:49.885102',
#      'duration': 0.000829,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '59c72d41'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.885493',
#      'end_time': '2024-05-27T10:09:49.907212',
#      'duration': 0.021719,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.888086Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.889021Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.900352Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.904411Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7e11802fffa64b9a84d7134d96152df2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '85c3eece'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.907575',
#      'end_time': '2024-05-27T10:09:49.907958',
#      'duration': 0.000383,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'b2c1fa12'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.908184',
#      'end_time': '2024-05-27T10:09:49.929050',
#      'duration': 0.020866,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.910000Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.910925Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.925606Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.924606Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': 'd8de7a2e'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.929506',
#      'end_time': '2024-05-27T10:09:49.929841',
#      'duration': 0.000335,
#      'status': 'completed'}},
#    'id': '14960358'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.930118',
#      'end_time': '2024-05-27T10:09:49.930401',
#      'duration': 0.000283,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '3e571e67'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.930787',
#      'end_time': '2024-05-27T10:09:49.942571',
#      'duration': 0.011784,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.934036Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.934921Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.937614Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.939436Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '98cd9fd6'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.942851',
#      'end_time': '2024-05-27T10:09:49.956772',
#      'duration': 0.013921,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.944391Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.945137Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.952763Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.953733Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7e11802fffa64b9a84d7134d96152df2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '4d035fec'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.957042',
#      'end_time': '2024-05-27T10:09:49.957365',
#      'duration': 0.000323,
#      'status': 'completed'}},
#    'id': 'cf373bc4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.957570',
#      'end_time': '2024-05-27T10:09:49.971557',
#      'duration': 0.013987,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.958837Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.959093Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.969228Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.968426Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7e11802fffa64b9a84d7134d96152df2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '9d265c44'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.971816',
#      'end_time': '2024-05-27T10:09:49.972069',
#      'duration': 0.000253,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'c3b47794'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:49.972298',
#      'end_time': '2024-05-27T10:09:49.994406',
#      'duration': 0.022108,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:49.973877Z',
#      'iopub.execute_input': '2024-05-27T10:09:49.974235Z',
#      'iopub.status.idle': '2024-05-27T10:09:49.990989Z',
#      'shell.execute_reply': '2024-05-27T10:09:49.989444Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7e11802fffa64b9a84d7134d96152df2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '50c84638'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T10:09:50.473188',
#    'end_time': '2024-05-27T10:09:54.632807',
#    'duration': 4.159619,
#    'exception': None}},
#  'cells': [{'id': '8d11d6ac',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.377702',
#      'end_time': '2024-05-27T10:09:51.393589',
#      'duration': 0.015887,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.379341Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.379794Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.389169Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.390357Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.395036',
#      'end_time': '2024-05-27T10:09:51.410756',
#      'duration': 0.01572,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.397749Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.399111Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.407746Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.405677Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '66f809f3'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.411032',
#      'end_time': '2024-05-27T10:09:51.507111',
#      'duration': 0.096079,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.412826Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.413671Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.504455Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.505115Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '0669c9fd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.507729',
#      'end_time': '2024-05-27T10:09:51.515141',
#      'duration': 0.007412,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.508856Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.509311Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.513204Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.512166Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '788bad79'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.515367',
#      'end_time': '2024-05-27T10:09:51.515592',
#      'duration': 0.000225,
#      'status': 'completed'}},
#    'id': '8840069f'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.515791',
#      'end_time': '2024-05-27T10:09:51.533982',
#      'duration': 0.018191,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.517033Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.517629Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.531402Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.532086Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '595545f5'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.534213',
#      'end_time': '2024-05-27T10:09:51.547091',
#      'duration': 0.012878,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.535165Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.535410Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.543873Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.544735Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:f53b983f-d904-4be1-827f-d90fbd4de2ae .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\nab:f53b983f-d904-4be1-827f-d90fbd4de2ae a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\n\n'}],
#    'id': '37a780ea'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.547349',
#      'end_time': '2024-05-27T10:09:51.547586',
#      'duration': 0.000237,
#      'status': 'completed'}},
#    'id': '76609584'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.547806',
#      'end_time': '2024-05-27T10:09:51.554952',
#      'duration': 0.007146,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.549357Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.550153Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.553480Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.552769Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '905151db'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.555162',
#      'end_time': '2024-05-27T10:09:51.555352',
#      'duration': 0.00019,
#      'status': 'completed'}},
#    'id': '6e95fa19'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.555563',
#      'end_time': '2024-05-27T10:09:51.561272',
#      'duration': 0.005709,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.556497Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.556704Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.559124Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.559804Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '6032156c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.561492',
#      'end_time': '2024-05-27T10:09:51.561643',
#      'duration': 0.000151,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '66b61fb8'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.561847',
#      'end_time': '2024-05-27T10:09:51.570047',
#      'duration': 0.0082,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.562785Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.563016Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.567928Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.568605Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'f1442b22'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.570258',
#      'end_time': '2024-05-27T10:09:51.570408',
#      'duration': 0.00015,
#      'status': 'completed'}},
#    'id': 'd217422d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.570594',
#      'end_time': '2024-05-27T10:09:51.578736',
#      'duration': 0.008142,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.571459Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.571692Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.577064Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.576361Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'de57c81c'},
#   {'cell_type': 'code',
#    'source': '# ID - SUBJECT\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.578904',
#      'end_time': '2024-05-27T10:09:51.584948',
#      'duration': 0.006044,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.579843Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.580101Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.583154Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.582453Z'}},
#    'execution_count': 11,
#    'outputs': [],
#    'id': '64530501'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.585144',
#      'end_time': '2024-05-27T10:09:51.595927',
#      'duration': 0.010783,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.586151Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.586354Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.593359Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.593871Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'c4052d75'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.596155',
#      'end_time': '2024-05-27T10:09:51.596387',
#      'duration': 0.000232,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': 'a000b5ce'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.596578',
#      'end_time': '2024-05-27T10:09:51.605077',
#      'duration': 0.008499,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.597885Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.598175Z',
#      'iopub.status.idle': '2024-05-27T10:09:51.603570Z',
#      'shell.execute_reply': '2024-05-27T10:09:51.602860Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': 'e33c747b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:51.605299',
#      'end_time': '2024-05-27T10:09:54.087119',
#      'duration': 2.48182,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:51.606199Z',
#      'iopub.execute_input': '2024-05-27T10:09:51.606410Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.083271Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.084522Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '781b1911'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.089326',
#      'end_time': '2024-05-27T10:09:54.107970',
#      'duration': 0.018644,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.100084Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.100522Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.106026Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.105228Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '18257e5c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.108160',
#      'end_time': '2024-05-27T10:09:54.108451',
#      'duration': 0.000291,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '09619cd9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.108634',
#      'end_time': '2024-05-27T10:09:54.137274',
#      'duration': 0.02864,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.110313Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.110982Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.134470Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.133677Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '0d30faa6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.137515',
#      'end_time': '2024-05-27T10:09:54.137745',
#      'duration': 0.00023,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'be1c89b2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.137950',
#      'end_time': '2024-05-27T10:09:54.146963',
#      'duration': 0.009013,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.140001Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.140725Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.144071Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.143229Z'}},
#    'cell_type': 'code',
#    'source': "\n#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': 'aeafaab9'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.147253',
#      'end_time': '2024-05-27T10:09:54.147514',
#      'duration': 0.000261,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '950317cd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.147724',
#      'end_time': '2024-05-27T10:09:54.166327',
#      'duration': 0.018603,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.149561Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.150287Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.154339Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.152419Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': '92df1b08'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.166610',
#      'end_time': '2024-05-27T10:09:54.166979',
#      'duration': 0.000369,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'e8a38fda'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.167273',
#      'end_time': '2024-05-27T10:09:54.195544',
#      'duration': 0.028271,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.168989Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.172343Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.192487Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.190916Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4c5696dd4b84d3b9c2d5bbdf39afcfe (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '83ccb012'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.196728',
#      'end_time': '2024-05-27T10:09:54.202065',
#      'duration': 0.005337,
#      'status': 'completed'}},
#    'id': '63a0a032'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.202440',
#      'end_time': '2024-05-27T10:09:54.239939',
#      'duration': 0.037499,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.205854Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.206254Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.236681Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.235615Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '079f2429'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.240243',
#      'end_time': '2024-05-27T10:09:54.262208',
#      'duration': 0.021965,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.241825Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.242426Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.259052Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.255270Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': '0eca6bfb'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:54.262465',
#      'end_time': '2024-05-27T10:09:54.310428',
#      'duration': 0.047963,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:54.264786Z',
#      'iopub.execute_input': '2024-05-27T10:09:54.266730Z',
#      'iopub.status.idle': '2024-05-27T10:09:54.293947Z',
#      'shell.execute_reply': '2024-05-27T10:09:54.292532Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb73c9321fdd84202af886c8dd719c6df (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': 'c87fb192'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T10:09:54.681060',
#    'end_time': '2024-05-27T10:09:58.044571',
#    'duration': 3.363511,
#    'exception': None}},
#  'cells': [{'id': 'b48c68d4',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.771080',
#      'end_time': '2024-05-27T10:09:55.779432',
#      'duration': 0.008352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.772284Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.772491Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.777286Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.777903Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.780230',
#      'end_time': '2024-05-27T10:09:55.788627',
#      'duration': 0.008397,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.781684Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.782443Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.785679Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.786538Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'f3774246'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.788894',
#      'end_time': '2024-05-27T10:09:55.856891',
#      'duration': 0.067997,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.790241Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.791136Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.854663Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.854050Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '927044f9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.857052',
#      'end_time': '2024-05-27T10:09:55.863215',
#      'duration': 0.006163,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.858333Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.858610Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.861329Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.861904Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '0c8fc5d5'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.863350',
#      'end_time': '2024-05-27T10:09:55.863529',
#      'duration': 0.000179,
#      'status': 'completed'}},
#    'id': '3eb0b12f'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.863638',
#      'end_time': '2024-05-27T10:09:55.883034',
#      'duration': 0.019396,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.864388Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.864562Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.881172Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.881747Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '0cd29dda'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.883606',
#      'end_time': '2024-05-27T10:09:55.896431',
#      'duration': 0.012825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.884587Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.884936Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.893823Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.894491Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': '4131dfb1'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.896580',
#      'end_time': '2024-05-27T10:09:55.896780',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'id': 'b2a368a7'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.896916',
#      'end_time': '2024-05-27T10:09:55.902270',
#      'duration': 0.005354,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.897921Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.898116Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.900961Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.900336Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '9e794705'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.902466',
#      'end_time': '2024-05-27T10:09:55.902603',
#      'duration': 0.000137,
#      'status': 'completed'}},
#    'id': '88af7484'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.902778',
#      'end_time': '2024-05-27T10:09:55.908274',
#      'duration': 0.005496,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.903675Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.903914Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.906956Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.906393Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'c85e3187'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.908464',
#      'end_time': '2024-05-27T10:09:55.908626',
#      'duration': 0.000162,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'b427ea8b'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.908809',
#      'end_time': '2024-05-27T10:09:55.915762',
#      'duration': 0.006953,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.909692Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.909874Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.913896Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.914403Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'abc076fa'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.915899',
#      'end_time': '2024-05-27T10:09:55.916106',
#      'duration': 0.000207,
#      'status': 'completed'}},
#    'id': 'f2a1e2a8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.916220',
#      'end_time': '2024-05-27T10:09:55.925106',
#      'duration': 0.008886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.917185Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.917415Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.923031Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.923679Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '77e0995d'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.925244',
#      'end_time': '2024-05-27T10:09:55.936041',
#      'duration': 0.010797,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.926205Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.926404Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.933967Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.934596Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': 'e420861f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.936180',
#      'end_time': '2024-05-27T10:09:55.936404',
#      'duration': 0.000224,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '85a6d636'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.936551',
#      'end_time': '2024-05-27T10:09:55.943024',
#      'duration': 0.006473,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.937430Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.937650Z',
#      'iopub.status.idle': '2024-05-27T10:09:55.941590Z',
#      'shell.execute_reply': '2024-05-27T10:09:55.940980Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'c1c633a0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:55.943168',
#      'end_time': '2024-05-27T10:09:57.713354',
#      'duration': 1.770186,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:55.944315Z',
#      'iopub.execute_input': '2024-05-27T10:09:55.944623Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.706571Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.708794Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '19b22b03'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.715048',
#      'end_time': '2024-05-27T10:09:57.733524',
#      'duration': 0.018476,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.718872Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.720150Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.727364Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.729335Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': '93fcbac7'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.733893',
#      'end_time': '2024-05-27T10:09:57.734366',
#      'duration': 0.000473,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '2bb50fcc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.734767',
#      'end_time': '2024-05-27T10:09:57.753853',
#      'duration': 0.019086,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.736930Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.737824Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.749530Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.750647Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': 'bc293b2f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.754059',
#      'end_time': '2024-05-27T10:09:57.754352',
#      'duration': 0.000293,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '83f5c1f3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.754565',
#      'end_time': '2024-05-27T10:09:57.761065',
#      'duration': 0.0065,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.756238Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.756554Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.759049Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.759647Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '608c69ef'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.761227',
#      'end_time': '2024-05-27T10:09:57.761453',
#      'duration': 0.000226,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '7c4c2ba3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.761606',
#      'end_time': '2024-05-27T10:09:57.766700',
#      'duration': 0.005094,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.762466Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.762672Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.765233Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.764681Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': 'e8fa6ebc'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.766924',
#      'end_time': '2024-05-27T10:09:57.767139',
#      'duration': 0.000215,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'f842d9eb'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.767291',
#      'end_time': '2024-05-27T10:09:57.782639',
#      'duration': 0.015348,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.768282Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.768489Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.780731Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.779949Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nafe40a7ed80042a3b9bb16e1f3fc6f7f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': 'ef27855a'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.782804',
#      'end_time': '2024-05-27T10:09:57.782992',
#      'duration': 0.000188,
#      'status': 'completed'}},
#    'id': '4b72011b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.783129',
#      'end_time': '2024-05-27T10:09:57.798694',
#      'duration': 0.015565,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.784124Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.784323Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.795944Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.796679Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'ca291cd1'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.798879',
#      'end_time': '2024-05-27T10:09:57.806990',
#      'duration': 0.008111,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.800037Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.800247Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.805128Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.804411Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': 'a78bba8a'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T10:09:57.807153',
#      'end_time': '2024-05-27T10:09:57.824570',
#      'duration': 0.017417,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T10:09:57.808053Z',
#      'iopub.execute_input': '2024-05-27T10:09:57.808248Z',
#      'iopub.status.idle': '2024-05-27T10:09:57.822940Z',
#      'shell.execute_reply': '2024-05-27T10:09:57.822296Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N982eba921e044ed98320bdcfa9abfff7 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '5e808042'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets
# Out:
# ['UPENN-GBM_clinical_info_v2', 'dicomimage']

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 39592e3a-7431-4768-92be-771f149d758a
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# bb05a348-3579-433d-97fd-110506152e93
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
