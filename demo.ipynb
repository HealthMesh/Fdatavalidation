# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm
import os

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '031cebc0',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.258995',
#      'end_time': '2024-05-25T13:52:46.287073',
#      'duration': 0.028078,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.262142Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.263898Z',
#      'iopub.status.idle': '2024-05-25T13:52:46.281652Z',
#      'shell.execute_reply': '2024-05-25T13:52:46.279290Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.289224',
#      'end_time': '2024-05-25T13:52:46.311468',
#      'duration': 0.022244,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.292636Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.294293Z',
#      'shell.execute_reply': '2024-05-25T13:52:46.303434Z',
#      'iopub.status.idle': '2024-05-25T13:52:46.305679Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.312261',
#      'end_time': '2024-05-25T13:52:46.312980',
#      'duration': 0.000719,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.313689',
#      'end_time': '2024-05-25T13:52:46.456866',
#      'duration': 0.143177,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.317975Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.319122Z',
#      'shell.execute_reply': '2024-05-25T13:52:46.454197Z',
#      'iopub.status.idle': '2024-05-25T13:52:46.455006Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.457652',
#      'end_time': '2024-05-25T13:52:46.480220',
#      'duration': 0.022568,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.459605Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.460294Z',
#      'shell.execute_reply': '2024-05-25T13:52:46.477472Z',
#      'iopub.status.idle': '2024-05-25T13:52:46.478233Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.480419',
#      'end_time': '2024-05-25T13:52:46.480699',
#      'duration': 0.00028,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'outputs': [],
#    'execution_count': None},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.480895',
#      'end_time': '2024-05-25T13:52:46.481113',
#      'duration': 0.000218,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.481310',
#      'end_time': '2024-05-25T13:52:46.489404',
#      'duration': 0.008094,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.482757Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.483169Z',
#      'shell.execute_reply': '2024-05-25T13:52:46.486668Z',
#      'iopub.status.idle': '2024-05-25T13:52:46.487599Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:46.489607',
#      'end_time': '2024-05-25T13:52:49.071212',
#      'duration': 2.581605,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:46.490790Z',
#      'iopub.execute_input': '2024-05-25T13:52:46.491036Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.063534Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.065956Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.073908',
#      'end_time': '2024-05-25T13:52:49.075116',
#      'duration': 0.001208,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.075979',
#      'end_time': '2024-05-25T13:52:49.099139',
#      'duration': 0.02316,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.081328Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.082240Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.093640Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.091351Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.099679',
#      'end_time': '2024-05-25T13:52:49.137561',
#      'duration': 0.037882,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.102513Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.104384Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.129366Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.131902Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.138074',
#      'end_time': '2024-05-25T13:52:49.138710',
#      'duration': 0.000636,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.139218',
#      'end_time': '2024-05-25T13:52:49.156153',
#      'duration': 0.016935,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.142165Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.142804Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.151495Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.149209Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.156669',
#      'end_time': '2024-05-25T13:52:49.177723',
#      'duration': 0.021054,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.159680Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.160387Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.172455Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.169981Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.179792',
#      'end_time': '2024-05-25T13:52:49.180467',
#      'duration': 0.000675,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.181225',
#      'end_time': '2024-05-25T13:52:49.202397',
#      'duration': 0.021172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.185174Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.187156Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.195821Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.192514Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.203112',
#      'end_time': '2024-05-25T13:52:49.220441',
#      'duration': 0.017329,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.206052Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.206733Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.212117Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.214538Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.221241',
#      'end_time': '2024-05-25T13:52:49.221957',
#      'duration': 0.000716,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.222760',
#      'end_time': '2024-05-25T13:52:49.241785',
#      'duration': 0.019025,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.226462Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.227541Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.236969Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.234587Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'outputs': [],
#    'execution_count': 13},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.242299',
#      'end_time': '2024-05-25T13:52:49.242896',
#      'duration': 0.000597,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:49.243424',
#      'end_time': '2024-05-25T13:52:49.290158',
#      'duration': 0.046734,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:49.246214Z',
#      'iopub.execute_input': '2024-05-25T13:52:49.246893Z',
#      'iopub.status.idle': '2024-05-25T13:52:49.285386Z',
#      'shell.execute_reply': '2024-05-25T13:52:49.282666Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nedc8ecaecf4e4cbc97e64ae89482f95f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:52:45.192642',
#    'end_time': '2024-05-25T13:52:49.722998',
#    'duration': 4.530356,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/26 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:52:49.840663',
#    'end_time': '2024-05-25T13:52:57.441853',
#    'duration': 7.60119,
#    'exception': None}},
#  'cells': [{'id': 'd693cc7e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:50.960608',
#      'end_time': '2024-05-25T13:52:50.992585',
#      'duration': 0.031977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:50.964424Z',
#      'iopub.execute_input': '2024-05-25T13:52:50.966569Z',
#      'shell.execute_reply': '2024-05-25T13:52:50.984319Z',
#      'iopub.status.idle': '2024-05-25T13:52:50.986899Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:50.995006',
#      'end_time': '2024-05-25T13:52:51.019601',
#      'duration': 0.024595,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:50.999459Z',
#      'iopub.execute_input': '2024-05-25T13:52:51.000214Z',
#      'shell.execute_reply': '2024-05-25T13:52:51.010148Z',
#      'iopub.status.idle': '2024-05-25T13:52:51.012488Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '4a22c9b1'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:51.020352',
#      'end_time': '2024-05-25T13:52:56.016617',
#      'duration': 4.996265,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:51.024987Z',
#      'iopub.execute_input': '2024-05-25T13:52:51.027341Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.009018Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.011398Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 3,
#    'id': 'e04d1d0f'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.020112',
#      'end_time': '2024-05-25T13:52:56.021657',
#      'duration': 0.001545,
#      'status': 'completed'}},
#    'id': '7c1f16ca'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.022374',
#      'end_time': '2024-05-25T13:52:56.059657',
#      'duration': 0.037283,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.027970Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.029991Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.052863Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.049665Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 4,
#    'id': '1e70fa42'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.060188',
#      'end_time': '2024-05-25T13:52:56.060822',
#      'duration': 0.000634,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '40d439c5'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.061661',
#      'end_time': '2024-05-25T13:52:56.717115',
#      'duration': 0.655454,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.065195Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.066110Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.714397Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.715255Z'}},
#    'outputs': [],
#    'execution_count': 5,
#    'id': '05df515f'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.718022',
#      'end_time': '2024-05-25T13:52:56.739000',
#      'duration': 0.020978,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.719414Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.720294Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.736615Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.737261Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 6,
#    'id': 'd31e2d5f'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.739202',
#      'end_time': '2024-05-25T13:52:56.739477',
#      'duration': 0.000275,
#      'status': 'completed'}},
#    'id': '53604479'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.739670',
#      'end_time': '2024-05-25T13:52:56.739923',
#      'duration': 0.000253,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'a1e1620d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.740116',
#      'end_time': '2024-05-25T13:52:56.746957',
#      'duration': 0.006841,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.741368Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.741790Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.744442Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.745221Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 7,
#    'id': 'd19cfeda'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.747155',
#      'end_time': '2024-05-25T13:52:56.757972',
#      'duration': 0.010817,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.748249Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.748515Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.755421Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.756208Z'}},
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'd1091a51'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.758199',
#      'end_time': '2024-05-25T13:52:56.758402',
#      'duration': 0.000203,
#      'status': 'completed'}},
#    'id': '5babf27d'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.758572',
#      'end_time': '2024-05-25T13:52:56.768873',
#      'duration': 0.010301,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.759560Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.760254Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.766453Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.767231Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 9}],
#    'execution_count': 9,
#    'id': 'b6941642'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.769057',
#      'end_time': '2024-05-25T13:52:56.769245',
#      'duration': 0.000188,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': 'aa599a93'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.769415',
#      'end_time': '2024-05-25T13:52:56.780903',
#      'duration': 0.011488,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.770533Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.771323Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.778166Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.778938Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N814e9d7e39fd4223a8729b298f4a31bc (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '476c308f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.781176',
#      'end_time': '2024-05-25T13:52:56.781521',
#      'duration': 0.000345,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '5bd903f8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.781844',
#      'end_time': '2024-05-25T13:52:56.793430',
#      'duration': 0.011586,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.783381Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.783717Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.789529Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.790393Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 11,
#    'id': '5b480556'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.793900',
#      'end_time': '2024-05-25T13:52:56.794352',
#      'duration': 0.000452,
#      'status': 'completed'}},
#    'id': '5594ac76'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.794701',
#      'end_time': '2024-05-25T13:52:56.795079',
#      'duration': 0.000378,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'e8e187d4'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.795393',
#      'end_time': '2024-05-25T13:52:56.812849',
#      'duration': 0.017456,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.797371Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.798577Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.808236Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.806265Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 12}],
#    'execution_count': 12,
#    'id': '4c75527f'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.813353',
#      'end_time': '2024-05-25T13:52:56.838549',
#      'duration': 0.025196,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.816197Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.816852Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.833267Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.830618Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N814e9d7e39fd4223a8729b298f4a31bc (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '4312cb19'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.840837',
#      'end_time': '2024-05-25T13:52:56.842320',
#      'duration': 0.001483,
#      'status': 'completed'}},
#    'id': '1b3f992e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.843035',
#      'end_time': '2024-05-25T13:52:56.874746',
#      'duration': 0.031711,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.846587Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.847591Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.866473Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.868795Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n#TYPE\nschema.add((abox.TA1, tbox.typeAcces, abox.Static))\nschema.add((abox.Static, RDF.type, tbox.Acces))\n\n# PATH\nschema.add((abox.Static, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N814e9d7e39fd4223a8729b298f4a31bc (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'ae8c4f0b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.875250',
#      'end_time': '2024-05-25T13:52:56.875773',
#      'duration': 0.000523,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '4ac495ca'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:56.876275',
#      'end_time': '2024-05-25T13:52:56.911397',
#      'duration': 0.035122,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:56.880082Z',
#      'iopub.execute_input': '2024-05-25T13:52:56.881115Z',
#      'shell.execute_reply': '2024-05-25T13:52:56.904945Z',
#      'iopub.status.idle': '2024-05-25T13:52:56.906859Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N814e9d7e39fd4223a8729b298f4a31bc (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': 'c8880f02'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:52:57.574949',
#    'end_time': '2024-05-25T13:53:05.588211',
#    'duration': 8.013262,
#    'exception': None}},
#  'cells': [{'id': 'c9a2ede7',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:59.033855',
#      'end_time': '2024-05-25T13:52:59.064889',
#      'duration': 0.031034,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:59.038466Z',
#      'iopub.execute_input': '2024-05-25T13:52:59.040645Z',
#      'shell.execute_reply': '2024-05-25T13:52:59.056856Z',
#      'iopub.status.idle': '2024-05-25T13:52:59.059187Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:59.067311',
#      'end_time': '2024-05-25T13:52:59.095826',
#      'duration': 0.028515,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:59.072265Z',
#      'iopub.execute_input': '2024-05-25T13:52:59.074801Z',
#      'shell.execute_reply': '2024-05-25T13:52:59.085982Z',
#      'iopub.status.idle': '2024-05-25T13:52:59.089479Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'd8584a1f'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:52:59.096667',
#      'end_time': '2024-05-25T13:53:04.058183',
#      'duration': 4.961516,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:52:59.100183Z',
#      'iopub.execute_input': '2024-05-25T13:52:59.100924Z',
#      'shell.execute_reply': '2024-05-25T13:53:04.053125Z',
#      'iopub.status.idle': '2024-05-25T13:53:04.054697Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 3,
#    'id': '42ab3e0d'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:04.059512',
#      'end_time': '2024-05-25T13:53:04.060134',
#      'duration': 0.000622,
#      'status': 'completed'}},
#    'id': '37c6e8be'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:04.060468',
#      'end_time': '2024-05-25T13:53:04.079258',
#      'duration': 0.01879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:04.063025Z',
#      'iopub.execute_input': '2024-05-25T13:53:04.063501Z',
#      'shell.execute_reply': '2024-05-25T13:53:04.073665Z',
#      'iopub.status.idle': '2024-05-25T13:53:04.075633Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 4,
#    'id': '169e3c33'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:04.079680',
#      'end_time': '2024-05-25T13:53:04.080058',
#      'duration': 0.000378,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '71b9c6e0'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:04.080383',
#      'end_time': '2024-05-25T13:53:04.704527',
#      'duration': 0.624144,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:04.082537Z',
#      'iopub.execute_input': '2024-05-25T13:53:04.083004Z',
#      'shell.execute_reply': '2024-05-25T13:53:04.697392Z',
#      'iopub.status.idle': '2024-05-25T13:53:04.699715Z'}},
#    'outputs': [],
#    'execution_count': 5,
#    'id': '2205356f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:04.706474',
#      'end_time': '2024-05-25T13:53:05.036936',
#      'duration': 0.330462,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:04.709685Z',
#      'iopub.execute_input': '2024-05-25T13:53:04.710490Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.034180Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.035029Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'outputs': [],
#    'execution_count': 6,
#    'id': '75fc82da'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.038009',
#      'end_time': '2024-05-25T13:53:05.063619',
#      'duration': 0.02561,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.039610Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.040396Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.060449Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.061285Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'execution_count': 7,
#    'id': 'ba8f56c0'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.063830',
#      'end_time': '2024-05-25T13:53:05.064069',
#      'duration': 0.000239,
#      'status': 'completed'}},
#    'id': '696218bc'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.064253',
#      'end_time': '2024-05-25T13:53:05.064488',
#      'duration': 0.000235,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '5893c894'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.064684',
#      'end_time': '2024-05-25T13:53:05.071179',
#      'duration': 0.006495,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.065788Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.066031Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.069464Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.068723Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'c14c7772'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.071373',
#      'end_time': '2024-05-25T13:53:05.083943',
#      'duration': 0.01257,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.072491Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.072794Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.080693Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.081529Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '04e19c09'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.084149',
#      'end_time': '2024-05-25T13:53:05.084394',
#      'duration': 0.000245,
#      'status': 'completed'}},
#    'id': '691fc3c3'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.084603',
#      'end_time': '2024-05-25T13:53:05.096113',
#      'duration': 0.01151,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.085757Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.085993Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.093421Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.092564Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '42c01702'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.096311',
#      'end_time': '2024-05-25T13:53:05.096547',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '85b24e5b'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.096740',
#      'end_time': '2024-05-25T13:53:05.106170',
#      'duration': 0.00943,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.097936Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.098174Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.104452Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.103618Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N364af7f8f2a64a429377583f8073b78f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '356096ed'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.106372',
#      'end_time': '2024-05-25T13:53:05.106622',
#      'duration': 0.00025,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'edce25bc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.106816',
#      'end_time': '2024-05-25T13:53:05.119004',
#      'duration': 0.012188,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.107889Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.108510Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.116497Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.117255Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': 'e9e276cc'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.119193',
#      'end_time': '2024-05-25T13:53:05.119424',
#      'duration': 0.000231,
#      'status': 'completed'}},
#    'id': '3ca11bbd'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.119583',
#      'end_time': '2024-05-25T13:53:05.119794',
#      'duration': 0.000211,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'a15110f5'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.119946',
#      'end_time': '2024-05-25T13:53:05.127319',
#      'duration': 0.007373,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.121006Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.121547Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.123967Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.124847Z'}},
#    'outputs': [],
#    'execution_count': 13,
#    'id': '0d741c2c'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.127518',
#      'end_time': '2024-05-25T13:53:05.137615',
#      'duration': 0.010097,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.128745Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.129266Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.134446Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.135243Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N364af7f8f2a64a429377583f8073b78f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': '70212563'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.138535',
#      'end_time': '2024-05-25T13:53:05.139175',
#      'duration': 0.00064,
#      'status': 'completed'}},
#    'id': '7b484875'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.139439',
#      'end_time': '2024-05-25T13:53:05.152323',
#      'duration': 0.012884,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.140821Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.141446Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.149155Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.150232Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n#TYPE\nschema.add((abox.TA1, tbox.typeAcces, abox.Static))\nschema.add((abox.Static, RDF.type, tbox.Acces))\n\n# PATH\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\nschema.add((abox.Static, tbox.path, Literal(data_path)))\n",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N364af7f8f2a64a429377583f8073b78f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': 'eec2a83f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.152521',
#      'end_time': '2024-05-25T13:53:05.152844',
#      'duration': 0.000323,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '65590754'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:05.153166',
#      'end_time': '2024-05-25T13:53:05.168099',
#      'duration': 0.014933,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:05.154529Z',
#      'iopub.execute_input': '2024-05-25T13:53:05.154804Z',
#      'shell.execute_reply': '2024-05-25T13:53:05.165601Z',
#      'iopub.status.idle': '2024-05-25T13:53:05.166412Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N364af7f8f2a64a429377583f8073b78f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '25139e35'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:53:05.669868',
#    'end_time': '2024-05-25T13:53:10.110551',
#    'duration': 4.440683,
#    'exception': None}},
#  'cells': [{'id': '8d4a7c31',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.746378',
#      'end_time': '2024-05-25T13:53:06.775863',
#      'duration': 0.029485,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.750078Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.750916Z',
#      'iopub.status.idle': '2024-05-25T13:53:06.769901Z',
#      'shell.execute_reply': '2024-05-25T13:53:06.767522Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.779500',
#      'end_time': '2024-05-25T13:53:06.808758',
#      'duration': 0.029258,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.784217Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.785004Z',
#      'shell.execute_reply': '2024-05-25T13:53:06.797699Z',
#      'iopub.status.idle': '2024-05-25T13:53:06.800335Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'f89741d1'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.809375',
#      'end_time': '2024-05-25T13:53:06.957181',
#      'duration': 0.147806,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.813395Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.814199Z',
#      'iopub.status.idle': '2024-05-25T13:53:06.955070Z',
#      'shell.execute_reply': '2024-05-25T13:53:06.954214Z'}},
#    'outputs': [],
#    'execution_count': 3,
#    'id': 'f7e9c6c9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.957967',
#      'end_time': '2024-05-25T13:53:06.967957',
#      'duration': 0.00999,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.959750Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.960042Z',
#      'shell.execute_reply': '2024-05-25T13:53:06.964305Z',
#      'iopub.status.idle': '2024-05-25T13:53:06.965259Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 4,
#    'id': '1bb18b85'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.968162',
#      'end_time': '2024-05-25T13:53:06.968391',
#      'duration': 0.000229,
#      'status': 'completed'}},
#    'id': '94d87d29'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.968574',
#      'end_time': '2024-05-25T13:53:06.995127',
#      'duration': 0.026553,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.969770Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.970045Z',
#      'shell.execute_reply': '2024-05-25T13:53:06.991766Z',
#      'iopub.status.idle': '2024-05-25T13:53:06.992752Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'execution_count': 5,
#    'id': 'a87acd6f'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:06.995326',
#      'end_time': '2024-05-25T13:53:07.010120',
#      'duration': 0.014794,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:06.996893Z',
#      'iopub.execute_input': '2024-05-25T13:53:06.997246Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.008091Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.007197Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Static a tb:Acces ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:Static .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'execution_count': 6,
#    'id': '54dc91c3'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.010315',
#      'end_time': '2024-05-25T13:53:07.010528',
#      'duration': 0.000213,
#      'status': 'completed'}},
#    'id': 'dcdee641'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.010709',
#      'end_time': '2024-05-25T13:53:07.018059',
#      'duration': 0.00735,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.011851Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.012124Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.016046Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.015099Z'}},
#    'outputs': [],
#    'execution_count': 7,
#    'id': '249c1073'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.018256',
#      'end_time': '2024-05-25T13:53:07.018472',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'id': '18661cfb'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.018654',
#      'end_time': '2024-05-25T13:53:07.026380',
#      'duration': 0.007726,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.019706Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.020021Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.024317Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.023367Z'}},
#    'outputs': [],
#    'execution_count': 8,
#    'id': '32534ecd'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.026578',
#      'end_time': '2024-05-25T13:53:07.026803',
#      'duration': 0.000225,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '43f786d0'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.026984',
#      'end_time': '2024-05-25T13:53:07.037095',
#      'duration': 0.010111,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.028340Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.028697Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.034138Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.035077Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'execution_count': 9,
#    'id': 'a750c030'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.037289',
#      'end_time': '2024-05-25T13:53:07.037506',
#      'duration': 0.000217,
#      'status': 'completed'}},
#    'id': '6b415544'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.037690',
#      'end_time': '2024-05-25T13:53:07.048531',
#      'duration': 0.010841,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.038803Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.039079Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.045530Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.046452Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '5a474694'},
#   {'cell_type': 'code',
#    'source': '# ID - SUBJECT\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.048747',
#      'end_time': '2024-05-25T13:53:07.055854',
#      'duration': 0.007107,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.050097Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.050404Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.053984Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.053133Z'}},
#    'outputs': [],
#    'execution_count': 11,
#    'id': '983b8097'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.056051',
#      'end_time': '2024-05-25T13:53:07.067090',
#      'duration': 0.011039,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.057123Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.057425Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.064311Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.065184Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'execution_count': 12,
#    'id': 'c068ddc6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.067939',
#      'end_time': '2024-05-25T13:53:07.068710',
#      'duration': 0.000771,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '0f80d2d7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.069003',
#      'end_time': '2024-05-25T13:53:07.082956',
#      'duration': 0.013953,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.070272Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.070602Z',
#      'iopub.status.idle': '2024-05-25T13:53:07.079972Z',
#      'shell.execute_reply': '2024-05-25T13:53:07.079019Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '99eb613a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:07.083280',
#      'end_time': '2024-05-25T13:53:09.425680',
#      'duration': 2.3424,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:07.085074Z',
#      'iopub.execute_input': '2024-05-25T13:53:07.085462Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.420262Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.417694Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 14,
#    'id': '268311bb'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.426178',
#      'end_time': '2024-05-25T13:53:09.447924',
#      'duration': 0.021746,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.430258Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.431015Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.443014Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.441028Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'outputs': [],
#    'execution_count': 15,
#    'id': '013829df'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.448491',
#      'end_time': '2024-05-25T13:53:09.449179',
#      'duration': 0.000688,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '0d32e876'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.449672',
#      'end_time': '2024-05-25T13:53:09.482615',
#      'duration': 0.032943,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.452531Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.453150Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.474677Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.477433Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'outputs': [],
#    'execution_count': 16,
#    'id': '53f6efcf'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.483133',
#      'end_time': '2024-05-25T13:53:09.483751',
#      'duration': 0.000618,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '7091736b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.485818',
#      'end_time': '2024-05-25T13:53:09.506873',
#      'duration': 0.021055,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.490521Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.491523Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.498275Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.501233Z'}},
#    'cell_type': 'code',
#    'source': "\n#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'outputs': [],
#    'execution_count': 17,
#    'id': '965602a2'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.507350',
#      'end_time': '2024-05-25T13:53:09.508007',
#      'duration': 0.000657,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'c67d5448'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.508517',
#      'end_time': '2024-05-25T13:53:09.527205',
#      'duration': 0.018688,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.511654Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.512320Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.518286Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.520607Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'outputs': [],
#    'execution_count': 18,
#    'id': '63c37284'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.527905',
#      'end_time': '2024-05-25T13:53:09.528558',
#      'duration': 0.000653,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '16d4bbe5'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.529267',
#      'end_time': '2024-05-25T13:53:09.562992',
#      'duration': 0.033725,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.532534Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.533269Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.554606Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.557217Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N222f297d8646448280d651dffb4cc46c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'execution_count': 19,
#    'id': '77abc4d5'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.563536',
#      'end_time': '2024-05-25T13:53:09.564054',
#      'duration': 0.000518,
#      'status': 'completed'}},
#    'id': '6044cab9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.564673',
#      'end_time': '2024-05-25T13:53:09.602772',
#      'duration': 0.038099,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.567452Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.568127Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.597701Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.595649Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'outputs': [],
#    'execution_count': 20,
#    'id': 'e79d70b3'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.604822',
#      'end_time': '2024-05-25T13:53:09.632082',
#      'duration': 0.02726,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.608787Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.609730Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.623421Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.626117Z'}},
#    'outputs': [],
#    'execution_count': 21,
#    'id': '1d4b98e9'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:09.632780',
#      'end_time': '2024-05-25T13:53:09.680192',
#      'duration': 0.047412,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:09.635756Z',
#      'iopub.execute_input': '2024-05-25T13:53:09.636413Z',
#      'shell.execute_reply': '2024-05-25T13:53:09.672855Z',
#      'iopub.status.idle': '2024-05-25T13:53:09.675300Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0dd06d07ad2d4eec945a3ba0caa55623 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'execution_count': 22,
#    'id': 'd299575e'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:53:10.252705',
#    'end_time': '2024-05-25T13:53:14.726868',
#    'duration': 4.474163,
#    'exception': None}},
#  'cells': [{'id': '3e7ca01c',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.390840',
#      'end_time': '2024-05-25T13:53:11.422641',
#      'duration': 0.031801,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.394631Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.395374Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.413887Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.416841Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.425332',
#      'end_time': '2024-05-25T13:53:11.450576',
#      'duration': 0.025244,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.429162Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.430939Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.440719Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.443394Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'df5648d2'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.451503',
#      'end_time': '2024-05-25T13:53:11.600145',
#      'duration': 0.148642,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.455679Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.456558Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.596828Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.597628Z'}},
#    'outputs': [],
#    'execution_count': 3,
#    'id': '7c151608'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.601032',
#      'end_time': '2024-05-25T13:53:11.613158',
#      'duration': 0.012126,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.603166Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.604099Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.610564Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.609457Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 4,
#    'id': '0a3325ad'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.613384',
#      'end_time': '2024-05-25T13:53:11.613607',
#      'duration': 0.000223,
#      'status': 'completed'}},
#    'id': '372890e3'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.613817',
#      'end_time': '2024-05-25T13:53:11.639696',
#      'duration': 0.025879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.615380Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.615838Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.637235Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.637981Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'execution_count': 5,
#    'id': 'e797e58a'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.639900',
#      'end_time': '2024-05-25T13:53:11.654378',
#      'duration': 0.014478,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.640974Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.641234Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.650805Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.651854Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:attribute "PositionerPrimaryAngle" .\n\nab:PositionerSecondaryAngle a tb:Attribute ;\n    tb:a ...
#    'execution_count': 6,
#    'id': '28e3a675'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.654630',
#      'end_time': '2024-05-25T13:53:11.654905',
#      'duration': 0.000275,
#      'status': 'completed'}},
#    'id': '90cbf9be'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.655114',
#      'end_time': '2024-05-25T13:53:11.662599',
#      'duration': 0.007485,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.656400Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.656666Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.660312Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.659475Z'}},
#    'outputs': [],
#    'execution_count': 7,
#    'id': '8cd2956c'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.662876',
#      'end_time': '2024-05-25T13:53:11.663086',
#      'duration': 0.00021,
#      'status': 'completed'}},
#    'id': '38972330'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.663333',
#      'end_time': '2024-05-25T13:53:11.670471',
#      'duration': 0.007138,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.664522Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.664767Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.667465Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.668213Z'}},
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'bd486f23'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.670670',
#      'end_time': '2024-05-25T13:53:11.670893',
#      'duration': 0.000223,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '966efd07'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.671059',
#      'end_time': '2024-05-25T13:53:11.679152',
#      'duration': 0.008093,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.672040Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.672273Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.676796Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.677473Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'execution_count': 9,
#    'id': 'a1c1bf64'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.679348',
#      'end_time': '2024-05-25T13:53:11.679611',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'id': '9705ea76'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.679795',
#      'end_time': '2024-05-25T13:53:11.688340',
#      'duration': 0.008545,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.680803Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.681031Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.685892Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.686551Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': 'c9050fe6'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.688529',
#      'end_time': '2024-05-25T13:53:11.702027',
#      'duration': 0.013498,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.689604Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.689831Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.698740Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.699581Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': 'e121df53'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.703094',
#      'end_time': '2024-05-25T13:53:11.703526',
#      'duration': 0.000432,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': 'dc9f55da'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.703810',
#      'end_time': '2024-05-25T13:53:11.713759',
#      'duration': 0.009949,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.705415Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.705708Z',
#      'iopub.status.idle': '2024-05-25T13:53:11.711718Z',
#      'shell.execute_reply': '2024-05-25T13:53:11.710795Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'execution_count': 12,
#    'id': '5c29ee87'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:11.713955',
#      'end_time': '2024-05-25T13:53:14.003701',
#      'duration': 2.289746,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:11.715250Z',
#      'iopub.execute_input': '2024-05-25T13:53:11.715558Z',
#      'shell.execute_reply': '2024-05-25T13:53:13.994810Z',
#      'iopub.status.idle': '2024-05-25T13:53:13.997184Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 13,
#    'id': '7e15cc92'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.004229',
#      'end_time': '2024-05-25T13:53:14.026847',
#      'duration': 0.022618,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.008092Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.009095Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.021956Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.019762Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'outputs': [],
#    'execution_count': 14,
#    'id': '7c9d9cb6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.027344',
#      'end_time': '2024-05-25T13:53:14.027980',
#      'duration': 0.000636,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '0c802532'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.028531',
#      'end_time': '2024-05-25T13:53:14.061934',
#      'duration': 0.033403,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.031388Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.032025Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.054618Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.052370Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'outputs': [],
#    'execution_count': 15,
#    'id': '5e7f3840'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.062472',
#      'end_time': '2024-05-25T13:53:14.063146',
#      'duration': 0.000674,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '07fe4ac0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.065218',
#      'end_time': '2024-05-25T13:53:14.087564',
#      'duration': 0.022346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.069155Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.071047Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.077892Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.080316Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'outputs': [],
#    'execution_count': 16,
#    'id': '04eefde9'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.088304',
#      'end_time': '2024-05-25T13:53:14.088994',
#      'duration': 0.00069,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '41a1dc82'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.089523',
#      'end_time': '2024-05-25T13:53:14.108134',
#      'duration': 0.018611,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.092758Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.093482Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.098772Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.101068Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'outputs': [],
#    'execution_count': 17,
#    'id': '939c8eb1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.108679',
#      'end_time': '2024-05-25T13:53:14.109354',
#      'duration': 0.000675,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'b9573327'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.109855',
#      'end_time': '2024-05-25T13:53:14.147284',
#      'duration': 0.037429,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.113351Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.114218Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.140829Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.142641Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N15a15d15e9394f689a174f92fda930a2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'execution_count': 18,
#    'id': 'f6dc3fc2'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.147932',
#      'end_time': '2024-05-25T13:53:14.148575',
#      'duration': 0.000643,
#      'status': 'completed'}},
#    'id': 'ba206bd2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.149073',
#      'end_time': '2024-05-25T13:53:14.200424',
#      'duration': 0.051351,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.152128Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.153148Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.192958Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.194992Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'outputs': [],
#    'execution_count': 19,
#    'id': 'ddd73f60'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.202818',
#      'end_time': '2024-05-25T13:53:14.235069',
#      'duration': 0.032251,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.207000Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.207713Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.227931Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.230146Z'}},
#    'outputs': [],
#    'execution_count': 20,
#    'id': '75a1cdfc'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:14.235575',
#      'end_time': '2024-05-25T13:53:14.295940',
#      'duration': 0.060365,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:14.238488Z',
#      'iopub.execute_input': '2024-05-25T13:53:14.239105Z',
#      'shell.execute_reply': '2024-05-25T13:53:14.289311Z',
#      'iopub.status.idle': '2024-05-25T13:53:14.291576Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nba00947c07ed439d89a8eefcc36472c0 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'execution_count': 21,
#    'id': '39e8ae28'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ## PARSER

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
        'folder': 'SideCar/ValidateContract/parser',
        'dp':'dicomimage'
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/14 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyN4yKHO/AzEIKjUVcLREMGS'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'SideCar/ValidateContract/parser',
#     'dp': 'dicomimage'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:53:14.860858',
#    'end_time': '2024-05-25T13:53:23.563681',
#    'duration': 8.702823,
#    'exception': None}},
#  'cells': [{'id': '8cef1490',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:15.777779',
#      'end_time': '2024-05-25T13:53:15.806489',
#      'duration': 0.02871,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:15.781277Z',
#      'iopub.execute_input': '2024-05-25T13:53:15.781975Z',
#      'shell.execute_reply': '2024-05-25T13:53:15.797239Z',
#      'iopub.status.idle': '2024-05-25T13:53:15.799565Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "SideCar/ValidateContract/parser"\ndp = "dicomimage"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:40.148414Z',
#      'start_time': '2024-05-25T13:22:40.113636Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:15.808706',
#      'end_time': '2024-05-25T13:53:15.833341',
#      'duration': 0.024635,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:15.813405Z',
#      'iopub.execute_input': '2024-05-25T13:53:15.814532Z',
#      'iopub.status.idle': '2024-05-25T13:53:15.826688Z',
#      'shell.execute_reply': '2024-05-25T13:53:15.824225Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\nif folder:\n    base_dir = os.path.join(base_dir, folder)',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'ac61bc68'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib > /dev/null\n!pip install owlrl > /dev/null\n!pip install pyshacl > /dev/null',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 't3is2tXnQ_8l',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713774875103,
#      'user_tz': -120,
#      'elapsed': 13414,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'b71b9038-4d7b-43d6-dc0a-fd590daaaa10',
#     'ExecuteTime': {'end_time': '2024-05-25T13:22:46.269321Z',
#      'start_time': '2024-05-25T13:22:40.175530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:15.833831',
#      'end_time': '2024-05-25T13:53:22.896256',
#      'duration': 7.062425,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:15.836876Z',
#      'iopub.execute_input': '2024-05-25T13:53:15.837523Z',
#      'shell.execute_reply': '2024-05-25T13:53:22.888170Z',
#      'iopub.status.idle': '2024-05-25T13:53:22.890836Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 3,
#    'id': '975c2331'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *\nfrom owlrl import *\nimport json\nimport pyshacl',
#    'metadata': {'id': 'kHjZOwhr28_o',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713774875104,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:22:46.280420Z',
#      'start_time': '2024-05-25T13:22:46.273611Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:22.898403',
#      'end_time': '2024-05-25T13:53:23.107836',
#      'duration': 0.209433,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:22.902884Z',
#      'iopub.execute_input': '2024-05-25T13:53:22.904768Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.104659Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.105341Z'}},
#    'outputs': [],
#    'execution_count': 4,
#    'id': 'ea9e8743'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:46.297193Z',
#      'start_time': '2024-05-25T13:22:46.282657Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.108724',
#      'end_time': '2024-05-25T13:53:23.119076',
#      'duration': 0.010352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.110171Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.110498Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.116241Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.114811Z'}},
#    'cell_type': 'code',
#    'source': 'tbox = Namespace(\'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\nabox = Namespace(\'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\ndcat = Namespace(\'https://www.w3.org/ns/dcat#\')\ndcterms = Namespace(\'http://purl.org/dc/terms/\')\ntb = Namespace("http://www.semanticweb.org/acraf/ontologies/2021/0/SDM#")\nodrl = Namespace("http://www.w3.org/ns/odrl/2/")\nprov = Namespace("http://www.w3.org/ns/prov#")\ndqv = Namespace("http://www.w3.org/ns/dqv#")',
#    'outputs': [],
#    'execution_count': 5,
#    'id': '896c09b2'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.119302',
#      'end_time': '2024-05-25T13:53:23.119565',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# LOAD CONTRACT',
#    'id': '875e21ce'},
#   {'cell_type': 'code',
#    'source': 'contract = Graph()\ncontract.parse(os.path.join(base_dir, "../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl"))',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'mH3rc9etnQtO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713774875789,
#      'user_tz': -120,
#      'elapsed': 693,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c47f473f-7644-4b53-faa6-9c8e2ad726cc',
#     'ExecuteTime': {'end_time': '2024-05-25T13:22:46.344471Z',
#      'start_time': '2024-05-25T13:22:46.301031Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.119759',
#      'end_time': '2024-05-25T13:53:23.156111',
#      'duration': 0.036352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.121208Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.121519Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.152644Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.153774Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b23f3a8418940c3be9e243e5eec299e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 6}],
#    'execution_count': 6,
#    'id': '539a8498'},
#   {'cell_type': 'markdown',
#    'source': '# PARSER CONTRACT',
#    'metadata': {'id': 'IYpNSeTH4EUm',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.156327',
#      'end_time': '2024-05-25T13:53:23.156648',
#      'duration': 0.000321,
#      'status': 'completed'}},
#    'id': 'c2a1ea5f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.156917',
#      'end_time': '2024-05-25T13:53:23.157144',
#      'duration': 0.000227,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Given a Data Product, Output a DC IRs',
#    'id': 'e160b962'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:46.353423Z',
#      'start_time': '2024-05-25T13:22:46.346947Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.157309',
#      'end_time': '2024-05-25T13:53:23.165555',
#      'duration': 0.008246,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.158830Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.159477Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.162821Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.163589Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'outputs': [],
#    'execution_count': 7,
#    'id': 'a5f8b707'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.165859',
#      'end_time': '2024-05-25T13:53:23.166146',
#      'duration': 0.000287,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '68deb59f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:46.368255Z',
#      'start_time': '2024-05-25T13:22:46.355279Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.166339',
#      'end_time': '2024-05-25T13:53:23.175700',
#      'duration': 0.009361,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.167594Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.168047Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.173944Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.173126Z'}},
#    'cell_type': 'code',
#    'source': 'class PolicyChecker(Graph):\n    \n    """ Create Policy Checker """\n    def __init__(self, p, p_type, format, *args, **kwargs):\n        super().__init__(*args, **kwargs)\n        self.p = p\n        self.bind("ab", "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#")\n        self.bind("tb", "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#")\n        self.URI = abox[f\'pc_{p.split("#")[1]}\']\n        self.add((self.URI, RDF.type, tbox.PolicyChecker))\n        self.add((self.URI, tbox.validates, p))\n        self.add((self.URI, tbox.hasType, Literal(format.split("#")[1])))\n        \n        self.p_type = p_type.split("/")[-1]\n                \n    def get_URI(self):\n        return self.URI\n    \n    def get_policy_type(self):\n        return self.p_type\n        ',
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'cba3a562'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:46.403174Z',
#      'start_time': '2024-05-25T13:22:46.370300Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.175892',
#      'end_time': '2024-05-25T13:53:23.207534',
#      'duration': 0.031642,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.177299Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.177544Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.204311Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.205448Z'}},
#    'cell_type': 'code',
#    'source': '\nclass DCParser:\n    """\n    Parse Policies of Data Contracts to Policy Checkers\n    """\n\n    def __init__(self, dp, graph):\n        self.dp = dp\n        self.g = graph\n        self.op_mappings = add_jsonld_instances(Graph(), os.path.join(base_dir, \'operations_mappings.json\'))\n        self.attr_mappings = None\n\n    def _validate_graph(self) -> bool:\n        """\n        Validate the policies grammar is compliant with the grammar defined\n        :return: conformance/non-conformance\n        """\n        from pyshacl import validate\n        shapes = Graph().parse(os.path.join(base_dir, \'policy_grammar.json\'), format="turtle")\n        conforms, report_graph, report_text = validate(self.g,shacl_graph=shapes)\n        #return boolean\n        return conforms\n    \n    def _read_contracts(self):\n        """\n        Get the policies associated with a data product\n        :return: list of policies\n        """\n        contracts = self.g.objects(subject=abox[self.dp],predicate=tbox.hasDC)\n        policies_list = []\n        mappings_dict = {}\n        for contract in contracts:\n            # handle mappings\n            policies = self.g.objects(subject=contract,predicate=tbox.hasPolicy)\n            for policy in policies:\n                print(policy)\n                policies_list.append(policy)\n                \n            mappings = self.g.objects(subject=contract,predicate=tbox.hasMapping)\n            for mapping in mappings:\n                mfrom = self.g.value(subject=mapping,predicate=tbox.mfrom)\n                mto = self.g.value(subject=mapping,predicate=tbox.mto)\n                mappings_dict[mto] = mfrom\n            \n        self.attr_mappings = mappings_dict\n        return policies_list, mappings_dict\n    \n    def _get_op(self, operation):\n        \n\n        operation = self.op_mappings.value(subject=operation,predicate=tbox.hasOP)\n        subgraph = Graph()\n        # Iterate over all triples in the graph that have the operation as the subject\n        for s, p, o in self.op_mappings.triples((operation, None, None)):\n            # Add each triple to the subgraph\n            subgraph.add((s, p, o))\n            \n        return operation, subgraph\n    \n    def _get_op_constraint(self, constraint):\n        \n        leftop = self.g.value(subject=constraint, predicate=odrl.leftOperand)\n        software_agent = self.g.value(subject=leftop, predicate=prov.wasAssociatedWith) \n        return self._get_op(software_agent)\n        \n    \n    def _get_op_predicate(self, constraint):\n        rightop = self.g.value(subject=constraint, predicate=odrl.rightOperand)\n        leftop = self.g.value(subject=constraint, predicate=odrl.leftOperand)\n        predicate = self.g.value(subject=constraint, predicate=odrl.operator)\n        if predicate == odrl.lteq:\n            predicate = Literal("<=")\n        elif predicate == odrl.gteq:\n            predicate = Literal(">=")\n        elif predicate == odrl.isA:\n            predicate = Literal("type")\n        return (leftop, predicate, rightop)\n    \n    def _initOP(self, policy, pc):\n        """\n        :param IR: \n        :param policy: \n        :return: \n        """\n        ta = self.g.value(subject=abox[self.dp], predicate=tbox.hasTA)\n        ta_type = self.g.value(subject=ta, predicate=tbox.typeAcces)\n        \n        # Check TA typeAcces\n        if ta_type.split("#")[1] == "Static":\n            init_operation, subgraph =  self._get_op(ta_type)\n            pc += subgraph\n            if subgraph.value(subject=init_operation, predicate=tbox.hasParameter):\n                pc.remove((init_operation, tbox.hasParameter, None))\n                ta_path = self.g.value(subject=ta_type, predicate=tbox.path)\n                pc.add((init_operation, tbox.hasParameter, ta_path))\n          \n            pc.add((pc.get_URI(), tbox.nextStep, init_operation)) \n            \n            \n    def _handle_attributes(self,  ...
#    'outputs': [],
#    'execution_count': 9,
#    'id': 'b769cb61'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:22:46.462156Z',
#      'start_time': '2024-05-25T13:22:46.404929Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:23.207726',
#      'end_time': '2024-05-25T13:53:23.240869',
#      'duration': 0.033143,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:23.208913Z',
#      'iopub.execute_input': '2024-05-25T13:53:23.209681Z',
#      'shell.execute_reply': '2024-05-25T13:53:23.238026Z',
#      'iopub.status.idle': '2024-05-25T13:53:23.238884Z'}},
#    'cell_type': 'code',
#    'source': 'DCParser(dp, contract).parse_contracts()',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#p1\n'}],
#    'execution_count': 10,
#    'id': '2eb269f8'}]}

# %% [markdown]
# ## TRANSLATOR

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
        'folder': 'SideCar/ValidateContract/translator',
        'pc' : 'pc_p1'
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyN4yKHO/AzEIKjUVcLREMGS'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'SideCar/ValidateContract/translator',
#     'pc': 'pc_p1'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-25T13:53:23.657731',
#    'end_time': '2024-05-25T13:53:35.938221',
#    'duration': 12.28049,
#    'exception': None}},
#  'cells': [{'id': 'caee5495',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:24.594776',
#      'end_time': '2024-05-25T13:53:24.622421',
#      'duration': 0.027645,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:24.597909Z',
#      'iopub.execute_input': '2024-05-25T13:53:24.598568Z',
#      'shell.execute_reply': '2024-05-25T13:53:24.614608Z',
#      'iopub.status.idle': '2024-05-25T13:53:24.616785Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "SideCar/ValidateContract/translator"\npc = "pc_p1"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:50:54.137534Z',
#      'start_time': '2024-05-25T13:50:54.127214Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:24.624883',
#      'end_time': '2024-05-25T13:53:24.646973',
#      'duration': 0.02209,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:24.628475Z',
#      'iopub.execute_input': '2024-05-25T13:53:24.629149Z',
#      'shell.execute_reply': '2024-05-25T13:53:24.638045Z',
#      'iopub.status.idle': '2024-05-25T13:53:24.640609Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'acdf84af'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib > /dev/null\n!pip install owlrl > /dev/null\n!pip install pyshacl > /dev/null\n!pip install autopep8 > /dev/null',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 't3is2tXnQ_8l',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713774875103,
#      'user_tz': -120,
#      'elapsed': 13414,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'b71b9038-4d7b-43d6-dc0a-fd590daaaa10',
#     'ExecuteTime': {'end_time': '2024-05-25T13:35:30.113649Z',
#      'start_time': '2024-05-25T13:35:19.373960Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:24.647887',
#      'end_time': '2024-05-25T13:53:34.434591',
#      'duration': 9.786704,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:24.652782Z',
#      'iopub.execute_input': '2024-05-25T13:53:24.655388Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.425628Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.428439Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 3,
#    'id': '16d2704e'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *\nfrom owlrl import *\nfrom jinja2 import Template\nimport types\nimport pyshacl\nimport functools\nimport inspect\nimport autopep8\nimport json',
#    'metadata': {'id': 'kHjZOwhr28_o',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713774875104,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:35:30.131043Z',
#      'start_time': '2024-05-25T13:35:30.120244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.436876',
#      'end_time': '2024-05-25T13:53:34.670566',
#      'duration': 0.23369,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.442345Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.444572Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.667858Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.668529Z'}},
#    'outputs': [],
#    'execution_count': 4,
#    'id': 'bc30cfef'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.149672Z',
#      'start_time': '2024-05-25T13:35:30.136272Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.671440',
#      'end_time': '2024-05-25T13:53:34.680020',
#      'duration': 0.00858,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.672839Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.673150Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.676829Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.677906Z'}},
#    'cell_type': 'code',
#    'source': 'tbox = Namespace(\'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\nabox = Namespace(\'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\ndcat = Namespace(\'https://www.w3.org/ns/dcat#\')\ndcterms = Namespace(\'http://purl.org/dc/terms/\')\ntb = Namespace("http://www.semanticweb.org/acraf/ontologies/2021/0/SDM#")\nodrl = Namespace("http://www.w3.org/ns/odrl/2/")',
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'ce72267d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.171618Z',
#      'start_time': '2024-05-25T13:35:30.158330Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.680347',
#      'end_time': '2024-05-25T13:53:34.690902',
#      'duration': 0.010555,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.681959Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.682726Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.687353Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.688462Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'outputs': [],
#    'execution_count': 6,
#    'id': '3fd062ce'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.691210',
#      'end_time': '2024-05-25T13:53:34.691534',
#      'duration': 0.000324,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# POLICYCHECKER TRANSLATOR',
#    'id': 'd82636a1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.691755',
#      'end_time': '2024-05-25T13:53:34.692047',
#      'duration': 0.000292,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Given a Data Product, Output a DC IRs',
#    'id': '7f66d779'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.209457Z',
#      'start_time': '2024-05-25T13:35:30.177791Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.692266',
#      'end_time': '2024-05-25T13:53:34.707703',
#      'duration': 0.015437,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.693945Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.694432Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.704848Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.705758Z'}},
#    'cell_type': 'code',
#    'source': 'import types\nimport autopep8\nfrom jinja2 import Template\nfrom rdflib import Graph\nimport time\n\nclass Implementation(type):\n    def __init__(cls, name, bases, attrs):\n        super().__init__(name, bases, attrs)\n        cls.tg = cls._initialize_graph()\n        cls.ex = Graph()\n        cls.translation = None\n    \n    @staticmethod\n    def _initialize_graph():\n        tg = Graph()\n        tg.bind("tb", "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#")\n        tg.bind("ab", "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#")\n        tg = add_jsonld_instances(tg, os.path.join(base_dir, \'translations_mappings.json\'))\n        return tg\n    \n    \n    def annotate_execution_times_and_results(cls):\n        def decorator(func):\n            def wrapper(*args, **kwargs):\n                start_time = time.time()\n                result = func(*args, **kwargs)\n                end_time = time.time()\n                EX = Namespace("http://example.org/ns#")\n                execution_time = end_time - start_time\n                execution_node = URIRef(f"http://example.org/execution/{cls.translation.split(\'#\')[-1]}")\n    \n                cls.ex.add((execution_node, RDF.type, EX.Execution))\n                cls.ex.add((execution_node, EX.executionTime, Literal(execution_time, datatype=XSD.decimal)))\n                cls.ex.add((execution_node, EX.intermediateResult, Literal(result)))\n                print(cls.ex.serialize(format="turtle"))\n                return result\n            return wrapper\n        return decorator\n    \n    def _translate_and_compile(cls, operation, template_str, context):\n        translation = cls.tg.value(subject=operation, predicate=tbox.hasTranslation)   \n        cls.translation = translation\n        try:\n            template = Template(template_str)\n            rendered_code = template.render(context)\n            fixed_code = autopep8.fix_code(rendered_code) \n            print(fixed_code)\n        except Exception as e:\n            print("Code Generation Error: ", e)\n            return None\n        \n        try:\n            compiled_code = compile(fixed_code, \'\', \'exec\')\n            new_func = types.FunctionType(compiled_code.co_consts[0], globals(), translation)\n            #new_func = cls.annotate_execution_times_and_results()(new_func)  # Apply the decorator\n        except Exception as e:\n            print("Code Compilation Error: ", e)\n            return None\n        \n        return new_func\n    # additional methods here\n    ',
#    'outputs': [],
#    'execution_count': 7,
#    'id': '112317cb'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.268205Z',
#      'start_time': '2024-05-25T13:35:30.214294Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.707949',
#      'end_time': '2024-05-25T13:53:34.732485',
#      'duration': 0.024536,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.709446Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.709724Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.729443Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.730365Z'}},
#    'cell_type': 'code',
#    'source': 'class Operator(metaclass=Implementation):\n    """..."""\n    \n     \n    def __init__(self, operation):\n        \n        # Static Metadata\n        self.tg = self.__class__.tg\n        # Function Implementaiton\n        self.f = self._init_func(operation)\n        \n    \n    def _init_func(self, operation):\n        """\n        Get the code associated with the operation\n        :param operation: operation\n        :return: python funcion \n        """\n        \n        translation = self.tg.value(subject=operation, predicate=tbox.hasTranslation)\n        code = self.tg.value(subject=translation, predicate=tbox.hasCode)\n        \n        c_path = self.tg.value(subject=code, predicate=tbox.code)\n        code = str(c_path)\n        params = self.tg.objects(subject=translation, predicate=tbox.hasParameters)\n        dependencies = self.tg.objects(subject=translation, predicate=tbox.dependsOn)\n        params = [self.tg.value(subject=p, predicate=tbox.name) for p in params]\n        dependencies = [self.tg.value(subject=d, predicate=tbox.name) for d in dependencies]\n        \n        context = {\n            "name": translation.split("#")[1],\n            "params": params,\n            "code": code,\n        }\n        \n        # Implementation Template\n        template = """\n        def {{ name }}({{",".join(params)}}, *args, **kwargs):\n            data = {{code}}\n            return data\n        """\n    \n        return self.__class__._translate_and_compile(operation, template, context)\n    \n    def get_func(self):\n        return self.f',
#    'outputs': [],
#    'execution_count': 8,
#    'id': '5c052784'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.298876Z',
#      'start_time': '2024-05-25T13:35:30.270744Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.732707',
#      'end_time': '2024-05-25T13:53:34.756063',
#      'duration': 0.023356,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.734161Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.734443Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.753067Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.754033Z'}},
#    'cell_type': 'code',
#    'source': 'class Operation(metaclass=Implementation):\n    """\n    Operation Class\n    """\n    \n    def __init__(self, operation, format="Tabular"):\n        \n        # Static Metadata\n        self.tg = self.__class__.tg\n        # Format\n        self.format = format\n        # Function Implementaiton\n        self.f = self._init_func(operation)\n  \n        \n    \n    def find_implementation(self, operation, type):\n        \n        # Define the base, type, and operation URIs\n        base_uri = "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#"\n        # Define the specific type and operation you\'re looking for\n        type_id = URIRef(base_uri + f"{type}")  # replace with your type\n        operation_id = operation  # replace with your operation\n        \n        \n        # Query the graph\n        qres = self.tg.query(\n            """\n            SELECT ?impl\n            WHERE {\n                ?impl tb:forType ?type .\n                ?impl tb:forOp ?operation .\n            }\n            LIMIT 1\n            """,\n            initBindings={\'type\': type_id, \'operation\': operation_id}\n        )\n        \n        # Print the results\n        for row in qres:\n\n            return row[0]\n        \n        return None\n        \n        \n    def _init_func(self, operation):\n        """\n        Get the code associated with the operation\n        :param operation: operation\n        :return: python funcion \n        """\n        \n        translation = self.find_implementation(operation, self.format) \n            \n        code = self.tg.value(subject=translation, predicate=tbox.hasCode)\n        params = self.tg.objects(subject=translation, predicate=tbox.hasParameters)\n        dependencies = self.tg.objects(subject=translation, predicate=tbox.dependsOn)\n        params = [self.tg.value(subject=p, predicate=tbox.name) for p in params]\n        dependencies = [self.tg.value(subject=d, predicate=tbox.name) for d in dependencies]\n        \n        \n        print(code, params, dependencies)\n                \n        c_path = self.tg.value(subject=code, predicate=tbox.code)\n        \n        codelines = str(c_path).split(\'\\n\')\n        \n        context = {\n            "name": translation.split("#")[1],\n            "codelines": codelines,\n            "params": params,\n            "libraries": dependencies\n        }\n        \n        # Implementation Template\n        template = """\n        def {{ name }}({{",".join(params)}}):\n        {% for library in libraries %}\n            import {{ library }}\n        {% endfor %}\n        {% for line in codelines %}\n            data = {{  line }}\n        {% endfor %}\n            return data\n        """   \n        return self.__class__._translate_and_compile(operation, template, context)\n    \n    \n    def get_func(self):\n        return self.f\n',
#    'outputs': [],
#    'execution_count': 9,
#    'id': 'f7e399ff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.332609Z',
#      'start_time': '2024-05-25T13:35:30.301275Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.756284',
#      'end_time': '2024-05-25T13:53:34.776912',
#      'duration': 0.020628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.757667Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.757956Z',
#      'shell.execute_reply': '2024-05-25T13:53:34.774151Z',
#      'iopub.status.idle': '2024-05-25T13:53:34.775008Z'}},
#    'cell_type': 'code',
#    'source': 'class PCTranslator:\n    """\n    Parse the PolicyChecker Operations to an executable Script\n    """\n    def __init__(self, pc, graph, format="Tabular"):\n        # Graph\n        self.g = graph\n        \n        # PolicyChecker\n        self.pc = abox[pc]\n        \n        # Execution Graph\n        self.eg = Graph()\n        # Format\n        \n        self.format = self.g.value(subject=self.pc, predicate=tbox.hasType)\n        \n        \n    def _validate_graph(self) -> bool:\n        """\n        Validate the policies grammar is compliant with the grammar defined\n        :return: conformance/non-conformance\n        """\n        from pyshacl import validate\n        shapes = Graph().parse(os.path.join(base_dir, \'pc_grammar.ttl\'), format="turtle")\n        conforms, report_graph, report_text = validate(self.g,shacl_graph=shapes)\n        #return boolean\n        return conforms\n    \n         \n    def _create_function_as_decorator(self, before_func=None, after_func=None, before_args={}, after_args={}) -> types.FunctionType:\n        def decorator(f):\n            def wrapper(*args, **kwargs):\n                if before_func is not None:\n                    before_func(*before_args)\n                data = f(*args, **kwargs)\n                if after_func is not None:\n                    result = after_func(data=data, **after_args)\n                    return result\n                return data\n            return wrapper\n        return decorator\n    \n    \n    def _get_func_parameters(self, f):\n        import inspect \n        return inspect.signature(f).parameters\n    \n    def _operation_to_code(self, operation) -> types.FunctionType:\n        \n        operation_type = str(self.g.value(subject=operation, predicate=RDF.type)).split("#")[-1]\n        kwargs = {}\n        \n        if operation_type == "initOperation":\n            imp = Operation(operation, self.format)\n            return imp.get_func()\n        \n        elif operation_type == "Operation":\n            imp = Operation(operation, self.format)\n            params = self._get_func_parameters(imp.get_func())\n            parameters = self.g.objects(subject=operation, predicate=tbox.hasParameter)\n            parameters = [str(p).split("#")[1] for p in parameters]\n            attrs = self.g.objects(subject=operation, predicate=tbox.hasAttribute)\n            attrs = [str(a).split("#")[1] for a in attrs]\n            \n            kwargs["attr"] = attrs[0]\n            \n            decorated_imp  = self._create_function_as_decorator(after_func=imp.get_func(), after_args=kwargs)\n            return decorated_imp\n                        \n        elif operation_type == "Operator":\n            operator = self.g.value(subject=operation, predicate=tbox.operator)\n            rightOperand = self.g.value(subject=operation, predicate=tbox.hasRightOperand)\n            leftOperand = self.g.value(subject=operation, predicate=tbox.hasLeftOperand)\n            imp = Operator(operation)            \n            \n            kwargs["ro"] = rightOperand\n            kwargs["lo"] = str(leftOperand).split("#")[1]\n            \n            decorated_imp  = self._create_function_as_decorator(after_func=imp.get_func(), after_args=kwargs)\n            return decorated_imp\n        \n   \n    def traverse_and_generate(self) -> types.FunctionType:\n        """\n        Traverse the policy checker and generate the code\n        :param language: \n        :return: \n        """\n        # Obtian policy checker\n        \n        # Get first operation\n        operation = self.g.value(subject=self.pc,predicate=tbox.nextStep)\n        function = None\n        \n        # Traverse the policy checker (path)\n        while operation:\n            operation_type = str(self.g.value(subject=operation, predicate=RDF.type)).split("#")[-1]\n            if operation_type == "initOperation":\n                function = self._operation_to_code(operation)\n       ...
#    'outputs': [],
#    'execution_count': 10,
#    'id': '3d996dfb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.777825',
#      'end_time': '2024-05-25T13:53:34.778257',
#      'duration': 0.000432,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Translate the Policy Checker',
#    'id': '53524690'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.456327Z',
#      'start_time': '2024-05-25T13:35:30.334399Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:34.778469',
#      'end_time': '2024-05-25T13:53:35.077811',
#      'duration': 0.299342,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:34.780540Z',
#      'iopub.execute_input': '2024-05-25T13:53:34.781293Z',
#      'shell.execute_reply': '2024-05-25T13:53:35.074630Z',
#      'iopub.status.idle': '2024-05-25T13:53:35.075443Z'}},
#    'cell_type': 'code',
#    'source': '# Translate the Policy Checker \ngraph = Graph().parse(os.path.join(base_dir, "../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl"), format="turtle")\n\nfunction = PCTranslator(pc, graph).translate()\nfunction',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#Imp9Code [rdflib.term.Literal('p')] [rdflib.term.Literal('pydicom')]\n\ndef Imp9(p):\n\n    import pydicom\n\n    data = pydicom.dcmread(p)\n\n    return data\n\nhttp://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#Imp6Code [rdflib.term.Literal('data'), rdflib.term.Literal('attr')] [rdflib.term.Literal('pydicom')]\n\ndef Imp6(data, attr):\n\n    import pydicom\n\n    data = getattr(data, attr, None) == None\n\n    return data\n\n"},
#     {'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '<function __main__.PCTranslator._create_function_as_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)>'},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '757cde41'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:35:30.476847Z',
#      'start_time': '2024-05-25T13:35:30.459435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-25T13:53:35.078011',
#      'end_time': '2024-05-25T13:53:35.414894',
#      'duration': 0.336883,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-25T13:53:35.079155Z',
#      'iopub.execute_input': '2024-05-25T13:53:35.079443Z',
#      'iopub.status.idle': '2024-05-25T13:53:35.413140Z',
#      'shell.execute_reply': '2024-05-25T13:53:35.412424Z'}},
#    'cell_type': 'code',
#    'source': "function('/home/acraf/psr/tfm/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM')",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'False'},
#      'execution_count': 12}],
#    'execution_count': 12,
#    'id': '6f265fed'}]}
