# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm
import os   
from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '748196ad',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.685877',
#      'end_time': '2024-05-26T20:39:41.714869',
#      'duration': 0.028992,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:41.689235Z',
#      'iopub.execute_input': '2024-05-26T20:39:41.689887Z',
#      'shell.execute_reply': '2024-05-26T20:39:41.706124Z',
#      'iopub.status.idle': '2024-05-26T20:39:41.708475Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.718383',
#      'end_time': '2024-05-26T20:39:41.743733',
#      'duration': 0.02535,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:41.722225Z',
#      'iopub.execute_input': '2024-05-26T20:39:41.722901Z',
#      'shell.execute_reply': '2024-05-26T20:39:41.734123Z',
#      'iopub.status.idle': '2024-05-26T20:39:41.736855Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.744293',
#      'end_time': '2024-05-26T20:39:41.744812',
#      'duration': 0.000519,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.745337',
#      'end_time': '2024-05-26T20:39:41.958162',
#      'duration': 0.212825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:41.748254Z',
#      'iopub.execute_input': '2024-05-26T20:39:41.750090Z',
#      'iopub.status.idle': '2024-05-26T20:39:41.955395Z',
#      'shell.execute_reply': '2024-05-26T20:39:41.954267Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.959877',
#      'end_time': '2024-05-26T20:39:41.989598',
#      'duration': 0.029721,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:41.962068Z',
#      'iopub.execute_input': '2024-05-26T20:39:41.962879Z',
#      'shell.execute_reply': '2024-05-26T20:39:41.986110Z',
#      'iopub.status.idle': '2024-05-26T20:39:41.987110Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.989869',
#      'end_time': '2024-05-26T20:39:41.990211',
#      'duration': 0.000342,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.990498',
#      'end_time': '2024-05-26T20:39:41.990824',
#      'duration': 0.000326,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:41.991086',
#      'end_time': '2024-05-26T20:39:42.001121',
#      'duration': 0.010035,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:41.992601Z',
#      'iopub.execute_input': '2024-05-26T20:39:41.992926Z',
#      'shell.execute_reply': '2024-05-26T20:39:41.997241Z',
#      'iopub.status.idle': '2024-05-26T20:39:41.998285Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:42.001530',
#      'end_time': '2024-05-26T20:39:44.384318',
#      'duration': 2.382788,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:42.003265Z',
#      'iopub.execute_input': '2024-05-26T20:39:42.003653Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.375999Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.379068Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.386662',
#      'end_time': '2024-05-26T20:39:44.387767',
#      'duration': 0.001105,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.388343',
#      'end_time': '2024-05-26T20:39:44.415296',
#      'duration': 0.026953,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.392878Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.394398Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.405388Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.408691Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.415934',
#      'end_time': '2024-05-26T20:39:44.452309',
#      'duration': 0.036375,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.419692Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.421339Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.446350Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.444363Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.452847',
#      'end_time': '2024-05-26T20:39:44.453475',
#      'duration': 0.000628,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.454046',
#      'end_time': '2024-05-26T20:39:44.476178',
#      'duration': 0.022132,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.457457Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.458434Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.466227Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.469051Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.476857',
#      'end_time': '2024-05-26T20:39:44.502706',
#      'duration': 0.025849,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.480252Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.482456Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.493090Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.495120Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.505876',
#      'end_time': '2024-05-26T20:39:44.507874',
#      'duration': 0.001998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.508508',
#      'end_time': '2024-05-26T20:39:44.531198',
#      'duration': 0.02269,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.514333Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.516932Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.523546Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.526159Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.531718',
#      'end_time': '2024-05-26T20:39:44.548461',
#      'duration': 0.016743,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.534592Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.535243Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.540829Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.543243Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.549115',
#      'end_time': '2024-05-26T20:39:44.549821',
#      'duration': 0.000706,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.550549',
#      'end_time': '2024-05-26T20:39:44.569757',
#      'duration': 0.019208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.553748Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.554436Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.562651Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.560111Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.570362',
#      'end_time': '2024-05-26T20:39:44.571088',
#      'duration': 0.000726,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:44.571720',
#      'end_time': '2024-05-26T20:39:44.623266',
#      'duration': 0.051546,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:44.574996Z',
#      'iopub.execute_input': '2024-05-26T20:39:44.575621Z',
#      'iopub.status.idle': '2024-05-26T20:39:44.616305Z',
#      'shell.execute_reply': '2024-05-26T20:39:44.614183Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na49030c36b9549529a6710f1ec7fd02b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T20:39:40.159565',
#    'end_time': '2024-05-26T20:39:45.059486',
#    'duration': 4.899921,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T20:39:45.194345',
#    'end_time': '2024-05-26T20:39:52.264075',
#    'duration': 7.06973,
#    'exception': None}},
#  'cells': [{'id': 'e99ba601',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:46.118218',
#      'end_time': '2024-05-26T20:39:46.154294',
#      'duration': 0.036076,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:46.122320Z',
#      'iopub.execute_input': '2024-05-26T20:39:46.123362Z',
#      'shell.execute_reply': '2024-05-26T20:39:46.146382Z',
#      'iopub.status.idle': '2024-05-26T20:39:46.148847Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:46.156438',
#      'end_time': '2024-05-26T20:39:46.179480',
#      'duration': 0.023042,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:46.160241Z',
#      'iopub.execute_input': '2024-05-26T20:39:46.160959Z',
#      'shell.execute_reply': '2024-05-26T20:39:46.170863Z',
#      'iopub.status.idle': '2024-05-26T20:39:46.174067Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '7a1ec559'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:46.180382',
#      'end_time': '2024-05-26T20:39:46.202931',
#      'duration': 0.022549,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:46.184533Z',
#      'iopub.execute_input': '2024-05-26T20:39:46.185551Z',
#      'shell.execute_reply': '2024-05-26T20:39:46.195255Z',
#      'iopub.status.idle': '2024-05-26T20:39:46.197422Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': 'a2bfb1d8'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:46.203743',
#      'end_time': '2024-05-26T20:39:51.082736',
#      'duration': 4.878993,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:46.206925Z',
#      'iopub.execute_input': '2024-05-26T20:39:46.207620Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.079348Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.080251Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': 'da782f48'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.083518',
#      'end_time': '2024-05-26T20:39:51.084059',
#      'duration': 0.000541,
#      'status': 'completed'}},
#    'id': 'aed305f7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.084345',
#      'end_time': '2024-05-26T20:39:51.096408',
#      'duration': 0.012063,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.086547Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.087009Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.093406Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.094493Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'aa3f801a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.096614',
#      'end_time': '2024-05-26T20:39:51.096881',
#      'duration': 0.000267,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'a7d4c276'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.097148',
#      'end_time': '2024-05-26T20:39:51.709192',
#      'duration': 0.612044,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.098543Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.098880Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.705808Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.706665Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '3b878683'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.710003',
#      'end_time': '2024-05-26T20:39:51.731938',
#      'duration': 0.021935,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.711373Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.711754Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.729993Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.729094Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '80eb3616'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.732171',
#      'end_time': '2024-05-26T20:39:51.732427',
#      'duration': 0.000256,
#      'status': 'completed'}},
#    'id': 'e61294f0'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.732597',
#      'end_time': '2024-05-26T20:39:51.732849',
#      'duration': 0.000252,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'd49ca55a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.733036',
#      'end_time': '2024-05-26T20:39:51.741274',
#      'duration': 0.008238,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.734195Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.734472Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.737375Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.738544Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': '589d6366'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.741566',
#      'end_time': '2024-05-26T20:39:51.752791',
#      'duration': 0.011225,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.743027Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.743744Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.750261Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.750996Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '02cfff4d'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.752990',
#      'end_time': '2024-05-26T20:39:51.753258',
#      'duration': 0.000268,
#      'status': 'completed'}},
#    'id': '8770ea6f'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.753449',
#      'end_time': '2024-05-26T20:39:51.764162',
#      'duration': 0.010713,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.754533Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.754789Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.762377Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.761627Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '9b3139fe'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.764460',
#      'end_time': '2024-05-26T20:39:51.764742',
#      'duration': 0.000282,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '60e7869c'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.765001',
#      'end_time': '2024-05-26T20:39:51.774862',
#      'duration': 0.009861,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.766196Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.766505Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.772034Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.772930Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N69ca7520498044dfa9d00b87d8fd8b87 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '681f80c1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.775060',
#      'end_time': '2024-05-26T20:39:51.775331',
#      'duration': 0.000271,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'a797441a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.775522',
#      'end_time': '2024-05-26T20:39:51.783975',
#      'duration': 0.008453,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.776594Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.776831Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.782186Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.781342Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '032b1a8b'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.784173',
#      'end_time': '2024-05-26T20:39:51.784441',
#      'duration': 0.000268,
#      'status': 'completed'}},
#    'id': '97f9e32c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.784632',
#      'end_time': '2024-05-26T20:39:51.784887',
#      'duration': 0.000255,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'aec80dc2'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.785074',
#      'end_time': '2024-05-26T20:39:51.792565',
#      'duration': 0.007491,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.786151Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.786391Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.790316Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.790934Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': 'ab948e01'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.792762',
#      'end_time': '2024-05-26T20:39:51.801522',
#      'duration': 0.00876,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.793922Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.794170Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.799840Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.799207Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N69ca7520498044dfa9d00b87d8fd8b87 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'd4f35fbc'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.801796',
#      'end_time': '2024-05-26T20:39:51.802044',
#      'duration': 0.000248,
#      'status': 'completed'}},
#    'id': '848780cf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.802292',
#      'end_time': '2024-05-26T20:39:51.812752',
#      'duration': 0.01046,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.803368Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.803629Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.810747Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.810049Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N69ca7520498044dfa9d00b87d8fd8b87 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '3b8fb521'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.813820',
#      'end_time': '2024-05-26T20:39:51.814772',
#      'duration': 0.000952,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '290cbd98'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:51.815163',
#      'end_time': '2024-05-26T20:39:51.840499',
#      'duration': 0.025336,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:51.818088Z',
#      'iopub.execute_input': '2024-05-26T20:39:51.818679Z',
#      'shell.execute_reply': '2024-05-26T20:39:51.834471Z',
#      'iopub.status.idle': '2024-05-26T20:39:51.836003Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N69ca7520498044dfa9d00b87d8fd8b87 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '382fcaf9'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T20:39:52.408800',
#    'end_time': '2024-05-26T20:39:59.945975',
#    'duration': 7.537175,
#    'exception': None}},
#  'cells': [{'id': 'cab3343d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:53.472270',
#      'end_time': '2024-05-26T20:39:53.510584',
#      'duration': 0.038314,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:53.476246Z',
#      'iopub.execute_input': '2024-05-26T20:39:53.478192Z',
#      'shell.execute_reply': '2024-05-26T20:39:53.503563Z',
#      'iopub.status.idle': '2024-05-26T20:39:53.505668Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:53.512698',
#      'end_time': '2024-05-26T20:39:53.536257',
#      'duration': 0.023559,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:53.516502Z',
#      'iopub.execute_input': '2024-05-26T20:39:53.517538Z',
#      'shell.execute_reply': '2024-05-26T20:39:53.528693Z',
#      'iopub.status.idle': '2024-05-26T20:39:53.531085Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'c841aca7'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:53.536916',
#      'end_time': '2024-05-26T20:39:58.659270',
#      'duration': 5.122354,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:53.541631Z',
#      'iopub.execute_input': '2024-05-26T20:39:53.542796Z',
#      'shell.execute_reply': '2024-05-26T20:39:58.655676Z',
#      'iopub.status.idle': '2024-05-26T20:39:58.656608Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'd0f7706a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:58.660094',
#      'end_time': '2024-05-26T20:39:58.670971',
#      'duration': 0.010877,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:58.662126Z',
#      'iopub.execute_input': '2024-05-26T20:39:58.662580Z',
#      'iopub.status.idle': '2024-05-26T20:39:58.668690Z',
#      'shell.execute_reply': '2024-05-26T20:39:58.667604Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '5f4f9e07'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:58.671336',
#      'end_time': '2024-05-26T20:39:58.671679',
#      'duration': 0.000343,
#      'status': 'completed'}},
#    'id': '90bacc56'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:58.672025',
#      'end_time': '2024-05-26T20:39:58.683809',
#      'duration': 0.011784,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:58.673499Z',
#      'iopub.execute_input': '2024-05-26T20:39:58.674312Z',
#      'shell.execute_reply': '2024-05-26T20:39:58.680336Z',
#      'iopub.status.idle': '2024-05-26T20:39:58.681256Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '6d2b6799'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:58.683997',
#      'end_time': '2024-05-26T20:39:58.684204',
#      'duration': 0.000207,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'ce9818ab'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:58.684376',
#      'end_time': '2024-05-26T20:39:59.125092',
#      'duration': 0.440716,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:58.685917Z',
#      'iopub.execute_input': '2024-05-26T20:39:58.686302Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.122028Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.122910Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': 'd6de37b1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.126154',
#      'end_time': '2024-05-26T20:39:59.393349',
#      'duration': 0.267195,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.127621Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.128029Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.389657Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.390680Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'e74b5d2e'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.394223',
#      'end_time': '2024-05-26T20:39:59.420550',
#      'duration': 0.026327,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.396066Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.396854Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.417382Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.418237Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': 'c48034c2'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.420736',
#      'end_time': '2024-05-26T20:39:59.420950',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'id': '47560844'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.421119',
#      'end_time': '2024-05-26T20:39:59.421296',
#      'duration': 0.000177,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '9b032c1b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.421458',
#      'end_time': '2024-05-26T20:39:59.428434',
#      'duration': 0.006976,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.422444Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.422686Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.426254Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.425431Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': 'b982a861'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.428617',
#      'end_time': '2024-05-26T20:39:59.439545',
#      'duration': 0.010928,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.429610Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.429841Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.436454Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.437205Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '6872849a'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.439763',
#      'end_time': '2024-05-26T20:39:59.439981',
#      'duration': 0.000218,
#      'status': 'completed'}},
#    'id': '0535a23f'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.440161',
#      'end_time': '2024-05-26T20:39:59.451331',
#      'duration': 0.01117,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.441364Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.441621Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.449494Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.448705Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': '314eaa22'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.451514',
#      'end_time': '2024-05-26T20:39:59.451719',
#      'duration': 0.000205,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '7fb786cd'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.451887',
#      'end_time': '2024-05-26T20:39:59.461510',
#      'duration': 0.009623,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.452872Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.453111Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.459792Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.459014Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb0b64d0127f542bfadfae59ddcaffb29 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '715c0879'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.461692',
#      'end_time': '2024-05-26T20:39:59.461891',
#      'duration': 0.000199,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '7b60153c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.462055',
#      'end_time': '2024-05-26T20:39:59.474427',
#      'duration': 0.012372,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.463235Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.463488Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.472560Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.471769Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '0717885c'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.474608',
#      'end_time': '2024-05-26T20:39:59.474803',
#      'duration': 0.000195,
#      'status': 'completed'}},
#    'id': '98c84a71'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.474966',
#      'end_time': '2024-05-26T20:39:59.475140',
#      'duration': 0.000174,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '76b197ee'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.475360',
#      'end_time': '2024-05-26T20:39:59.481563',
#      'duration': 0.006203,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.476452Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.476693Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.479091Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.479860Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '87fb9d0d'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.481755',
#      'end_time': '2024-05-26T20:39:59.490502',
#      'duration': 0.008747,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.482768Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.483065Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.487749Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.488452Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb0b64d0127f542bfadfae59ddcaffb29 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '7f5dadd0'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.490702',
#      'end_time': '2024-05-26T20:39:59.490992',
#      'duration': 0.00029,
#      'status': 'completed'}},
#    'id': '89f22d68'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.491190',
#      'end_time': '2024-05-26T20:39:59.502732',
#      'duration': 0.011542,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.492435Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.492763Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.500166Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.500932Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb0b64d0127f542bfadfae59ddcaffb29 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': 'de36daa4'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.503520',
#      'end_time': '2024-05-26T20:39:59.503980',
#      'duration': 0.00046,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'bbb44713'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:39:59.504243',
#      'end_time': '2024-05-26T20:39:59.522660',
#      'duration': 0.018417,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:39:59.505616Z',
#      'iopub.execute_input': '2024-05-26T20:39:59.506386Z',
#      'shell.execute_reply': '2024-05-26T20:39:59.519460Z',
#      'iopub.status.idle': '2024-05-26T20:39:59.520402Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb0b64d0127f542bfadfae59ddcaffb29 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '3197110c'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T20:40:00.079147',
#    'end_time': '2024-05-26T20:40:04.891506',
#    'duration': 4.812359,
#    'exception': None}},
#  'cells': [{'id': 'fefce8e6',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.131629',
#      'end_time': '2024-05-26T20:40:01.164035',
#      'duration': 0.032406,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.135264Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.136174Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.157429Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.155154Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.166416',
#      'end_time': '2024-05-26T20:40:01.191525',
#      'duration': 0.025109,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.171795Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.172786Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.186054Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.183273Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '16628014'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.192025',
#      'end_time': '2024-05-26T20:40:01.388870',
#      'duration': 0.196845,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.195787Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.197568Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.379604Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.381667Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'efe01194'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.392184',
#      'end_time': '2024-05-26T20:40:01.420263',
#      'duration': 0.028079,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.397020Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.397713Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.410013Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.413226Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '8353c818'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.420860',
#      'end_time': '2024-05-26T20:40:01.421849',
#      'duration': 0.000989,
#      'status': 'completed'}},
#    'id': '702fd70f'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.422715',
#      'end_time': '2024-05-26T20:40:01.478373',
#      'duration': 0.055658,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.426346Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.427308Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.472679Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.469245Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': 'a82e31ac'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.479201',
#      'end_time': '2024-05-26T20:40:01.508675',
#      'duration': 0.029474,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.482448Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.483272Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.500410Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.502788Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:18db2f65-2c79-4ecb-9fdc-703a2c2123ba a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:18db2f65-2c79-4ecb-9fdc-703a2c2123ba .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': '13006784'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.511424',
#      'end_time': '2024-05-26T20:40:01.512408',
#      'duration': 0.000984,
#      'status': 'completed'}},
#    'id': '8de31d96'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.512924',
#      'end_time': '2024-05-26T20:40:01.534876',
#      'duration': 0.021952,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.516755Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.518040Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.529573Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.526796Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'd3889b9d'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.535719',
#      'end_time': '2024-05-26T20:40:01.536491',
#      'duration': 0.000772,
#      'status': 'completed'}},
#    'id': '54e6b627'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.537257',
#      'end_time': '2024-05-26T20:40:01.556291',
#      'duration': 0.019034,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.540223Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.541184Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.548323Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.550842Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'd953e917'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.557139',
#      'end_time': '2024-05-26T20:40:01.557746',
#      'duration': 0.000607,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'f81b9e7c'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.558241',
#      'end_time': '2024-05-26T20:40:01.584045',
#      'duration': 0.025804,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.561292Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.561974Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.575931Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.578236Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'bfb86ddc'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.584697',
#      'end_time': '2024-05-26T20:40:01.585379',
#      'duration': 0.000682,
#      'status': 'completed'}},
#    'id': 'f1e3dda2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.585866',
#      'end_time': '2024-05-26T20:40:01.614073',
#      'duration': 0.028207,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.588837Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.589480Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.608992Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.605957Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '6077a014'},
#   {'cell_type': 'code',
#    'source': '# ID - SUBJECT\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.616204',
#      'end_time': '2024-05-26T20:40:01.645229',
#      'duration': 0.029025,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.622234Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.624170Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.636632Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.632279Z'}},
#    'execution_count': 11,
#    'outputs': [],
#    'id': 'f748e818'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.646088',
#      'end_time': '2024-05-26T20:40:01.680866',
#      'duration': 0.034778,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.650388Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.651638Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.674647Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.672098Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '10e11d27'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.681669',
#      'end_time': '2024-05-26T20:40:01.682481',
#      'duration': 0.000812,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '21be5753'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.683004',
#      'end_time': '2024-05-26T20:40:01.712325',
#      'duration': 0.029321,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.686563Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.687473Z',
#      'shell.execute_reply': '2024-05-26T20:40:01.701965Z',
#      'iopub.status.idle': '2024-05-26T20:40:01.704875Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '76ce76b7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:01.712878',
#      'end_time': '2024-05-26T20:40:04.182773',
#      'duration': 2.469895,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:01.716442Z',
#      'iopub.execute_input': '2024-05-26T20:40:01.717928Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.175125Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.177576Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '9464990a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.185339',
#      'end_time': '2024-05-26T20:40:04.213776',
#      'duration': 0.028437,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.190471Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.191810Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.204215Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.207620Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '60161dea'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.214501',
#      'end_time': '2024-05-26T20:40:04.215073',
#      'duration': 0.000572,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '7c110a91'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.215726',
#      'end_time': '2024-05-26T20:40:04.249759',
#      'duration': 0.034033,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.218811Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.219910Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.242456Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.244815Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'f525ff72'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.250279',
#      'end_time': '2024-05-26T20:40:04.251014',
#      'duration': 0.000735,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'e8921b4a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.251576',
#      'end_time': '2024-05-26T20:40:04.266280',
#      'duration': 0.014704,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.254433Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.255080Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.262042Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.260376Z'}},
#    'cell_type': 'code',
#    'source': "\n#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '064bb297'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.267018',
#      'end_time': '2024-05-26T20:40:04.267646',
#      'duration': 0.000628,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'd9601b70'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.268136',
#      'end_time': '2024-05-26T20:40:04.286181',
#      'duration': 0.018045,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.270903Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.271518Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.277357Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.280579Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': '4d9ca3dd'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.289203',
#      'end_time': '2024-05-26T20:40:04.290384',
#      'duration': 0.001181,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'c175ac29'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.291133',
#      'end_time': '2024-05-26T20:40:04.331569',
#      'duration': 0.040436,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.296400Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.297521Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.322828Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.325248Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N957216c738fe4d6ea676bbeb82332e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': 'e68bb679'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.332127',
#      'end_time': '2024-05-26T20:40:04.332746',
#      'duration': 0.000619,
#      'status': 'completed'}},
#    'id': 'd2bdb0bd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.333185',
#      'end_time': '2024-05-26T20:40:04.382656',
#      'duration': 0.049471,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.336297Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.337033Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.374769Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.377057Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': 'c9d85804'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.383192',
#      'end_time': '2024-05-26T20:40:04.404492',
#      'duration': 0.0213,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.386382Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.387069Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.396106Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.398664Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': '6f30d076'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:04.406727',
#      'end_time': '2024-05-26T20:40:04.460692',
#      'duration': 0.053965,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:04.409931Z',
#      'iopub.execute_input': '2024-05-26T20:40:04.410792Z',
#      'shell.execute_reply': '2024-05-26T20:40:04.453815Z',
#      'iopub.status.idle': '2024-05-26T20:40:04.455778Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N4c17d0f36b4a47a59def4b39b4cc8518 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '1c591bf1'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T20:40:05.025725',
#    'end_time': '2024-05-26T20:40:09.390621',
#    'duration': 4.364896,
#    'exception': None}},
#  'cells': [{'id': 'beba0c11',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.055268',
#      'end_time': '2024-05-26T20:40:06.070865',
#      'duration': 0.015597,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.057346Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.057914Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.068031Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.067071Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.072641',
#      'end_time': '2024-05-26T20:40:06.086406',
#      'duration': 0.013765,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.075749Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.076788Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.082820Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.081648Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '3c003804'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.086795',
#      'end_time': '2024-05-26T20:40:06.181163',
#      'duration': 0.094368,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.088987Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.089357Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.177041Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.178483Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'f85c4790'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.182647',
#      'end_time': '2024-05-26T20:40:06.197121',
#      'duration': 0.014474,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.185194Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.186379Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.193783Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.191775Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '0450ae26'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.197460',
#      'end_time': '2024-05-26T20:40:06.197760',
#      'duration': 0.0003,
#      'status': 'completed'}},
#    'id': 'f733edaf'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.197990',
#      'end_time': '2024-05-26T20:40:06.229170',
#      'duration': 0.03118,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.199667Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.200078Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.226042Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.227058Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '508c8088'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.229403',
#      'end_time': '2024-05-26T20:40:06.246586',
#      'duration': 0.017183,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.230763Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.231057Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.244074Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.243044Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': 'b5421022'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.246819',
#      'end_time': '2024-05-26T20:40:06.247165',
#      'duration': 0.000346,
#      'status': 'completed'}},
#    'id': 'd3c251dd'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.247393',
#      'end_time': '2024-05-26T20:40:06.255885',
#      'duration': 0.008492,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.248781Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.249092Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.253471Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.252373Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '7221ea34'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.256240',
#      'end_time': '2024-05-26T20:40:06.256588',
#      'duration': 0.000348,
#      'status': 'completed'}},
#    'id': '36547430'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.256918',
#      'end_time': '2024-05-26T20:40:06.266600',
#      'duration': 0.009682,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.258517Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.258853Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.263523Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.262425Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '3fdf8262'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.266840',
#      'end_time': '2024-05-26T20:40:06.267179',
#      'duration': 0.000339,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'cc0b3cc0'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.267405',
#      'end_time': '2024-05-26T20:40:06.279434',
#      'duration': 0.012029,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.268981Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.269384Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.275407Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.276514Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '8524fe85'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.279668',
#      'end_time': '2024-05-26T20:40:06.280010',
#      'duration': 0.000342,
#      'status': 'completed'}},
#    'id': '9085c779'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.280244',
#      'end_time': '2024-05-26T20:40:06.293180',
#      'duration': 0.012936,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.281739Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.282060Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.289568Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.288382Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '99df465b'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.294268',
#      'end_time': '2024-05-26T20:40:06.316001',
#      'duration': 0.021733,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.295970Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.296318Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.312832Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.313910Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '8093f840'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.316235',
#      'end_time': '2024-05-26T20:40:06.316515',
#      'duration': 0.00028,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': 'e01c4a45'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.316708',
#      'end_time': '2024-05-26T20:40:06.327614',
#      'duration': 0.010906,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.318008Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.318334Z',
#      'iopub.status.idle': '2024-05-26T20:40:06.325390Z',
#      'shell.execute_reply': '2024-05-26T20:40:06.324360Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'e2663142'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:06.327864',
#      'end_time': '2024-05-26T20:40:08.774720',
#      'duration': 2.446856,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:06.329134Z',
#      'iopub.execute_input': '2024-05-26T20:40:06.329442Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.764362Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.767145Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '9c0510ca'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.775260',
#      'end_time': '2024-05-26T20:40:08.798162',
#      'duration': 0.022902,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.779951Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.780764Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.793405Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.791354Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': '6f14c613'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.798807',
#      'end_time': '2024-05-26T20:40:08.799454',
#      'duration': 0.000647,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'aba33bba'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.801614',
#      'end_time': '2024-05-26T20:40:08.838504',
#      'duration': 0.03689,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.805486Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.806451Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.833717Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.831254Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '19724f6b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.839008',
#      'end_time': '2024-05-26T20:40:08.839819',
#      'duration': 0.000811,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'fcc684e7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.840645',
#      'end_time': '2024-05-26T20:40:08.858696',
#      'duration': 0.018051,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.844188Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.845983Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.850990Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.853348Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'f66a8498'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.859207',
#      'end_time': '2024-05-26T20:40:08.859836',
#      'duration': 0.000629,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '348c4f84'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.860385',
#      'end_time': '2024-05-26T20:40:08.876749',
#      'duration': 0.016364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.863528Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.865379Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.870033Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.872041Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '6e91cb9e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.877302',
#      'end_time': '2024-05-26T20:40:08.877875',
#      'duration': 0.000573,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'd98d4c8e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.878392',
#      'end_time': '2024-05-26T20:40:08.917701',
#      'duration': 0.039309,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.881277Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.883346Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.910082Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.912423Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c1071fe4753480f8a0629720012168a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': '940c5a4b'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.919682',
#      'end_time': '2024-05-26T20:40:08.921227',
#      'duration': 0.001545,
#      'status': 'completed'}},
#    'id': '83fdb339'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.921934',
#      'end_time': '2024-05-26T20:40:08.977950',
#      'duration': 0.056016,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.925621Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.926326Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.971117Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.973165Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'edf76bfe'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:08.978447',
#      'end_time': '2024-05-26T20:40:09.001003',
#      'duration': 0.022556,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:08.981191Z',
#      'iopub.execute_input': '2024-05-26T20:40:08.981824Z',
#      'shell.execute_reply': '2024-05-26T20:40:08.993968Z',
#      'iopub.status.idle': '2024-05-26T20:40:08.996085Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': 'd6e144d7'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T20:40:09.001775',
#      'end_time': '2024-05-26T20:40:09.059990',
#      'duration': 0.058215,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T20:40:09.004678Z',
#      'iopub.execute_input': '2024-05-26T20:40:09.005422Z',
#      'shell.execute_reply': '2024-05-26T20:40:09.052693Z',
#      'iopub.status.idle': '2024-05-26T20:40:09.055100Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1600f9dd9a6b4d439edc942e12340a85 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '8b6079f3'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets
# Out:
# ['UPENN-GBM_clinical_info_v2', 'dicomimage']

# %% [markdown]
# ## PARSER

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 56ac560c-28de-43c1-bc65-00ab04550808
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 18b434d0-b76c-40ee-bf47-5314915f22d2
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
