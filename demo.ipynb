# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:09<00:00,  1.53cell/s]
# {'cells': [{'id': '9cb68c17',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.496634',
#      'end_time': '2024-10-15T10:08:01.525759',
#      'duration': 0.029125,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.501831Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.502252Z',
#      'iopub.status.idle': '2024-10-15T10:08:01.522592Z',
#      'shell.execute_reply': '2024-10-15T10:08:01.521621Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.527278',
#      'end_time': '2024-10-15T10:08:01.537815',
#      'duration': 0.010537,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.528949Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.529362Z',
#      'iopub.status.idle': '2024-10-15T10:08:01.535531Z',
#      'shell.execute_reply': '2024-10-15T10:08:01.534732Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.538025',
#      'end_time': '2024-10-15T10:08:01.538265',
#      'duration': 0.00024,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.538449',
#      'end_time': '2024-10-15T10:08:01.638001',
#      'duration': 0.099552,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.539593Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.540322Z',
#      'iopub.status.idle': '2024-10-15T10:08:01.635643Z',
#      'shell.execute_reply': '2024-10-15T10:08:01.634745Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.638946',
#      'end_time': '2024-10-15T10:08:01.675447',
#      'duration': 0.036501,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.640328Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.640668Z',
#      'shell.execute_reply': '2024-10-15T10:08:01.672308Z',
#      'iopub.status.idle': '2024-10-15T10:08:01.673195Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.675601',
#      'end_time': '2024-10-15T10:08:01.675848',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.676071',
#      'end_time': '2024-10-15T10:08:01.684661',
#      'duration': 0.00859,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.677237Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.677530Z',
#      'shell.execute_reply': '2024-10-15T10:08:01.681183Z',
#      'iopub.status.idle': '2024-10-15T10:08:01.682191Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:01.684843',
#      'end_time': '2024-10-15T10:08:04.845263',
#      'duration': 3.16042,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:01.686359Z',
#      'iopub.execute_input': '2024-10-15T10:08:01.686674Z',
#      'shell.execute_reply': '2024-10-15T10:08:04.842531Z',
#      'iopub.status.idle': '2024-10-15T10:08:04.843520Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.846159',
#      'end_time': '2024-10-15T10:08:04.846718',
#      'duration': 0.000559,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.846902',
#      'end_time': '2024-10-15T10:08:04.855747',
#      'duration': 0.008845,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:04.848853Z',
#      'iopub.execute_input': '2024-10-15T10:08:04.849344Z',
#      'iopub.status.idle': '2024-10-15T10:08:04.854050Z',
#      'shell.execute_reply': '2024-10-15T10:08:04.853418Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.855886',
#      'end_time': '2024-10-15T10:08:04.866084',
#      'duration': 0.010198,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:04.856807Z',
#      'iopub.execute_input': '2024-10-15T10:08:04.857233Z',
#      'shell.execute_reply': '2024-10-15T10:08:04.863886Z',
#      'iopub.status.idle': '2024-10-15T10:08:04.864563Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.866223',
#      'end_time': '2024-10-15T10:08:04.866458',
#      'duration': 0.000235,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.866578',
#      'end_time': '2024-10-15T10:08:04.878549',
#      'duration': 0.011971,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:04.867521Z',
#      'iopub.execute_input': '2024-10-15T10:08:04.867782Z',
#      'iopub.status.idle': '2024-10-15T10:08:04.876994Z',
#      'shell.execute_reply': '2024-10-15T10:08:04.876103Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.878693',
#      'end_time': '2024-10-15T10:08:04.878857',
#      'duration': 0.000164,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:04.878974',
#      'end_time': '2024-10-15T10:08:04.897450',
#      'duration': 0.018476,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:04.880003Z',
#      'iopub.execute_input': '2024-10-15T10:08:04.880226Z',
#      'iopub.status.idle': '2024-10-15T10:08:04.895607Z',
#      'shell.execute_reply': '2024-10-15T10:08:04.894904Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7b1d28ad5c7c4ad8a2081d3cbeb0a36c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-15T10:07:55.318048',
#    'end_time': '2024-10-15T10:08:05.116108',
#    'duration': 9.79806,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:16<00:00,  1.37s/cell]
# {'cells': [{'id': '9eb5dfee',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:11.342221',
#      'end_time': '2024-10-15T10:08:11.379538',
#      'duration': 0.037317,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:11.345858Z',
#      'iopub.execute_input': '2024-10-15T10:08:11.346990Z',
#      'shell.execute_reply': '2024-10-15T10:08:11.368298Z',
#      'iopub.status.idle': '2024-10-15T10:08:11.371929Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:11.383064',
#      'end_time': '2024-10-15T10:08:20.472979',
#      'duration': 9.089915,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:11.390089Z',
#      'iopub.execute_input': '2024-10-15T10:08:11.391508Z',
#      'shell.execute_reply': '2024-10-15T10:08:20.470255Z',
#      'iopub.status.idle': '2024-10-15T10:08:20.471202Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:20.473762',
#      'end_time': '2024-10-15T10:08:20.486414',
#      'duration': 0.012652,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:20.475666Z',
#      'iopub.execute_input': '2024-10-15T10:08:20.477779Z',
#      'iopub.status.idle': '2024-10-15T10:08:20.484244Z',
#      'shell.execute_reply': '2024-10-15T10:08:20.483205Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:20.486550',
#      'end_time': '2024-10-15T10:08:20.559363',
#      'duration': 0.072813,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:20.487790Z',
#      'iopub.execute_input': '2024-10-15T10:08:20.488082Z',
#      'shell.execute_reply': '2024-10-15T10:08:20.556868Z',
#      'iopub.status.idle': '2024-10-15T10:08:20.557652Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:20.559486',
#      'end_time': '2024-10-15T10:08:20.559668',
#      'duration': 0.000182,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:20.559781',
#      'end_time': '2024-10-15T10:08:21.251728',
#      'duration': 0.691947,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:20.560825Z',
#      'iopub.execute_input': '2024-10-15T10:08:20.561150Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.247399Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.246257Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.253036',
#      'end_time': '2024-10-15T10:08:21.273720',
#      'duration': 0.020684,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:21.255174Z',
#      'iopub.execute_input': '2024-10-15T10:08:21.266309Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.269935Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.270997Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.273869',
#      'end_time': '2024-10-15T10:08:21.290826',
#      'duration': 0.016957,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:21.275135Z',
#      'iopub.execute_input': '2024-10-15T10:08:21.275882Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.288144Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.289043Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.290972',
#      'end_time': '2024-10-15T10:08:21.299018',
#      'duration': 0.008046,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:21.292117Z',
#      'iopub.execute_input': '2024-10-15T10:08:21.292509Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.295669Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.296495Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.299292',
#      'end_time': '2024-10-15T10:08:21.299592',
#      'duration': 0.0003,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.299817',
#      'end_time': '2024-10-15T10:08:21.322529',
#      'duration': 0.022712,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:21.301228Z',
#      'iopub.execute_input': '2024-10-15T10:08:21.301925Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.319821Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.320617Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:21.322780',
#      'end_time': '2024-10-15T10:08:21.355464',
#      'duration': 0.032684,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:21.323804Z',
#      'iopub.execute_input': '2024-10-15T10:08:21.324086Z',
#      'iopub.status.idle': '2024-10-15T10:08:21.353639Z',
#      'shell.execute_reply': '2024-10-15T10:08:21.352657Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nde820173f882475686132ea2a924f8af (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-15T10:08:05.258236',
#    'end_time': '2024-10-15T10:08:21.686813',
#    'duration': 16.428577,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:21<00:00,  1.75s/cell]
# {'cells': [{'id': 'a2e81e40',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:28.001151',
#      'end_time': '2024-10-15T10:08:28.022080',
#      'duration': 0.020929,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:28.007528Z',
#      'iopub.execute_input': '2024-10-15T10:08:28.007921Z',
#      'iopub.status.idle': '2024-10-15T10:08:28.018217Z',
#      'shell.execute_reply': '2024-10-15T10:08:28.017014Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:28.029022',
#      'end_time': '2024-10-15T10:08:41.700705',
#      'duration': 13.671683,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:28.031128Z',
#      'iopub.execute_input': '2024-10-15T10:08:28.031839Z',
#      'shell.execute_reply': '2024-10-15T10:08:41.696957Z',
#      'iopub.status.idle': '2024-10-15T10:08:41.698024Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\r\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:41.701565',
#      'end_time': '2024-10-15T10:08:41.711583',
#      'duration': 0.010018,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:41.703409Z',
#      'iopub.execute_input': '2024-10-15T10:08:41.703661Z',
#      'shell.execute_reply': '2024-10-15T10:08:41.708037Z',
#      'iopub.status.idle': '2024-10-15T10:08:41.708994Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:41.711722',
#      'end_time': '2024-10-15T10:08:41.791627',
#      'duration': 0.079905,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:41.713111Z',
#      'iopub.execute_input': '2024-10-15T10:08:41.713880Z',
#      'shell.execute_reply': '2024-10-15T10:08:41.788566Z',
#      'iopub.status.idle': '2024-10-15T10:08:41.789264Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:41.791774',
#      'end_time': '2024-10-15T10:08:41.792035',
#      'duration': 0.000261,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:41.792169',
#      'end_time': '2024-10-15T10:08:42.404086',
#      'duration': 0.611917,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:41.793605Z',
#      'iopub.execute_input': '2024-10-15T10:08:41.793835Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.401627Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.402433Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.404886',
#      'end_time': '2024-10-15T10:08:42.412290',
#      'duration': 0.007404,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:42.406047Z',
#      'iopub.execute_input': '2024-10-15T10:08:42.406484Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.409741Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.410708Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.412504',
#      'end_time': '2024-10-15T10:08:42.432682',
#      'duration': 0.020178,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:42.413609Z',
#      'iopub.execute_input': '2024-10-15T10:08:42.413912Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.429092Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.429895Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.432890',
#      'end_time': '2024-10-15T10:08:42.442448',
#      'duration': 0.009558,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:42.434071Z',
#      'iopub.execute_input': '2024-10-15T10:08:42.434428Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.439483Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.438472Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.442684',
#      'end_time': '2024-10-15T10:08:42.442955',
#      'duration': 0.000271,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.443152',
#      'end_time': '2024-10-15T10:08:42.471516',
#      'duration': 0.028364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:42.444674Z',
#      'iopub.execute_input': '2024-10-15T10:08:42.445122Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.468563Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.469168Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:42.471676',
#      'end_time': '2024-10-15T10:08:42.524595',
#      'duration': 0.052919,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:42.472751Z',
#      'iopub.execute_input': '2024-10-15T10:08:42.472982Z',
#      'shell.execute_reply': '2024-10-15T10:08:42.521683Z',
#      'iopub.status.idle': '2024-10-15T10:08:42.522389Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N40f7f0967e1e446c8dab2ace2f0c5755 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-15T10:08:21.802148',
#    'end_time': '2024-10-15T10:08:42.849881',
#    'duration': 21.047733,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:20<00:00,  1.19s/cell]
# {'cells': [{'id': 'a0a91a7e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:48.923445',
#      'end_time': '2024-10-15T10:08:48.941368',
#      'duration': 0.017923,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:48.925502Z',
#      'iopub.execute_input': '2024-10-15T10:08:48.925990Z',
#      'iopub.status.idle': '2024-10-15T10:08:48.938123Z',
#      'shell.execute_reply': '2024-10-15T10:08:48.936881Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:08:48.942617',
#      'end_time': '2024-10-15T10:09:02.719880',
#      'duration': 13.777263,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:08:48.946759Z',
#      'iopub.execute_input': '2024-10-15T10:08:48.947594Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.718430Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.717571Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.720610',
#      'end_time': '2024-10-15T10:09:02.728917',
#      'duration': 0.008307,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.722246Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.722568Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.727407Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.726641Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.729092',
#      'end_time': '2024-10-15T10:09:02.818663',
#      'duration': 0.089571,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.729976Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.730177Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.816440Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.817148Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.818803',
#      'end_time': '2024-10-15T10:09:02.825538',
#      'duration': 0.006735,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.819612Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.819810Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.823313Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.824038Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.826413',
#      'end_time': '2024-10-15T10:09:02.838502',
#      'duration': 0.012089,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.827979Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.828402Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.835979Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.836734Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.838706',
#      'end_time': '2024-10-15T10:09:02.838942',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.839124',
#      'end_time': '2024-10-15T10:09:02.839336',
#      'duration': 0.000212,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.839510',
#      'end_time': '2024-10-15T10:09:02.869724',
#      'duration': 0.030214,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.840675Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.840970Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.867516Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.868176Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.869905',
#      'end_time': '2024-10-15T10:09:02.870139',
#      'duration': 0.000234,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.870308',
#      'end_time': '2024-10-15T10:09:02.878260',
#      'duration': 0.007952,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.871443Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.871736Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.876139Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.875551Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.878389',
#      'end_time': '2024-10-15T10:09:02.884883',
#      'duration': 0.006494,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.879406Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.879611Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.882801Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.882191Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.885015',
#      'end_time': '2024-10-15T10:09:02.892424',
#      'duration': 0.007409,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.886026Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.886215Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.890306Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.889457Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.892618',
#      'end_time': '2024-10-15T10:09:02.899790',
#      'duration': 0.007172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.893738Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.893942Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.897639Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.896822Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.899923',
#      'end_time': '2024-10-15T10:09:02.906030',
#      'duration': 0.006107,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.900897Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.901138Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.903324Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.904067Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.906253',
#      'end_time': '2024-10-15T10:09:02.906482',
#      'duration': 0.000229,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:02.906707',
#      'end_time': '2024-10-15T10:09:02.949990',
#      'duration': 0.043283,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:02.907703Z',
#      'iopub.execute_input': '2024-10-15T10:09:02.907916Z',
#      'iopub.status.idle': '2024-10-15T10:09:02.947803Z',
#      'shell.execute_reply': '2024-10-15T10:09:02.947032Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N265148a58bdc4e78b974dba2f4058a37 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-15T10:08:42.901504',
#    'end_time': '2024-10-15T10:09:03.170720',
#    'duration': 20.269216,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:14<00:00,  1.16cell/s]
# {'cells': [{'id': 'b6d32d24',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:09.069226',
#      'end_time': '2024-10-15T10:09:09.086274',
#      'duration': 0.017048,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:09.071851Z',
#      'iopub.execute_input': '2024-10-15T10:09:09.072261Z',
#      'shell.execute_reply': '2024-10-15T10:09:09.083402Z',
#      'iopub.status.idle': '2024-10-15T10:09:09.083988Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:09.087169',
#      'end_time': '2024-10-15T10:09:17.369567',
#      'duration': 8.282398,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:09.088653Z',
#      'iopub.execute_input': '2024-10-15T10:09:09.089072Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.367398Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.366270Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.370367',
#      'end_time': '2024-10-15T10:09:17.379336',
#      'duration': 0.008969,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.371941Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.372328Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.376497Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.377444Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.379498',
#      'end_time': '2024-10-15T10:09:17.449636',
#      'duration': 0.070138,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.380546Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.381215Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.447176Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.447872Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.449880',
#      'end_time': '2024-10-15T10:09:17.457941',
#      'duration': 0.008061,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.451023Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.451396Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.455684Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.454830Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.458088',
#      'end_time': '2024-10-15T10:09:17.473527',
#      'duration': 0.015439,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.459719Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.460479Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.470500Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.471401Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.474265',
#      'end_time': '2024-10-15T10:09:17.474885',
#      'duration': 0.00062,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.475018',
#      'end_time': '2024-10-15T10:09:17.475196',
#      'duration': 0.000178,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.475314',
#      'end_time': '2024-10-15T10:09:17.502325',
#      'duration': 0.027011,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.476539Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.477191Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.499426Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.500121Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.502467',
#      'end_time': '2024-10-15T10:09:17.502700',
#      'duration': 0.000233,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.502830',
#      'end_time': '2024-10-15T10:09:17.510447',
#      'duration': 0.007617,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.503820Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.504039Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.507501Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.508179Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.510698',
#      'end_time': '2024-10-15T10:09:17.516523',
#      'duration': 0.005825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.511717Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.511931Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.514460Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.514987Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.516663',
#      'end_time': '2024-10-15T10:09:17.523514',
#      'duration': 0.006851,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.517556Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.517760Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.521549Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.520813Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.523660',
#      'end_time': '2024-10-15T10:09:17.529763',
#      'duration': 0.006103,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.524598Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.524804Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.528267Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.527592Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.529898',
#      'end_time': '2024-10-15T10:09:17.536075',
#      'duration': 0.006177,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.530777Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.530976Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.533333Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.533986Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.536223',
#      'end_time': '2024-10-15T10:09:17.536462',
#      'duration': 0.000239,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-15T10:09:17.536591',
#      'end_time': '2024-10-15T10:09:17.595624',
#      'duration': 0.059033,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-15T10:09:17.537864Z',
#      'iopub.execute_input': '2024-10-15T10:09:17.538182Z',
#      'shell.execute_reply': '2024-10-15T10:09:17.592793Z',
#      'iopub.status.idle': '2024-10-15T10:09:17.593605Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5db7a0855ad5445eb13bf03588355df3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-15T10:09:03.216269',
#    'end_time': '2024-10-15T10:09:17.818155',
#    'duration': 14.601886,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:13<00:00,  1.14cell/s]
# ---------------------------------------------------------------------------
# PapermillExecutionError                   Traceback (most recent call last)
# Cell In[61], line 2
#       1 for dp in datasets:
# ----> 2     pm.execute_notebook(
#       3         os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
#       4             'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
#       5             'dp': dp
#       6         }
#       7     )
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/papermill/execute.py:131, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     116         nb = papermill_engines.execute_notebook_with_engine(
#     117             engine_name,
#     118             nb,
#    (...)
#     127             **engine_kwargs,
#     128         )
#     130     # Check for errors first (it saves on error before raising)
# --> 131     raise_for_execution_errors(nb, output_path)
#     133 # Write final output in case the engine didn't write it on cell completion.
#     134 write_ipynb(nb, output_path)
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/papermill/execute.py:251, in raise_for_execution_errors(nb, output_path)
#     248 nb.cells.insert(0, error_msg_cell)
#     250 write_ipynb(nb, output_path)
# --> 251 raise error
#
# PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [11]":
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 DCParser(dp, contract).parse_contracts()
#
# Cell In[10], line 165, in DCParser.parse_contracts(self)
#     162 policies, mappings = self._read_contracts()
#     164 for policy in policies:
# --> 165     pc = self._parse_policy(policy)
#     166     self.g = self.g + pc
#     168 self.g.serialize(destination=os.path.join(base_dir, "../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl"), format="turtle")
#
# Cell In[10], line 136, in DCParser._parse_policy(self, policy)
#     129 """
#     130 Parse the policy to intermediate representation
#     131 :param policy: policy to parse
#     132 :return: None
#     133 """
#     135 # create policy checker graph
# --> 136 pc = PolicyChecker(policy, self.dp)
#     138 # Check Data Dependencies
#     139 last_op, pc = self._initOP(policy, pc)
#
# Cell In[9], line 13, in PolicyChecker.__init__(self, p, dp, *args, **kwargs)
#      11 self.add((self.URI, RDF.type, tbox.PolicyChecker))
#      12 self.add((self.URI, tbox.accordingTo, p))
# ---> 13 self.add((self.URI, tbox.validates, dp))
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/rdflib/graph.py:532, in Graph.add(self, triple)
#     530 assert isinstance(s, Node), "Subject %s must be an rdflib term" % (s,)
#     531 assert isinstance(p, Node), "Predicate %s must be an rdflib term" % (p,)
# --> 532 assert isinstance(o, Node), "Object %s must be an rdflib term" % (o,)
#     533 self.__store.add((s, p, o), self, quoted=False)
#     534 return self
#
# AssertionError: Object UPENN-GBM_clinical_info_v21csv must be an rdflib term

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0fba0713-bf98-4a2e-8113-1c13e568a89a
# Executing: 100%|██████████| 17/17 [00:12<00:00,  1.32cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# cf406614-ec5f-43d4-9ddd-be787bde213b
# Executing: 100%|██████████| 17/17 [00:12<00:00,  1.38cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c4114c70-b11b-4d33-b7b0-b5c4972b8881
# Executing: 100%|██████████| 17/17 [00:13<00:00,  1.24cell/s]
