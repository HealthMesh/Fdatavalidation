# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:04<00:00,  3.08cell/s]
# {'cells': [{'id': 'c75af3da',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.213687',
#      'end_time': '2024-09-12T13:21:59.248593',
#      'duration': 0.034906,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.215682Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.216680Z',
#      'iopub.status.idle': '2024-09-12T13:21:59.245602Z',
#      'shell.execute_reply': '2024-09-12T13:21:59.244606Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.249591',
#      'end_time': '2024-09-12T13:21:59.264553',
#      'duration': 0.014962,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.251586Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.252585Z',
#      'iopub.status.idle': '2024-09-12T13:21:59.261559Z',
#      'shell.execute_reply': '2024-09-12T13:21:59.260596Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.264553',
#      'end_time': '2024-09-12T13:21:59.264553',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.264553',
#      'end_time': '2024-09-12T13:21:59.496073',
#      'duration': 0.23152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.266547Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.267544Z',
#      'iopub.status.idle': '2024-09-12T13:21:59.493083Z',
#      'shell.execute_reply': '2024-09-12T13:21:59.492084Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.497072',
#      'end_time': '2024-09-12T13:21:59.540954',
#      'duration': 0.043882,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.499065Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.500064Z',
#      'iopub.status.idle': '2024-09-12T13:21:59.538960Z',
#      'shell.execute_reply': '2024-09-12T13:21:59.537962Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.540954',
#      'end_time': '2024-09-12T13:21:59.540954',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.540954',
#      'end_time': '2024-09-12T13:21:59.555914',
#      'duration': 0.01496,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.541952Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.542949Z',
#      'iopub.status.idle': '2024-09-12T13:21:59.553921Z',
#      'shell.execute_reply': '2024-09-12T13:21:59.552925Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:21:59.555914',
#      'end_time': '2024-09-12T13:22:01.893013',
#      'duration': 2.337099,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:21:59.557909Z',
#      'iopub.execute_input': '2024-09-12T13:21:59.557909Z',
#      'shell.execute_reply': '2024-09-12T13:22:01.890978Z',
#      'iopub.status.idle': '2024-09-12T13:22:01.890978Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (0.6.2)\nRequirement already satisfied: rdflib>=5.0.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib_jsonld) (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.894031',
#      'end_time': '2024-09-12T13:22:01.894031',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.895030',
#      'end_time': '2024-09-12T13:22:01.907967',
#      'duration': 0.012937,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:01.896001Z',
#      'iopub.execute_input': '2024-09-12T13:22:01.896001Z',
#      'shell.execute_reply': '2024-09-12T13:22:01.906134Z',
#      'iopub.status.idle': '2024-09-12T13:22:01.906969Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.908964',
#      'end_time': '2024-09-12T13:22:01.924121',
#      'duration': 0.015157,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:01.909992Z',
#      'iopub.execute_input': '2024-09-12T13:22:01.909992Z',
#      'shell.execute_reply': '2024-09-12T13:22:01.922158Z',
#      'iopub.status.idle': '2024-09-12T13:22:01.923122Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.925117',
#      'end_time': '2024-09-12T13:22:01.925117',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.925117',
#      'end_time': '2024-09-12T13:22:01.940943',
#      'duration': 0.015826,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:01.926113Z',
#      'iopub.execute_input': '2024-09-12T13:22:01.927110Z',
#      'iopub.status.idle': '2024-09-12T13:22:01.939078Z',
#      'shell.execute_reply': '2024-09-12T13:22:01.938091Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.940943',
#      'end_time': '2024-09-12T13:22:01.940943',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:01.940943',
#      'end_time': '2024-09-12T13:22:01.971286',
#      'duration': 0.030343,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:01.941944Z',
#      'iopub.execute_input': '2024-09-12T13:22:01.941944Z',
#      'shell.execute_reply': '2024-09-12T13:22:01.969292Z',
#      'iopub.status.idle': '2024-09-12T13:22:01.969292Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N4e3cd58dc1404d6e9acf16dbb3b4fe53 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-12T13:21:57.333278',
#    'end_time': '2024-09-12T13:22:02.207617',
#    'duration': 4.874339,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"C:\Users\Usuario\PycharmProjects\Fdatavalidation\DataProductLayer\DataProduct\Data\Explotation\UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:10<00:00,  1.18cell/s]
# {'cells': [{'id': '4d1cbfd7',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:03.746019',
#      'end_time': '2024-09-12T13:22:03.779308',
#      'duration': 0.033289,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:03.750012Z',
#      'iopub.execute_input': '2024-09-12T13:22:03.752006Z',
#      'iopub.status.idle': '2024-09-12T13:22:03.777315Z',
#      'shell.execute_reply': '2024-09-12T13:22:03.776317Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\nfile_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataProductLayer\\\\DataProduct\\\\Data\\\\Explotation\\\\UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:03.780307',
#      'end_time': '2024-09-12T13:22:11.031939',
#      'duration': 7.251632,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:03.781304Z',
#      'iopub.execute_input': '2024-09-12T13:22:03.782302Z',
#      'shell.execute_reply': '2024-09-12T13:22:11.021973Z',
#      'iopub.status.idle': '2024-09-12T13:22:11.024951Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.2.2)\nRequirement already satisfied: numpy>=1.22.4 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.1.0)\nRequirement already satisfied: python-dateutil>=2.8.2 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.9.0.post0)\nRequirement already satisfied: pytz>=2020.1 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: tzdata>=2022.7 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: six>=1.5 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.4.4)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:11.034937',
#      'end_time': '2024-09-12T13:22:11.055905',
#      'duration': 0.020968,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:11.039915Z',
#      'iopub.execute_input': '2024-09-12T13:22:11.040947Z',
#      'shell.execute_reply': '2024-09-12T13:22:11.051908Z',
#      'iopub.status.idle': '2024-09-12T13:22:11.052910Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:11.055905',
#      'end_time': '2024-09-12T13:22:11.214302',
#      'duration': 0.158397,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:11.057918Z',
#      'iopub.execute_input': '2024-09-12T13:22:11.057918Z',
#      'shell.execute_reply': '2024-09-12T13:22:11.208315Z',
#      'iopub.status.idle': '2024-09-12T13:22:11.210313Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:11.216297',
#      'end_time': '2024-09-12T13:22:11.217289',
#      'duration': 0.000992,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:11.218291',
#      'end_time': '2024-09-12T13:22:11.981910',
#      'duration': 0.763619,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:11.221281Z',
#      'iopub.execute_input': '2024-09-12T13:22:11.221281Z',
#      'shell.execute_reply': '2024-09-12T13:22:11.975014Z',
#      'iopub.status.idle': '2024-09-12T13:22:11.977923Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, abox.Tabular))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[attribute],  ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:11.983905',
#      'end_time': '2024-09-12T13:22:12.007529',
#      'duration': 0.023624,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:11.987891Z',
#      'iopub.execute_input': '2024-09-12T13:22:11.988889Z',
#      'shell.execute_reply': '2024-09-12T13:22:12.005533Z',
#      'iopub.status.idle': '2024-09-12T13:22:12.006532Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:12.008525',
#      'end_time': '2024-09-12T13:22:12.045231',
#      'duration': 0.036706,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:12.009522Z',
#      'iopub.execute_input': '2024-09-12T13:22:12.009522Z',
#      'shell.execute_reply': '2024-09-12T13:22:12.036259Z',
#      'iopub.status.idle': '2024-09-12T13:22:12.039256Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:12.045231',
#      'end_time': '2024-09-12T13:22:12.078259',
#      'duration': 0.033028,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:12.048269Z',
#      'iopub.execute_input': '2024-09-12T13:22:12.048269Z',
#      'iopub.status.idle': '2024-09-12T13:22:12.071235Z',
#      'shell.execute_reply': '2024-09-12T13:22:12.068335Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:12.079255',
#      'end_time': '2024-09-12T13:22:12.079255',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:12.080254',
#      'end_time': '2024-09-12T13:22:12.122196',
#      'duration': 0.041942,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:12.082243Z',
#      'iopub.execute_input': '2024-09-12T13:22:12.084200Z',
#      'shell.execute_reply': '2024-09-12T13:22:12.115219Z',
#      'iopub.status.idle': '2024-09-12T13:22:12.118227Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:12.123878',
#      'end_time': '2024-09-12T13:22:12.165728',
#      'duration': 0.04185,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:12.125835Z',
#      'iopub.execute_input': '2024-09-12T13:22:12.126868Z',
#      'shell.execute_reply': '2024-09-12T13:22:12.162809Z',
#      'iopub.status.idle': '2024-09-12T13:22:12.163764Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7898080e3b7f4281a8d4f46312146bda (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration',
#     'file_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataProductLayer\\DataProduct\\Data\\Explotation\\UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-12T13:22:02.331132',
#    'end_time': '2024-09-12T13:22:12.506248',
#    'duration': 10.175116,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"C:\Users\Usuario\PycharmProjects\Fdatavalidation\DataProductLayer\DataProduct2\Data\0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:08<00:00,  1.45cell/s]
# {'cells': [{'id': '3509ca30',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:13.896545',
#      'end_time': '2024-09-12T13:22:13.913854',
#      'duration': 0.017309,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:13.898328Z',
#      'iopub.execute_input': '2024-09-12T13:22:13.898328Z',
#      'shell.execute_reply': '2024-09-12T13:22:13.911856Z',
#      'iopub.status.idle': '2024-09-12T13:22:13.912858Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\nfile_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataProductLayer\\\\DataProduct2\\\\Data\\\\0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:13.914852',
#      'end_time': '2024-09-12T13:22:19.445363',
#      'duration': 5.530511,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:13.916847Z',
#      'iopub.execute_input': '2024-09-12T13:22:13.916847Z',
#      'shell.execute_reply': '2024-09-12T13:22:19.440462Z',
#      'iopub.status.idle': '2024-09-12T13:22:19.441410Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.2.2)\nRequirement already satisfied: numpy>=1.22.4 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.1.0)\nRequirement already satisfied: python-dateutil>=2.8.2 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.9.0.post0)\nRequirement already satisfied: pytz>=2020.1 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: tzdata>=2022.7 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: six>=1.5 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.4.4)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:19.446407',
#      'end_time': '2024-09-12T13:22:19.460323',
#      'duration': 0.013916,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:19.449356Z',
#      'iopub.execute_input': '2024-09-12T13:22:19.450358Z',
#      'iopub.status.idle': '2024-09-12T13:22:19.457333Z',
#      'shell.execute_reply': '2024-09-12T13:22:19.456452Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:19.460323',
#      'end_time': '2024-09-12T13:22:19.585586',
#      'duration': 0.125263,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:19.462350Z',
#      'iopub.execute_input': '2024-09-12T13:22:19.462350Z',
#      'shell.execute_reply': '2024-09-12T13:22:19.582568Z',
#      'iopub.status.idle': '2024-09-12T13:22:19.583564Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:19.586557',
#      'end_time': '2024-09-12T13:22:19.586557',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:19.586557',
#      'end_time': '2024-09-12T13:22:20.357155',
#      'duration': 0.770598,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:19.588553Z',
#      'iopub.execute_input': '2024-09-12T13:22:19.588553Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.354136Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.355135Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, abox.Tabular))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[attribute],  ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.358155',
#      'end_time': '2024-09-12T13:22:20.372229',
#      'duration': 0.014074,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:20.359150Z',
#      'iopub.execute_input': '2024-09-12T13:22:20.360148Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.370231Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.369313Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.372229',
#      'end_time': '2024-09-12T13:22:20.403318',
#      'duration': 0.031089,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:20.373225Z',
#      'iopub.execute_input': '2024-09-12T13:22:20.373225Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.400413Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.401321Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.403318',
#      'end_time': '2024-09-12T13:22:20.419303',
#      'duration': 0.015985,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:20.404314Z',
#      'iopub.execute_input': '2024-09-12T13:22:20.405310Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.417309Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.416406Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.419303',
#      'end_time': '2024-09-12T13:22:20.419303',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.419303',
#      'end_time': '2024-09-12T13:22:20.467114',
#      'duration': 0.047811,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:20.420301Z',
#      'iopub.execute_input': '2024-09-12T13:22:20.421297Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.464124Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.465118Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:20.468136',
#      'end_time': '2024-09-12T13:22:20.531629',
#      'duration': 0.063493,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:20.470106Z',
#      'iopub.execute_input': '2024-09-12T13:22:20.470106Z',
#      'iopub.status.idle': '2024-09-12T13:22:20.529661Z',
#      'shell.execute_reply': '2024-09-12T13:22:20.527745Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N528bb92164a74a73bde868e7211e327a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration',
#     'file_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataProductLayer\\DataProduct2\\Data\\0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-12T13:22:12.587044',
#    'end_time': '2024-09-12T13:22:20.876203',
#    'duration': 8.289159,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:02<00:00,  6.54cell/s]
# {'cells': [{'id': 'a19ce437',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:22.774635',
#      'end_time': '2024-09-12T13:22:22.793543',
#      'duration': 0.018908,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:22.777595Z',
#      'iopub.execute_input': '2024-09-12T13:22:22.777595Z',
#      'iopub.status.idle': '2024-09-12T13:22:22.791549Z',
#      'shell.execute_reply': '2024-09-12T13:22:22.790739Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\ndp_meta_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:22.793543',
#      'end_time': '2024-09-12T13:22:22.934902',
#      'duration': 0.141359,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:22.795539Z',
#      'iopub.execute_input': '2024-09-12T13:22:22.795539Z',
#      'iopub.status.idle': '2024-09-12T13:22:22.932875Z',
#      'shell.execute_reply': '2024-09-12T13:22:22.931873Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:22.935866',
#      'end_time': '2024-09-12T13:22:22.949719',
#      'duration': 0.013853,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:22.936865Z',
#      'iopub.execute_input': '2024-09-12T13:22:22.937862Z',
#      'iopub.status.idle': '2024-09-12T13:22:22.947692Z',
#      'shell.execute_reply': '2024-09-12T13:22:22.946893Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:22.949719',
#      'end_time': '2024-09-12T13:22:23.057752',
#      'duration': 0.108033,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:22.950686Z',
#      'iopub.execute_input': '2024-09-12T13:22:22.950686Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.055761Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.055761Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.058749',
#      'end_time': '2024-09-12T13:22:23.078846',
#      'duration': 0.020097,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.059746Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.059746Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.073822Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.070899Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.078846',
#      'end_time': '2024-09-12T13:22:23.105757',
#      'duration': 0.026911,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.081831Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.082792Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.102735Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.103728Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.105757',
#      'end_time': '2024-09-12T13:22:23.105757',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.105757',
#      'end_time': '2024-09-12T13:22:23.105757',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.106720',
#      'end_time': '2024-09-12T13:22:23.155066',
#      'duration': 0.048346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.107718Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.107718Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.149084Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.150117Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.155066',
#      'end_time': '2024-09-12T13:22:23.155066',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.156062',
#      'end_time': '2024-09-12T13:22:23.168066',
#      'duration': 0.012004,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.157065Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.158093Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.165040Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.166038Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.168066',
#      'end_time': '2024-09-12T13:22:23.189888',
#      'duration': 0.021822,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.170028Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.170028Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.184900Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.180994Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.189888',
#      'end_time': '2024-09-12T13:22:23.198861',
#      'duration': 0.008973,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.191882Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.192875Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.196876Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.197863Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.199858',
#      'end_time': '2024-09-12T13:22:23.222147',
#      'duration': 0.022289,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.200854Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.200854Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.212114Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.215124Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.223147',
#      'end_time': '2024-09-12T13:22:23.253392',
#      'duration': 0.030245,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.225099Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.226101Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.243505Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.247420Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.253392',
#      'end_time': '2024-09-12T13:22:23.254389',
#      'duration': 0.000997,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:23.254389',
#      'end_time': '2024-09-12T13:22:23.331272',
#      'duration': 0.076883,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:23.256435Z',
#      'iopub.execute_input': '2024-09-12T13:22:23.257430Z',
#      'iopub.status.idle': '2024-09-12T13:22:23.326289Z',
#      'shell.execute_reply': '2024-09-12T13:22:23.322385Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nfb8280d168a7492aabad6f7e01b21c2b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration',
#     'dp_meta_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-12T13:22:20.973667',
#    'end_time': '2024-09-12T13:22:23.573672',
#    'duration': 2.600005,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:02<00:00,  7.35cell/s]
# {'cells': [{'id': '13fbb98e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.140590',
#      'end_time': '2024-09-12T13:22:25.159498',
#      'duration': 0.018908,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.141546Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.141546Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.156506Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.157504Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\ndp_meta_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.160495',
#      'end_time': '2024-09-12T13:22:25.303486',
#      'duration': 0.142991,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.161493Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.162490Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.300494Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.298504Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.304485',
#      'end_time': '2024-09-12T13:22:25.323437',
#      'duration': 0.018952,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.306478Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.306478Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.313461Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.318448Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.323437',
#      'end_time': '2024-09-12T13:22:25.461115',
#      'duration': 0.137678,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.326426Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.327423Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.456123Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.453138Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.463108',
#      'end_time': '2024-09-12T13:22:25.488115',
#      'duration': 0.025007,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.466096Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.467095Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.485120Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.486118Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.488115',
#      'end_time': '2024-09-12T13:22:25.503071',
#      'duration': 0.014956,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.489111Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.490108Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.501076Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.501076Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.503071',
#      'end_time': '2024-09-12T13:22:25.504069',
#      'duration': 0.000998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.504069',
#      'end_time': '2024-09-12T13:22:25.504069',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.504069',
#      'end_time': '2024-09-12T13:22:25.556063',
#      'duration': 0.051994,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.505065Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.506061Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.547074Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.551125Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.556063',
#      'end_time': '2024-09-12T13:22:25.556063',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.557093',
#      'end_time': '2024-09-12T13:22:25.580993',
#      'duration': 0.0239,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.559054Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.560085Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.578000Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.577035Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.583515',
#      'end_time': '2024-09-12T13:22:25.595521',
#      'duration': 0.012006,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.585508Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.585508Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.592558Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.593488Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.595521',
#      'end_time': '2024-09-12T13:22:25.617477',
#      'duration': 0.021956,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.596514Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.597476Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.611491Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.608579Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.618503',
#      'end_time': '2024-09-12T13:22:25.643404',
#      'duration': 0.024901,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.620466Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.621463Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.641406Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.640407Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.643404',
#      'end_time': '2024-09-12T13:22:25.657364',
#      'duration': 0.01396,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.644400Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.644400Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.655367Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.655367Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.657364',
#      'end_time': '2024-09-12T13:22:25.658398',
#      'duration': 0.001034,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-12T13:22:25.658398',
#      'end_time': '2024-09-12T13:22:25.727322',
#      'duration': 0.068924,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-12T13:22:25.659360Z',
#      'iopub.execute_input': '2024-09-12T13:22:25.660389Z',
#      'iopub.status.idle': '2024-09-12T13:22:25.722334Z',
#      'shell.execute_reply': '2024-09-12T13:22:25.719357Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N6e4cc3e63eb14daea7f47362efda3be9 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration',
#     'dp_meta_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-12T13:22:23.660441',
#    'end_time': '2024-09-12T13:22:25.972934',
#    'duration': 2.312493,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 16/16 [00:02<00:00,  6.32cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 16/16 [00:02<00:00,  6.45cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0f7c3897-b203-45d7-9ea7-daac3c3a66ae
# Executing: 100%|██████████| 18/18 [00:04<00:00,  4.28cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 16984674-e0f6-48fe-a67f-ee734015e128
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.47cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 17bfa842-99d9-484a-919f-cdc5d6ec545a
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.09cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 23e2720d-9416-4aef-8865-9ccf93a26b10
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.03cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0f7c3897-b203-45d7-9ea7-daac3c3a66ae
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.83cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 16984674-e0f6-48fe-a67f-ee734015e128
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.58cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 17bfa842-99d9-484a-919f-cdc5d6ec545a
# Executing: 100%|██████████| 18/18 [00:03<00:00,  5.89cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 23e2720d-9416-4aef-8865-9ccf93a26b10
# Executing: 100%|██████████| 18/18 [00:02<00:00,  6.05cell/s]
