# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 22/22 [00:09<00:00,  2.26cell/s]
# {'cells': [{'id': 'ea399e9c',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.156826',
#      'end_time': '2024-09-03T10:36:03.194123',
#      'duration': 0.037297,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.158822Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.159814Z',
#      'shell.execute_reply': '2024-09-03T10:36:03.187095Z',
#      'iopub.status.idle': '2024-09-03T10:36:03.189096Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:28:54.878181Z',
#      'start_time': '2024-09-03T09:28:54.843118Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.195642',
#      'end_time': '2024-09-03T10:36:03.224002',
#      'duration': 0.02836,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.198072Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.199152Z',
#      'shell.execute_reply': '2024-09-03T10:36:03.218337Z',
#      'iopub.status.idle': '2024-09-03T10:36:03.221014Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.224998',
#      'end_time': '2024-09-03T10:36:03.225145',
#      'duration': 0.000147,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:28:55.424700Z',
#      'start_time': '2024-09-03T09:28:54.915021Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.225145',
#      'end_time': '2024-09-03T10:36:03.619950',
#      'duration': 0.394805,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.228278Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.228989Z',
#      'shell.execute_reply': '2024-09-03T10:36:03.610128Z',
#      'iopub.status.idle': '2024-09-03T10:36:03.612962Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:28:56.268399Z',
#      'start_time': '2024-09-03T09:28:56.196593Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.622936',
#      'end_time': '2024-09-03T10:36:03.713691',
#      'duration': 0.090755,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.627385Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.629921Z',
#      'shell.execute_reply': '2024-09-03T10:36:03.703951Z',
#      'iopub.status.idle': '2024-09-03T10:36:03.706713Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:28:56.427113Z',
#      'start_time': '2024-09-03T09:28:56.407081Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.714695',
#      'end_time': '2024-09-03T10:36:03.715856',
#      'duration': 0.001161,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'outputs': [],
#    'execution_count': None},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.715856',
#      'end_time': '2024-09-03T10:36:03.716687',
#      'duration': 0.000831,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:28:56.568657Z',
#      'start_time': '2024-09-03T09:28:56.540881Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.717688',
#      'end_time': '2024-09-03T10:36:03.763643',
#      'duration': 0.045955,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.722670Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.724665Z',
#      'shell.execute_reply': '2024-09-03T10:36:03.750904Z',
#      'iopub.status.idle': '2024-09-03T10:36:03.754696Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:01.504260Z',
#      'start_time': '2024-09-03T09:28:56.714209Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:03.767552',
#      'end_time': '2024-09-03T10:36:08.758411',
#      'duration': 4.990859,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:03.774529Z',
#      'iopub.execute_input': '2024-09-03T10:36:03.776676Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.750432Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.753429Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (0.6.2)\nRequirement already satisfied: rdflib>=5.0.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib_jsonld) (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.759451',
#      'end_time': '2024-09-03T10:36:08.760404',
#      'duration': 0.000953,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.125916Z',
#      'start_time': '2024-09-03T09:29:02.105972Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.762399',
#      'end_time': '2024-09-03T10:36:08.787375',
#      'duration': 0.024976,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.766428Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.768383Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.780356Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.782348Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.329223Z',
#      'start_time': '2024-09-03T09:29:02.287614Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.788330',
#      'end_time': '2024-09-03T10:36:08.836201',
#      'duration': 0.047871,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.791322Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.792318Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.828223Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.831218Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.836201',
#      'end_time': '2024-09-03T10:36:08.837199',
#      'duration': 0.000998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.391987Z',
#      'start_time': '2024-09-03T09:29:02.365142Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.837199',
#      'end_time': '2024-09-03T10:36:08.866663',
#      'duration': 0.029464,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.841189Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.842230Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.859145Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.861134Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.516612Z',
#      'start_time': '2024-09-03T09:29:02.452023Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.869165',
#      'end_time': '2024-09-03T10:36:08.898044',
#      'duration': 0.028879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.873187Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.874101Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.893053Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.891184Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.898646',
#      'end_time': '2024-09-03T10:36:08.899036',
#      'duration': 0.00039,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.580440Z',
#      'start_time': '2024-09-03T09:29:02.570466Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.899036',
#      'end_time': '2024-09-03T10:36:08.929951',
#      'duration': 0.030915,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.902029Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.904018Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.923968Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.922129Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.628314Z',
#      'start_time': '2024-09-03T09:29:02.617340Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.930949',
#      'end_time': '2024-09-03T10:36:08.957874',
#      'duration': 0.026925,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.933940Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.933940Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.953885Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.952888Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.957874',
#      'end_time': '2024-09-03T10:36:08.958871',
#      'duration': 0.000997,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.675519Z',
#      'start_time': '2024-09-03T09:29:02.663554Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.958871',
#      'end_time': '2024-09-03T10:36:08.972835',
#      'duration': 0.013964,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.959930Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.960870Z',
#      'iopub.status.idle': '2024-09-03T10:36:08.969844Z',
#      'shell.execute_reply': '2024-09-03T10:36:08.968945Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'outputs': [],
#    'execution_count': 13},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.974829',
#      'end_time': '2024-09-03T10:36:08.975827',
#      'duration': 0.000998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:29:02.769080Z',
#      'start_time': '2024-09-03T09:29:02.713418Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:08.975827',
#      'end_time': '2024-09-03T10:36:09.024039',
#      'duration': 0.048212,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:08.977856Z',
#      'iopub.execute_input': '2024-09-03T10:36:08.978818Z',
#      'shell.execute_reply': '2024-09-03T10:36:09.015008Z',
#      'iopub.status.idle': '2024-09-03T10:36:09.017718Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb34a94661d534c0cad8e4d2c9daf4754 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-03T10:35:59.650025',
#    'end_time': '2024-09-03T10:36:09.396705',
#    'duration': 9.74668,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/federate_dp1.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 27/27 [00:13<00:00,  1.94cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-03T10:36:09.475770',
#    'end_time': '2024-09-03T10:36:23.391873',
#    'duration': 13.916103,
#    'exception': None}},
#  'cells': [{'id': 'c6f4f10f',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:12.910206',
#      'end_time': '2024-09-03T10:36:12.966112',
#      'duration': 0.055906,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:12.914196Z',
#      'iopub.execute_input': '2024-09-03T10:36:12.915251Z',
#      'shell.execute_reply': '2024-09-03T10:36:12.955127Z',
#      'iopub.status.idle': '2024-09-03T10:36:12.958079Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:25.608768Z',
#      'start_time': '2024-09-03T10:16:25.594806Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:12.969048',
#      'end_time': '2024-09-03T10:36:13.013932',
#      'duration': 0.044884,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:12.976841Z',
#      'iopub.execute_input': '2024-09-03T10:36:12.978025Z',
#      'shell.execute_reply': '2024-09-03T10:36:13.001959Z',
#      'iopub.status.idle': '2024-09-03T10:36:13.005951Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '9f894587'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:25.640723Z',
#      'start_time': '2024-09-03T10:16:25.618741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:13.013932',
#      'end_time': '2024-09-03T10:36:13.058929',
#      'duration': 0.044997,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:13.018992Z',
#      'iopub.execute_input': '2024-09-03T10:36:13.022171Z',
#      'iopub.status.idle': '2024-09-03T10:36:13.051827Z',
#      'shell.execute_reply': '2024-09-03T10:36:13.047836Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '5296b28a'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:34.318612Z',
#      'start_time': '2024-09-03T10:16:26.115427Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:13.059805',
#      'end_time': '2024-09-03T10:36:21.457871',
#      'duration': 8.398066,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:13.064794Z',
#      'iopub.execute_input': '2024-09-03T10:36:13.067787Z',
#      'shell.execute_reply': '2024-09-03T10:36:21.452232Z',
#      'iopub.status.idle': '2024-09-03T10:36:21.454089Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.2.2)\nRequirement already satisfied: numpy>=1.22.4 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.1.0)\nRequirement already satisfied: python-dateutil>=2.8.2 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.9.0.post0)\nRequirement already satisfied: pytz>=2020.1 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: tzdata>=2022.7 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: six>=1.5 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 4,
#    'id': 'cec0bfca'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:21.459810',
#      'end_time': '2024-09-03T10:36:21.459810',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'id': '362aabb5'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:34.473727Z',
#      'start_time': '2024-09-03T10:16:34.453254Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:21.460807',
#      'end_time': '2024-09-03T10:36:21.490728',
#      'duration': 0.029921,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:21.463867Z',
#      'iopub.execute_input': '2024-09-03T10:36:21.464798Z',
#      'shell.execute_reply': '2024-09-03T10:36:21.483794Z',
#      'iopub.status.idle': '2024-09-03T10:36:21.485745Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': '2d801b1d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:21.491725',
#      'end_time': '2024-09-03T10:36:21.491725',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '98541905'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:35.691653Z',
#      'start_time': '2024-09-03T10:16:34.572323Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:21.491725',
#      'end_time': '2024-09-03T10:36:22.393433',
#      'duration': 0.901708,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:21.493719Z',
#      'iopub.execute_input': '2024-09-03T10:36:21.494742Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.387408Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.389403Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': 'e163f676'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:35.800544Z',
#      'start_time': '2024-09-03T10:16:35.757477Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.394391',
#      'end_time': '2024-09-03T10:36:22.475183',
#      'duration': 0.080792,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.398381Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.399379Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.468196Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.465256Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': 'ea54058d'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.476227',
#      'end_time': '2024-09-03T10:36:22.477174',
#      'duration': 0.000947,
#      'status': 'completed'}},
#    'id': '0d554d93'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.477774',
#      'end_time': '2024-09-03T10:36:22.478615',
#      'duration': 0.000841,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '35ad3005'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:35.847586Z',
#      'start_time': '2024-09-03T10:16:35.837690Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.479167',
#      'end_time': '2024-09-03T10:36:22.508093',
#      'duration': 0.028926,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.484152Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.485207Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.500111Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.497172Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': '3c850a5c'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:35.923416Z',
#      'start_time': '2024-09-03T10:16:35.896489Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.514074',
#      'end_time': '2024-09-03T10:36:22.567683',
#      'duration': 0.053609,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.521054Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.524045Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.557995Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.560817Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '98236234'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.568676',
#      'end_time': '2024-09-03T10:36:22.569620',
#      'duration': 0.000944,
#      'status': 'completed'}},
#    'id': 'b39ad6e5'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:35.986287Z',
#      'start_time': '2024-09-03T10:16:35.958289Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.569620',
#      'end_time': '2024-09-03T10:36:22.614546',
#      'duration': 0.044926,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.574606Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.576656Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.604951Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.608622Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '99fa909b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.617628',
#      'end_time': '2024-09-03T10:36:22.618496',
#      'duration': 0.000868,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '095edfd1'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:36.096920Z',
#      'start_time': '2024-09-03T10:16:36.074976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.619537',
#      'end_time': '2024-09-03T10:36:22.677538',
#      'duration': 0.058001,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.624536Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.626521Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.667514Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.671347Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na1aa98cb502b49868872dab381268a94 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '0a6be37f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.678374',
#      'end_time': '2024-09-03T10:36:22.679383',
#      'duration': 0.001009,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'ac82e08d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:36.237346Z',
#      'start_time': '2024-09-03T10:16:36.212610Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.679383',
#      'end_time': '2024-09-03T10:36:22.724099',
#      'duration': 0.044716,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.683507Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.686308Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.714507Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.718133Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '65a13235'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.727469',
#      'end_time': '2024-09-03T10:36:22.729173',
#      'duration': 0.001704,
#      'status': 'completed'}},
#    'id': '0ef8c556'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.730045',
#      'end_time': '2024-09-03T10:36:22.732376',
#      'duration': 0.002331,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '37862fb9'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:36.347048Z',
#      'start_time': '2024-09-03T10:16:36.323404Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.733378',
#      'end_time': '2024-09-03T10:36:22.772289',
#      'duration': 0.038911,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.737073Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.739022Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.765336Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.761694Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '1105a5c0'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:36.440084Z',
#      'start_time': '2024-09-03T10:16:36.423112Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.772289',
#      'end_time': '2024-09-03T10:36:22.819164',
#      'duration': 0.046875,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.777229Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.780226Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.811420Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.808188Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na1aa98cb502b49868872dab381268a94 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'f8e2714d'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.820162',
#      'end_time': '2024-09-03T10:36:22.821110',
#      'duration': 0.000948,
#      'status': 'completed'}},
#    'id': 'a4a431dd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T10:16:36.534596Z',
#      'start_time': '2024-09-03T10:16:36.509615Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.821110',
#      'end_time': '2024-09-03T10:36:22.865366',
#      'duration': 0.044256,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.826132Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.829134Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.854648Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.858554Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na1aa98cb502b49868872dab381268a94 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': 'c62b3c54'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.869356',
#      'end_time': '2024-09-03T10:36:22.870393',
#      'duration': 0.001037,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '3c05d0a7'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-09-03T10:16:36.611799Z',
#      'start_time': '2024-09-03T10:16:36.586412Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:22.871351',
#      'end_time': '2024-09-03T10:36:22.927809',
#      'duration': 0.056458,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:22.874340Z',
#      'iopub.execute_input': '2024-09-03T10:36:22.876336Z',
#      'shell.execute_reply': '2024-09-03T10:36:22.918231Z',
#      'iopub.status.idle': '2024-09-03T10:36:22.921783Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na1aa98cb502b49868872dab381268a94 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': 'f22c8579'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/federate_dp2.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 28/28 [00:14<00:00,  1.88cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-03T10:36:23.786626',
#    'end_time': '2024-09-03T10:36:38.675921',
#    'duration': 14.889295,
#    'exception': None}},
#  'cells': [{'id': '6328cb26',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:27.791037',
#      'end_time': '2024-09-03T10:36:27.811872',
#      'duration': 0.020835,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:27.792852Z',
#      'iopub.execute_input': '2024-09-03T10:36:27.793789Z',
#      'shell.execute_reply': '2024-09-03T10:36:27.806778Z',
#      'iopub.status.idle': '2024-09-03T10:36:27.807736Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:27.813315',
#      'end_time': '2024-09-03T10:36:27.847632',
#      'duration': 0.034317,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:27.815714Z',
#      'iopub.execute_input': '2024-09-03T10:36:27.817709Z',
#      'shell.execute_reply': '2024-09-03T10:36:27.837657Z',
#      'iopub.status.idle': '2024-09-03T10:36:27.841062Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '3bceca2b'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:27.847632',
#      'end_time': '2024-09-03T10:36:35.844758',
#      'duration': 7.997126,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:27.851751Z',
#      'iopub.execute_input': '2024-09-03T10:36:27.852620Z',
#      'shell.execute_reply': '2024-09-03T10:36:35.836729Z',
#      'iopub.status.idle': '2024-09-03T10:36:35.838813Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.4.4)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'id': '360b9853'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:35.847702',
#      'end_time': '2024-09-03T10:36:35.878183',
#      'duration': 0.030481,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:35.850962Z',
#      'iopub.execute_input': '2024-09-03T10:36:35.853738Z',
#      'iopub.status.idle': '2024-09-03T10:36:35.870638Z',
#      'shell.execute_reply': '2024-09-03T10:36:35.867868Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '9cfe4cbc'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:35.878660',
#      'end_time': '2024-09-03T10:36:35.879756',
#      'duration': 0.001096,
#      'status': 'completed'}},
#    'id': '78d2d6f1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:35.879756',
#      'end_time': '2024-09-03T10:36:35.924494',
#      'duration': 0.044738,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:35.884601Z',
#      'iopub.execute_input': '2024-09-03T10:36:35.885599Z',
#      'shell.execute_reply': '2024-09-03T10:36:35.914721Z',
#      'iopub.status.idle': '2024-09-03T10:36:35.917511Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '7f6f80b1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:35.924494',
#      'end_time': '2024-09-03T10:36:35.925492',
#      'duration': 0.000998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'fd582158'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:35.926598',
#      'end_time': '2024-09-03T10:36:37.235650',
#      'duration': 1.309052,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:35.930530Z',
#      'iopub.execute_input': '2024-09-03T10:36:35.932470Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.230706Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.228936Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': 'db4b3f61'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.237698',
#      'end_time': '2024-09-03T10:36:37.798388',
#      'duration': 0.56069,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.240636Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.242683Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.794574Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.796496Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'cb532eb4'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.800150',
#      'end_time': '2024-09-03T10:36:37.830684',
#      'duration': 0.030534,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.801346Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.802396Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.826629Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.824938Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '12b4d29f'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.830684',
#      'end_time': '2024-09-03T10:36:37.831596',
#      'duration': 0.000912,
#      'status': 'completed'}},
#    'id': '7f600b85'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.831596',
#      'end_time': '2024-09-03T10:36:37.832813',
#      'duration': 0.001217,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'b2c18c0e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.832813',
#      'end_time': '2024-09-03T10:36:37.862500',
#      'duration': 0.029687,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.834925Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.836568Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.858515Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.855519Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': 'd7e0dd5d'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.862500',
#      'end_time': '2024-09-03T10:36:37.892785',
#      'duration': 0.030285,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.864497Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.865569Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.886747Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.888752Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': 'e25d69fd'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.892785',
#      'end_time': '2024-09-03T10:36:37.893794',
#      'duration': 0.001009,
#      'status': 'completed'}},
#    'id': '67bc2338'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.893794',
#      'end_time': '2024-09-03T10:36:37.924680',
#      'duration': 0.030886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.895769Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.896727Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.918873Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.920734Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': '73488280'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.926681',
#      'end_time': '2024-09-03T10:36:37.926681',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '96fe669a'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.927619',
#      'end_time': '2024-09-03T10:36:37.954978',
#      'duration': 0.027359,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.930611Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.931608Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.949135Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.951020Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c72c7370d93464e979d86d500b61058 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'b4d5a076'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.954978',
#      'end_time': '2024-09-03T10:36:37.956359',
#      'duration': 0.001381,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'a9628cc3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.956359',
#      'end_time': '2024-09-03T10:36:37.986886',
#      'duration': 0.030527,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.958966Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.959302Z',
#      'shell.execute_reply': '2024-09-03T10:36:37.980177Z',
#      'iopub.status.idle': '2024-09-03T10:36:37.981913Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '5515f7e5'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.986886',
#      'end_time': '2024-09-03T10:36:37.987883',
#      'duration': 0.000997,
#      'status': 'completed'}},
#    'id': 'c3a80dc2'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.987883',
#      'end_time': '2024-09-03T10:36:37.988832',
#      'duration': 0.000949,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '46a167e4'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:37.988832',
#      'end_time': '2024-09-03T10:36:38.021386',
#      'duration': 0.032554,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:37.991870Z',
#      'iopub.execute_input': '2024-09-03T10:36:37.992822Z',
#      'shell.execute_reply': '2024-09-03T10:36:38.011365Z',
#      'iopub.status.idle': '2024-09-03T10:36:38.014403Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'fcb644a2'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:38.021386',
#      'end_time': '2024-09-03T10:36:38.067579',
#      'duration': 0.046193,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:38.025339Z',
#      'iopub.execute_input': '2024-09-03T10:36:38.026459Z',
#      'iopub.status.idle': '2024-09-03T10:36:38.060482Z',
#      'shell.execute_reply': '2024-09-03T10:36:38.057669Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c72c7370d93464e979d86d500b61058 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '409da631'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:38.071887',
#      'end_time': '2024-09-03T10:36:38.072503',
#      'duration': 0.000616,
#      'status': 'completed'}},
#    'id': '60732562'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:38.073549',
#      'end_time': '2024-09-03T10:36:38.115376',
#      'duration': 0.041827,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:38.077435Z',
#      'iopub.execute_input': '2024-09-03T10:36:38.079472Z',
#      'shell.execute_reply': '2024-09-03T10:36:38.104806Z',
#      'iopub.status.idle': '2024-09-03T10:36:38.109394Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c72c7370d93464e979d86d500b61058 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '71f3c65e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:38.116388',
#      'end_time': '2024-09-03T10:36:38.117373',
#      'duration': 0.000985,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'd04d11f7'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:38.117373',
#      'end_time': '2024-09-03T10:36:38.194553',
#      'duration': 0.07718,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:38.121320Z',
#      'iopub.execute_input': '2024-09-03T10:36:38.123312Z',
#      'shell.execute_reply': '2024-09-03T10:36:38.183950Z',
#      'iopub.status.idle': '2024-09-03T10:36:38.187572Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8c72c7370d93464e979d86d500b61058 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '287eda19'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/integrateDP1.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 33/33 [00:08<00:00,  3.76cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-03T10:36:38.931110',
#    'end_time': '2024-09-03T10:36:47.707116',
#    'duration': 8.776006,
#    'exception': None}},
#  'cells': [{'id': '223764dd',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.721217',
#      'end_time': '2024-09-03T10:36:42.741095',
#      'duration': 0.019878,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:42.723315Z',
#      'iopub.execute_input': '2024-09-03T10:36:42.724140Z',
#      'shell.execute_reply': '2024-09-03T10:36:42.737102Z',
#      'iopub.status.idle': '2024-09-03T10:36:42.738066Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:28.529880Z',
#      'start_time': '2024-09-03T09:41:28.504839Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.742172',
#      'end_time': '2024-09-03T10:36:42.756051',
#      'duration': 0.013879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:42.744050Z',
#      'iopub.execute_input': '2024-09-03T10:36:42.745048Z',
#      'shell.execute_reply': '2024-09-03T10:36:42.753028Z',
#      'iopub.status.idle': '2024-09-03T10:36:42.754024Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'b73c814a'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:28.747944Z',
#      'start_time': '2024-09-03T09:41:28.539811Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.757052',
#      'end_time': '2024-09-03T10:36:42.928522',
#      'duration': 0.17147,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:42.758012Z',
#      'iopub.execute_input': '2024-09-03T10:36:42.759035Z',
#      'iopub.status.idle': '2024-09-03T10:36:42.924631Z',
#      'shell.execute_reply': '2024-09-03T10:36:42.922869Z'}},
#    'outputs': [],
#    'execution_count': 3,
#    'id': '81736c90'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:29.270126Z',
#      'start_time': '2024-09-03T09:41:29.259486Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.930919',
#      'end_time': '2024-09-03T10:36:42.960721',
#      'duration': 0.029802,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:42.934588Z',
#      'iopub.execute_input': '2024-09-03T10:36:42.935487Z',
#      'shell.execute_reply': '2024-09-03T10:36:42.952914Z',
#      'iopub.status.idle': '2024-09-03T10:36:42.955678Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 4,
#    'id': '93f37b36'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.960721',
#      'end_time': '2024-09-03T10:36:42.961910',
#      'duration': 0.001189,
#      'status': 'completed'}},
#    'id': '2f84860a'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:29.347994Z',
#      'start_time': '2024-09-03T09:41:29.306110Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:42.961910',
#      'end_time': '2024-09-03T10:36:43.056783',
#      'duration': 0.094873,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:42.964704Z',
#      'iopub.execute_input': '2024-09-03T10:36:42.965729Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.050699Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.047026Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'execution_count': 5,
#    'id': '6ae2c25a'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:29.536553Z',
#      'start_time': '2024-09-03T09:41:29.480958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.059995',
#      'end_time': '2024-09-03T10:36:43.121130',
#      'duration': 0.061135,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.065033Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.066656Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.109251Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.113111Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:db182904-d3dc-4c7a-94dd-f122954e8e7f .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\nab:db182904-d3dc-4c7a-94dd-f122954e8e7f a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration\\\\../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\n\n'}],
#    'execution_count': 6,
#    'id': '1d1d73bf'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.122086',
#      'end_time': '2024-09-03T10:36:43.123082',
#      'duration': 0.000996,
#      'status': 'completed'}},
#    'id': '562a33cf'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:29.738010Z',
#      'start_time': '2024-09-03T09:41:29.730126Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.123082',
#      'end_time': '2024-09-03T10:36:43.150008',
#      'duration': 0.026926,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.128069Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.130108Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.140477Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.144084Z'}},
#    'outputs': [],
#    'execution_count': 7,
#    'id': '29c8307c'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.151164',
#      'end_time': '2024-09-03T10:36:43.152044',
#      'duration': 0.00088,
#      'status': 'completed'}},
#    'id': 'dd7f49f1'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:29.863677Z',
#      'start_time': '2024-09-03T09:41:29.850707Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.152044',
#      'end_time': '2024-09-03T10:36:43.182959',
#      'duration': 0.030915,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.156992Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.159035Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.172125Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.176311Z'}},
#    'outputs': [],
#    'execution_count': 8,
#    'id': '1ce6be64'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.185915',
#      'end_time': '2024-09-03T10:36:43.187909',
#      'duration': 0.001994,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '8e5a7143'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:29.957423Z',
#      'start_time': '2024-09-03T09:41:29.941466Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.188907',
#      'end_time': '2024-09-03T10:36:43.234823',
#      'duration': 0.045916,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.192959Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.195888Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.224814Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.219970Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'execution_count': 9,
#    'id': 'e84f38ad'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.235991',
#      'end_time': '2024-09-03T10:36:43.237777',
#      'duration': 0.001786,
#      'status': 'completed'}},
#    'id': 'a3b4957a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:30.019255Z',
#      'start_time': '2024-09-03T09:41:29.998350Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.238777',
#      'end_time': '2024-09-03T10:36:43.277634',
#      'duration': 0.038857,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.243033Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.244765Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.270688Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.267020Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '96b8d2f9'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:30.098079Z',
#      'start_time': '2024-09-03T09:41:30.082088Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.278680',
#      'end_time': '2024-09-03T10:36:43.323860',
#      'duration': 0.04518,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.282785Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.284664Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.313878Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.317877Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '7cf593c2'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:30.160998Z',
#      'start_time': '2024-09-03T09:41:30.143268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.327848',
#      'end_time': '2024-09-03T10:36:43.385737',
#      'duration': 0.057889,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.332097Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.333872Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.379710Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.375960Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'execution_count': 12,
#    'id': 'a5379ff5'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.386951',
#      'end_time': '2024-09-03T10:36:43.387732',
#      'duration': 0.000781,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': 'b489f0c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:30.331642Z',
#      'start_time': '2024-09-03T09:41:30.293586Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.387732',
#      'end_time': '2024-09-03T10:36:43.432622',
#      'duration': 0.04489,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.392676Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.394670Z',
#      'shell.execute_reply': '2024-09-03T10:36:43.422962Z',
#      'iopub.status.idle': '2024-09-03T10:36:43.426240Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '51920eda'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:34.741459Z',
#      'start_time': '2024-09-03T09:41:30.589908Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:43.435191',
#      'end_time': '2024-09-03T10:36:47.021162',
#      'duration': 3.585971,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:43.439553Z',
#      'iopub.execute_input': '2024-09-03T10:36:43.441554Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.015363Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.017100Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (0.6.2)\nRequirement already satisfied: rdflib>=5.0.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib_jsonld) (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 14,
#    'id': 'cd9ffbe5'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:35.070892Z',
#      'start_time': '2024-09-03T09:41:35.048846Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.022117',
#      'end_time': '2024-09-03T10:36:47.052570',
#      'duration': 0.030453,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.024065Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.025158Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.048626Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.046775Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'outputs': [],
#    'execution_count': 15,
#    'id': '82204057'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.052570',
#      'end_time': '2024-09-03T10:36:47.053693',
#      'duration': 0.001123,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'bfc9fdd0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:35.212336Z',
#      'start_time': '2024-09-03T09:41:35.176540Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.055219',
#      'end_time': '2024-09-03T10:36:47.103744',
#      'duration': 0.048525,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.057671Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.059504Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.094939Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.097722Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'outputs': [],
#    'execution_count': 16,
#    'id': 'f85cec7a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.103744',
#      'end_time': '2024-09-03T10:36:47.105455',
#      'duration': 0.001711,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '89d970af'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:42:02.145028Z',
#      'start_time': '2024-09-03T09:42:02.104077Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.105867',
#      'end_time': '2024-09-03T10:36:47.153014',
#      'duration': 0.047147,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.109731Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.112753Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.142920Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.145969Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p2.json')\ng = add_jsonld_instances(contract, p2)",
#    'outputs': [],
#    'execution_count': 17,
#    'id': '0d3dcffb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.153014',
#      'end_time': '2024-09-03T10:36:47.153942',
#      'duration': 0.000928,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'ed021ead'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:36.187555900Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.157889',
#      'end_time': '2024-09-03T10:36:47.200334',
#      'duration': 0.042445,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.163038Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.165007Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.190568Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.194387Z'}},
#    'cell_type': 'code',
#    'source': "\np3 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p3.json')\ng = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': 'dbe58844'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.200334',
#      'end_time': '2024-09-03T10:36:47.201378',
#      'duration': 0.001044,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '2bc991b7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:36.287239900Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.202382',
#      'end_time': '2024-09-03T10:36:47.263334',
#      'duration': 0.060952,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.206318Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.208366Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.254190Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.257181Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N14263b37ae484942858c96179e60424f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': 'c8bb8bb1'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.266210',
#      'end_time': '2024-09-03T10:36:47.267268',
#      'duration': 0.001058,
#      'status': 'completed'}},
#    'id': '6ca96678'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-03T09:41:36.290172100Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.268205',
#      'end_time': '2024-09-03T10:36:47.373913',
#      'duration': 0.105708,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.273181Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.275134Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.363949Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.368042Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '650d53c6'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:36.292408Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.374868',
#      'end_time': '2024-09-03T10:36:47.420788',
#      'duration': 0.04592,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.379905Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.381849Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.410816Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.413767Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': 'ec9036fc'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-09-03T09:41:36.363971200Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:47.422738',
#      'end_time': '2024-09-03T10:36:47.462655',
#      'duration': 0.039917,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:47.425772Z',
#      'iopub.execute_input': '2024-09-03T10:36:47.427731Z',
#      'shell.execute_reply': '2024-09-03T10:36:47.458674Z',
#      'iopub.status.idle': '2024-09-03T10:36:47.459907Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc30f1331f3774cf3a3d26a58a6f4b78b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '31461eef'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/integrateDP2.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 32/32 [00:09<00:00,  3.25cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-03T10:36:48.249018',
#    'end_time': '2024-09-03T10:36:58.101227',
#    'duration': 9.852209,
#    'exception': None}},
#  'cells': [{'id': '905d7cd3',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.243401',
#      'end_time': '2024-09-03T10:36:52.300315',
#      'duration': 0.056914,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.247376Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.250321Z',
#      'shell.execute_reply': '2024-09-03T10:36:52.288684Z',
#      'iopub.status.idle': '2024-09-03T10:36:52.292206Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.302182',
#      'end_time': '2024-09-03T10:36:52.344069',
#      'duration': 0.041887,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.308451Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.311154Z',
#      'shell.execute_reply': '2024-09-03T10:36:52.334091Z',
#      'iopub.status.idle': '2024-09-03T10:36:52.337143Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '00728165'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.345117',
#      'end_time': '2024-09-03T10:36:52.798904',
#      'duration': 0.453787,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.348059Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.350051Z',
#      'shell.execute_reply': '2024-09-03T10:36:52.788882Z',
#      'iopub.status.idle': '2024-09-03T10:36:52.791919Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'ea6406d7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.802967',
#      'end_time': '2024-09-03T10:36:52.831770',
#      'duration': 0.028803,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.807869Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.810099Z',
#      'shell.execute_reply': '2024-09-03T10:36:52.821014Z',
#      'iopub.status.idle': '2024-09-03T10:36:52.824782Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '59034116'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.832763',
#      'end_time': '2024-09-03T10:36:52.833759',
#      'duration': 0.000996,
#      'status': 'completed'}},
#    'id': '94166358'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.833759',
#      'end_time': '2024-09-03T10:36:52.956473',
#      'duration': 0.122714,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.838791Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.839748Z',
#      'shell.execute_reply': '2024-09-03T10:36:52.946447Z',
#      'iopub.status.idle': '2024-09-03T10:36:52.949486Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '3fd5376a'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:52.959739',
#      'end_time': '2024-09-03T10:36:53.020312',
#      'duration': 0.060573,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:52.965406Z',
#      'iopub.execute_input': '2024-09-03T10:36:52.966402Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.010339Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.013611Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:0592f80b-4514-4d25-aa51-8175c9cf4ba2 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration\\\\../../DataProductLayer/DataProduct2/Data/0002.DCM" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "P ...
#    'id': '713cdc6e'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.021312',
#      'end_time': '2024-09-03T10:36:53.022250',
#      'duration': 0.000938,
#      'status': 'completed'}},
#    'id': '3c34dbc8'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.022250',
#      'end_time': '2024-09-03T10:36:53.051276',
#      'duration': 0.029026,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.027296Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.029418Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.040613Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.044244Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '2c77b56c'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.051276',
#      'end_time': '2024-09-03T10:36:53.052173',
#      'duration': 0.000897,
#      'status': 'completed'}},
#    'id': '8a115948'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.053284',
#      'end_time': '2024-09-03T10:36:53.081780',
#      'duration': 0.028496,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.057213Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.059209Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.071674Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.075116Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '9fa04aef'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.085085',
#      'end_time': '2024-09-03T10:36:53.086675',
#      'duration': 0.00159,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'ddc6e770'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.087683',
#      'end_time': '2024-09-03T10:36:53.129660',
#      'duration': 0.041977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.091680Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.093682Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.118644Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.122664Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '8b408936'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.130474',
#      'end_time': '2024-09-03T10:36:53.131475',
#      'duration': 0.001001,
#      'status': 'completed'}},
#    'id': '8fc431e0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.131475',
#      'end_time': '2024-09-03T10:36:53.176359',
#      'duration': 0.044884,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.136407Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.139509Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.166323Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.169326Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'e2aa272a'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.177359',
#      'end_time': '2024-09-03T10:36:53.240186',
#      'duration': 0.062827,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.181347Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.184288Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.232162Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.228221Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '07a48019'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.242588',
#      'end_time': '2024-09-03T10:36:53.246120',
#      'duration': 0.003532,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '3cd91e68'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.247162',
#      'end_time': '2024-09-03T10:36:53.302189',
#      'duration': 0.055027,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.255209Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.257095Z',
#      'shell.execute_reply': '2024-09-03T10:36:53.288628Z',
#      'iopub.status.idle': '2024-09-03T10:36:53.292266Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'e6eff0fa'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:53.302189',
#      'end_time': '2024-09-03T10:36:57.298127',
#      'duration': 3.995938,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:53.307234Z',
#      'iopub.execute_input': '2024-09-03T10:36:53.309228Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.292064Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.294054Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (0.6.2)\nRequirement already satisfied: rdflib>=5.0.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib_jsonld) (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'id': 'a8a57863'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.300587',
#      'end_time': '2024-09-03T10:36:57.334018',
#      'duration': 0.033431,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.303069Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.304032Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.323989Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.327451Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': '2f90006e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.335022',
#      'end_time': '2024-09-03T10:36:57.336334',
#      'duration': 0.001312,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '23a6991b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.336964',
#      'end_time': '2024-09-03T10:36:57.397292',
#      'duration': 0.060328,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.340548Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.343006Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.387477Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.390874Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '1f7651ac'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.398362',
#      'end_time': '2024-09-03T10:36:57.399244',
#      'duration': 0.000882,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'a332250d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.402343',
#      'end_time': '2024-09-03T10:36:57.429279',
#      'duration': 0.026936,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.408221Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.410440Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.418402Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.422182Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'e68b7936'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.429279',
#      'end_time': '2024-09-03T10:36:57.430216',
#      'duration': 0.000937,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '3a69518f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.431375',
#      'end_time': '2024-09-03T10:36:57.459690',
#      'duration': 0.028315,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.435209Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.436157Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.449657Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.453212Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': 'dbb57fae'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.460693',
#      'end_time': '2024-09-03T10:36:57.461637',
#      'duration': 0.000944,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '48d4e4e9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.461637',
#      'end_time': '2024-09-03T10:36:57.523334',
#      'duration': 0.061697,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.465794Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.467661Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.512311Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.515320Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N05a5e54f45ba44ff9ac60f97765ab111 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': '7f26c32c'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.525991',
#      'end_time': '2024-09-03T10:36:57.527281',
#      'duration': 0.00129,
#      'status': 'completed'}},
#    'id': 'd8b7fa38'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.528278',
#      'end_time': '2024-09-03T10:36:57.631046',
#      'duration': 0.102768,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.533305Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.534427Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.621371Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.624487Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': '1c28568b'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.631046',
#      'end_time': '2024-09-03T10:36:57.661321',
#      'duration': 0.030275,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.635041Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.635996Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.652285Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.655612Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '2e4a1463'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-03T10:36:57.664267',
#      'end_time': '2024-09-03T10:36:57.758207',
#      'duration': 0.09394,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-03T10:36:57.668315Z',
#      'iopub.execute_input': '2024-09-03T10:36:57.670247Z',
#      'shell.execute_reply': '2024-09-03T10:36:57.747334Z',
#      'iopub.status.idle': '2024-09-03T10:36:57.750695Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0897115c45fe470e8bd1d7d6a4e7fded (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': 'dcba1e74'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.64cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:06<00:00,  2.21cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 4deb89fd-8d3f-444a-bf30-c550921aea33
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.84cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# f02753f2-4129-479a-87bf-1e7de70a4bb3
# Executing: 100%|██████████| 18/18 [00:07<00:00,  2.26cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 031d7ed6-1fdb-467c-aae6-b4f5a6420cd0
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.82cell/s]
