# %%
import os

# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': 'bb890dd9',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.196745',
#      'end_time': '2024-06-08T14:59:41.228986',
#      'duration': 0.032241,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.202198Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.204524Z',
#      'iopub.status.idle': '2024-06-08T14:59:41.222957Z',
#      'shell.execute_reply': '2024-06-08T14:59:41.220340Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.231329',
#      'end_time': '2024-06-08T14:59:41.247494',
#      'duration': 0.016165,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.233930Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.234670Z',
#      'shell.execute_reply': '2024-06-08T14:59:41.241821Z',
#      'iopub.status.idle': '2024-06-08T14:59:41.243476Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.247951',
#      'end_time': '2024-06-08T14:59:41.248321',
#      'duration': 0.00037,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.248666',
#      'end_time': '2024-06-08T14:59:41.368628',
#      'duration': 0.119962,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.250237Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.250575Z',
#      'shell.execute_reply': '2024-06-08T14:59:41.366241Z',
#      'iopub.status.idle': '2024-06-08T14:59:41.366834Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.369410',
#      'end_time': '2024-06-08T14:59:41.392853',
#      'duration': 0.023443,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.370613Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.370839Z',
#      'shell.execute_reply': '2024-06-08T14:59:41.390234Z',
#      'iopub.status.idle': '2024-06-08T14:59:41.390778Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.393133',
#      'end_time': '2024-06-08T14:59:41.393325',
#      'duration': 0.000192,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.393594',
#      'end_time': '2024-06-08T14:59:41.393746',
#      'duration': 0.000152,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.393948',
#      'end_time': '2024-06-08T14:59:41.400379',
#      'duration': 0.006431,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.394906Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.395326Z',
#      'shell.execute_reply': '2024-06-08T14:59:41.397748Z',
#      'iopub.status.idle': '2024-06-08T14:59:41.398320Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:41.400632',
#      'end_time': '2024-06-08T14:59:43.565011',
#      'duration': 2.164379,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:41.401632Z',
#      'iopub.execute_input': '2024-06-08T14:59:41.401903Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.556824Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.559283Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.567860',
#      'end_time': '2024-06-08T14:59:43.569104',
#      'duration': 0.001244,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.570052',
#      'end_time': '2024-06-08T14:59:43.592622',
#      'duration': 0.02257,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.575423Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.576264Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.585226Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.588708Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.593195',
#      'end_time': '2024-06-08T14:59:43.615762',
#      'duration': 0.022567,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.595554Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.596008Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.611604Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.612755Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.616151',
#      'end_time': '2024-06-08T14:59:43.616491',
#      'duration': 0.00034,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.616933',
#      'end_time': '2024-06-08T14:59:43.628281',
#      'duration': 0.011348,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.619080Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.619489Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.625074Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.623721Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.628702',
#      'end_time': '2024-06-08T14:59:43.641107',
#      'duration': 0.012405,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.630306Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.630654Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.637393Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.638544Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.641542',
#      'end_time': '2024-06-08T14:59:43.641902',
#      'duration': 0.00036,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.642275',
#      'end_time': '2024-06-08T14:59:43.651620',
#      'duration': 0.009345,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.643818Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.644184Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.647664Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.648973Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.652144',
#      'end_time': '2024-06-08T14:59:43.662031',
#      'duration': 0.009887,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.654123Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.654527Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.657662Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.658838Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.662369',
#      'end_time': '2024-06-08T14:59:43.662722',
#      'duration': 0.000353,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.663049',
#      'end_time': '2024-06-08T14:59:43.670541',
#      'duration': 0.007492,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.664389Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.664651Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.667192Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.668310Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.671502',
#      'end_time': '2024-06-08T14:59:43.672013',
#      'duration': 0.000511,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:43.672341',
#      'end_time': '2024-06-08T14:59:43.694046',
#      'duration': 0.021705,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:43.673904Z',
#      'iopub.execute_input': '2024-06-08T14:59:43.674325Z',
#      'shell.execute_reply': '2024-06-08T14:59:43.691624Z',
#      'iopub.status.idle': '2024-06-08T14:59:43.692305Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N09966865906f46bd97b58a148cc7b116 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T14:59:40.096028',
#    'end_time': '2024-06-08T14:59:43.913186',
#    'duration': 3.817158,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T14:59:43.965126',
#    'end_time': '2024-06-08T14:59:50.428512',
#    'duration': 6.463386,
#    'exception': None}},
#  'cells': [{'id': 'b0d50fe8',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:45.007294',
#      'end_time': '2024-06-08T14:59:45.038969',
#      'duration': 0.031675,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:45.011074Z',
#      'iopub.execute_input': '2024-06-08T14:59:45.011854Z',
#      'shell.execute_reply': '2024-06-08T14:59:45.029611Z',
#      'iopub.status.idle': '2024-06-08T14:59:45.032131Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:45.041877',
#      'end_time': '2024-06-08T14:59:45.068220',
#      'duration': 0.026343,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:45.046166Z',
#      'iopub.execute_input': '2024-06-08T14:59:45.046950Z',
#      'iopub.status.idle': '2024-06-08T14:59:45.061648Z',
#      'shell.execute_reply': '2024-06-08T14:59:45.058192Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '6f1451e8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:45.068887',
#      'end_time': '2024-06-08T14:59:45.079611',
#      'duration': 0.010724,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:45.071780Z',
#      'iopub.execute_input': '2024-06-08T14:59:45.072286Z',
#      'shell.execute_reply': '2024-06-08T14:59:45.076139Z',
#      'iopub.status.idle': '2024-06-08T14:59:45.077388Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '5e358e19'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:45.079891',
#      'end_time': '2024-06-08T14:59:49.354549',
#      'duration': 4.274658,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:45.081189Z',
#      'iopub.execute_input': '2024-06-08T14:59:45.081478Z',
#      'shell.execute_reply': '2024-06-08T14:59:49.352247Z',
#      'iopub.status.idle': '2024-06-08T14:59:49.352890Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': '5e72dc8c'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:49.355418',
#      'end_time': '2024-06-08T14:59:49.356054',
#      'duration': 0.000636,
#      'status': 'completed'}},
#    'id': '22d16a0d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:49.356204',
#      'end_time': '2024-06-08T14:59:49.366206',
#      'duration': 0.010002,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:49.357554Z',
#      'iopub.execute_input': '2024-06-08T14:59:49.357802Z',
#      'shell.execute_reply': '2024-06-08T14:59:49.363286Z',
#      'iopub.status.idle': '2024-06-08T14:59:49.364005Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'cd3a2de9'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:49.366451',
#      'end_time': '2024-06-08T14:59:49.366662',
#      'duration': 0.000211,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '8f95ff8b'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:49.366873',
#      'end_time': '2024-06-08T14:59:49.982009',
#      'duration': 0.615136,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:49.368055Z',
#      'iopub.execute_input': '2024-06-08T14:59:49.368433Z',
#      'shell.execute_reply': '2024-06-08T14:59:49.979284Z',
#      'iopub.status.idle': '2024-06-08T14:59:49.979982Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '0e314acd'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:49.982615',
#      'end_time': '2024-06-08T14:59:50.020226',
#      'duration': 0.037611,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:49.983714Z',
#      'iopub.execute_input': '2024-06-08T14:59:49.984081Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.017465Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.015899Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '58e43a5f'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.020560',
#      'end_time': '2024-06-08T14:59:50.020889',
#      'duration': 0.000329,
#      'status': 'completed'}},
#    'id': '3fddcf6f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.021114',
#      'end_time': '2024-06-08T14:59:50.021372',
#      'duration': 0.000258,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '92d97697'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.021626',
#      'end_time': '2024-06-08T14:59:50.029434',
#      'duration': 0.007808,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.023049Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.023367Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.027229Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.026423Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': '4ac26a94'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.029695',
#      'end_time': '2024-06-08T14:59:50.040804',
#      'duration': 0.011109,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.030867Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.031099Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.038698Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.037876Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': 'c819be6b'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.041015',
#      'end_time': '2024-06-08T14:59:50.041208',
#      'duration': 0.000193,
#      'status': 'completed'}},
#    'id': '28c560f0'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.041401',
#      'end_time': '2024-06-08T14:59:50.051015',
#      'duration': 0.009614,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.042359Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.042567Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.049527Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.048966Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '55fd3cf4'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.051216',
#      'end_time': '2024-06-08T14:59:50.051407',
#      'duration': 0.000191,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '747f59a9'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.051528',
#      'end_time': '2024-06-08T14:59:50.059237',
#      'duration': 0.007709,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.052571Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.052926Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.057816Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.057187Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc13f63db4b1b486086fc7e9645c352aa (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '197d7390'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.059429',
#      'end_time': '2024-06-08T14:59:50.059624',
#      'duration': 0.000195,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '7fd8ce6a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.059797',
#      'end_time': '2024-06-08T14:59:50.066607',
#      'duration': 0.00681,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.060714Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.060924Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.065130Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.064485Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '77f00f27'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.066791',
#      'end_time': '2024-06-08T14:59:50.066979',
#      'duration': 0.000188,
#      'status': 'completed'}},
#    'id': '8abc1fbe'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.067147',
#      'end_time': '2024-06-08T14:59:50.067309',
#      'duration': 0.000162,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'f4414f3b'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.067455',
#      'end_time': '2024-06-08T14:59:50.074965',
#      'duration': 0.00751,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.068537Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.068838Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.073290Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.072677Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '4ceae952'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.075158',
#      'end_time': '2024-06-08T14:59:50.082922',
#      'duration': 0.007764,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.076076Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.076308Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.080710Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.081341Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc13f63db4b1b486086fc7e9645c352aa (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': '19effe80'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.083486',
#      'end_time': '2024-06-08T14:59:50.083767',
#      'duration': 0.000281,
#      'status': 'completed'}},
#    'id': '0ae7462c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.083930',
#      'end_time': '2024-06-08T14:59:50.093284',
#      'duration': 0.009354,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.085008Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.085312Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.091266Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.091965Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc13f63db4b1b486086fc7e9645c352aa (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '701bf83e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.093439',
#      'end_time': '2024-06-08T14:59:50.093586',
#      'duration': 0.000147,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '129fb0b1'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:50.093744',
#      'end_time': '2024-06-08T14:59:50.106986',
#      'duration': 0.013242,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:50.094665Z',
#      'iopub.execute_input': '2024-06-08T14:59:50.094905Z',
#      'shell.execute_reply': '2024-06-08T14:59:50.104839Z',
#      'iopub.status.idle': '2024-06-08T14:59:50.105562Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc13f63db4b1b486086fc7e9645c352aa (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '3d72ae6c'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T14:59:50.524253',
#    'end_time': '2024-06-08T14:59:56.861399',
#    'duration': 6.337146,
#    'exception': None}},
#  'cells': [{'id': '5893187c',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:51.573365',
#      'end_time': '2024-06-08T14:59:51.605139',
#      'duration': 0.031774,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:51.577026Z',
#      'iopub.execute_input': '2024-06-08T14:59:51.577826Z',
#      'shell.execute_reply': '2024-06-08T14:59:51.594071Z',
#      'iopub.status.idle': '2024-06-08T14:59:51.596735Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:51.607902',
#      'end_time': '2024-06-08T14:59:51.629009',
#      'duration': 0.021107,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:51.612633Z',
#      'iopub.execute_input': '2024-06-08T14:59:51.614150Z',
#      'iopub.status.idle': '2024-06-08T14:59:51.625429Z',
#      'shell.execute_reply': '2024-06-08T14:59:51.623958Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '742f1b29'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:51.629255',
#      'end_time': '2024-06-08T14:59:55.697794',
#      'duration': 4.068539,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:51.630813Z',
#      'iopub.execute_input': '2024-06-08T14:59:51.631101Z',
#      'iopub.status.idle': '2024-06-08T14:59:55.695882Z',
#      'shell.execute_reply': '2024-06-08T14:59:55.695193Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'ada29d09'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:55.698610',
#      'end_time': '2024-06-08T14:59:55.706761',
#      'duration': 0.008151,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:55.700141Z',
#      'iopub.execute_input': '2024-06-08T14:59:55.700452Z',
#      'shell.execute_reply': '2024-06-08T14:59:55.703849Z',
#      'iopub.status.idle': '2024-06-08T14:59:55.704699Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '95c51e67'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:55.706912',
#      'end_time': '2024-06-08T14:59:55.707118',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'id': 'add4b200'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:55.707314',
#      'end_time': '2024-06-08T14:59:55.715914',
#      'duration': 0.0086,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:55.708641Z',
#      'iopub.execute_input': '2024-06-08T14:59:55.709092Z',
#      'iopub.status.idle': '2024-06-08T14:59:55.714437Z',
#      'shell.execute_reply': '2024-06-08T14:59:55.713922Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '4bb04995'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:55.716161',
#      'end_time': '2024-06-08T14:59:55.716375',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '3beaa800'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:55.716571',
#      'end_time': '2024-06-08T14:59:56.236696',
#      'duration': 0.520125,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:55.717636Z',
#      'iopub.execute_input': '2024-06-08T14:59:55.718024Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.234800Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.234227Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': '180595ea'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.237441',
#      'end_time': '2024-06-08T14:59:56.402787',
#      'duration': 0.165346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.238841Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.239478Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.400667Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.401297Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': '9996b3a6'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.403543',
#      'end_time': '2024-06-08T14:59:56.426843',
#      'duration': 0.0233,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.404932Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.405544Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.424681Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.425332Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': 'fa569eaf'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.427049',
#      'end_time': '2024-06-08T14:59:56.427250',
#      'duration': 0.000201,
#      'status': 'completed'}},
#    'id': '5dec64c8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.427416',
#      'end_time': '2024-06-08T14:59:56.427589',
#      'duration': 0.000173,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '28319606'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.427770',
#      'end_time': '2024-06-08T14:59:56.433015',
#      'duration': 0.005245,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.428645Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.428849Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.431742Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.431144Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': 'b8cb603a'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.433162',
#      'end_time': '2024-06-08T14:59:56.452526',
#      'duration': 0.019364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.434394Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.434729Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.450072Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.450890Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': 'ae3b10a9'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.452722',
#      'end_time': '2024-06-08T14:59:56.452968',
#      'duration': 0.000246,
#      'status': 'completed'}},
#    'id': '76ab73dd'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.453114',
#      'end_time': '2024-06-08T14:59:56.463027',
#      'duration': 0.009913,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.454164Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.454370Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.460189Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.461012Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': 'cb3cc235'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.463241',
#      'end_time': '2024-06-08T14:59:56.463435',
#      'duration': 0.000194,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '6007e6bf'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.463621',
#      'end_time': '2024-06-08T14:59:56.474979',
#      'duration': 0.011358,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.464830Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.465316Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.472544Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.473231Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd4734eaaa50d4a4bb636498408877fc5 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '84c39367'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.475139',
#      'end_time': '2024-06-08T14:59:56.475358',
#      'duration': 0.000219,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '633b54bc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.475499',
#      'end_time': '2024-06-08T14:59:56.489268',
#      'duration': 0.013769,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.476667Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.476982Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.487126Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.487781Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '37a285a4'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.489417',
#      'end_time': '2024-06-08T14:59:56.489631',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'id': '1a20b1ab'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.489782',
#      'end_time': '2024-06-08T14:59:56.489982',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '0779960d'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.490118',
#      'end_time': '2024-06-08T14:59:56.495361',
#      'duration': 0.005243,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.490973Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.491151Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.493686Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.493211Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '7df5284e'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.495572',
#      'end_time': '2024-06-08T14:59:56.502892',
#      'duration': 0.00732,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.496458Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.496640Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.501307Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.500720Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd4734eaaa50d4a4bb636498408877fc5 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': 'ac808c14'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.503609',
#      'end_time': '2024-06-08T14:59:56.504288',
#      'duration': 0.000679,
#      'status': 'completed'}},
#    'id': 'cb92e581'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.504430',
#      'end_time': '2024-06-08T14:59:56.516489',
#      'duration': 0.012059,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.505623Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.505989Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.514690Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.514037Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd4734eaaa50d4a4bb636498408877fc5 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': 'febcefff'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.516695',
#      'end_time': '2024-06-08T14:59:56.516855',
#      'duration': 0.00016,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '0911aa59'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:56.517047',
#      'end_time': '2024-06-08T14:59:56.541352',
#      'duration': 0.024305,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:56.518116Z',
#      'iopub.execute_input': '2024-06-08T14:59:56.518461Z',
#      'shell.execute_reply': '2024-06-08T14:59:56.539489Z',
#      'iopub.status.idle': '2024-06-08T14:59:56.540041Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd4734eaaa50d4a4bb636498408877fc5 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': 'ecce827c'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T14:59:56.919414',
#    'end_time': '2024-06-08T15:00:01.397136',
#    'duration': 4.477722,
#    'exception': None}},
#  'cells': [{'id': '13be8af6',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.016848',
#      'end_time': '2024-06-08T14:59:58.051143',
#      'duration': 0.034295,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.022320Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.023470Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.045568Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.043043Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.054369',
#      'end_time': '2024-06-08T14:59:58.081568',
#      'duration': 0.027199,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.059175Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.060261Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.077118Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.073862Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'e9afdbee'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.082128',
#      'end_time': '2024-06-08T14:59:58.208322',
#      'duration': 0.126194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.084425Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.085700Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.205713Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.206381Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'bbab10fc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.208963',
#      'end_time': '2024-06-08T14:59:58.216888',
#      'duration': 0.007925,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.210040Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.210247Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.213643Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.214492Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': 'f2e42685'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.217204',
#      'end_time': '2024-06-08T14:59:58.217608',
#      'duration': 0.000404,
#      'status': 'completed'}},
#    'id': 'a61c213a'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.217841',
#      'end_time': '2024-06-08T14:59:58.234695',
#      'duration': 0.016854,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.219100Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.219548Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.232359Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.232991Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '3021210d'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.234847',
#      'end_time': '2024-06-08T14:59:58.244133',
#      'duration': 0.009286,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.235812Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.236059Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.242200Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.242813Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:9d22d272-2e35-4ecb-86ce-700fbb289de4 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:9d22d272-2e35-4ecb-86ce-700fbb289de4 .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': '102e1640'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.244289',
#      'end_time': '2024-06-08T14:59:58.244519',
#      'duration': 0.00023,
#      'status': 'completed'}},
#    'id': '34aceda4'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.244666',
#      'end_time': '2024-06-08T14:59:58.250395',
#      'duration': 0.005729,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.245580Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.245770Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.248848Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.248009Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'ef21ceef'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.250619',
#      'end_time': '2024-06-08T14:59:58.250833',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'id': 'bab2860b'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.251033',
#      'end_time': '2024-06-08T14:59:58.257029',
#      'duration': 0.005996,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.252048Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.252339Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.255538Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.254888Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '24b48b4c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.257179',
#      'end_time': '2024-06-08T14:59:58.257372',
#      'duration': 0.000193,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '784019eb'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.257494',
#      'end_time': '2024-06-08T14:59:58.264942',
#      'duration': 0.007448,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.258313Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.258516Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.262469Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.263188Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '3e23369a'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.265189',
#      'end_time': '2024-06-08T14:59:58.265437',
#      'duration': 0.000248,
#      'status': 'completed'}},
#    'id': 'b1fcf501'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.265658',
#      'end_time': '2024-06-08T14:59:58.273246',
#      'duration': 0.007588,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.266703Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.266960Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.271279Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.271838Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '796e80c2'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.273397',
#      'end_time': '2024-06-08T14:59:58.280540',
#      'duration': 0.007143,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.274293Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.274531Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.279101Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.278465Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '58f13724'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.280716',
#      'end_time': '2024-06-08T14:59:58.290236',
#      'duration': 0.00952,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.281625Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.281882Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.288679Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.288138Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'fda37b19'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.290452',
#      'end_time': '2024-06-08T14:59:58.290658',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '3870e45f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.290846',
#      'end_time': '2024-06-08T14:59:58.297774',
#      'duration': 0.006928,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.291706Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.291909Z',
#      'iopub.status.idle': '2024-06-08T14:59:58.296046Z',
#      'shell.execute_reply': '2024-06-08T14:59:58.295583Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': 'b5d6ce62'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T14:59:58.297929',
#      'end_time': '2024-06-08T15:00:00.949522',
#      'duration': 2.651593,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T14:59:58.298904Z',
#      'iopub.execute_input': '2024-06-08T14:59:58.299105Z',
#      'shell.execute_reply': '2024-06-08T15:00:00.939997Z',
#      'iopub.status.idle': '2024-06-08T15:00:00.943290Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'f88ef6d2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:00.953808',
#      'end_time': '2024-06-08T15:00:00.982691',
#      'duration': 0.028883,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:00.963321Z',
#      'iopub.execute_input': '2024-06-08T15:00:00.965206Z',
#      'iopub.status.idle': '2024-06-08T15:00:00.979531Z',
#      'shell.execute_reply': '2024-06-08T15:00:00.977651Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '40fe3849'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:00.983181',
#      'end_time': '2024-06-08T15:00:00.983649',
#      'duration': 0.000468,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'cb39e131'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:00.983929',
#      'end_time': '2024-06-08T15:00:01.004674',
#      'duration': 0.020745,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:00.985358Z',
#      'iopub.execute_input': '2024-06-08T15:00:00.985727Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.002652Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.001878Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'e1fa0d88'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.004880',
#      'end_time': '2024-06-08T15:00:01.005107',
#      'duration': 0.000227,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '5cf7aba5'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.005227',
#      'end_time': '2024-06-08T15:00:01.014680',
#      'duration': 0.009453,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.006235Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.006501Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.012171Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.012793Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\ng = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '280fdc09'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.014895',
#      'end_time': '2024-06-08T15:00:01.015082',
#      'duration': 0.000187,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'e5a2a913'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.015277',
#      'end_time': '2024-06-08T15:00:01.021085',
#      'duration': 0.005808,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.016351Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.016607Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.019063Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.019772Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': '5674f0e6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.021305',
#      'end_time': '2024-06-08T15:00:01.021505',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '3c30378a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.021698',
#      'end_time': '2024-06-08T15:00:01.037414',
#      'duration': 0.015716,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.022699Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.022958Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.035165Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.035692Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N413b06a91052446c999ee8f0a181833f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '1e23c3d1'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.037618',
#      'end_time': '2024-06-08T15:00:01.037812',
#      'duration': 0.000194,
#      'status': 'completed'}},
#    'id': '0a5b04bc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.037982',
#      'end_time': '2024-06-08T15:00:01.049479',
#      'duration': 0.011497,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.038994Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.039395Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.048115Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.047497Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '63349995'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.049672',
#      'end_time': '2024-06-08T15:00:01.056339',
#      'duration': 0.006667,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.050800Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.051112Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.054537Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.055106Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': 'd94275a0'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:01.056925',
#      'end_time': '2024-06-08T15:00:01.074271',
#      'duration': 0.017346,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:01.058194Z',
#      'iopub.execute_input': '2024-06-08T15:00:01.058478Z',
#      'shell.execute_reply': '2024-06-08T15:00:01.071664Z',
#      'iopub.status.idle': '2024-06-08T15:00:01.072281Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf989016998a445b09bd0bfc9abfea632 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '10a1cd06'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T15:00:01.486590',
#    'end_time': '2024-06-08T15:00:05.622233',
#    'duration': 4.135643,
#    'exception': None}},
#  'cells': [{'id': '9db37b80',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.632692',
#      'end_time': '2024-06-08T15:00:02.666446',
#      'duration': 0.033754,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.636723Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.637447Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.656846Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.659291Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.670641',
#      'end_time': '2024-06-08T15:00:02.688250',
#      'duration': 0.017609,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.675002Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.675872Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.684428Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.685648Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '83f54641'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.688596',
#      'end_time': '2024-06-08T15:00:02.825791',
#      'duration': 0.137195,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.690271Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.690951Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.824147Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.823532Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '41c48ba3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.826356',
#      'end_time': '2024-06-08T15:00:02.834533',
#      'duration': 0.008177,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.827633Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.827901Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.832259Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.831450Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '3d31c22f'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.834733',
#      'end_time': '2024-06-08T15:00:02.834971',
#      'duration': 0.000238,
#      'status': 'completed'}},
#    'id': '358f8f6d'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.835195',
#      'end_time': '2024-06-08T15:00:02.855165',
#      'duration': 0.01997,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.836298Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.836501Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.852398Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.853261Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '0b65b147'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.855316',
#      'end_time': '2024-06-08T15:00:02.867498',
#      'duration': 0.012182,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.856237Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.856420Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.865741Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.865059Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': '104ebf76'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.867648',
#      'end_time': '2024-06-08T15:00:02.867838',
#      'duration': 0.00019,
#      'status': 'completed'}},
#    'id': 'b8106862'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.867977',
#      'end_time': '2024-06-08T15:00:02.873743',
#      'duration': 0.005766,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.868982Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.869191Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.871532Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.872122Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '6ea9984b'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.873899',
#      'end_time': '2024-06-08T15:00:02.874112',
#      'duration': 0.000213,
#      'status': 'completed'}},
#    'id': '32ab2623'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.874242',
#      'end_time': '2024-06-08T15:00:02.879748',
#      'duration': 0.005506,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.875169Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.875348Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.877465Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.878090Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'a4376927'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.879884',
#      'end_time': '2024-06-08T15:00:02.880028',
#      'duration': 0.000144,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '7895990b'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.880151',
#      'end_time': '2024-06-08T15:00:02.886433',
#      'duration': 0.006282,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.880969Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.881137Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.885236Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.884744Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '2219af61'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.886567',
#      'end_time': '2024-06-08T15:00:02.886747',
#      'duration': 0.00018,
#      'status': 'completed'}},
#    'id': 'da298766'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.886875',
#      'end_time': '2024-06-08T15:00:02.893330',
#      'duration': 0.006455,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.887650Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.887817Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.891600Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.892098Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '168d2f08'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.893465',
#      'end_time': '2024-06-08T15:00:02.905826',
#      'duration': 0.012361,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.894192Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.894354Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.904609Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.904128Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': 'e326fb78'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.906022',
#      'end_time': '2024-06-08T15:00:02.906213',
#      'duration': 0.000191,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '29d5e05f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.906383',
#      'end_time': '2024-06-08T15:00:02.912234',
#      'duration': 0.005851,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.907136Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.907345Z',
#      'iopub.status.idle': '2024-06-08T15:00:02.910939Z',
#      'shell.execute_reply': '2024-06-08T15:00:02.910425Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '76a031a8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:02.912366',
#      'end_time': '2024-06-08T15:00:05.159219',
#      'duration': 2.246853,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:02.913150Z',
#      'iopub.execute_input': '2024-06-08T15:00:02.913321Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.150554Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.153456Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'fa3b0cf9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.163196',
#      'end_time': '2024-06-08T15:00:05.193260',
#      'duration': 0.030064,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.169248Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.171461Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.185701Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.182998Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': '675ec75d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.193840',
#      'end_time': '2024-06-08T15:00:05.194549',
#      'duration': 0.000709,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '18bdcf99'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.195144',
#      'end_time': '2024-06-08T15:00:05.220495',
#      'duration': 0.025351,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.199143Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.201075Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.217176Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.218224Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': 'aadab78f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.220687',
#      'end_time': '2024-06-08T15:00:05.220853',
#      'duration': 0.000166,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'ea26a1c6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.221005',
#      'end_time': '2024-06-08T15:00:05.227569',
#      'duration': 0.006564,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.222202Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.222410Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.225514Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.224733Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '3530209b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.227731',
#      'end_time': '2024-06-08T15:00:05.227937',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '9562208d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.228079',
#      'end_time': '2024-06-08T15:00:05.234049',
#      'duration': 0.00597,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.229191Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.229466Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.232178Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.231581Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '053dd2f0'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.234201',
#      'end_time': '2024-06-08T15:00:05.234416',
#      'duration': 0.000215,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '5ba3c438'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.234555',
#      'end_time': '2024-06-08T15:00:05.248938',
#      'duration': 0.014383,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.235730Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.236018Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.246235Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.246989Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N74d72243d7c141c895b14bae28340d92 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': 'e1c2d39a'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.249159',
#      'end_time': '2024-06-08T15:00:05.249364',
#      'duration': 0.000205,
#      'status': 'completed'}},
#    'id': '3a59deac'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.249542',
#      'end_time': '2024-06-08T15:00:05.268830',
#      'duration': 0.019288,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.250670Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.250989Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.266200Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.266884Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': '265f02e2'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.269403',
#      'end_time': '2024-06-08T15:00:05.278645',
#      'duration': 0.009242,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.270751Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.271107Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.276619Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.277310Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '227aced2'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T15:00:05.278781',
#      'end_time': '2024-06-08T15:00:05.304195',
#      'duration': 0.025414,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T15:00:05.279902Z',
#      'iopub.execute_input': '2024-06-08T15:00:05.280185Z',
#      'iopub.status.idle': '2024-06-08T15:00:05.302326Z',
#      'shell.execute_reply': '2024-06-08T15:00:05.301515Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0f5a9380d9e9414483e5987bc57a067f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '5df6290a'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/Si+deCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 664c3439-4405-44a2-9252-faf82c5a78dd
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 609c912f-da91-47e6-a101-b3c0af7c8404
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c9748d64-ff97-404a-be7b-666f69a743f7
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
