# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm
import os   
from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '08262f39',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.490030',
#      'end_time': '2024-05-27T11:20:28.519329',
#      'duration': 0.029299,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.493609Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.494371Z',
#      'shell.execute_reply': '2024-05-27T11:20:28.511609Z',
#      'iopub.status.idle': '2024-05-27T11:20:28.513898Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.522190',
#      'end_time': '2024-05-27T11:20:28.546913',
#      'duration': 0.024723,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.526663Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.527428Z',
#      'shell.execute_reply': '2024-05-27T11:20:28.540313Z',
#      'iopub.status.idle': '2024-05-27T11:20:28.542895Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.547564',
#      'end_time': '2024-05-27T11:20:28.548070',
#      'duration': 0.000506,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.548505',
#      'end_time': '2024-05-27T11:20:28.628629',
#      'duration': 0.080124,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.550626Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.551005Z',
#      'shell.execute_reply': '2024-05-27T11:20:28.626488Z',
#      'iopub.status.idle': '2024-05-27T11:20:28.627123Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.629215',
#      'end_time': '2024-05-27T11:20:28.648684',
#      'duration': 0.019469,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.630667Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.630949Z',
#      'iopub.status.idle': '2024-05-27T11:20:28.646951Z',
#      'shell.execute_reply': '2024-05-27T11:20:28.646305Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.648839',
#      'end_time': '2024-05-27T11:20:28.649061',
#      'duration': 0.000222,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.649189',
#      'end_time': '2024-05-27T11:20:28.649360',
#      'duration': 0.000171,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.649482',
#      'end_time': '2024-05-27T11:20:28.655482',
#      'duration': 0.006,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.650362Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.650546Z',
#      'iopub.status.idle': '2024-05-27T11:20:28.653969Z',
#      'shell.execute_reply': '2024-05-27T11:20:28.653403Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:28.655721',
#      'end_time': '2024-05-27T11:20:30.520268',
#      'duration': 1.864547,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:28.656788Z',
#      'iopub.execute_input': '2024-05-27T11:20:28.657094Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.511507Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.514384Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.522833',
#      'end_time': '2024-05-27T11:20:30.524272',
#      'duration': 0.001439,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.524883',
#      'end_time': '2024-05-27T11:20:30.564556',
#      'duration': 0.039673,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.530965Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.534062Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.560905Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.556443Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.564837',
#      'end_time': '2024-05-27T11:20:30.591757',
#      'duration': 0.02692,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.574456Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.574961Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.589281Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.588410Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.592004',
#      'end_time': '2024-05-27T11:20:30.592274',
#      'duration': 0.00027,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.592486',
#      'end_time': '2024-05-27T11:20:30.607951',
#      'duration': 0.015465,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.594302Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.594839Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.605288Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.604265Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.608208',
#      'end_time': '2024-05-27T11:20:30.616514',
#      'duration': 0.008306,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.609619Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.610092Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.615026Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.614337Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.616676',
#      'end_time': '2024-05-27T11:20:30.616871',
#      'duration': 0.000195,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.616998',
#      'end_time': '2024-05-27T11:20:30.622350',
#      'duration': 0.005352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.617839Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.618036Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.620684Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.620141Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.623143',
#      'end_time': '2024-05-27T11:20:30.629034',
#      'duration': 0.005891,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.624446Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.624711Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.626878Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.627594Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.629195',
#      'end_time': '2024-05-27T11:20:30.629385',
#      'duration': 0.00019,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.629512',
#      'end_time': '2024-05-27T11:20:30.634588',
#      'duration': 0.005076,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.630354Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.630862Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.633210Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.632595Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.634741',
#      'end_time': '2024-05-27T11:20:30.634957',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:30.635114',
#      'end_time': '2024-05-27T11:20:30.648390',
#      'duration': 0.013276,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:30.635975Z',
#      'iopub.execute_input': '2024-05-27T11:20:30.636375Z',
#      'shell.execute_reply': '2024-05-27T11:20:30.646459Z',
#      'iopub.status.idle': '2024-05-27T11:20:30.647038Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc4f31c6c51664cd0a008715665ff82b6 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T11:20:27.624534',
#    'end_time': '2024-05-27T11:20:30.866925',
#    'duration': 3.242391,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T11:20:30.915495',
#    'end_time': '2024-05-27T11:20:36.272840',
#    'duration': 5.357345,
#    'exception': None}},
#  'cells': [{'id': 'a00b1772',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:31.646182',
#      'end_time': '2024-05-27T11:20:31.682142',
#      'duration': 0.03596,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:31.650008Z',
#      'iopub.execute_input': '2024-05-27T11:20:31.650764Z',
#      'shell.execute_reply': '2024-05-27T11:20:31.671144Z',
#      'iopub.status.idle': '2024-05-27T11:20:31.674265Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:31.684095',
#      'end_time': '2024-05-27T11:20:31.696516',
#      'duration': 0.012421,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:31.687234Z',
#      'iopub.execute_input': '2024-05-27T11:20:31.688586Z',
#      'shell.execute_reply': '2024-05-27T11:20:31.693363Z',
#      'iopub.status.idle': '2024-05-27T11:20:31.694207Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '9a87bae8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:31.696717',
#      'end_time': '2024-05-27T11:20:31.703359',
#      'duration': 0.006642,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:31.697950Z',
#      'iopub.execute_input': '2024-05-27T11:20:31.698221Z',
#      'iopub.status.idle': '2024-05-27T11:20:31.701749Z',
#      'shell.execute_reply': '2024-05-27T11:20:31.701153Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '88d405eb'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:31.703541',
#      'end_time': '2024-05-27T11:20:35.375161',
#      'duration': 3.67162,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:31.704528Z',
#      'iopub.execute_input': '2024-05-27T11:20:31.704740Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.372642Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.373310Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': '80617743'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.375934',
#      'end_time': '2024-05-27T11:20:35.376406',
#      'duration': 0.000472,
#      'status': 'completed'}},
#    'id': '7f6a35f3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.376616',
#      'end_time': '2024-05-27T11:20:35.388669',
#      'duration': 0.012053,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.378118Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.378606Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.386429Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.385750Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'da04ed55'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.388868',
#      'end_time': '2024-05-27T11:20:35.389161',
#      'duration': 0.000293,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '193fc917'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.389420',
#      'end_time': '2024-05-27T11:20:35.824222',
#      'duration': 0.434802,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.390871Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.391582Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.822209Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.822825Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': 'a6fef00c'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.824810',
#      'end_time': '2024-05-27T11:20:35.866438',
#      'duration': 0.041628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.826132Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.826591Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.859805Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.862222Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': 'dc0ad83d'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.866699',
#      'end_time': '2024-05-27T11:20:35.866988',
#      'duration': 0.000289,
#      'status': 'completed'}},
#    'id': '52a567e7'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.867256',
#      'end_time': '2024-05-27T11:20:35.867506',
#      'duration': 0.00025,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '60856e9d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.867753',
#      'end_time': '2024-05-27T11:20:35.875951',
#      'duration': 0.008198,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.869446Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.869830Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.873170Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.873916Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': '0b711abf'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.876181',
#      'end_time': '2024-05-27T11:20:35.887306',
#      'duration': 0.011125,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.877574Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.878022Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.884961Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.885714Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '584a4d00'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.887461',
#      'end_time': '2024-05-27T11:20:35.887626',
#      'duration': 0.000165,
#      'status': 'completed'}},
#    'id': '36f991b6'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.887765',
#      'end_time': '2024-05-27T11:20:35.897470',
#      'duration': 0.009705,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.888754Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.888965Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.894794Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.895515Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '2e1916fa'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.897622',
#      'end_time': '2024-05-27T11:20:35.897794',
#      'duration': 0.000172,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '0a5d0fe3'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.897938',
#      'end_time': '2024-05-27T11:20:35.906484',
#      'duration': 0.008546,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.898918Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.899123Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.904552Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.903862Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N98fe0dfb80fc4ae8b919c8062bb3789b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': 'cd2350d6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.906633',
#      'end_time': '2024-05-27T11:20:35.906809',
#      'duration': 0.000176,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '3deafa7b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.906946',
#      'end_time': '2024-05-27T11:20:35.914316',
#      'duration': 0.00737,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.907896Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.908101Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.912637Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.912056Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '048b5eea'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.914447',
#      'end_time': '2024-05-27T11:20:35.914602',
#      'duration': 0.000155,
#      'status': 'completed'}},
#    'id': 'a2a90656'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.914722',
#      'end_time': '2024-05-27T11:20:35.914856',
#      'duration': 0.000134,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '5afdcd3d'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.915034',
#      'end_time': '2024-05-27T11:20:35.921623',
#      'duration': 0.006589,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.915861Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.916167Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.919932Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.919331Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '510fad9a'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.921774',
#      'end_time': '2024-05-27T11:20:35.928925',
#      'duration': 0.007151,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.922665Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.922835Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.927219Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.926604Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N98fe0dfb80fc4ae8b919c8062bb3789b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'd44731ea'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.929542',
#      'end_time': '2024-05-27T11:20:35.929830',
#      'duration': 0.000288,
#      'status': 'completed'}},
#    'id': '12919938'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.929969',
#      'end_time': '2024-05-27T11:20:35.939622',
#      'duration': 0.009653,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.931336Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.931765Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.937826Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.937093Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N98fe0dfb80fc4ae8b919c8062bb3789b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '088b43a6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.939759',
#      'end_time': '2024-05-27T11:20:35.939917',
#      'duration': 0.000158,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '3780db19'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:35.940040',
#      'end_time': '2024-05-27T11:20:35.950017',
#      'duration': 0.009977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:35.940947Z',
#      'iopub.execute_input': '2024-05-27T11:20:35.941181Z',
#      'iopub.status.idle': '2024-05-27T11:20:35.948296Z',
#      'shell.execute_reply': '2024-05-27T11:20:35.947751Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N98fe0dfb80fc4ae8b919c8062bb3789b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': 'bd28c5ad'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T11:20:36.348481',
#    'end_time': '2024-05-27T11:20:41.640752',
#    'duration': 5.292271,
#    'exception': None}},
#  'cells': [{'id': 'bb692124',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:37.295764',
#      'end_time': '2024-05-27T11:20:37.304036',
#      'duration': 0.008272,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:37.296802Z',
#      'iopub.execute_input': '2024-05-27T11:20:37.296983Z',
#      'iopub.status.idle': '2024-05-27T11:20:37.302008Z',
#      'shell.execute_reply': '2024-05-27T11:20:37.301457Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:37.304789',
#      'end_time': '2024-05-27T11:20:37.312448',
#      'duration': 0.007659,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:37.306121Z',
#      'iopub.execute_input': '2024-05-27T11:20:37.306843Z',
#      'iopub.status.idle': '2024-05-27T11:20:37.310486Z',
#      'shell.execute_reply': '2024-05-27T11:20:37.309508Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '954f6a5a'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:37.312606',
#      'end_time': '2024-05-27T11:20:40.732205',
#      'duration': 3.419599,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:37.313671Z',
#      'iopub.execute_input': '2024-05-27T11:20:37.313962Z',
#      'shell.execute_reply': '2024-05-27T11:20:40.730017Z',
#      'iopub.status.idle': '2024-05-27T11:20:40.730742Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'd5f488e0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:40.732949',
#      'end_time': '2024-05-27T11:20:40.740134',
#      'duration': 0.007185,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:40.734074Z',
#      'iopub.execute_input': '2024-05-27T11:20:40.734591Z',
#      'iopub.status.idle': '2024-05-27T11:20:40.738436Z',
#      'shell.execute_reply': '2024-05-27T11:20:40.737647Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': 'f6cd3a13'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:40.740353',
#      'end_time': '2024-05-27T11:20:40.740512',
#      'duration': 0.000159,
#      'status': 'completed'}},
#    'id': '25186017'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:40.740695',
#      'end_time': '2024-05-27T11:20:40.747549',
#      'duration': 0.006854,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:40.741715Z',
#      'iopub.execute_input': '2024-05-27T11:20:40.741910Z',
#      'shell.execute_reply': '2024-05-27T11:20:40.745615Z',
#      'iopub.status.idle': '2024-05-27T11:20:40.746194Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '29cbf677'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:40.747704',
#      'end_time': '2024-05-27T11:20:40.747879',
#      'duration': 0.000175,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'e64df409'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:40.748032',
#      'end_time': '2024-05-27T11:20:41.078408',
#      'duration': 0.330376,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:40.748929Z',
#      'iopub.execute_input': '2024-05-27T11:20:40.749134Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.076573Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.077022Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': '2729e288'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.078977',
#      'end_time': '2024-05-27T11:20:41.220389',
#      'duration': 0.141412,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.080094Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.080481Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.218934Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.218327Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'f73976a0'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.220983',
#      'end_time': '2024-05-27T11:20:41.244157',
#      'duration': 0.023174,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.221917Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.222109Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.242891Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.242401Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '3df0d35f'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.244304',
#      'end_time': '2024-05-27T11:20:41.244520',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'id': '4ba8707f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.244660',
#      'end_time': '2024-05-27T11:20:41.244860',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '38c5d6bf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.245008',
#      'end_time': '2024-05-27T11:20:41.249794',
#      'duration': 0.004786,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.245836Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.246016Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.248134Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.248590Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': 'f8231dd2'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.249935',
#      'end_time': '2024-05-27T11:20:41.258210',
#      'duration': 0.008275,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.250699Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.250877Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.256715Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.255871Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '536c0195'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.258423',
#      'end_time': '2024-05-27T11:20:41.258574',
#      'duration': 0.000151,
#      'status': 'completed'}},
#    'id': 'b5d65694'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.258698',
#      'end_time': '2024-05-27T11:20:41.267210',
#      'duration': 0.008512,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.259622Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.259912Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.265295Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.265884Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': '09cf3aa5'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.267353',
#      'end_time': '2024-05-27T11:20:41.267538',
#      'duration': 0.000185,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '034984a5'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.267659',
#      'end_time': '2024-05-27T11:20:41.274804',
#      'duration': 0.007145,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.268543Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.268732Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.273547Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.273041Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na61e285815af430abaccf4d317adf587 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'a5b1136d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.275020',
#      'end_time': '2024-05-27T11:20:41.275221',
#      'duration': 0.000201,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '06d1214d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.275401',
#      'end_time': '2024-05-27T11:20:41.285398',
#      'duration': 0.009997,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.276185Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.276400Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.282997Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.283797Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': 'bd8e9e50'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.285619',
#      'end_time': '2024-05-27T11:20:41.285821',
#      'duration': 0.000202,
#      'status': 'completed'}},
#    'id': '1218831c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.285975',
#      'end_time': '2024-05-27T11:20:41.286137',
#      'duration': 0.000162,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'a12d1191'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.286276',
#      'end_time': '2024-05-27T11:20:41.291791',
#      'duration': 0.005515,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.287191Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.287554Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.289703Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.290348Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '5801a3d4'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.291991',
#      'end_time': '2024-05-27T11:20:41.298946',
#      'duration': 0.006955,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.292891Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.293081Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.297664Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.297132Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na61e285815af430abaccf4d317adf587 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': 'fcd4222e'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.299162',
#      'end_time': '2024-05-27T11:20:41.299394',
#      'duration': 0.000232,
#      'status': 'completed'}},
#    'id': '8f5144fd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.299576',
#      'end_time': '2024-05-27T11:20:41.307895',
#      'duration': 0.008319,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.300378Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.300563Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.305528Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.306044Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na61e285815af430abaccf4d317adf587 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '19bcaaf8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.308048',
#      'end_time': '2024-05-27T11:20:41.308203',
#      'duration': 0.000155,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '7d434416'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:41.308328',
#      'end_time': '2024-05-27T11:20:41.319369',
#      'duration': 0.011041,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:41.309138Z',
#      'iopub.execute_input': '2024-05-27T11:20:41.309437Z',
#      'shell.execute_reply': '2024-05-27T11:20:41.317283Z',
#      'iopub.status.idle': '2024-05-27T11:20:41.317905Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na61e285815af430abaccf4d317adf587 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': 'e06f2b5d'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T11:20:41.708684',
#    'end_time': '2024-05-27T11:20:44.530015',
#    'duration': 2.821331,
#    'exception': None}},
#  'cells': [{'id': '6d2b6a15',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.392078',
#      'end_time': '2024-05-27T11:20:42.401377',
#      'duration': 0.009299,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.393298Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.393516Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.398902Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.399531Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.402077',
#      'end_time': '2024-05-27T11:20:42.412197',
#      'duration': 0.01012,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.403544Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.404062Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.408352Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.409423Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '0cc690dc'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.412453',
#      'end_time': '2024-05-27T11:20:42.477929',
#      'duration': 0.065476,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.413946Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.414253Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.475468Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.476085Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '2b0d67cb'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.478082',
#      'end_time': '2024-05-27T11:20:42.483514',
#      'duration': 0.005432,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.479023Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.479204Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.482266Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.481749Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '6bee1e27'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.483656',
#      'end_time': '2024-05-27T11:20:42.483833',
#      'duration': 0.000177,
#      'status': 'completed'}},
#    'id': '71a0c286'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.483951',
#      'end_time': '2024-05-27T11:20:42.497956',
#      'duration': 0.014005,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.484846Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.485125Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.496059Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.496630Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '65d63b74'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.498173',
#      'end_time': '2024-05-27T11:20:42.507091',
#      'duration': 0.008918,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.498963Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.499132Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.505816Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.505195Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:20ece8df-7d5a-42ad-baeb-699bbf45501e a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:20ece8df-7d5a-42ad-baeb-699bbf45501e .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': 'e6074859'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.507769',
#      'end_time': '2024-05-27T11:20:42.508047',
#      'duration': 0.000278,
#      'status': 'completed'}},
#    'id': '6a2b28c1'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.508243',
#      'end_time': '2024-05-27T11:20:42.514421',
#      'duration': 0.006178,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.509346Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.509636Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.512942Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.512040Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '81d032b7'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.514643',
#      'end_time': '2024-05-27T11:20:42.514825',
#      'duration': 0.000182,
#      'status': 'completed'}},
#    'id': '9dee23d6'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.515045',
#      'end_time': '2024-05-27T11:20:42.521362',
#      'duration': 0.006317,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.516100Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.516427Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.519025Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.519658Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '940cfef4'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.521583',
#      'end_time': '2024-05-27T11:20:42.521778',
#      'duration': 0.000195,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '0670d57a'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.521968',
#      'end_time': '2024-05-27T11:20:42.529087',
#      'duration': 0.007119,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.522939Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.523210Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.527770Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.527251Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '8d0e910f'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.529291',
#      'end_time': '2024-05-27T11:20:42.529459',
#      'duration': 0.000168,
#      'status': 'completed'}},
#    'id': 'b9d5263a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.529643',
#      'end_time': '2024-05-27T11:20:42.536634',
#      'duration': 0.006991,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.530512Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.530736Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.534918Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.535388Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'ecebf66c'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.536841',
#      'end_time': '2024-05-27T11:20:42.543535',
#      'duration': 0.006694,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.537675Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.537844Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.541687Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.542247Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': 'a86e21cd'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.543732',
#      'end_time': '2024-05-27T11:20:42.552433',
#      'duration': 0.008701,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.544562Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.544746Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.551046Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.550444Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '11701521'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.552578',
#      'end_time': '2024-05-27T11:20:42.552765',
#      'duration': 0.000187,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '97e09c0f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.552885',
#      'end_time': '2024-05-27T11:20:42.560090',
#      'duration': 0.007205,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.553710Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.554005Z',
#      'shell.execute_reply': '2024-05-27T11:20:42.557704Z',
#      'iopub.status.idle': '2024-05-27T11:20:42.558277Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '1b0a47fa'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:42.560239',
#      'end_time': '2024-05-27T11:20:44.202481',
#      'duration': 1.642242,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:42.561040Z',
#      'iopub.execute_input': '2024-05-27T11:20:42.561211Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.196656Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.193754Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '86ba3b2c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.204823',
#      'end_time': '2024-05-27T11:20:44.231088',
#      'duration': 0.026265,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.210061Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.210934Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.224251Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.227399Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '94246654'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.231644',
#      'end_time': '2024-05-27T11:20:44.232187',
#      'duration': 0.000543,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '77cff5b1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.232703',
#      'end_time': '2024-05-27T11:20:44.252486',
#      'duration': 0.019783,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.235226Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.235719Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.249516Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.250405Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '084fcf65'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.252674',
#      'end_time': '2024-05-27T11:20:44.252939',
#      'duration': 0.000265,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'ece030b6'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.253118',
#      'end_time': '2024-05-27T11:20:44.263479',
#      'duration': 0.010361,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.254134Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.254361Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.261053Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.261869Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\ng = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '23460295'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.263646',
#      'end_time': '2024-05-27T11:20:44.263860',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '499ed764'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.264014',
#      'end_time': '2024-05-27T11:20:44.269336',
#      'duration': 0.005322,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.264931Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.265157Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.267324Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.267837Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': 'e6eee343'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.269501',
#      'end_time': '2024-05-27T11:20:44.269739',
#      'duration': 0.000238,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'c2f0ac50'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.269899',
#      'end_time': '2024-05-27T11:20:44.279849',
#      'duration': 0.00995,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.270848Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.271043Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.278528Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.277998Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1ca1352797a14511992541a3d5272379 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '9e1bcd59'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.279999',
#      'end_time': '2024-05-27T11:20:44.280229',
#      'duration': 0.00023,
#      'status': 'completed'}},
#    'id': '67a982bf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.280368',
#      'end_time': '2024-05-27T11:20:44.291659',
#      'duration': 0.011291,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.281259Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.281559Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.289632Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.290303Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '842b3321'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.291816',
#      'end_time': '2024-05-27T11:20:44.298108',
#      'duration': 0.006292,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.292779Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.292980Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.296711Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.296030Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': '57f18492'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:44.298253',
#      'end_time': '2024-05-27T11:20:44.311147',
#      'duration': 0.012894,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:44.299215Z',
#      'iopub.execute_input': '2024-05-27T11:20:44.299444Z',
#      'iopub.status.idle': '2024-05-27T11:20:44.309859Z',
#      'shell.execute_reply': '2024-05-27T11:20:44.309273Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N721e135aa01c447195b44a686a8fc86a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': 'b9f4ae9d'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-27T11:20:44.585643',
#    'end_time': '2024-05-27T11:20:47.550825',
#    'duration': 2.965182,
#    'exception': None}},
#  'cells': [{'id': '5001db37',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.361251',
#      'end_time': '2024-05-27T11:20:45.386205',
#      'duration': 0.024954,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.365334Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.366263Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.381999Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.383333Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.387381',
#      'end_time': '2024-05-27T11:20:45.398017',
#      'duration': 0.010636,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.389561Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.390296Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.394856Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.395743Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'e62bd458'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.398188',
#      'end_time': '2024-05-27T11:20:45.458660',
#      'duration': 0.060472,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.399346Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.399569Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.456657Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.457247Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'e00432d4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.458801',
#      'end_time': '2024-05-27T11:20:45.464829',
#      'duration': 0.006028,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.459646Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.459817Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.463171Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.462540Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '72546f63'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.464975',
#      'end_time': '2024-05-27T11:20:45.465136',
#      'duration': 0.000161,
#      'status': 'completed'}},
#    'id': 'b59b0634'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.465254',
#      'end_time': '2024-05-27T11:20:45.482424',
#      'duration': 0.01717,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.466090Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.466312Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.480007Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.480659Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '44ec2af0'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.482572',
#      'end_time': '2024-05-27T11:20:45.493126',
#      'duration': 0.010554,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.483451Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.483626Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.491444Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.490798Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': '21644abc'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.493826',
#      'end_time': '2024-05-27T11:20:45.494300',
#      'duration': 0.000474,
#      'status': 'completed'}},
#    'id': 'a81b8f05'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.494487',
#      'end_time': '2024-05-27T11:20:45.501634',
#      'duration': 0.007147,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.495889Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.496514Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.499748Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.499117Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '92b8cac1'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.501823',
#      'end_time': '2024-05-27T11:20:45.501978',
#      'duration': 0.000155,
#      'status': 'completed'}},
#    'id': '70db84c7'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.502094',
#      'end_time': '2024-05-27T11:20:45.508162',
#      'duration': 0.006068,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.503158Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.503400Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.505935Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.506454Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'd6cf87cb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.508364',
#      'end_time': '2024-05-27T11:20:45.508574',
#      'duration': 0.00021,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '6e15b75e'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.508746',
#      'end_time': '2024-05-27T11:20:45.515667',
#      'duration': 0.006921,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.509641Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.509817Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.513637Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.514252Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '3e519a87'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.515805',
#      'end_time': '2024-05-27T11:20:45.515999',
#      'duration': 0.000194,
#      'status': 'completed'}},
#    'id': 'a577b751'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.516173',
#      'end_time': '2024-05-27T11:20:45.523665',
#      'duration': 0.007492,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.517010Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.517430Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.521809Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.521242Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '3e4da1bf'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.523850',
#      'end_time': '2024-05-27T11:20:45.534632',
#      'duration': 0.010782,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.524816Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.525070Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.532193Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.532877Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '55647ab8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.534776',
#      'end_time': '2024-05-27T11:20:45.534956',
#      'duration': 0.00018,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '1ead34f1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.535091',
#      'end_time': '2024-05-27T11:20:45.541796',
#      'duration': 0.006705,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.536085Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.536452Z',
#      'shell.execute_reply': '2024-05-27T11:20:45.539514Z',
#      'iopub.status.idle': '2024-05-27T11:20:45.540146Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'd6d74c9f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:45.541941',
#      'end_time': '2024-05-27T11:20:47.222797',
#      'duration': 1.680856,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:45.542823Z',
#      'iopub.execute_input': '2024-05-27T11:20:45.543311Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.212868Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.215526Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '909e66d8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.225308',
#      'end_time': '2024-05-27T11:20:47.252710',
#      'duration': 0.027402,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.231118Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.232586Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.248529Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.246168Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'ecb0ce7a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.252992',
#      'end_time': '2024-05-27T11:20:47.253350',
#      'duration': 0.000358,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '191d1c3b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.253619',
#      'end_time': '2024-05-27T11:20:47.269484',
#      'duration': 0.015865,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.255441Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.255844Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.266534Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.267278Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '2f445867'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.269663',
#      'end_time': '2024-05-27T11:20:47.269879',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '6599299b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.270046',
#      'end_time': '2024-05-27T11:20:47.276041',
#      'duration': 0.005995,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.271159Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.271577Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.274059Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.273292Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '30155e16'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.276206',
#      'end_time': '2024-05-27T11:20:47.276405',
#      'duration': 0.000199,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'bd50f6a2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.276558',
#      'end_time': '2024-05-27T11:20:47.282119',
#      'duration': 0.005561,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.277511Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.277708Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.280293Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.279591Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '9df2dd58'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.282275',
#      'end_time': '2024-05-27T11:20:47.282465',
#      'duration': 0.00019,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '942adba5'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.282607',
#      'end_time': '2024-05-27T11:20:47.294348',
#      'duration': 0.011741,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.283537Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.283720Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.291954Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.292608Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N5ba80b351fd546eeb6a5c7e48093c123 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': 'e969099e'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.294496',
#      'end_time': '2024-05-27T11:20:47.294648',
#      'duration': 0.000152,
#      'status': 'completed'}},
#    'id': 'fc45d319'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.294768',
#      'end_time': '2024-05-27T11:20:47.308968',
#      'duration': 0.0142,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.295659Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.295835Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.306714Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.307289Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'a980342a'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.309114',
#      'end_time': '2024-05-27T11:20:47.315892',
#      'duration': 0.006778,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.309975Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.310150Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.314285Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.313740Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '6223c421'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-27T11:20:47.316099',
#      'end_time': '2024-05-27T11:20:47.332481',
#      'duration': 0.016382,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-27T11:20:47.317003Z',
#      'iopub.execute_input': '2024-05-27T11:20:47.317181Z',
#      'shell.execute_reply': '2024-05-27T11:20:47.330554Z',
#      'iopub.status.idle': '2024-05-27T11:20:47.331174Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3c90784b89dc45b8acff059984a1db0b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '1fa2724f'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 61d9a858-f582-467e-b780-21c48ef76e4e
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 9580c789-e610-4f86-be36-0438693047d5
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# b6ba8ccb-0734-4b1d-b930-a083420ff2ee
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
