# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:03<00:00,  4.45cell/s]
# {'cells': [{'id': '5b5a7bbf',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.674235',
#      'end_time': '2024-10-08T07:53:12.689558',
#      'duration': 0.015323,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.675931Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.676272Z',
#      'shell.execute_reply': '2024-10-08T07:53:12.685892Z',
#      'iopub.status.idle': '2024-10-08T07:53:12.687191Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.690914',
#      'end_time': '2024-10-08T07:53:12.703470',
#      'duration': 0.012556,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.694692Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.695058Z',
#      'shell.execute_reply': '2024-10-08T07:53:12.699749Z',
#      'iopub.status.idle': '2024-10-08T07:53:12.701028Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.703689',
#      'end_time': '2024-10-08T07:53:12.704003',
#      'duration': 0.000314,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.704185',
#      'end_time': '2024-10-08T07:53:12.778452',
#      'duration': 0.074267,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.705624Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.705968Z',
#      'shell.execute_reply': '2024-10-08T07:53:12.776132Z',
#      'iopub.status.idle': '2024-10-08T07:53:12.776835Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.778640',
#      'end_time': '2024-10-08T07:53:12.804201',
#      'duration': 0.025561,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.779578Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.779795Z',
#      'shell.execute_reply': '2024-10-08T07:53:12.801867Z',
#      'iopub.status.idle': '2024-10-08T07:53:12.802598Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.804896',
#      'end_time': '2024-10-08T07:53:12.805181',
#      'duration': 0.000285,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.805318',
#      'end_time': '2024-10-08T07:53:12.814708',
#      'duration': 0.00939,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.806683Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.807076Z',
#      'iopub.status.idle': '2024-10-08T07:53:12.813155Z',
#      'shell.execute_reply': '2024-10-08T07:53:12.812357Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:12.814857',
#      'end_time': '2024-10-08T07:53:14.798471',
#      'duration': 1.983614,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:12.815897Z',
#      'iopub.execute_input': '2024-10-08T07:53:12.816130Z',
#      'shell.execute_reply': '2024-10-08T07:53:14.787636Z',
#      'iopub.status.idle': '2024-10-08T07:53:14.791482Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.801336',
#      'end_time': '2024-10-08T07:53:14.803605',
#      'duration': 0.002269,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.804197',
#      'end_time': '2024-10-08T07:53:14.829721',
#      'duration': 0.025524,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:14.809221Z',
#      'iopub.execute_input': '2024-10-08T07:53:14.810268Z',
#      'iopub.status.idle': '2024-10-08T07:53:14.823413Z',
#      'shell.execute_reply': '2024-10-08T07:53:14.820486Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.830326',
#      'end_time': '2024-10-08T07:53:14.869584',
#      'duration': 0.039258,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:14.834670Z',
#      'iopub.execute_input': '2024-10-08T07:53:14.835538Z',
#      'shell.execute_reply': '2024-10-08T07:53:14.865886Z',
#      'iopub.status.idle': '2024-10-08T07:53:14.867191Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.869963',
#      'end_time': '2024-10-08T07:53:14.870334',
#      'duration': 0.000371,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.870535',
#      'end_time': '2024-10-08T07:53:14.886440',
#      'duration': 0.015905,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:14.871846Z',
#      'iopub.execute_input': '2024-10-08T07:53:14.872123Z',
#      'shell.execute_reply': '2024-10-08T07:53:14.882621Z',
#      'iopub.status.idle': '2024-10-08T07:53:14.883605Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.886626',
#      'end_time': '2024-10-08T07:53:14.886943',
#      'duration': 0.000317,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:14.887118',
#      'end_time': '2024-10-08T07:53:14.912586',
#      'duration': 0.025468,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:14.888434Z',
#      'iopub.execute_input': '2024-10-08T07:53:14.888850Z',
#      'iopub.status.idle': '2024-10-08T07:53:14.909874Z',
#      'shell.execute_reply': '2024-10-08T07:53:14.908879Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0be062c514ea49b0a56538396612b616 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-08T07:53:11.767244',
#    'end_time': '2024-10-08T07:53:15.136649',
#    'duration': 3.369405,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:08<00:00,  1.46cell/s]
# {'cells': [{'id': '5aa28b15',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:16.332250',
#      'end_time': '2024-10-08T07:53:16.372686',
#      'duration': 0.040436,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:16.336896Z',
#      'iopub.execute_input': '2024-10-08T07:53:16.337779Z',
#      'iopub.status.idle': '2024-10-08T07:53:16.365709Z',
#      'shell.execute_reply': '2024-10-08T07:53:16.362184Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:16.374544',
#      'end_time': '2024-10-08T07:53:22.297395',
#      'duration': 5.922851,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:16.377612Z',
#      'iopub.execute_input': '2024-10-08T07:53:16.378885Z',
#      'iopub.status.idle': '2024-10-08T07:53:22.290688Z',
#      'shell.execute_reply': '2024-10-08T07:53:22.288130Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:22.298926',
#      'end_time': '2024-10-08T07:53:22.310944',
#      'duration': 0.012018,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:22.302300Z',
#      'iopub.execute_input': '2024-10-08T07:53:22.302700Z',
#      'shell.execute_reply': '2024-10-08T07:53:22.307827Z',
#      'iopub.status.idle': '2024-10-08T07:53:22.308844Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:22.311118',
#      'end_time': '2024-10-08T07:53:22.386888',
#      'duration': 0.07577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:22.312375Z',
#      'iopub.execute_input': '2024-10-08T07:53:22.312653Z',
#      'shell.execute_reply': '2024-10-08T07:53:22.383653Z',
#      'iopub.status.idle': '2024-10-08T07:53:22.384391Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:22.387040',
#      'end_time': '2024-10-08T07:53:22.387279',
#      'duration': 0.000239,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:22.387417',
#      'end_time': '2024-10-08T07:53:23.023837',
#      'duration': 0.63642,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:22.388746Z',
#      'iopub.execute_input': '2024-10-08T07:53:22.389284Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.019020Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.017936Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.025441',
#      'end_time': '2024-10-08T07:53:23.035781',
#      'duration': 0.01034,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:23.027515Z',
#      'iopub.execute_input': '2024-10-08T07:53:23.028237Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.033221Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.032006Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.036007',
#      'end_time': '2024-10-08T07:53:23.059346',
#      'duration': 0.023339,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:23.037417Z',
#      'iopub.execute_input': '2024-10-08T07:53:23.037845Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.056980Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.055963Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.059561',
#      'end_time': '2024-10-08T07:53:23.068268',
#      'duration': 0.008707,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:23.061034Z',
#      'iopub.execute_input': '2024-10-08T07:53:23.061526Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.065905Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.064834Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.068487',
#      'end_time': '2024-10-08T07:53:23.068760',
#      'duration': 0.000273,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.068967',
#      'end_time': '2024-10-08T07:53:23.102564',
#      'duration': 0.033597,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:23.070385Z',
#      'iopub.execute_input': '2024-10-08T07:53:23.070806Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.100065Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.098959Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:23.102787',
#      'end_time': '2024-10-08T07:53:23.142759',
#      'duration': 0.039972,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:23.104229Z',
#      'iopub.execute_input': '2024-10-08T07:53:23.104694Z',
#      'shell.execute_reply': '2024-10-08T07:53:23.138486Z',
#      'iopub.status.idle': '2024-10-08T07:53:23.139894Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N9539a29ca583497fb3b7847bbe586eaa (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-08T07:53:15.275788',
#    'end_time': '2024-10-08T07:53:23.470277',
#    'duration': 8.194489,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:07<00:00,  1.51cell/s]
# {'cells': [{'id': '6efb98fe',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:24.616703',
#      'end_time': '2024-10-08T07:53:24.641742',
#      'duration': 0.025039,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:24.621608Z',
#      'iopub.execute_input': '2024-10-08T07:53:24.622870Z',
#      'shell.execute_reply': '2024-10-08T07:53:24.638104Z',
#      'iopub.status.idle': '2024-10-08T07:53:24.639349Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:24.643124',
#      'end_time': '2024-10-08T07:53:30.458992',
#      'duration': 5.815868,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:24.644717Z',
#      'iopub.execute_input': '2024-10-08T07:53:24.645612Z',
#      'shell.execute_reply': '2024-10-08T07:53:30.448397Z',
#      'iopub.status.idle': '2024-10-08T07:53:30.451879Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:30.462189',
#      'end_time': '2024-10-08T07:53:30.492321',
#      'duration': 0.030132,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:30.468879Z',
#      'iopub.execute_input': '2024-10-08T07:53:30.469847Z',
#      'iopub.status.idle': '2024-10-08T07:53:30.485851Z',
#      'shell.execute_reply': '2024-10-08T07:53:30.483013Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:30.492886',
#      'end_time': '2024-10-08T07:53:30.581240',
#      'duration': 0.088354,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:30.497804Z',
#      'iopub.execute_input': '2024-10-08T07:53:30.501175Z',
#      'shell.execute_reply': '2024-10-08T07:53:30.578017Z',
#      'iopub.status.idle': '2024-10-08T07:53:30.578836Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:30.582110',
#      'end_time': '2024-10-08T07:53:30.582345',
#      'duration': 0.000235,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:30.582482',
#      'end_time': '2024-10-08T07:53:31.085072',
#      'duration': 0.50259,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:30.583970Z',
#      'iopub.execute_input': '2024-10-08T07:53:30.584470Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.080059Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.076849Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.087033',
#      'end_time': '2024-10-08T07:53:31.098049',
#      'duration': 0.011016,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:31.089333Z',
#      'iopub.execute_input': '2024-10-08T07:53:31.090770Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.095865Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.094443Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.098376',
#      'end_time': '2024-10-08T07:53:31.124158',
#      'duration': 0.025782,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:31.099635Z',
#      'iopub.execute_input': '2024-10-08T07:53:31.100196Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.120989Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.121744Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.124420',
#      'end_time': '2024-10-08T07:53:31.131702',
#      'duration': 0.007282,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:31.125463Z',
#      'iopub.execute_input': '2024-10-08T07:53:31.125813Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.129241Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.128497Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.131852',
#      'end_time': '2024-10-08T07:53:31.132105',
#      'duration': 0.000253,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.132245',
#      'end_time': '2024-10-08T07:53:31.157100',
#      'duration': 0.024855,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:31.133274Z',
#      'iopub.execute_input': '2024-10-08T07:53:31.133630Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.153892Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.154790Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:31.157246',
#      'end_time': '2024-10-08T07:53:31.193567',
#      'duration': 0.036321,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:31.158321Z',
#      'iopub.execute_input': '2024-10-08T07:53:31.158606Z',
#      'shell.execute_reply': '2024-10-08T07:53:31.191730Z',
#      'iopub.status.idle': '2024-10-08T07:53:31.192282Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nba717feb77cc428ab8b77909ac8e5dbc (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-08T07:53:23.575320',
#    'end_time': '2024-10-08T07:53:31.512245',
#    'duration': 7.936925,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:09<00:00,  1.89cell/s]
# {'cells': [{'id': 'c5200bce',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:32.417105',
#      'end_time': '2024-10-08T07:53:32.428278',
#      'duration': 0.011173,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:32.418588Z',
#      'iopub.execute_input': '2024-10-08T07:53:32.419333Z',
#      'shell.execute_reply': '2024-10-08T07:53:32.425258Z',
#      'iopub.status.idle': '2024-10-08T07:53:32.425991Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:32.429823',
#      'end_time': '2024-10-08T07:53:40.038410',
#      'duration': 7.608587,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:32.431767Z',
#      'iopub.execute_input': '2024-10-08T07:53:32.432355Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.028178Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.032311Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.041026',
#      'end_time': '2024-10-08T07:53:40.072369',
#      'duration': 0.031343,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.048762Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.050064Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.063301Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.066228Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.072939',
#      'end_time': '2024-10-08T07:53:40.168450',
#      'duration': 0.095511,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.076833Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.077746Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.165140Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.165985Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.169123',
#      'end_time': '2024-10-08T07:53:40.175566',
#      'duration': 0.006443,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.170192Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.170422Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.174130Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.173514Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.175765',
#      'end_time': '2024-10-08T07:53:40.187278',
#      'duration': 0.011513,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.176724Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.176973Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.185705Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.184948Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.187420',
#      'end_time': '2024-10-08T07:53:40.187648',
#      'duration': 0.000228,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.187760',
#      'end_time': '2024-10-08T07:53:40.187965',
#      'duration': 0.000205,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.188074',
#      'end_time': '2024-10-08T07:53:40.212074',
#      'duration': 0.024,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.189023Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.189231Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.209906Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.210634Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.212207',
#      'end_time': '2024-10-08T07:53:40.212418',
#      'duration': 0.000211,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.212527',
#      'end_time': '2024-10-08T07:53:40.235391',
#      'duration': 0.022864,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.213871Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.214260Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.226910Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.229945Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.235886',
#      'end_time': '2024-10-08T07:53:40.256694',
#      'duration': 0.020808,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.239058Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.240058Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.248118Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.251135Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.257188',
#      'end_time': '2024-10-08T07:53:40.279013',
#      'duration': 0.021825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.260401Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.261382Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.274413Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.271421Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.281379',
#      'end_time': '2024-10-08T07:53:40.291971',
#      'duration': 0.010592,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.284124Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.285053Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.288873Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.289919Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.292338',
#      'end_time': '2024-10-08T07:53:40.302405',
#      'duration': 0.010067,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.294024Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.294625Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.298707Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.299644Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.302721',
#      'end_time': '2024-10-08T07:53:40.303019',
#      'duration': 0.000298,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:40.303308',
#      'end_time': '2024-10-08T07:53:40.352136',
#      'duration': 0.048828,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:40.304587Z',
#      'iopub.execute_input': '2024-10-08T07:53:40.305381Z',
#      'shell.execute_reply': '2024-10-08T07:53:40.349885Z',
#      'iopub.status.idle': '2024-10-08T07:53:40.350640Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0d64ce7ad9d84c4ba32f3039a6d8cbe2 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-08T07:53:31.566506',
#    'end_time': '2024-10-08T07:53:40.573582',
#    'duration': 9.007076,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:09<00:00,  1.80cell/s]
# {'cells': [{'id': '0658f6e8',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:41.802274',
#      'end_time': '2024-10-08T07:53:41.821743',
#      'duration': 0.019469,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:41.804275Z',
#      'iopub.execute_input': '2024-10-08T07:53:41.804691Z',
#      'shell.execute_reply': '2024-10-08T07:53:41.817023Z',
#      'iopub.status.idle': '2024-10-08T07:53:41.818522Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:41.823085',
#      'end_time': '2024-10-08T07:53:49.630606',
#      'duration': 7.807521,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:41.826201Z',
#      'iopub.execute_input': '2024-10-08T07:53:41.827855Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.620887Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.623960Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.633339',
#      'end_time': '2024-10-08T07:53:49.661661',
#      'duration': 0.028322,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.638680Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.639569Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.654007Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.656656Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.662053',
#      'end_time': '2024-10-08T07:53:49.737268',
#      'duration': 0.075215,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.664391Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.664821Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.735010Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.735719Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.737943',
#      'end_time': '2024-10-08T07:53:49.746525',
#      'duration': 0.008582,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.739019Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.739311Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.743886Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.742825Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.746753',
#      'end_time': '2024-10-08T07:53:49.760598',
#      'duration': 0.013845,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.748061Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.748659Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.757016Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.757934Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.760755',
#      'end_time': '2024-10-08T07:53:49.760982',
#      'duration': 0.000227,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.761120',
#      'end_time': '2024-10-08T07:53:49.761372',
#      'duration': 0.000252,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.761510',
#      'end_time': '2024-10-08T07:53:49.787396',
#      'duration': 0.025886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.762545Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.762781Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.785737Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.784889Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.787527',
#      'end_time': '2024-10-08T07:53:49.787767',
#      'duration': 0.00024,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.787891',
#      'end_time': '2024-10-08T07:53:49.802789',
#      'duration': 0.014898,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.789032Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.789297Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.800154Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.801050Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.802930',
#      'end_time': '2024-10-08T07:53:49.810838',
#      'duration': 0.007908,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.804127Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.804455Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.808749Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.807791Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.810977',
#      'end_time': '2024-10-08T07:53:49.818605',
#      'duration': 0.007628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.811969Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.812303Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.815660Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.816398Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.818760',
#      'end_time': '2024-10-08T07:53:49.825608',
#      'duration': 0.006848,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.819849Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.820065Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.822488Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.823232Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.825780',
#      'end_time': '2024-10-08T07:53:49.833170',
#      'duration': 0.00739,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.826861Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.827450Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.830126Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.830818Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.833316',
#      'end_time': '2024-10-08T07:53:49.833555',
#      'duration': 0.000239,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-08T07:53:49.833690',
#      'end_time': '2024-10-08T07:53:49.878635',
#      'duration': 0.044945,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-08T07:53:49.834808Z',
#      'iopub.execute_input': '2024-10-08T07:53:49.835007Z',
#      'shell.execute_reply': '2024-10-08T07:53:49.875636Z',
#      'iopub.status.idle': '2024-10-08T07:53:49.876372Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nbfbe80c1342b45a18e985d170280df2b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-08T07:53:40.657430',
#    'end_time': '2024-10-08T07:53:50.098556',
#    'duration': 9.441126,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:17<00:00,  1.18s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:17<00:00,  1.16s/cell]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 2c8174e9-15d6-424a-ab7e-5128f3f6ec86
# Executing: 100%|██████████| 17/17 [00:19<00:00,  1.13s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 335eeb26-f3f6-46d7-8d1e-190ef4e77450
# Executing: 100%|██████████| 17/17 [00:19<00:00,  1.14s/cell]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c6ab3e4c-f6af-4aab-8741-d0a03e646f00
# Executing: 100%|██████████| 17/17 [00:20<00:00,  1.18s/cell]
