# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.
# El sistema no puede encontrar la ruta especificada.

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:06<00:00,  2.23cell/s]
# {'cells': [{'id': '2f281de0',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:51.845464',
#      'end_time': '2024-09-17T07:21:51.894793',
#      'duration': 0.049329,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:51.860462Z',
#      'iopub.execute_input': '2024-09-17T07:21:51.864472Z',
#      'iopub.status.idle': '2024-09-17T07:21:51.892761Z',
#      'shell.execute_reply': '2024-09-17T07:21:51.891879Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:51.895756',
#      'end_time': '2024-09-17T07:21:51.911715',
#      'duration': 0.015959,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:51.896755Z',
#      'iopub.execute_input': '2024-09-17T07:21:51.896755Z',
#      'iopub.status.idle': '2024-09-17T07:21:51.909719Z',
#      'shell.execute_reply': '2024-09-17T07:21:51.907951Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:51.911715',
#      'end_time': '2024-09-17T07:21:51.911715',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:51.911715',
#      'end_time': '2024-09-17T07:21:52.423281',
#      'duration': 0.511566,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:51.912733Z',
#      'iopub.execute_input': '2024-09-17T07:21:51.913746Z',
#      'shell.execute_reply': '2024-09-17T07:21:52.420322Z',
#      'iopub.status.idle': '2024-09-17T07:21:52.420322Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:52.424281',
#      'end_time': '2024-09-17T07:21:52.473147',
#      'duration': 0.048866,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:52.427270Z',
#      'iopub.execute_input': '2024-09-17T07:21:52.428269Z',
#      'iopub.status.idle': '2024-09-17T07:21:52.471152Z',
#      'shell.execute_reply': '2024-09-17T07:21:52.468194Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:52.473147',
#      'end_time': '2024-09-17T07:21:52.473147',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:52.473147',
#      'end_time': '2024-09-17T07:21:52.488106',
#      'duration': 0.014959,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:52.474144Z',
#      'iopub.execute_input': '2024-09-17T07:21:52.475142Z',
#      'iopub.status.idle': '2024-09-17T07:21:52.486255Z',
#      'shell.execute_reply': '2024-09-17T07:21:52.484118Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:52.488106',
#      'end_time': '2024-09-17T07:21:56.189692',
#      'duration': 3.701586,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:52.489103Z',
#      'iopub.execute_input': '2024-09-17T07:21:52.489103Z',
#      'shell.execute_reply': '2024-09-17T07:21:56.186799Z',
#      'iopub.status.idle': '2024-09-17T07:21:56.187877Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (0.6.2)\nRequirement already satisfied: rdflib>=5.0.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib_jsonld) (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.189692',
#      'end_time': '2024-09-17T07:21:56.190505',
#      'duration': 0.000813,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.190505',
#      'end_time': '2024-09-17T07:21:56.205495',
#      'duration': 0.01499,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:56.191505Z',
#      'iopub.execute_input': '2024-09-17T07:21:56.191505Z',
#      'shell.execute_reply': '2024-09-17T07:21:56.202513Z',
#      'iopub.status.idle': '2024-09-17T07:21:56.203474Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.205495',
#      'end_time': '2024-09-17T07:21:56.236385',
#      'duration': 0.03089,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:56.206465Z',
#      'iopub.execute_input': '2024-09-17T07:21:56.206465Z',
#      'shell.execute_reply': '2024-09-17T07:21:56.234391Z',
#      'iopub.status.idle': '2024-09-17T07:21:56.234391Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.236385',
#      'end_time': '2024-09-17T07:21:56.236385',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.237382',
#      'end_time': '2024-09-17T07:21:56.282278',
#      'duration': 0.044896,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:56.238380Z',
#      'iopub.execute_input': '2024-09-17T07:21:56.238380Z',
#      'shell.execute_reply': '2024-09-17T07:21:56.280279Z',
#      'iopub.status.idle': '2024-09-17T07:21:56.281281Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.283275',
#      'end_time': '2024-09-17T07:21:56.283275',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:56.283275',
#      'end_time': '2024-09-17T07:21:56.314300',
#      'duration': 0.031025,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:56.284306Z',
#      'iopub.execute_input': '2024-09-17T07:21:56.285271Z',
#      'shell.execute_reply': '2024-09-17T07:21:56.311305Z',
#      'iopub.status.idle': '2024-09-17T07:21:56.312306Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N705f1aa37a7841b18cd4e753a9621b07 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-17T07:21:49.846488',
#    'end_time': '2024-09-17T07:21:56.574652',
#    'duration': 6.728164,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"C:\Users\Usuario\PycharmProjects\Fdatavalidation\DataProductLayer\DataProduct\Data\Explotation\UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:10<00:00,  1.11cell/s]
# {'cells': [{'id': '7773ee72',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:58.149655',
#      'end_time': '2024-09-17T07:21:58.168651',
#      'duration': 0.018996,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:58.151666Z',
#      'iopub.execute_input': '2024-09-17T07:21:58.151666Z',
#      'shell.execute_reply': '2024-09-17T07:21:58.164612Z',
#      'iopub.status.idle': '2024-09-17T07:21:58.165612Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\nfile_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataProductLayer\\\\DataProduct\\\\Data\\\\Explotation\\\\UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:21:58.169650',
#      'end_time': '2024-09-17T07:22:04.519547',
#      'duration': 6.349897,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:21:58.170599Z',
#      'iopub.execute_input': '2024-09-17T07:21:58.171596Z',
#      'shell.execute_reply': '2024-09-17T07:22:04.516531Z',
#      'iopub.status.idle': '2024-09-17T07:22:04.517528Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.2.2)\nRequirement already satisfied: numpy>=1.22.4 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.1.0)\nRequirement already satisfied: python-dateutil>=2.8.2 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.9.0.post0)\nRequirement already satisfied: pytz>=2020.1 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: tzdata>=2022.7 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: six>=1.5 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.4.4)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:04.519547',
#      'end_time': '2024-09-17T07:22:04.535162',
#      'duration': 0.015615,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:04.521517Z',
#      'iopub.execute_input': '2024-09-17T07:22:04.521517Z',
#      'shell.execute_reply': '2024-09-17T07:22:04.531885Z',
#      'iopub.status.idle': '2024-09-17T07:22:04.533120Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:04.535162',
#      'end_time': '2024-09-17T07:22:04.660826',
#      'duration': 0.125664,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:04.536116Z',
#      'iopub.execute_input': '2024-09-17T07:22:04.536116Z',
#      'shell.execute_reply': '2024-09-17T07:22:04.657708Z',
#      'iopub.status.idle': '2024-09-17T07:22:04.658793Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:04.660826',
#      'end_time': '2024-09-17T07:22:04.661625',
#      'duration': 0.000799,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:04.661625',
#      'end_time': '2024-09-17T07:22:07.036638',
#      'duration': 2.375013,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:04.662625Z',
#      'iopub.execute_input': '2024-09-17T07:22:04.663623Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.033645Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.034644Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.037636',
#      'end_time': '2024-09-17T07:22:07.053593',
#      'duration': 0.015957,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:07.040628Z',
#      'iopub.execute_input': '2024-09-17T07:22:07.041626Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.049606Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.050601Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.053593',
#      'end_time': '2024-09-17T07:22:07.086509',
#      'duration': 0.032916,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:07.054591Z',
#      'iopub.execute_input': '2024-09-17T07:22:07.055590Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.083531Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.081518Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.086509',
#      'end_time': '2024-09-17T07:22:07.101465',
#      'duration': 0.014956,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:07.087503Z',
#      'iopub.execute_input': '2024-09-17T07:22:07.088501Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.099472Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.097476Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.101465',
#      'end_time': '2024-09-17T07:22:07.102463',
#      'duration': 0.000998,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.102463',
#      'end_time': '2024-09-17T07:22:07.147343',
#      'duration': 0.04488,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:07.103460Z',
#      'iopub.execute_input': '2024-09-17T07:22:07.104460Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.145348Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.144384Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:07.149340',
#      'end_time': '2024-09-17T07:22:07.194247',
#      'duration': 0.044907,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:07.152330Z',
#      'iopub.execute_input': '2024-09-17T07:22:07.152330Z',
#      'shell.execute_reply': '2024-09-17T07:22:07.191252Z',
#      'iopub.status.idle': '2024-09-17T07:22:07.192223Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne4f7a746e3cf4efeb42b74d9ba64cc4c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration',
#     'file_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataProductLayer\\DataProduct\\Data\\Explotation\\UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-17T07:21:56.731220',
#    'end_time': '2024-09-17T07:22:07.566064',
#    'duration': 10.834844,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"C:\Users\Usuario\PycharmProjects\Fdatavalidation\DataProductLayer\DataProduct2\Data\0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:08<00:00,  1.38cell/s]
# {'cells': [{'id': 'a853d671',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:09.203091',
#      'end_time': '2024-09-17T07:22:09.240051',
#      'duration': 0.03696,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:09.207090Z',
#      'iopub.execute_input': '2024-09-17T07:22:09.208134Z',
#      'shell.execute_reply': '2024-09-17T07:22:09.234200Z',
#      'iopub.status.idle': '2024-09-17T07:22:09.236064Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Registration"\nfile_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataProductLayer\\\\DataProduct2\\\\Data\\\\0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:09.241053',
#      'end_time': '2024-09-17T07:22:15.143355',
#      'duration': 5.902302,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:09.245041Z',
#      'iopub.execute_input': '2024-09-17T07:22:09.247033Z',
#      'iopub.status.idle': '2024-09-17T07:22:15.141359Z',
#      'shell.execute_reply': '2024-09-17T07:22:15.140396Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (7.0.0)\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (0.6.1)\nRequirement already satisfied: pyparsing<4,>=2.1.0 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from rdflib) (3.1.4)\nRequirement already satisfied: six in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.2.2)\nRequirement already satisfied: numpy>=1.22.4 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.1.0)\nRequirement already satisfied: python-dateutil>=2.8.2 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2.9.0.post0)\nRequirement already satisfied: pytz>=2020.1 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: tzdata>=2022.7 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from pandas) (2024.1)\nRequirement already satisfied: six>=1.5 in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in c:\\users\\usuario\\pycharmprojects\\fdatavalidation\\venv\\lib\\site-packages (2.4.4)\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n[notice] A new release of pip is available: 23.2.1 -> 24.2\n[notice] To update, run: python.exe -m pip install --upgrade pip\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:15.144351',
#      'end_time': '2024-09-17T07:22:15.159311',
#      'duration': 0.01496,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:15.147344Z',
#      'iopub.execute_input': '2024-09-17T07:22:15.148342Z',
#      'shell.execute_reply': '2024-09-17T07:22:15.156318Z',
#      'iopub.status.idle': '2024-09-17T07:22:15.157316Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:15.159311',
#      'end_time': '2024-09-17T07:22:15.300931',
#      'duration': 0.14162,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:15.161306Z',
#      'iopub.execute_input': '2024-09-17T07:22:15.161306Z',
#      'iopub.status.idle': '2024-09-17T07:22:15.298937Z',
#      'shell.execute_reply': '2024-09-17T07:22:15.297940Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:15.301929',
#      'end_time': '2024-09-17T07:22:15.301929',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:15.301929',
#      'end_time': '2024-09-17T07:22:16.037642',
#      'duration': 0.735713,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:15.303924Z',
#      'iopub.execute_input': '2024-09-17T07:22:15.304922Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.036618Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.035810Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.038612',
#      'end_time': '2024-09-17T07:22:16.052856',
#      'duration': 0.014244,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:16.040607Z',
#      'iopub.execute_input': '2024-09-17T07:22:16.041604Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.050826Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.051826Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.052856',
#      'end_time': '2024-09-17T07:22:16.085261',
#      'duration': 0.032405,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:16.053849Z',
#      'iopub.execute_input': '2024-09-17T07:22:16.054884Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.082575Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.083270Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.085261',
#      'end_time': '2024-09-17T07:22:16.100218',
#      'duration': 0.014957,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:16.086258Z',
#      'iopub.execute_input': '2024-09-17T07:22:16.086258Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.098189Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.099187Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.100218',
#      'end_time': '2024-09-17T07:22:16.101181',
#      'duration': 0.000963,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.101181',
#      'end_time': '2024-09-17T07:22:16.133024',
#      'duration': 0.031843,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:16.102212Z',
#      'iopub.execute_input': '2024-09-17T07:22:16.102212Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.129899Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.131082Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:16.133024',
#      'end_time': '2024-09-17T07:22:16.178421',
#      'duration': 0.045397,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:16.133282Z',
#      'iopub.execute_input': '2024-09-17T07:22:16.134316Z',
#      'shell.execute_reply': '2024-09-17T07:22:16.175647Z',
#      'iopub.status.idle': '2024-09-17T07:22:16.176649Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N92a1bbbb91cc4ebf998d7a8cfbcafc39 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration',
#     'file_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataProductLayer\\DataProduct2\\Data\\0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-17T07:22:07.721639',
#    'end_time': '2024-09-17T07:22:16.415815',
#    'duration': 8.694176,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:02<00:00,  7.81cell/s]
# {'cells': [{'id': 'd5f1f97f',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:17.884401',
#      'end_time': '2024-09-17T07:22:17.920422',
#      'duration': 0.036021,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:17.888441Z',
#      'iopub.execute_input': '2024-09-17T07:22:17.890391Z',
#      'shell.execute_reply': '2024-09-17T07:22:17.915576Z',
#      'iopub.status.idle': '2024-09-17T07:22:17.917389Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\ndp_meta_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:17.921156',
#      'end_time': '2024-09-17T07:22:18.075296',
#      'duration': 0.15414,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:17.924153Z',
#      'iopub.execute_input': '2024-09-17T07:22:17.924153Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.073269Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.072266Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.075296',
#      'end_time': '2024-09-17T07:22:18.090910',
#      'duration': 0.015614,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.077259Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.077259Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.088734Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.087985Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.090910',
#      'end_time': '2024-09-17T07:22:18.200464',
#      'duration': 0.109554,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.091163Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.092197Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.198720Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.199463Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.201461',
#      'end_time': '2024-09-17T07:22:18.216443',
#      'duration': 0.014982,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.202458Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.203455Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.214547Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.215445Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.217439',
#      'end_time': '2024-09-17T07:22:18.233029',
#      'duration': 0.01559,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.218437Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.218437Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.231001Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.229999Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.233029',
#      'end_time': '2024-09-17T07:22:18.233556',
#      'duration': 0.000527,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.233556',
#      'end_time': '2024-09-17T07:22:18.233920',
#      'duration': 0.000364,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.233920',
#      'end_time': '2024-09-17T07:22:18.279564',
#      'duration': 0.045644,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.234145Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.235181Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.276759Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.276759Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.279564',
#      'end_time': '2024-09-17T07:22:18.279564',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.279564',
#      'end_time': '2024-09-17T07:22:18.294810',
#      'duration': 0.015246,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.280596Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.281559Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.292142Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.292812Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.294810',
#      'end_time': '2024-09-17T07:22:18.319477',
#      'duration': 0.024667,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.295807Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.296804Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.312460Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.307518Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.321433',
#      'end_time': '2024-09-17T07:22:18.342254',
#      'duration': 0.020821,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.324422Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.325420Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.338995Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.340223Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.343218',
#      'end_time': '2024-09-17T07:22:18.358389',
#      'duration': 0.015171,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.344368Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.344368Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.355713Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.354707Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.358389',
#      'end_time': '2024-09-17T07:22:18.374338',
#      'duration': 0.015949,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.359741Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.359741Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.370569Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.371313Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.374338',
#      'end_time': '2024-09-17T07:22:18.374338',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:18.374338',
#      'end_time': '2024-09-17T07:22:18.434691',
#      'duration': 0.060353,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:18.376300Z',
#      'iopub.execute_input': '2024-09-17T07:22:18.376300Z',
#      'iopub.status.idle': '2024-09-17T07:22:18.433661Z',
#      'shell.execute_reply': '2024-09-17T07:22:18.432659Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N32ad08c3cc5d45bd945bcde506555118 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration',
#     'dp_meta_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-17T07:22:16.507566',
#    'end_time': '2024-09-17T07:22:18.686254',
#    'duration': 2.178688,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:02<00:00,  8.19cell/s]
# {'cells': [{'id': '10fdf1e1',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.105334',
#      'end_time': '2024-09-17T07:22:20.139677',
#      'duration': 0.034343,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.111313Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.113309Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.134641Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.135640Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration"\ndp_meta_path = "C:\\\\Users\\\\Usuario\\\\PycharmProjects\\\\Fdatavalidation\\\\DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.140660',
#      'end_time': '2024-09-17T07:22:20.278488',
#      'duration': 0.137828,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.142621Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.143617Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.275490Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.276491Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'El sistema no puede encontrar la ruta especificada.\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.280482',
#      'end_time': '2024-09-17T07:22:20.294052',
#      'duration': 0.01357,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.281479Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.282477Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.292020Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.290926Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.294052',
#      'end_time': '2024-09-17T07:22:20.431858',
#      'duration': 0.137806,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.295015Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.295015Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.428987Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.429860Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.432857',
#      'end_time': '2024-09-17T07:22:20.448253',
#      'duration': 0.015396,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.433854Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.433854Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.444558Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.445225Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.448253',
#      'end_time': '2024-09-17T07:22:20.462595',
#      'duration': 0.014342,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.449721Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.449721Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.460601Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.459599Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.462595',
#      'end_time': '2024-09-17T07:22:20.462595',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.463594',
#      'end_time': '2024-09-17T07:22:20.463594',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.463594',
#      'end_time': '2024-09-17T07:22:20.507490',
#      'duration': 0.043896,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.464590Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.465621Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.505456Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.505456Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.507490',
#      'end_time': '2024-09-17T07:22:20.508451',
#      'duration': 0.000961,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.508451',
#      'end_time': '2024-09-17T07:22:20.523775',
#      'duration': 0.015324,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.509448Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.509448Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.521774Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.520802Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.523775',
#      'end_time': '2024-09-17T07:22:20.538674',
#      'duration': 0.014899,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.524807Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.524807Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.536647Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.535644Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.538674',
#      'end_time': '2024-09-17T07:22:20.554000',
#      'duration': 0.015326,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.539475Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.540476Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.551272Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.552272Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.554000',
#      'end_time': '2024-09-17T07:22:20.568821',
#      'duration': 0.014821,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.554245Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.555279Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.566043Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.566798Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.568821',
#      'end_time': '2024-09-17T07:22:20.583174',
#      'duration': 0.014353,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.569786Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.570820Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.581380Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.582173Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.584171',
#      'end_time': '2024-09-17T07:22:20.584171',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-17T07:22:20.584171',
#      'end_time': '2024-09-17T07:22:20.648646',
#      'duration': 0.064475,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-17T07:22:20.585169Z',
#      'iopub.execute_input': '2024-09-17T07:22:20.585169Z',
#      'shell.execute_reply': '2024-09-17T07:22:20.644895Z',
#      'iopub.status.idle': '2024-09-17T07:22:20.646613Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N4d8e47b8eb77421da71222b2d3452112 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration',
#     'dp_meta_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Usuario\\PycharmProjects\\Fdatavalidation\\DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-09-17T07:22:18.805833',
#    'end_time': '2024-09-17T07:22:20.882554',
#    'duration': 2.076721,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:03<00:00,  3.77cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:03<00:00,  4.77cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 6a9d7fc0-1468-422d-8e90-79ce657416a7
# Executing: 100%|██████████| 17/17 [00:03<00:00,  5.43cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 77c78862-11f7-4c9b-9b5e-5e982f2e5f7a
# Executing: 100%|██████████| 17/17 [00:03<00:00,  5.16cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# cc4d6532-c660-434c-977d-120a4f5c95dc
# Executing: 100%|██████████| 17/17 [00:03<00:00,  4.72cell/s]
