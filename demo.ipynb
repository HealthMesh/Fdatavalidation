# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm
import os   
from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '9198e9cb',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.069581',
#      'end_time': '2024-05-26T21:11:35.089465',
#      'duration': 0.019884,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.071424Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.071884Z',
#      'shell.execute_reply': '2024-05-26T21:11:35.084458Z',
#      'iopub.status.idle': '2024-05-26T21:11:35.086503Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.090802',
#      'end_time': '2024-05-26T21:11:35.107472',
#      'duration': 0.01667,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.093569Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.095180Z',
#      'iopub.status.idle': '2024-05-26T21:11:35.102470Z',
#      'shell.execute_reply': '2024-05-26T21:11:35.100595Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.108176',
#      'end_time': '2024-05-26T21:11:35.108696',
#      'duration': 0.00052,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.109205',
#      'end_time': '2024-05-26T21:11:35.404882',
#      'duration': 0.295677,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.113154Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.114272Z',
#      'iopub.status.idle': '2024-05-26T21:11:35.399471Z',
#      'shell.execute_reply': '2024-05-26T21:11:35.397719Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.406637',
#      'end_time': '2024-05-26T21:11:35.467980',
#      'duration': 0.061343,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.409507Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.410689Z',
#      'iopub.status.idle': '2024-05-26T21:11:35.460665Z',
#      'shell.execute_reply': '2024-05-26T21:11:35.458505Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.468647',
#      'end_time': '2024-05-26T21:11:35.469203',
#      'duration': 0.000556,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.469634',
#      'end_time': '2024-05-26T21:11:35.470028',
#      'duration': 0.000394,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.470392',
#      'end_time': '2024-05-26T21:11:35.487534',
#      'duration': 0.017142,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.472347Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.472757Z',
#      'iopub.status.idle': '2024-05-26T21:11:35.482385Z',
#      'shell.execute_reply': '2024-05-26T21:11:35.480505Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:35.488023',
#      'end_time': '2024-05-26T21:11:38.745994',
#      'duration': 3.257971,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:35.490501Z',
#      'iopub.execute_input': '2024-05-26T21:11:35.491094Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.738569Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.735879Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.748562',
#      'end_time': '2024-05-26T21:11:38.750150',
#      'duration': 0.001588,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.750935',
#      'end_time': '2024-05-26T21:11:38.783112',
#      'duration': 0.032177,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.757367Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.759484Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.772000Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.774850Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.783925',
#      'end_time': '2024-05-26T21:11:38.824861',
#      'duration': 0.040936,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.788647Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.790147Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.819618Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.817131Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.825374',
#      'end_time': '2024-05-26T21:11:38.826003',
#      'duration': 0.000629,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.826508',
#      'end_time': '2024-05-26T21:11:38.845561',
#      'duration': 0.019053,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.829316Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.829935Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.836437Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.838736Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.846130',
#      'end_time': '2024-05-26T21:11:38.870421',
#      'duration': 0.024291,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.849613Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.851350Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.861650Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.863948Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.872469',
#      'end_time': '2024-05-26T21:11:38.873876',
#      'duration': 0.001407,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.874400',
#      'end_time': '2024-05-26T21:11:38.893078',
#      'duration': 0.018678,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.877335Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.878091Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.884762Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.887926Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.893602',
#      'end_time': '2024-05-26T21:11:38.910950',
#      'duration': 0.017348,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.896733Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.897409Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.904517Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.902577Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.911732',
#      'end_time': '2024-05-26T21:11:38.912560',
#      'duration': 0.000828,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.913292',
#      'end_time': '2024-05-26T21:11:38.932476',
#      'duration': 0.019184,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.916432Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.918041Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.924656Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.926856Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.933002',
#      'end_time': '2024-05-26T21:11:38.933674',
#      'duration': 0.000672,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:38.934184',
#      'end_time': '2024-05-26T21:11:38.984459',
#      'duration': 0.050275,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:38.936922Z',
#      'iopub.execute_input': '2024-05-26T21:11:38.937608Z',
#      'shell.execute_reply': '2024-05-26T21:11:38.977507Z',
#      'iopub.status.idle': '2024-05-26T21:11:38.979473Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0862bf0a80fa495681288ea9fef06b60 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T21:11:32.401909',
#    'end_time': '2024-05-26T21:11:39.416743',
#    'duration': 7.014834,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T21:11:39.472270',
#    'end_time': '2024-05-26T21:11:47.440754',
#    'duration': 7.968484,
#    'exception': None}},
#  'cells': [{'id': '7cd494db',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:40.463863',
#      'end_time': '2024-05-26T21:11:40.476899',
#      'duration': 0.013036,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:40.465651Z',
#      'iopub.execute_input': '2024-05-26T21:11:40.466337Z',
#      'shell.execute_reply': '2024-05-26T21:11:40.472611Z',
#      'iopub.status.idle': '2024-05-26T21:11:40.473702Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:40.477780',
#      'end_time': '2024-05-26T21:11:40.489477',
#      'duration': 0.011697,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:40.479738Z',
#      'iopub.execute_input': '2024-05-26T21:11:40.480336Z',
#      'iopub.status.idle': '2024-05-26T21:11:40.486958Z',
#      'shell.execute_reply': '2024-05-26T21:11:40.485803Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '78077f92'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:40.489788',
#      'end_time': '2024-05-26T21:11:40.500269',
#      'duration': 0.010481,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:40.491448Z',
#      'iopub.execute_input': '2024-05-26T21:11:40.492167Z',
#      'shell.execute_reply': '2024-05-26T21:11:40.496043Z',
#      'iopub.status.idle': '2024-05-26T21:11:40.497153Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '2762092c'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:40.500601',
#      'end_time': '2024-05-26T21:11:45.706798',
#      'duration': 5.206197,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:40.502278Z',
#      'iopub.execute_input': '2024-05-26T21:11:40.502692Z',
#      'shell.execute_reply': '2024-05-26T21:11:45.703145Z',
#      'iopub.status.idle': '2024-05-26T21:11:45.704123Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': 'a586a8d9'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:45.707588',
#      'end_time': '2024-05-26T21:11:45.708052',
#      'duration': 0.000464,
#      'status': 'completed'}},
#    'id': '67d7a2a3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:45.708250',
#      'end_time': '2024-05-26T21:11:45.720154',
#      'duration': 0.011904,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:45.710078Z',
#      'iopub.execute_input': '2024-05-26T21:11:45.710827Z',
#      'shell.execute_reply': '2024-05-26T21:11:45.717383Z',
#      'iopub.status.idle': '2024-05-26T21:11:45.718146Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'e50f36cb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:45.720354',
#      'end_time': '2024-05-26T21:11:45.720648',
#      'duration': 0.000294,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'd1280c73'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:45.720840',
#      'end_time': '2024-05-26T21:11:46.661851',
#      'duration': 0.941011,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:45.721924Z',
#      'iopub.execute_input': '2024-05-26T21:11:45.722166Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.659084Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.659874Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': 'e25f9c4c'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.662626',
#      'end_time': '2024-05-26T21:11:46.691835',
#      'duration': 0.029209,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.664065Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.664402Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.690076Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.689252Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '436f168c'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.692112',
#      'end_time': '2024-05-26T21:11:46.692364',
#      'duration': 0.000252,
#      'status': 'completed'}},
#    'id': '687dcc54'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.692609',
#      'end_time': '2024-05-26T21:11:46.692841',
#      'duration': 0.000232,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'a0168164'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.693085',
#      'end_time': '2024-05-26T21:11:46.700172',
#      'duration': 0.007087,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.694155Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.694411Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.697219Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.698016Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'f3cf9bef'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.700449',
#      'end_time': '2024-05-26T21:11:46.713006',
#      'duration': 0.012557,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.701526Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.701763Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.709066Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.709997Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '36c9f576'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.713295',
#      'end_time': '2024-05-26T21:11:46.713625',
#      'duration': 0.00033,
#      'status': 'completed'}},
#    'id': 'b978daed'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.713888',
#      'end_time': '2024-05-26T21:11:46.731504',
#      'duration': 0.017616,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.715455Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.715792Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.727388Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.726036Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': 'c6652546'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.731910',
#      'end_time': '2024-05-26T21:11:46.732414',
#      'duration': 0.000504,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '7aa9ec17'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.732822',
#      'end_time': '2024-05-26T21:11:46.757716',
#      'duration': 0.024894,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.735229Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.736681Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.751611Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.749170Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na6f4a07e34d8479c8360442a3fc2a8ac (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '62cdb627'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.758585',
#      'end_time': '2024-05-26T21:11:46.759320',
#      'duration': 0.000735,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'dbdce25f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.760083',
#      'end_time': '2024-05-26T21:11:46.782821',
#      'duration': 0.022738,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.763566Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.764242Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.775858Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.778039Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '63018ef2'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.785283',
#      'end_time': '2024-05-26T21:11:46.786233',
#      'duration': 0.00095,
#      'status': 'completed'}},
#    'id': '32221a5e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.786737',
#      'end_time': '2024-05-26T21:11:46.787732',
#      'duration': 0.000995,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '3d6a3b2a'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.788235',
#      'end_time': '2024-05-26T21:11:46.813411',
#      'duration': 0.025176,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.792427Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.793974Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.807546Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.804970Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '1b30611d'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.813946',
#      'end_time': '2024-05-26T21:11:46.840029',
#      'duration': 0.026083,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.817640Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.819039Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.834797Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.832582Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na6f4a07e34d8479c8360442a3fc2a8ac (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'e4a265bb'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.840558',
#      'end_time': '2024-05-26T21:11:46.841071',
#      'duration': 0.000513,
#      'status': 'completed'}},
#    'id': '6b9ccd35'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.841503',
#      'end_time': '2024-05-26T21:11:46.869795',
#      'duration': 0.028292,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.844215Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.844874Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.863948Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.861354Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na6f4a07e34d8479c8360442a3fc2a8ac (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': 'ccc420d9'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.870362',
#      'end_time': '2024-05-26T21:11:46.870995',
#      'duration': 0.000633,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '2859523d'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:46.871582',
#      'end_time': '2024-05-26T21:11:46.904916',
#      'duration': 0.033334,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:46.874930Z',
#      'iopub.execute_input': '2024-05-26T21:11:46.875782Z',
#      'shell.execute_reply': '2024-05-26T21:11:46.896671Z',
#      'iopub.status.idle': '2024-05-26T21:11:46.899357Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Na6f4a07e34d8479c8360442a3fc2a8ac (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '3ef53e24'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T21:11:47.589699',
#    'end_time': '2024-05-26T21:11:55.143288',
#    'duration': 7.553589,
#    'exception': None}},
#  'cells': [{'id': 'a3c97302',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:48.615874',
#      'end_time': '2024-05-26T21:11:48.645727',
#      'duration': 0.029853,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:48.620012Z',
#      'iopub.execute_input': '2024-05-26T21:11:48.622319Z',
#      'shell.execute_reply': '2024-05-26T21:11:48.637543Z',
#      'iopub.status.idle': '2024-05-26T21:11:48.639884Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:48.648544',
#      'end_time': '2024-05-26T21:11:48.679190',
#      'duration': 0.030646,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:48.653825Z',
#      'iopub.execute_input': '2024-05-26T21:11:48.656016Z',
#      'shell.execute_reply': '2024-05-26T21:11:48.670613Z',
#      'iopub.status.idle': '2024-05-26T21:11:48.673227Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '96aa34e5'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:48.679778',
#      'end_time': '2024-05-26T21:11:53.803170',
#      'duration': 5.123392,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:48.683186Z',
#      'iopub.execute_input': '2024-05-26T21:11:48.685920Z',
#      'shell.execute_reply': '2024-05-26T21:11:53.800126Z',
#      'iopub.status.idle': '2024-05-26T21:11:53.801080Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '58076cae'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:53.803994',
#      'end_time': '2024-05-26T21:11:53.813582',
#      'duration': 0.009588,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:53.805591Z',
#      'iopub.execute_input': '2024-05-26T21:11:53.805904Z',
#      'iopub.status.idle': '2024-05-26T21:11:53.811208Z',
#      'shell.execute_reply': '2024-05-26T21:11:53.810155Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '3aa613a9'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:53.813777',
#      'end_time': '2024-05-26T21:11:53.813975',
#      'duration': 0.000198,
#      'status': 'completed'}},
#    'id': '68c90233'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:53.814146',
#      'end_time': '2024-05-26T21:11:53.826025',
#      'duration': 0.011879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:53.815492Z',
#      'iopub.execute_input': '2024-05-26T21:11:53.815754Z',
#      'shell.execute_reply': '2024-05-26T21:11:53.821853Z',
#      'iopub.status.idle': '2024-05-26T21:11:53.822883Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': 'f1890450'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:53.826323',
#      'end_time': '2024-05-26T21:11:53.826609',
#      'duration': 0.000286,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'ac0d26a6'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:53.826880',
#      'end_time': '2024-05-26T21:11:54.243809',
#      'duration': 0.416929,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:53.828504Z',
#      'iopub.execute_input': '2024-05-26T21:11:53.829335Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.240878Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.241674Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': '339327a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.244621',
#      'end_time': '2024-05-26T21:11:54.583781',
#      'duration': 0.33916,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.246042Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.246787Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.578624Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.580015Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': '1457c1c5'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.585267',
#      'end_time': '2024-05-26T21:11:54.616631',
#      'duration': 0.031364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.587814Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.588391Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.613643Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.614390Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '724329f5'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.616879',
#      'end_time': '2024-05-26T21:11:54.617100',
#      'duration': 0.000221,
#      'status': 'completed'}},
#    'id': '1cd4ca64'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.617273',
#      'end_time': '2024-05-26T21:11:54.617449',
#      'duration': 0.000176,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'b31bcd8e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.617619',
#      'end_time': '2024-05-26T21:11:54.625305',
#      'duration': 0.007686,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.619139Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.619513Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.622536Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.623479Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': '940c615f'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.625578',
#      'end_time': '2024-05-26T21:11:54.637357',
#      'duration': 0.011779,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.626728Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.627322Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.634487Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.635352Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '85096ad4'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.637556',
#      'end_time': '2024-05-26T21:11:54.637832',
#      'duration': 0.000276,
#      'status': 'completed'}},
#    'id': 'abb823d5'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.638017',
#      'end_time': '2024-05-26T21:11:54.648091',
#      'duration': 0.010074,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.639180Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.639519Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.646312Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.645693Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': 'd43f6267'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.648289',
#      'end_time': '2024-05-26T21:11:54.648525',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': 'a44eb7ce'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.648689',
#      'end_time': '2024-05-26T21:11:54.657432',
#      'duration': 0.008743,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.649778Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.650015Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.655174Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.655800Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N281267206fe74e23a87e663b635c48ab (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '87cce74d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.657630',
#      'end_time': '2024-05-26T21:11:54.657866',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'eef92df8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.658030',
#      'end_time': '2024-05-26T21:11:54.669844',
#      'duration': 0.011814,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.659159Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.659397Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.667433Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.668067Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '64b2c748'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.670038',
#      'end_time': '2024-05-26T21:11:54.670285',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'id': 'be287b18'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.670451',
#      'end_time': '2024-05-26T21:11:54.670667',
#      'duration': 0.000216,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'e243d77d'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.670825',
#      'end_time': '2024-05-26T21:11:54.677130',
#      'duration': 0.006305,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.671823Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.672056Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.674496Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.675328Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '2bbacf87'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.677331',
#      'end_time': '2024-05-26T21:11:54.687289',
#      'duration': 0.009958,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.678340Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.678577Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.684407Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.683689Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N281267206fe74e23a87e663b635c48ab (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '10e9e248'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.688063',
#      'end_time': '2024-05-26T21:11:54.688539',
#      'duration': 0.000476,
#      'status': 'completed'}},
#    'id': 'dc651260'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.688775',
#      'end_time': '2024-05-26T21:11:54.702288',
#      'duration': 0.013513,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.690401Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.690821Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.698796Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.699682Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N281267206fe74e23a87e663b635c48ab (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '4aa39b19'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.702493',
#      'end_time': '2024-05-26T21:11:54.702734',
#      'duration': 0.000241,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '033068fb'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:54.702924',
#      'end_time': '2024-05-26T21:11:54.718776',
#      'duration': 0.015852,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:54.704110Z',
#      'iopub.execute_input': '2024-05-26T21:11:54.704355Z',
#      'iopub.status.idle': '2024-05-26T21:11:54.716468Z',
#      'shell.execute_reply': '2024-05-26T21:11:54.715565Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N281267206fe74e23a87e663b635c48ab (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '236a5018'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T21:11:55.339993',
#    'end_time': '2024-05-26T21:11:59.697007',
#    'duration': 4.357014,
#    'exception': None}},
#  'cells': [{'id': '445e0ef0',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.460542',
#      'end_time': '2024-05-26T21:11:56.490470',
#      'duration': 0.029928,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.464119Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.464796Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.485153Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.482446Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.492658',
#      'end_time': '2024-05-26T21:11:56.508757',
#      'duration': 0.016099,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.496991Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.497654Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.505582Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.504169Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'f68d9b2e'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.509039',
#      'end_time': '2024-05-26T21:11:56.616348',
#      'duration': 0.107309,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.510811Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.511758Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.612647Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.613586Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'e52e38eb'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.617247',
#      'end_time': '2024-05-26T21:11:56.628349',
#      'duration': 0.011102,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.619038Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.619818Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.625625Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.624632Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': 'a769d1e1'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.628575',
#      'end_time': '2024-05-26T21:11:56.628844',
#      'duration': 0.000269,
#      'status': 'completed'}},
#    'id': '3b9c595c'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.629064',
#      'end_time': '2024-05-26T21:11:56.651318',
#      'duration': 0.022254,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.630401Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.631041Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.647849Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.648811Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '2fd3b558'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.651660',
#      'end_time': '2024-05-26T21:11:56.665300',
#      'duration': 0.01364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.653223Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.653646Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.661788Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.662778Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:f180f488-9d61-4ae4-8b79-f10ff41ce324 .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\nab:f180f488-9d61-4ae4-8b79-f10ff41ce324 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\n\n'}],
#    'id': '95bf9a59'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.665523',
#      'end_time': '2024-05-26T21:11:56.665786',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'id': '3827c6ed'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.665996',
#      'end_time': '2024-05-26T21:11:56.673899',
#      'duration': 0.007903,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.667352Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.667983Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.670481Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.671432Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '86df4098'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.674121',
#      'end_time': '2024-05-26T21:11:56.674378',
#      'duration': 0.000257,
#      'status': 'completed'}},
#    'id': '1757c05e'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.674590',
#      'end_time': '2024-05-26T21:11:56.682015',
#      'duration': 0.007425,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.675802Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.676067Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.679656Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.678875Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '6fb0f249'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.682321',
#      'end_time': '2024-05-26T21:11:56.682598',
#      'duration': 0.000277,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'a5d97cf1'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.682872',
#      'end_time': '2024-05-26T21:11:56.693352',
#      'duration': 0.01048,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.684279Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.684931Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.690007Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.690951Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '4e9538ab'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.693589',
#      'end_time': '2024-05-26T21:11:56.693890',
#      'duration': 0.000301,
#      'status': 'completed'}},
#    'id': '0b73ef5e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.694094',
#      'end_time': '2024-05-26T21:11:56.703795',
#      'duration': 0.009701,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.695324Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.695583Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.701006Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.701785Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'e9eaadc5'},
#   {'cell_type': 'code',
#    'source': '# ID - SUBJECT\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.704033',
#      'end_time': '2024-05-26T21:11:56.711513',
#      'duration': 0.00748,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.705309Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.705873Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.708068Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.708980Z'}},
#    'execution_count': 11,
#    'outputs': [],
#    'id': '023e0ba7'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.711732',
#      'end_time': '2024-05-26T21:11:56.724605',
#      'duration': 0.012873,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.712995Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.713908Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.721234Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.722174Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'ac1b1cd6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.725724',
#      'end_time': '2024-05-26T21:11:56.725987',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': 'eeb2dcef'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.726195',
#      'end_time': '2024-05-26T21:11:56.739389',
#      'duration': 0.013194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.727544Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.728176Z',
#      'iopub.status.idle': '2024-05-26T21:11:56.735532Z',
#      'shell.execute_reply': '2024-05-26T21:11:56.734592Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '2aa63547'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:56.739711',
#      'end_time': '2024-05-26T21:11:59.096272',
#      'duration': 2.356561,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:56.741018Z',
#      'iopub.execute_input': '2024-05-26T21:11:56.741701Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.090946Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.088156Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'e09868b7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.096742',
#      'end_time': '2024-05-26T21:11:59.117239',
#      'duration': 0.020497,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.100361Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.101098Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.109979Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.112043Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': 'a378d984'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.117711',
#      'end_time': '2024-05-26T21:11:59.118234',
#      'duration': 0.000523,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'baff14c3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.118676',
#      'end_time': '2024-05-26T21:11:59.152191',
#      'duration': 0.033515,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.121439Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.122083Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.145827Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.143220Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'aa94cafd'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.152719',
#      'end_time': '2024-05-26T21:11:59.153467',
#      'duration': 0.000748,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'ee925d05'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.156046',
#      'end_time': '2024-05-26T21:11:59.175428',
#      'duration': 0.019382,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.159774Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.160544Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.167729Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.170160Z'}},
#    'cell_type': 'code',
#    'source': "\n#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '3ba85daa'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.176191',
#      'end_time': '2024-05-26T21:11:59.176935',
#      'duration': 0.000744,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '16057d6d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.177458',
#      'end_time': '2024-05-26T21:11:59.196703',
#      'duration': 0.019245,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.180517Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.181307Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.191159Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.188179Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': 'a2dd1f9e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.197285',
#      'end_time': '2024-05-26T21:11:59.197995',
#      'duration': 0.00071,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '4ef353d7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.198755',
#      'end_time': '2024-05-26T21:11:59.228907',
#      'duration': 0.030152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.201770Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.202439Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.224100Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.221766Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N938104a0d32b43b29847cfbe4a0eefa3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '6e3a0bfe'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.229415',
#      'end_time': '2024-05-26T21:11:59.230050',
#      'duration': 0.000635,
#      'status': 'completed'}},
#    'id': '3e78824e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.230812',
#      'end_time': '2024-05-26T21:11:59.278414',
#      'duration': 0.047602,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.233740Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.235633Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.272053Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.269588Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '0cb93545'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.280962',
#      'end_time': '2024-05-26T21:11:59.309826',
#      'duration': 0.028864,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.286246Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.289076Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.301490Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.303654Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': 'df22460c'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:11:59.310402',
#      'end_time': '2024-05-26T21:11:59.367271',
#      'duration': 0.056869,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:11:59.313778Z',
#      'iopub.execute_input': '2024-05-26T21:11:59.314420Z',
#      'shell.execute_reply': '2024-05-26T21:11:59.360265Z',
#      'iopub.status.idle': '2024-05-26T21:11:59.362436Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3058416d41d74b6e8a29ffcb330bf63a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '6106c563'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-05-26T21:11:59.846965',
#    'end_time': '2024-05-26T21:12:04.206152',
#    'duration': 4.359187,
#    'exception': None}},
#  'cells': [{'id': '8991f1bc',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:00.974793',
#      'end_time': '2024-05-26T21:12:01.010483',
#      'duration': 0.03569,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:00.978043Z',
#      'iopub.execute_input': '2024-05-26T21:12:00.979803Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.000071Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.003218Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.012631',
#      'end_time': '2024-05-26T21:12:01.034644',
#      'duration': 0.022013,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.016902Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.019098Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.029441Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.027262Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '4da79027'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.035386',
#      'end_time': '2024-05-26T21:12:01.174680',
#      'duration': 0.139294,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.038570Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.039223Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.171989Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.172796Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '17898a11'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.175653',
#      'end_time': '2024-05-26T21:12:01.184901',
#      'duration': 0.009248,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.177268Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.177557Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.181568Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.182392Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '67be47f9'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.185214',
#      'end_time': '2024-05-26T21:12:01.185558',
#      'duration': 0.000344,
#      'status': 'completed'}},
#    'id': '440a123c'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.185801',
#      'end_time': '2024-05-26T21:12:01.210667',
#      'duration': 0.024866,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.187371Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.187711Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.207241Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.208162Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '145dc539'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.210877',
#      'end_time': '2024-05-26T21:12:01.225797',
#      'duration': 0.01492,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.212202Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.212462Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.222491Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.223406Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': 'd0297bad'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.226006',
#      'end_time': '2024-05-26T21:12:01.226257',
#      'duration': 0.000251,
#      'status': 'completed'}},
#    'id': '44d7640d'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.226454',
#      'end_time': '2024-05-26T21:12:01.233901',
#      'duration': 0.007447,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.227667Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.227924Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.230599Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.231503Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'a394c265'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.234111',
#      'end_time': '2024-05-26T21:12:01.234353',
#      'duration': 0.000242,
#      'status': 'completed'}},
#    'id': '94da49a7'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.234553',
#      'end_time': '2024-05-26T21:12:01.242765',
#      'duration': 0.008212,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.235973Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.236330Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.240260Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.239284Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '7954947b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.242974',
#      'end_time': '2024-05-26T21:12:01.243221',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '610e8fa8'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.243416',
#      'end_time': '2024-05-26T21:12:01.253375',
#      'duration': 0.009959,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.244610Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.244856Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.249769Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.250692Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '4a941764'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.253598',
#      'end_time': '2024-05-26T21:12:01.253848',
#      'duration': 0.00025,
#      'status': 'completed'}},
#    'id': 'b15a2a44'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.254070',
#      'end_time': '2024-05-26T21:12:01.264227',
#      'duration': 0.010157,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.255254Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.255505Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.261507Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.260613Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'fece7061'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.264437',
#      'end_time': '2024-05-26T21:12:01.278266',
#      'duration': 0.013829,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.265636Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.265890Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.276360Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.275473Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': 'ffb16eb0'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.279115',
#      'end_time': '2024-05-26T21:12:01.279595',
#      'duration': 0.00048,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '77fa15df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.279875',
#      'end_time': '2024-05-26T21:12:01.291519',
#      'duration': 0.011644,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.281816Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.282237Z',
#      'shell.execute_reply': '2024-05-26T21:12:01.288590Z',
#      'iopub.status.idle': '2024-05-26T21:12:01.289586Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '626fecbf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:01.291802',
#      'end_time': '2024-05-26T21:12:03.584193',
#      'duration': 2.292391,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:01.293016Z',
#      'iopub.execute_input': '2024-05-26T21:12:01.293277Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.574754Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.577715Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'd4d87395'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.584813',
#      'end_time': '2024-05-26T21:12:03.607302',
#      'duration': 0.022489,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.588871Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.590768Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.599755Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.602078Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'a2c35991'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.607829',
#      'end_time': '2024-05-26T21:12:03.608506',
#      'duration': 0.000677,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '07c72cdd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.609084',
#      'end_time': '2024-05-26T21:12:03.639190',
#      'duration': 0.030106,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.612052Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.613723Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.631693Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.633791Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '7fc67ee0'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.639695',
#      'end_time': '2024-05-26T21:12:03.640390',
#      'duration': 0.000695,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '19da3470'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.643148',
#      'end_time': '2024-05-26T21:12:03.664733',
#      'duration': 0.021585,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.646846Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.648966Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.654920Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.658529Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '3be73662'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.665234',
#      'end_time': '2024-05-26T21:12:03.665853',
#      'duration': 0.000619,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '08fc069a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.666343',
#      'end_time': '2024-05-26T21:12:03.681680',
#      'duration': 0.015337,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.669327Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.669995Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.675211Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.677177Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '7dd013f2'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.682176',
#      'end_time': '2024-05-26T21:12:03.682794',
#      'duration': 0.000618,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'c36fdc55'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.683285',
#      'end_time': '2024-05-26T21:12:03.730993',
#      'duration': 0.047708,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.687268Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.689457Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.723881Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.726421Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb84a2bbbe42149039d0d5604ed9a0366 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': 'ba586316'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.731490',
#      'end_time': '2024-05-26T21:12:03.732112',
#      'duration': 0.000622,
#      'status': 'completed'}},
#    'id': '965e5d27'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.732614',
#      'end_time': '2024-05-26T21:12:03.788922',
#      'duration': 0.056308,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.735914Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.737885Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.783178Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.781080Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': '5877f312'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.792062',
#      'end_time': '2024-05-26T21:12:03.820214',
#      'duration': 0.028152,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.796483Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.797766Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.813414Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.815382Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '78c84d65'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-05-26T21:12:03.820787',
#      'end_time': '2024-05-26T21:12:03.879255',
#      'duration': 0.058468,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-05-26T21:12:03.824321Z',
#      'iopub.execute_input': '2024-05-26T21:12:03.824946Z',
#      'shell.execute_reply': '2024-05-26T21:12:03.872393Z',
#      'iopub.status.idle': '2024-05-26T21:12:03.874566Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N596ae713d4d64bc299160dde18910fec (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '8d744e7e'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets
# Out:
# ['UPENN-GBM_clinical_info_v2', 'dicomimage']

# %% [markdown]
# ## PARSER

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# a7890852-3d13-4690-acea-2546900d4d4d
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 47ad56c4-54b9-4d9d-8fc2-06fbaa05a0ea
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
