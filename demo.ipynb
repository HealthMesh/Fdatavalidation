# %%
import os

# %%
base_dir = os.getcwd()

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](demo_images/GD.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'FederatedComputationalGovernance/'),
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:03<00:00,  4.45cell/s]
# {'cells': [{'id': 'ae2388bc',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.756718',
#      'end_time': '2024-10-18T14:24:16.773367',
#      'duration': 0.016649,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.759081Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.760152Z',
#      'shell.execute_reply': '2024-10-18T14:24:16.768586Z',
#      'iopub.status.idle': '2024-10-18T14:24:16.770050Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.775146',
#      'end_time': '2024-10-18T14:24:16.788175',
#      'duration': 0.013029,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.777293Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.777943Z',
#      'shell.execute_reply': '2024-10-18T14:24:16.784142Z',
#      'iopub.status.idle': '2024-10-18T14:24:16.785602Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.788362',
#      'end_time': '2024-10-18T14:24:16.788680',
#      'duration': 0.000318,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.789060',
#      'end_time': '2024-10-18T14:24:16.867663',
#      'duration': 0.078603,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.790484Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.790852Z',
#      'shell.execute_reply': '2024-10-18T14:24:16.864057Z',
#      'iopub.status.idle': '2024-10-18T14:24:16.864773Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.867831',
#      'end_time': '2024-10-18T14:24:16.890470',
#      'duration': 0.022639,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.868915Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.869146Z',
#      'shell.execute_reply': '2024-10-18T14:24:16.886476Z',
#      'iopub.status.idle': '2024-10-18T14:24:16.887639Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.891573',
#      'end_time': '2024-10-18T14:24:16.891958',
#      'duration': 0.000385,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.892116',
#      'end_time': '2024-10-18T14:24:16.900418',
#      'duration': 0.008302,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.893832Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.894268Z',
#      'shell.execute_reply': '2024-10-18T14:24:16.897841Z',
#      'iopub.status.idle': '2024-10-18T14:24:16.898556Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:16.900560',
#      'end_time': '2024-10-18T14:24:18.840656',
#      'duration': 1.940096,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:16.901561Z',
#      'iopub.execute_input': '2024-10-18T14:24:16.901847Z',
#      'shell.execute_reply': '2024-10-18T14:24:18.824760Z',
#      'iopub.status.idle': '2024-10-18T14:24:18.827282Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.843784',
#      'end_time': '2024-10-18T14:24:18.844981',
#      'duration': 0.001197,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.845508',
#      'end_time': '2024-10-18T14:24:18.869318',
#      'duration': 0.02381,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:18.852108Z',
#      'iopub.execute_input': '2024-10-18T14:24:18.852994Z',
#      'shell.execute_reply': '2024-10-18T14:24:18.863084Z',
#      'iopub.status.idle': '2024-10-18T14:24:18.865020Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.869589',
#      'end_time': '2024-10-18T14:24:18.885340',
#      'duration': 0.015751,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:18.871350Z',
#      'iopub.execute_input': '2024-10-18T14:24:18.871704Z',
#      'shell.execute_reply': '2024-10-18T14:24:18.881620Z',
#      'iopub.status.idle': '2024-10-18T14:24:18.882489Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.885540',
#      'end_time': '2024-10-18T14:24:18.885802',
#      'duration': 0.000262,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.885968',
#      'end_time': '2024-10-18T14:24:18.905250',
#      'duration': 0.019282,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:18.887394Z',
#      'iopub.execute_input': '2024-10-18T14:24:18.887703Z',
#      'shell.execute_reply': '2024-10-18T14:24:18.902484Z',
#      'iopub.status.idle': '2024-10-18T14:24:18.903322Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.905517',
#      'end_time': '2024-10-18T14:24:18.905774',
#      'duration': 0.000257,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:18.905918',
#      'end_time': '2024-10-18T14:24:18.927002',
#      'duration': 0.021084,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:18.907164Z',
#      'iopub.execute_input': '2024-10-18T14:24:18.907947Z',
#      'iopub.status.idle': '2024-10-18T14:24:18.925460Z',
#      'shell.execute_reply': '2024-10-18T14:24:18.924748Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1054f4c12687457b880ff8211f837edb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-18T14:24:15.774724',
#    'end_time': '2024-10-18T14:24:19.149752',
#    'duration': 3.375028,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](demo_images/SG.png)

# %% [markdown]
# ### DP1

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:08<00:00,  1.46cell/s]
# {'cells': [{'id': 'a7b9a844',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:20.426377',
#      'end_time': '2024-10-18T14:24:20.458973',
#      'duration': 0.032596,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:20.431416Z',
#      'iopub.execute_input': '2024-10-18T14:24:20.432313Z',
#      'shell.execute_reply': '2024-10-18T14:24:20.453040Z',
#      'iopub.status.idle': '2024-10-18T14:24:20.454960Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:20.462700',
#      'end_time': '2024-10-18T14:24:26.399754',
#      'duration': 5.937054,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:20.466337Z',
#      'iopub.execute_input': '2024-10-18T14:24:20.467131Z',
#      'iopub.status.idle': '2024-10-18T14:24:26.391744Z',
#      'shell.execute_reply': '2024-10-18T14:24:26.387924Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:26.402801',
#      'end_time': '2024-10-18T14:24:26.441101',
#      'duration': 0.0383,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:26.416392Z',
#      'iopub.execute_input': '2024-10-18T14:24:26.417529Z',
#      'shell.execute_reply': '2024-10-18T14:24:26.431066Z',
#      'iopub.status.idle': '2024-10-18T14:24:26.434570Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:26.441632',
#      'end_time': '2024-10-18T14:24:26.531751',
#      'duration': 0.090119,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:26.445211Z',
#      'iopub.execute_input': '2024-10-18T14:24:26.446331Z',
#      'iopub.status.idle': '2024-10-18T14:24:26.530018Z',
#      'shell.execute_reply': '2024-10-18T14:24:26.529174Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:26.532621',
#      'end_time': '2024-10-18T14:24:26.533195',
#      'duration': 0.000574,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:26.533333',
#      'end_time': '2024-10-18T14:24:27.065325',
#      'duration': 0.531992,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:26.534579Z',
#      'iopub.execute_input': '2024-10-18T14:24:26.534816Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.062819Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.063664Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.065994',
#      'end_time': '2024-10-18T14:24:27.073230',
#      'duration': 0.007236,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:27.066948Z',
#      'iopub.execute_input': '2024-10-18T14:24:27.067255Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.070491Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.071418Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.073368',
#      'end_time': '2024-10-18T14:24:27.090727',
#      'duration': 0.017359,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:27.074648Z',
#      'iopub.execute_input': '2024-10-18T14:24:27.075034Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.088207Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.088971Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.090859',
#      'end_time': '2024-10-18T14:24:27.097810',
#      'duration': 0.006951,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:27.092049Z',
#      'iopub.execute_input': '2024-10-18T14:24:27.092398Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.095379Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.096171Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.097942',
#      'end_time': '2024-10-18T14:24:27.098129',
#      'duration': 0.000187,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.098250',
#      'end_time': '2024-10-18T14:24:27.122129',
#      'duration': 0.023879,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:27.099372Z',
#      'iopub.execute_input': '2024-10-18T14:24:27.099684Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.117128Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.114202Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:27.122491',
#      'end_time': '2024-10-18T14:24:27.160047',
#      'duration': 0.037556,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:27.124821Z',
#      'iopub.execute_input': '2024-10-18T14:24:27.125247Z',
#      'shell.execute_reply': '2024-10-18T14:24:27.157814Z',
#      'iopub.status.idle': '2024-10-18T14:24:27.158611Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N581aa49ceb8b46c799235aadd8cd61cb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-18T14:24:19.281408',
#    'end_time': '2024-10-18T14:24:27.487290',
#    'duration': 8.205882,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, 'DataPlatformLayer/Registration'),
        'file_path': file_path
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 12/12 [00:07<00:00,  1.56cell/s]
# {'cells': [{'id': '8328f831',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:28.522073',
#      'end_time': '2024-10-18T14:24:28.556802',
#      'duration': 0.034729,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:28.525333Z',
#      'iopub.execute_input': '2024-10-18T14:24:28.527346Z',
#      'shell.execute_reply': '2024-10-18T14:24:28.548822Z',
#      'iopub.status.idle': '2024-10-18T14:24:28.551513Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-10T09:27:22.109698Z',
#      'start_time': '2024-09-10T09:27:14.824065Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:28.559221',
#      'end_time': '2024-10-18T14:24:34.298050',
#      'duration': 5.738829,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:28.561463Z',
#      'iopub.execute_input': '2024-10-18T14:24:28.561857Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.287557Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.291265Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.1.0)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.154749Z',
#      'start_time': '2024-09-10T09:27:22.138621Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.301037',
#      'end_time': '2024-10-18T14:24:34.326694',
#      'duration': 0.025657,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.307038Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.308569Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.321775Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.320063Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.201137Z',
#      'start_time': '2024-09-10T09:27:22.190169Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.326959',
#      'end_time': '2024-10-18T14:24:34.399415',
#      'duration': 0.072456,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.328932Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.329416Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.397065Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.397762Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.400281',
#      'end_time': '2024-10-18T14:24:34.400542',
#      'duration': 0.000261,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Profiler Class',
#    'id': 'fea2f70eac74b64e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:22.262977Z',
#      'start_time': '2024-09-10T09:27:22.234349Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.400744',
#      'end_time': '2024-10-18T14:24:34.885775',
#      'duration': 0.485031,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.401907Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.402160Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.883857Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.882916Z'}},
#    'cell_type': 'code',
#    'source': 'import os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, dcat.Dataset))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n\n    def extract_csv_metadata(self):\n        df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            self.source_graph.add((abox[column], tbox.attribute, Literal(column)))\n        return self.source_graph\n\n    def extract_dicom_metadata(self, n_attributes=50):\n        ds = pydicom.dcmread(self.file_path)\n        # Iterate over all attributes\n        for attribute in dir(ds)[:n_attributes]:\n            if attribute[0].isalpha():\n                if hasattr(ds, attribute):\n                    self.source_graph.add((abox[at ...
#    'id': '8288accb67ee6c29',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:31:22.369177Z',
#      'start_time': '2024-09-10T09:31:22.351234Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.886446',
#      'end_time': '2024-10-18T14:24:34.894336',
#      'duration': 0.00789,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.887945Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.888424Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.891626Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.892611Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.053495Z',
#      'start_time': '2024-09-10T09:27:25.032551Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.894466',
#      'end_time': '2024-10-18T14:24:34.930525',
#      'duration': 0.036059,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.895703Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.895987Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.927540Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.928544Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.084443Z',
#      'start_time': '2024-09-10T09:27:25.075438Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.930676',
#      'end_time': '2024-10-18T14:24:34.938150',
#      'duration': 0.007474,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.931929Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.932391Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.935025Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.936011Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.938333',
#      'end_time': '2024-10-18T14:24:34.938589',
#      'duration': 0.000256,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.147275Z',
#      'start_time': '2024-09-10T09:27:25.117322Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.938731',
#      'end_time': '2024-10-18T14:24:34.961272',
#      'duration': 0.022541,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.940044Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.940812Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.958049Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.958768Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-10T09:27:25.208087Z',
#      'start_time': '2024-09-10T09:27:25.164197Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:34.961475',
#      'end_time': '2024-10-18T14:24:34.999994',
#      'duration': 0.038519,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:34.962649Z',
#      'iopub.execute_input': '2024-10-18T14:24:34.962871Z',
#      'shell.execute_reply': '2024-10-18T14:24:34.996968Z',
#      'iopub.status.idle': '2024-10-18T14:24:34.997731Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc2b87448ee134744ac773cbbc2c6b4ae (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct2/Data/0002.DCM'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-18T14:24:27.623334',
#    'end_time': '2024-10-18T14:24:35.319673',
#    'duration': 7.696339,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](demo_images/SDM.png)

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp1.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:09<00:00,  1.83cell/s]
# {'cells': [{'id': '69ab4462',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:36.233761',
#      'end_time': '2024-10-18T14:24:36.270768',
#      'duration': 0.037007,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:36.237908Z',
#      'iopub.execute_input': '2024-10-18T14:24:36.238765Z',
#      'shell.execute_reply': '2024-10-18T14:24:36.260450Z',
#      'iopub.status.idle': '2024-10-18T14:24:36.263923Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:36.274943',
#      'end_time': '2024-10-18T14:24:44.206534',
#      'duration': 7.931591,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:36.279954Z',
#      'iopub.execute_input': '2024-10-18T14:24:36.281315Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.199764Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.196137Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.209548',
#      'end_time': '2024-10-18T14:24:44.243298',
#      'duration': 0.03375,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.217562Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.219019Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.236500Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.232951Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.243992',
#      'end_time': '2024-10-18T14:24:44.327679',
#      'duration': 0.083687,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.247971Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.249805Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.324655Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.325357Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.328674',
#      'end_time': '2024-10-18T14:24:44.336372',
#      'duration': 0.007698,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.329730Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.330197Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.333322Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.334378Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.336625',
#      'end_time': '2024-10-18T14:24:44.350065',
#      'duration': 0.01344,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.337828Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.338072Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.348194Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.347251Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.350382',
#      'end_time': '2024-10-18T14:24:44.350583',
#      'duration': 0.000201,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.350706',
#      'end_time': '2024-10-18T14:24:44.350884',
#      'duration': 0.000178,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.351005',
#      'end_time': '2024-10-18T14:24:44.387135',
#      'duration': 0.03613,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.352114Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.352349Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.382246Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.378622Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.387477',
#      'end_time': '2024-10-18T14:24:44.388075',
#      'duration': 0.000598,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.388393',
#      'end_time': '2024-10-18T14:24:44.400456',
#      'duration': 0.012063,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.390500Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.390949Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.396796Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.398268Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.400623',
#      'end_time': '2024-10-18T14:24:44.407764',
#      'duration': 0.007141,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.401705Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.401990Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.405043Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.405980Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.407935',
#      'end_time': '2024-10-18T14:24:44.414978',
#      'duration': 0.007043,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.408823Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.409026Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.412184Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.413095Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.415108',
#      'end_time': '2024-10-18T14:24:44.422888',
#      'duration': 0.00778,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.416374Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.417091Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.420858Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.419841Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.423019',
#      'end_time': '2024-10-18T14:24:44.430905',
#      'duration': 0.007886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.424192Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.424524Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.427969Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.428915Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.431738',
#      'end_time': '2024-10-18T14:24:44.432323',
#      'duration': 0.000585,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:44.432457',
#      'end_time': '2024-10-18T14:24:44.491468',
#      'duration': 0.059011,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:44.434015Z',
#      'iopub.execute_input': '2024-10-18T14:24:44.434615Z',
#      'shell.execute_reply': '2024-10-18T14:24:44.489183Z',
#      'iopub.status.idle': '2024-10-18T14:24:44.489855Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N543e5df95d6a455b88848c5b0732eab3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp1.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-18T14:24:35.406231',
#    'end_time': '2024-10-18T14:24:44.716573',
#    'duration': 9.310342,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    os.path.join(base_dir, 'DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, 'DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, 'DataPlatformLayer/Integration/dp2.json'),
    }
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 17/17 [00:10<00:00,  1.68cell/s]
# {'cells': [{'id': '732858f4',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:45.838770',
#      'end_time': '2024-10-18T14:24:45.869503',
#      'duration': 0.030733,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:45.843114Z',
#      'iopub.execute_input': '2024-10-18T14:24:45.844397Z',
#      'shell.execute_reply': '2024-10-18T14:24:45.864391Z',
#      'iopub.status.idle': '2024-10-18T14:24:45.866102Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:45.877848',
#      'end_time': '2024-10-18T14:24:54.569866',
#      'duration': 8.692018,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:45.879717Z',
#      'iopub.execute_input': '2024-10-18T14:24:45.880086Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.564862Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.562901Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.2\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.570858',
#      'end_time': '2024-10-18T14:24:54.582091',
#      'duration': 0.011233,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.573079Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.573408Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.579241Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.578027Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.582402',
#      'end_time': '2024-10-18T14:24:54.673250',
#      'duration': 0.090848,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.584257Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.584657Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.671368Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.670361Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.673979',
#      'end_time': '2024-10-18T14:24:54.687869',
#      'duration': 0.01389,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.682428Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.682663Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.685702Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.686363Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.688130',
#      'end_time': '2024-10-18T14:24:54.699825',
#      'duration': 0.011695,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.689194Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.689420Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.697420Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.698239Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.700089',
#      'end_time': '2024-10-18T14:24:54.700281',
#      'duration': 0.000192,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.700513',
#      'end_time': '2024-10-18T14:24:54.700679',
#      'duration': 0.000166,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.700905',
#      'end_time': '2024-10-18T14:24:54.736201',
#      'duration': 0.035296,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.701943Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.702456Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.733698Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.734385Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.736378',
#      'end_time': '2024-10-18T14:24:54.736590',
#      'duration': 0.000212,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.736699',
#      'end_time': '2024-10-18T14:24:54.744231',
#      'duration': 0.007532,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.737668Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.737878Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.742102Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.741234Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.744479',
#      'end_time': '2024-10-18T14:24:54.751478',
#      'duration': 0.006999,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.745524Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.746175Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.748368Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.749200Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.751728',
#      'end_time': '2024-10-18T14:24:54.759356',
#      'duration': 0.007628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.752894Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.753100Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.756433Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.755745Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.759501',
#      'end_time': '2024-10-18T14:24:54.766348',
#      'duration': 0.006847,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.760671Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.760885Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.763839Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.764755Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.766493',
#      'end_time': '2024-10-18T14:24:54.773460',
#      'duration': 0.006967,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.767690Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.768028Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.771325Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.771996Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.774422',
#      'end_time': '2024-10-18T14:24:54.775093',
#      'duration': 0.000671,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-10-18T14:24:54.775334',
#      'end_time': '2024-10-18T14:24:54.829330',
#      'duration': 0.053996,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-10-18T14:24:54.776671Z',
#      'iopub.execute_input': '2024-10-18T14:24:54.777106Z',
#      'iopub.status.idle': '2024-10-18T14:24:54.827927Z',
#      'shell.execute_reply': '2024-10-18T14:24:54.827340Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ndaa7e67235ba4b1580013c4288133b4f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/dp2.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-10-18T14:24:44.957560',
#    'end_time': '2024-10-18T14:24:55.060959',
#    'duration': 10.103399,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](demo_images/AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 dp = input("SELECT NAME OF DATA PRODUCT: ")
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'0002DCM', 'UPENN-GBM_clinical_info_v21csv'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](demo_images/PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 15/15 [00:13<00:00,  1.14cell/s]
# ---------------------------------------------------------------------------
# PapermillExecutionError                   Traceback (most recent call last)
# Cell In[61], line 2
#       1 for dp in datasets:
# ----> 2     pm.execute_notebook(
#       3         os.path.join(base_dir, 'SideCar/ValidateContract/parser/parser.ipynb'),None, parameters={
#       4             'folder': os.path.join(base_dir, 'SideCar/ValidateContract/parser/'),
#       5             'dp': dp
#       6         }
#       7     )
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/papermill/execute.py:131, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     116         nb = papermill_engines.execute_notebook_with_engine(
#     117             engine_name,
#     118             nb,
#    (...)
#     127             **engine_kwargs,
#     128         )
#     130     # Check for errors first (it saves on error before raising)
# --> 131     raise_for_execution_errors(nb, output_path)
#     133 # Write final output in case the engine didn't write it on cell completion.
#     134 write_ipynb(nb, output_path)
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/papermill/execute.py:251, in raise_for_execution_errors(nb, output_path)
#     248 nb.cells.insert(0, error_msg_cell)
#     250 write_ipynb(nb, output_path)
# --> 251 raise error
#
# PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [11]":
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 DCParser(dp, contract).parse_contracts()
#
# Cell In[10], line 165, in DCParser.parse_contracts(self)
#     162 policies, mappings = self._read_contracts()
#     164 for policy in policies:
# --> 165     pc = self._parse_policy(policy)
#     166     self.g = self.g + pc
#     168 self.g.serialize(destination=os.path.join(base_dir, "../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl"), format="turtle")
#
# Cell In[10], line 136, in DCParser._parse_policy(self, policy)
#     129 """
#     130 Parse the policy to intermediate representation
#     131 :param policy: policy to parse
#     132 :return: None
#     133 """
#     135 # create policy checker graph
# --> 136 pc = PolicyChecker(policy, self.dp)
#     138 # Check Data Dependencies
#     139 last_op, pc = self._initOP(policy, pc)
#
# Cell In[9], line 13, in PolicyChecker.__init__(self, p, dp, *args, **kwargs)
#      11 self.add((self.URI, RDF.type, tbox.PolicyChecker))
#      12 self.add((self.URI, tbox.accordingTo, p))
# ---> 13 self.add((self.URI, tbox.validates, dp))
#
# File ~/psr/Fdatavalidation/venv/lib/python3.11/site-packages/rdflib/graph.py:532, in Graph.add(self, triple)
#     530 assert isinstance(s, Node), "Subject %s must be an rdflib term" % (s,)
#     531 assert isinstance(p, Node), "Predicate %s must be an rdflib term" % (p,)
# --> 532 assert isinstance(o, Node), "Object %s must be an rdflib term" % (o,)
#     533 self.__store.add((s, p, o), self, quoted=False)
#     534 return self
#
# AssertionError: Object UPENN-GBM_clinical_info_v21csv must be an rdflib term

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](demo_images/SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, 'SideCar/ValidateContract/translator/translator.ipynb'),None, parameters={
                'folder': 'SideCar/ValidateContract/translator/',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0fba0713-bf98-4a2e-8113-1c13e568a89a
# Executing: 100%|██████████| 17/17 [00:12<00:00,  1.32cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# cf406614-ec5f-43d4-9ddd-be787bde213b
# Executing: 100%|██████████| 17/17 [00:12<00:00,  1.38cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c4114c70-b11b-4d33-b7b0-b5c4972b8881
# Executing: 100%|██████████| 17/17 [00:13<00:00,  1.24cell/s]
