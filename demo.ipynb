# %%
import os

# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '40f06e79',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.353352',
#      'end_time': '2024-06-09T10:46:31.361592',
#      'duration': 0.00824,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.354612Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.354842Z',
#      'iopub.status.idle': '2024-06-09T10:46:31.359750Z',
#      'shell.execute_reply': '2024-06-09T10:46:31.359292Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.362314',
#      'end_time': '2024-06-09T10:46:31.372565',
#      'duration': 0.010251,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.363443Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.363629Z',
#      'shell.execute_reply': '2024-06-09T10:46:31.369741Z',
#      'iopub.status.idle': '2024-06-09T10:46:31.370562Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.372783',
#      'end_time': '2024-06-09T10:46:31.373031',
#      'duration': 0.000248,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.373225',
#      'end_time': '2024-06-09T10:46:31.428211',
#      'duration': 0.054986,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.374276Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.374525Z',
#      'shell.execute_reply': '2024-06-09T10:46:31.426041Z',
#      'iopub.status.idle': '2024-06-09T10:46:31.426707Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.428361',
#      'end_time': '2024-06-09T10:46:31.445627',
#      'duration': 0.017266,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.429476Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.429732Z',
#      'shell.execute_reply': '2024-06-09T10:46:31.443456Z',
#      'iopub.status.idle': '2024-06-09T10:46:31.444107Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.445779',
#      'end_time': '2024-06-09T10:46:31.446023',
#      'duration': 0.000244,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.446158',
#      'end_time': '2024-06-09T10:46:31.446360',
#      'duration': 0.000202,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.446494',
#      'end_time': '2024-06-09T10:46:31.452636',
#      'duration': 0.006142,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.447322Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.447500Z',
#      'shell.execute_reply': '2024-06-09T10:46:31.450219Z',
#      'iopub.status.idle': '2024-06-09T10:46:31.450932Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:31.452787',
#      'end_time': '2024-06-09T10:46:33.474764',
#      'duration': 2.021977,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:31.453789Z',
#      'iopub.execute_input': '2024-06-09T10:46:31.454022Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.473147Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.472431Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.475374',
#      'end_time': '2024-06-09T10:46:33.475655',
#      'duration': 0.000281,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.475843',
#      'end_time': '2024-06-09T10:46:33.485176',
#      'duration': 0.009333,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.477343Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.477911Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.482253Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.483277Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.485372',
#      'end_time': '2024-06-09T10:46:33.500067',
#      'duration': 0.014695,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.486488Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.486758Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.498625Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.497898Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.500256',
#      'end_time': '2024-06-09T10:46:33.500462',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.500628',
#      'end_time': '2024-06-09T10:46:33.506577',
#      'duration': 0.005949,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.501751Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.501931Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.504867Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.504173Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.506772',
#      'end_time': '2024-06-09T10:46:33.513351',
#      'duration': 0.006579,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.507633Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.507824Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.511979Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.511355Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.513532',
#      'end_time': '2024-06-09T10:46:33.513760',
#      'duration': 0.000228,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.513897',
#      'end_time': '2024-06-09T10:46:33.520256',
#      'duration': 0.006359,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.514960Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.515230Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.517498Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.518167Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.520403',
#      'end_time': '2024-06-09T10:46:33.525451',
#      'duration': 0.005048,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.521429Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.521794Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.523604Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.524214Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.525592',
#      'end_time': '2024-06-09T10:46:33.525790',
#      'duration': 0.000198,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.525920',
#      'end_time': '2024-06-09T10:46:33.531464',
#      'duration': 0.005544,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.526868Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.527230Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.529011Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.529709Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.531598',
#      'end_time': '2024-06-09T10:46:33.531812',
#      'duration': 0.000214,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:33.531938',
#      'end_time': '2024-06-09T10:46:33.548130',
#      'duration': 0.016192,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:33.532839Z',
#      'iopub.execute_input': '2024-06-09T10:46:33.533282Z',
#      'shell.execute_reply': '2024-06-09T10:46:33.545752Z',
#      'iopub.status.idle': '2024-06-09T10:46:33.546412Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N1bc44999661f442e9b0a217c74bcd77b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T10:46:30.414460',
#    'end_time': '2024-06-09T10:46:33.765489',
#    'duration': 3.351029,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T10:46:33.838330',
#    'end_time': '2024-06-09T10:46:40.769139',
#    'duration': 6.930809,
#    'exception': None}},
#  'cells': [{'id': '557eefa5',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:34.675316',
#      'end_time': '2024-06-09T10:46:34.683256',
#      'duration': 0.00794,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:34.676404Z',
#      'iopub.execute_input': '2024-06-09T10:46:34.676845Z',
#      'shell.execute_reply': '2024-06-09T10:46:34.681134Z',
#      'iopub.status.idle': '2024-06-09T10:46:34.681815Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:34.684060',
#      'end_time': '2024-06-09T10:46:34.692360',
#      'duration': 0.0083,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:34.685084Z',
#      'iopub.execute_input': '2024-06-09T10:46:34.685380Z',
#      'iopub.status.idle': '2024-06-09T10:46:34.690744Z',
#      'shell.execute_reply': '2024-06-09T10:46:34.689805Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '648b1e1f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:34.692507',
#      'end_time': '2024-06-09T10:46:34.698919',
#      'duration': 0.006412,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:34.693779Z',
#      'iopub.execute_input': '2024-06-09T10:46:34.694397Z',
#      'shell.execute_reply': '2024-06-09T10:46:34.696778Z',
#      'iopub.status.idle': '2024-06-09T10:46:34.697407Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': 'b97a9076'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:34.699060',
#      'end_time': '2024-06-09T10:46:39.777753',
#      'duration': 5.078693,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:34.700022Z',
#      'iopub.execute_input': '2024-06-09T10:46:34.700744Z',
#      'iopub.status.idle': '2024-06-09T10:46:39.776134Z',
#      'shell.execute_reply': '2024-06-09T10:46:39.775339Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': 'c445a622'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:39.778470',
#      'end_time': '2024-06-09T10:46:39.778906',
#      'duration': 0.000436,
#      'status': 'completed'}},
#    'id': '263e8906'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:39.779060',
#      'end_time': '2024-06-09T10:46:39.790638',
#      'duration': 0.011578,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:39.780661Z',
#      'iopub.execute_input': '2024-06-09T10:46:39.781196Z',
#      'shell.execute_reply': '2024-06-09T10:46:39.787954Z',
#      'iopub.status.idle': '2024-06-09T10:46:39.788863Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'e2a8753a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:39.790885',
#      'end_time': '2024-06-09T10:46:39.791145',
#      'duration': 0.00026,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'cb0fa9a5'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:39.791363',
#      'end_time': '2024-06-09T10:46:40.347541',
#      'duration': 0.556178,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:39.792579Z',
#      'iopub.execute_input': '2024-06-09T10:46:39.793252Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.346023Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.345354Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '94ecbf56'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.348257',
#      'end_time': '2024-06-09T10:46:40.374205',
#      'duration': 0.025948,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.349630Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.349970Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.372835Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.372209Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '28092c02'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.374420',
#      'end_time': '2024-06-09T10:46:40.374626',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'id': '68e1da5a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.374831',
#      'end_time': '2024-06-09T10:46:40.375017',
#      'duration': 0.000186,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'c76f9423'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.375205',
#      'end_time': '2024-06-09T10:46:40.380763',
#      'duration': 0.005558,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.376161Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.376369Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.378709Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.379225Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': '27792130'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.380987',
#      'end_time': '2024-06-09T10:46:40.389941',
#      'duration': 0.008954,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.381816Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.382019Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.387859Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.388594Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '14c6f20e'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.390147',
#      'end_time': '2024-06-09T10:46:40.390356',
#      'duration': 0.000209,
#      'status': 'completed'}},
#    'id': '0490ecae'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.390542',
#      'end_time': '2024-06-09T10:46:40.399409',
#      'duration': 0.008867,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.391344Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.391554Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.397019Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.397681Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '598b6468'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.399630',
#      'end_time': '2024-06-09T10:46:40.399806',
#      'duration': 0.000176,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '1b4c482f'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.400005',
#      'end_time': '2024-06-09T10:46:40.408447',
#      'duration': 0.008442,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.400793Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.401060Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.405855Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.406585Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3d312dc5ddc345bc8d2af6e89f3445c8 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': '727ef955'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.408673',
#      'end_time': '2024-06-09T10:46:40.408853',
#      'duration': 0.00018,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '692a2cfe'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.409047',
#      'end_time': '2024-06-09T10:46:40.416046',
#      'duration': 0.006999,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.409991Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.410416Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.414439Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.413811Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '5e346fb9'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.416261',
#      'end_time': '2024-06-09T10:46:40.416428',
#      'duration': 0.000167,
#      'status': 'completed'}},
#    'id': '6b4adb8a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.416609',
#      'end_time': '2024-06-09T10:46:40.416775',
#      'duration': 0.000166,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '43ded61a'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.416952',
#      'end_time': '2024-06-09T10:46:40.423431',
#      'duration': 0.006479,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.417791Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.418146Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.421800Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.421222Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': 'cc57d66a'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.423582',
#      'end_time': '2024-06-09T10:46:40.430923',
#      'duration': 0.007341,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.424503Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.424771Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.428641Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.429266Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3d312dc5ddc345bc8d2af6e89f3445c8 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'c1037eb8'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.431060',
#      'end_time': '2024-06-09T10:46:40.431249',
#      'duration': 0.000189,
#      'status': 'completed'}},
#    'id': '90a76051'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.431379',
#      'end_time': '2024-06-09T10:46:40.439407',
#      'duration': 0.008028,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.432240Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.432603Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.437140Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.437721Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3d312dc5ddc345bc8d2af6e89f3445c8 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '3573f30d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.439548',
#      'end_time': '2024-06-09T10:46:40.439736',
#      'duration': 0.000188,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'fd564664'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:40.439867',
#      'end_time': '2024-06-09T10:46:40.448835',
#      'duration': 0.008968,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:40.440694Z',
#      'iopub.execute_input': '2024-06-09T10:46:40.440926Z',
#      'shell.execute_reply': '2024-06-09T10:46:40.446889Z',
#      'iopub.status.idle': '2024-06-09T10:46:40.447456Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N3d312dc5ddc345bc8d2af6e89f3445c8 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '79caccf2'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T10:46:40.809590',
#    'end_time': '2024-06-09T10:46:47.485147',
#    'duration': 6.675557,
#    'exception': None}},
#  'cells': [{'id': 'c26eadf8',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:41.877615',
#      'end_time': '2024-06-09T10:46:41.885661',
#      'duration': 0.008046,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:41.878631Z',
#      'iopub.execute_input': '2024-06-09T10:46:41.878841Z',
#      'shell.execute_reply': '2024-06-09T10:46:41.883684Z',
#      'iopub.status.idle': '2024-06-09T10:46:41.884299Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:41.886258',
#      'end_time': '2024-06-09T10:46:41.894986',
#      'duration': 0.008728,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:41.887741Z',
#      'iopub.execute_input': '2024-06-09T10:46:41.888611Z',
#      'iopub.status.idle': '2024-06-09T10:46:41.893130Z',
#      'shell.execute_reply': '2024-06-09T10:46:41.892432Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': 'fe8183bc'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:41.895178',
#      'end_time': '2024-06-09T10:46:46.045280',
#      'duration': 4.150102,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:41.896271Z',
#      'iopub.execute_input': '2024-06-09T10:46:41.896786Z',
#      'shell.execute_reply': '2024-06-09T10:46:46.042860Z',
#      'iopub.status.idle': '2024-06-09T10:46:46.043630Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'd1c283b1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.046328',
#      'end_time': '2024-06-09T10:46:46.057288',
#      'duration': 0.01096,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:46.048011Z',
#      'iopub.execute_input': '2024-06-09T10:46:46.048408Z',
#      'iopub.status.idle': '2024-06-09T10:46:46.054538Z',
#      'shell.execute_reply': '2024-06-09T10:46:46.053420Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': 'ed24e6ed'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.057524',
#      'end_time': '2024-06-09T10:46:46.057783',
#      'duration': 0.000259,
#      'status': 'completed'}},
#    'id': '3209be26'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.058014',
#      'end_time': '2024-06-09T10:46:46.066055',
#      'duration': 0.008041,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:46.059271Z',
#      'iopub.execute_input': '2024-06-09T10:46:46.059789Z',
#      'iopub.status.idle': '2024-06-09T10:46:46.064453Z',
#      'shell.execute_reply': '2024-06-09T10:46:46.063738Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '0d6c87f2'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.066218',
#      'end_time': '2024-06-09T10:46:46.066431',
#      'duration': 0.000213,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'f579e96f'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.066564',
#      'end_time': '2024-06-09T10:46:46.459880',
#      'duration': 0.393316,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:46.067580Z',
#      'iopub.execute_input': '2024-06-09T10:46:46.067796Z',
#      'shell.execute_reply': '2024-06-09T10:46:46.456919Z',
#      'iopub.status.idle': '2024-06-09T10:46:46.457694Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': 'aa340b4c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.460551',
#      'end_time': '2024-06-09T10:46:46.665207',
#      'duration': 0.204656,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:46.461798Z',
#      'iopub.execute_input': '2024-06-09T10:46:46.462094Z',
#      'shell.execute_reply': '2024-06-09T10:46:46.661923Z',
#      'iopub.status.idle': '2024-06-09T10:46:46.662905Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': '8ecc83c2'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:46.666637',
#      'end_time': '2024-06-09T10:46:47.058334',
#      'duration': 0.391697,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:46.668403Z',
#      'iopub.execute_input': '2024-06-09T10:46:46.669100Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.055867Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.056504Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '33e8fd0a'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.059294',
#      'end_time': '2024-06-09T10:46:47.059593',
#      'duration': 0.000299,
#      'status': 'completed'}},
#    'id': '3c47ad83'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.059822',
#      'end_time': '2024-06-09T10:46:47.060058',
#      'duration': 0.000236,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '00f83078'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.060280',
#      'end_time': '2024-06-09T10:46:47.068699',
#      'duration': 0.008419,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.061545Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.062370Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.065843Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.066740Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': 'ca881ef5'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.068961',
#      'end_time': '2024-06-09T10:46:47.080565',
#      'duration': 0.011604,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.070171Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.070542Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.078361Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.079069Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '97304aaf'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.080813',
#      'end_time': '2024-06-09T10:46:47.081026',
#      'duration': 0.000213,
#      'status': 'completed'}},
#    'id': 'c9d2c06a'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.081261',
#      'end_time': '2024-06-09T10:46:47.094820',
#      'duration': 0.013559,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.082529Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.082887Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.093143Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.092518Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': '9f43c598'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.095090',
#      'end_time': '2024-06-09T10:46:47.095273',
#      'duration': 0.000183,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '08d68cf9'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.095507',
#      'end_time': '2024-06-09T10:46:47.107578',
#      'duration': 0.012071,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.096827Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.097172Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.105721Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.104857Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf2dc501f51e143d0a31d736b8e4bbd07 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'b9652f3c'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.107857',
#      'end_time': '2024-06-09T10:46:47.108040',
#      'duration': 0.000183,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '368c0c15'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.108295',
#      'end_time': '2024-06-09T10:46:47.126265',
#      'duration': 0.01797,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.109623Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.109961Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.124042Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.124755Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': 'a435dec3'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.126522',
#      'end_time': '2024-06-09T10:46:47.126780',
#      'duration': 0.000258,
#      'status': 'completed'}},
#    'id': '768a65de'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.127028',
#      'end_time': '2024-06-09T10:46:47.127233',
#      'duration': 0.000205,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '7c3aa4ca'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.127472',
#      'end_time': '2024-06-09T10:46:47.133704',
#      'duration': 0.006232,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.128570Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.128773Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.131069Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.131799Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'f08f099d'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.133981',
#      'end_time': '2024-06-09T10:46:47.141811',
#      'duration': 0.00783,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.135141Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.135433Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.140100Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.139500Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf2dc501f51e143d0a31d736b8e4bbd07 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '6eb56e75'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.142078',
#      'end_time': '2024-06-09T10:46:47.142266',
#      'duration': 0.000188,
#      'status': 'completed'}},
#    'id': '96eb7635'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.142508',
#      'end_time': '2024-06-09T10:46:47.151434',
#      'duration': 0.008926,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.143446Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.143637Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.149643Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.148983Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf2dc501f51e143d0a31d736b8e4bbd07 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '54395b7a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.151699',
#      'end_time': '2024-06-09T10:46:47.151888',
#      'duration': 0.000189,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '914bdc3a'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:47.152133',
#      'end_time': '2024-06-09T10:46:47.165237',
#      'duration': 0.013104,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:47.153196Z',
#      'iopub.execute_input': '2024-06-09T10:46:47.153456Z',
#      'shell.execute_reply': '2024-06-09T10:46:47.163062Z',
#      'iopub.status.idle': '2024-06-09T10:46:47.163796Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nf2dc501f51e143d0a31d736b8e4bbd07 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '12d7dd57'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T10:46:47.527989',
#    'end_time': '2024-06-09T10:46:50.761804',
#    'duration': 3.233815,
#    'exception': None}},
#  'cells': [{'id': '279977b3',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.383953',
#      'end_time': '2024-06-09T10:46:48.391722',
#      'duration': 0.007769,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.385069Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.385255Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.390428Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.389957Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.392529',
#      'end_time': '2024-06-09T10:46:48.400871',
#      'duration': 0.008342,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.393853Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.394154Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.398110Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.398925Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '259530b6'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.401120',
#      'end_time': '2024-06-09T10:46:48.460502',
#      'duration': 0.059382,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.402228Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.402417Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.458225Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.457408Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'd01ba4e4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.460679',
#      'end_time': '2024-06-09T10:46:48.467876',
#      'duration': 0.007197,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.461854Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.462625Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.466006Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.465431Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '5a4f4c49'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.468137',
#      'end_time': '2024-06-09T10:46:48.468365',
#      'duration': 0.000228,
#      'status': 'completed'}},
#    'id': '8ce3be0b'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.468505',
#      'end_time': '2024-06-09T10:46:48.485057',
#      'duration': 0.016552,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.469548Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.470185Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.483101Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.482485Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': 'efcbd67f'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.485276',
#      'end_time': '2024-06-09T10:46:48.494853',
#      'duration': 0.009577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.486296Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.486571Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.492298Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.492907Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:0999e62a-9bd0-4ccc-b43f-509f7298edd5 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:0999e62a-9bd0-4ccc-b43f-509f7298edd5 .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': '443a25c3'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.495640',
#      'end_time': '2024-06-09T10:46:48.496113',
#      'duration': 0.000473,
#      'status': 'completed'}},
#    'id': '253ed360'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.496279',
#      'end_time': '2024-06-09T10:46:48.505054',
#      'duration': 0.008775,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.498044Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.498821Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.502716Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.501878Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'af666dec'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.505270',
#      'end_time': '2024-06-09T10:46:48.505452',
#      'duration': 0.000182,
#      'status': 'completed'}},
#    'id': '82a84425'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.505581',
#      'end_time': '2024-06-09T10:46:48.511564',
#      'duration': 0.005983,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.506628Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.506893Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.509880Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.509297Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '5f03631b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.511696',
#      'end_time': '2024-06-09T10:46:48.511852',
#      'duration': 0.000156,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': 'a13293d5'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.511971',
#      'end_time': '2024-06-09T10:46:48.519448',
#      'duration': 0.007477,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.512722Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.512943Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.516725Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.517515Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'ec4af837'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.519581',
#      'end_time': '2024-06-09T10:46:48.519749',
#      'duration': 0.000168,
#      'status': 'completed'}},
#    'id': '3be83bc8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.519869',
#      'end_time': '2024-06-09T10:46:48.527974',
#      'duration': 0.008105,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.521065Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.521290Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.526255Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.525694Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '50d97b1d'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.528141',
#      'end_time': '2024-06-09T10:46:48.534998',
#      'duration': 0.006857,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.528958Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.529136Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.533022Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.533600Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '3d543c23'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.535125',
#      'end_time': '2024-06-09T10:46:48.545554',
#      'duration': 0.010429,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.535880Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.536058Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.544159Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.543559Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '09abfe5a'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.545677',
#      'end_time': '2024-06-09T10:46:48.545813',
#      'duration': 0.000136,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '53bfb21e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.545926',
#      'end_time': '2024-06-09T10:46:48.553506',
#      'duration': 0.00758,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.546796Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.547042Z',
#      'iopub.status.idle': '2024-06-09T10:46:48.551805Z',
#      'shell.execute_reply': '2024-06-09T10:46:48.551202Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '9e85c552'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:48.553714',
#      'end_time': '2024-06-09T10:46:50.458621',
#      'duration': 1.904907,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:48.554782Z',
#      'iopub.execute_input': '2024-06-09T10:46:48.555274Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.454691Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.455899Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '46696694'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.459373',
#      'end_time': '2024-06-09T10:46:50.469527',
#      'duration': 0.010154,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.461300Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.461733Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.467313Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.466435Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '1605a471'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.469785',
#      'end_time': '2024-06-09T10:46:50.470095',
#      'duration': 0.00031,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'e40946ab'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.470323',
#      'end_time': '2024-06-09T10:46:50.480966',
#      'duration': 0.010643,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.471607Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.471873Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.478827Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.479497Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '1f036359'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.481184',
#      'end_time': '2024-06-09T10:46:50.481380',
#      'duration': 0.000196,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'f258e78f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.481612',
#      'end_time': '2024-06-09T10:46:50.490244',
#      'duration': 0.008632,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.482566Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.483141Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.488164Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.488791Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\ng = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '2aab3d89'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.490442',
#      'end_time': '2024-06-09T10:46:50.490642',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '91015c63'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.490820',
#      'end_time': '2024-06-09T10:46:50.497450',
#      'duration': 0.00663,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.491700Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.491941Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.495555Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.496184Z'}},
#    'cell_type': 'code',
#    'source': "\np3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\ng = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': 'bc449916'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.497642',
#      'end_time': '2024-06-09T10:46:50.497827',
#      'duration': 0.000185,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'fd81768f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.497999',
#      'end_time': '2024-06-09T10:46:50.509264',
#      'duration': 0.011265,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.498812Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.499247Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.507654Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.506693Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N23ed5ea2e3974d6998da2ea7a207688a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '0e3ea41e'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.509423',
#      'end_time': '2024-06-09T10:46:50.509654',
#      'duration': 0.000231,
#      'status': 'completed'}},
#    'id': '0a2292bf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.509799',
#      'end_time': '2024-06-09T10:46:50.522395',
#      'duration': 0.012596,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.510778Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.511428Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.520012Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.520714Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': 'b6d8d7a4'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.522559',
#      'end_time': '2024-06-09T10:46:50.529320',
#      'duration': 0.006761,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.523493Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.523683Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.527015Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.527644Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': 'fda36612'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:50.529477',
#      'end_time': '2024-06-09T10:46:50.544211',
#      'duration': 0.014734,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:50.530348Z',
#      'iopub.execute_input': '2024-06-09T10:46:50.530534Z',
#      'shell.execute_reply': '2024-06-09T10:46:50.541578Z',
#      'iopub.status.idle': '2024-06-09T10:46:50.542286Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nffe26e07450d4847b487793f981787a6 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '3f96b38f'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T10:46:50.806939',
#    'end_time': '2024-06-09T10:46:54.254973',
#    'duration': 3.448034,
#    'exception': None}},
#  'cells': [{'id': 'f5805e06',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.650037',
#      'end_time': '2024-06-09T10:46:51.658244',
#      'duration': 0.008207,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.651226Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.651436Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.656091Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.656577Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.659136',
#      'end_time': '2024-06-09T10:46:51.684713',
#      'duration': 0.025577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.660748Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.661561Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.680260Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.677949Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '2300510d'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.685241',
#      'end_time': '2024-06-09T10:46:51.743107',
#      'duration': 0.057866,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.687162Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.687543Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.741642Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.741026Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '628c9fb3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.743302',
#      'end_time': '2024-06-09T10:46:51.748991',
#      'duration': 0.005689,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.744207Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.744553Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.747009Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.747636Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '5b7069ee'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.749183',
#      'end_time': '2024-06-09T10:46:51.749385',
#      'duration': 0.000202,
#      'status': 'completed'}},
#    'id': '94172ca2'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.749557',
#      'end_time': '2024-06-09T10:46:51.766324',
#      'duration': 0.016767,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.750436Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.750757Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.765019Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.764370Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': 'dc2afb88'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.767054',
#      'end_time': '2024-06-09T10:46:51.781672',
#      'duration': 0.014618,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.768382Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.769041Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.779060Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.779753Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:8577b88d-440f-42c2-ba0e-9f07a8929983 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct2/Data/0002.DCM" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\ ...
#    'id': '2c548c97'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.781831',
#      'end_time': '2024-06-09T10:46:51.781987',
#      'duration': 0.000156,
#      'status': 'completed'}},
#    'id': '2dd7e78e'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.782124',
#      'end_time': '2024-06-09T10:46:51.789366',
#      'duration': 0.007242,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.783183Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.783581Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.787375Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.786481Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'fb746ad2'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.789500',
#      'end_time': '2024-06-09T10:46:51.789643',
#      'duration': 0.000143,
#      'status': 'completed'}},
#    'id': '9079bd76'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.789765',
#      'end_time': '2024-06-09T10:46:51.795832',
#      'duration': 0.006067,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.790805Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.791119Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.794540Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.793874Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '62925661'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.795986',
#      'end_time': '2024-06-09T10:46:51.796156',
#      'duration': 0.00017,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '13e08ec1'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.796275',
#      'end_time': '2024-06-09T10:46:51.804097',
#      'duration': 0.007822,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.797390Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.797691Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.802800Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.802241Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'f1444516'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.804236',
#      'end_time': '2024-06-09T10:46:51.804376',
#      'duration': 0.00014,
#      'status': 'completed'}},
#    'id': '4e375d11'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.804490',
#      'end_time': '2024-06-09T10:46:51.814107',
#      'duration': 0.009617,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.805503Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.805768Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.812255Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.811441Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '522549fa'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.814288',
#      'end_time': '2024-06-09T10:46:51.824604',
#      'duration': 0.010316,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.815239Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.815429Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.823209Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.822574Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '89f0087b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.824801',
#      'end_time': '2024-06-09T10:46:51.825012',
#      'duration': 0.000211,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '79b26566'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.825146',
#      'end_time': '2024-06-09T10:46:51.831976',
#      'duration': 0.00683,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.826114Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.826350Z',
#      'iopub.status.idle': '2024-06-09T10:46:51.830512Z',
#      'shell.execute_reply': '2024-06-09T10:46:51.829869Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '7ba1fcf2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:51.832127',
#      'end_time': '2024-06-09T10:46:53.908321',
#      'duration': 2.076194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:51.833147Z',
#      'iopub.execute_input': '2024-06-09T10:46:51.833361Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.906095Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.906882Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '646a2a6e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.909025',
#      'end_time': '2024-06-09T10:46:53.936504',
#      'duration': 0.027479,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.910589Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.911038Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.932569Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.930641Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'b62c72ac'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.936761',
#      'end_time': '2024-06-09T10:46:53.937050',
#      'duration': 0.000289,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'cba208f9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.937265',
#      'end_time': '2024-06-09T10:46:53.950926',
#      'duration': 0.013661,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.938875Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.939218Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.947408Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.948349Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '6849413d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.951183',
#      'end_time': '2024-06-09T10:46:53.951429',
#      'duration': 0.000246,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'bcae6db0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.951652',
#      'end_time': '2024-06-09T10:46:53.957781',
#      'duration': 0.006129,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.952998Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.953338Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.955867Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.956448Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '6118f269'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.957938',
#      'end_time': '2024-06-09T10:46:53.958129',
#      'duration': 0.000191,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'aca75e5f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.958308',
#      'end_time': '2024-06-09T10:46:53.964123',
#      'duration': 0.005815,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.959559Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.960194Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.962049Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.962640Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '75a8d243'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.964275',
#      'end_time': '2024-06-09T10:46:53.964481',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'd6a097bf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.964604',
#      'end_time': '2024-06-09T10:46:53.978255',
#      'duration': 0.013651,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.965793Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.966218Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.975636Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.976318Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0b653962b0bf49cfb2a0577d21bddc1a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': '3d9a96a2'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.978414',
#      'end_time': '2024-06-09T10:46:53.978597',
#      'duration': 0.000183,
#      'status': 'completed'}},
#    'id': '4b05d424'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.978716',
#      'end_time': '2024-06-09T10:46:53.993553',
#      'duration': 0.014837,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.979667Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.979854Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.991559Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.992207Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'def42f74'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:53.993687',
#      'end_time': '2024-06-09T10:46:54.000544',
#      'duration': 0.006857,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:53.994613Z',
#      'iopub.execute_input': '2024-06-09T10:46:53.995115Z',
#      'shell.execute_reply': '2024-06-09T10:46:53.998661Z',
#      'iopub.status.idle': '2024-06-09T10:46:53.999256Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '2e67118d'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T10:46:54.000678',
#      'end_time': '2024-06-09T10:46:54.034266',
#      'duration': 0.033588,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T10:46:54.001578Z',
#      'iopub.execute_input': '2024-06-09T10:46:54.002182Z',
#      'shell.execute_reply': '2024-06-09T10:46:54.030689Z',
#      'iopub.status.idle': '2024-06-09T10:46:54.031813Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N64b07409e6f749e88c9735a83f6aa029 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': 'd71c3793'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/Si+deCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 664c3439-4405-44a2-9252-faf82c5a78dd
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 609c912f-da91-47e6-a101-b3c0af7c8404
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# c9748d64-ff97-404a-be7b-666f69a743f7
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
