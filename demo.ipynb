# %%
import os

# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '84f2edb9',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:12.822323',
#      'end_time': '2024-06-08T13:48:12.852200',
#      'duration': 0.029877,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:12.826947Z',
#      'iopub.execute_input': '2024-06-08T13:48:12.827692Z',
#      'shell.execute_reply': '2024-06-08T13:48:12.844074Z',
#      'iopub.status.idle': '2024-06-08T13:48:12.846416Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:12.855046',
#      'end_time': '2024-06-08T13:48:12.879161',
#      'duration': 0.024115,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:12.859659Z',
#      'iopub.execute_input': '2024-06-08T13:48:12.860416Z',
#      'iopub.status.idle': '2024-06-08T13:48:12.872617Z',
#      'shell.execute_reply': '2024-06-08T13:48:12.869966Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:12.879857',
#      'end_time': '2024-06-08T13:48:12.880462',
#      'duration': 0.000605,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:12.880998',
#      'end_time': '2024-06-08T13:48:13.083028',
#      'duration': 0.20203,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:12.884758Z',
#      'iopub.execute_input': '2024-06-08T13:48:12.885612Z',
#      'shell.execute_reply': '2024-06-08T13:48:13.077343Z',
#      'iopub.status.idle': '2024-06-08T13:48:13.078584Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:13.084248',
#      'end_time': '2024-06-08T13:48:13.117133',
#      'duration': 0.032885,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:13.086059Z',
#      'iopub.execute_input': '2024-06-08T13:48:13.086438Z',
#      'shell.execute_reply': '2024-06-08T13:48:13.113235Z',
#      'iopub.status.idle': '2024-06-08T13:48:13.114381Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:13.117533',
#      'end_time': '2024-06-08T13:48:13.117901',
#      'duration': 0.000368,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:13.118324',
#      'end_time': '2024-06-08T13:48:13.118732',
#      'duration': 0.000408,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:13.119121',
#      'end_time': '2024-06-08T13:48:13.134489',
#      'duration': 0.015368,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:13.121403Z',
#      'iopub.execute_input': '2024-06-08T13:48:13.121973Z',
#      'iopub.status.idle': '2024-06-08T13:48:13.129439Z',
#      'shell.execute_reply': '2024-06-08T13:48:13.128245Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:13.134982',
#      'end_time': '2024-06-08T13:48:15.658825',
#      'duration': 2.523843,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:13.136916Z',
#      'iopub.execute_input': '2024-06-08T13:48:13.137276Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.649077Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.652265Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.663011',
#      'end_time': '2024-06-08T13:48:15.664278',
#      'duration': 0.001267,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.665400',
#      'end_time': '2024-06-08T13:48:15.691409',
#      'duration': 0.026009,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.671328Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.673030Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.682178Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.685209Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.692475',
#      'end_time': '2024-06-08T13:48:15.731603',
#      'duration': 0.039128,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.696707Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.697818Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.725958Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.723438Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.732774',
#      'end_time': '2024-06-08T13:48:15.733448',
#      'duration': 0.000674,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.734191',
#      'end_time': '2024-06-08T13:48:15.752882',
#      'duration': 0.018691,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.737437Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.738125Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.747788Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.745330Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.753589',
#      'end_time': '2024-06-08T13:48:15.781037',
#      'duration': 0.027448,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.757140Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.759269Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.773268Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.770928Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.783805',
#      'end_time': '2024-06-08T13:48:15.784944',
#      'duration': 0.001139,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.786052',
#      'end_time': '2024-06-08T13:48:15.814146',
#      'duration': 0.028094,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.789913Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.791038Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.804475Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.800395Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.815209',
#      'end_time': '2024-06-08T13:48:15.842258',
#      'duration': 0.027049,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.819603Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.822032Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.828773Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.832090Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.843218',
#      'end_time': '2024-06-08T13:48:15.844060',
#      'duration': 0.000842,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.845067',
#      'end_time': '2024-06-08T13:48:15.867343',
#      'duration': 0.022276,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.850032Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.850782Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.856190Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.858605Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.868402',
#      'end_time': '2024-06-08T13:48:15.869378',
#      'duration': 0.000976,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:15.870820',
#      'end_time': '2024-06-08T13:48:15.971396',
#      'duration': 0.100576,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:15.875882Z',
#      'iopub.execute_input': '2024-06-08T13:48:15.877739Z',
#      'shell.execute_reply': '2024-06-08T13:48:15.961572Z',
#      'iopub.status.idle': '2024-06-08T13:48:15.964761Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd8ead800806243fb80ea30c83dcfaa2c (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T13:48:11.657029',
#    'end_time': '2024-06-08T13:48:16.516882',
#    'duration': 4.859853,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T13:48:16.670197',
#    'end_time': '2024-06-08T13:48:25.181629',
#    'duration': 8.511432,
#    'exception': None}},
#  'cells': [{'id': '3a1e117d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:18.171803',
#      'end_time': '2024-06-08T13:48:18.202010',
#      'duration': 0.030207,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:18.175369Z',
#      'iopub.execute_input': '2024-06-08T13:48:18.176236Z',
#      'iopub.status.idle': '2024-06-08T13:48:18.195641Z',
#      'shell.execute_reply': '2024-06-08T13:48:18.193186Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:18.205241',
#      'end_time': '2024-06-08T13:48:18.239298',
#      'duration': 0.034057,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:18.210534Z',
#      'iopub.execute_input': '2024-06-08T13:48:18.211652Z',
#      'iopub.status.idle': '2024-06-08T13:48:18.230533Z',
#      'shell.execute_reply': '2024-06-08T13:48:18.225252Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': 'd7eb78ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:18.240302',
#      'end_time': '2024-06-08T13:48:18.263991',
#      'duration': 0.023689,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:18.244892Z',
#      'iopub.execute_input': '2024-06-08T13:48:18.246081Z',
#      'iopub.status.idle': '2024-06-08T13:48:18.258114Z',
#      'shell.execute_reply': '2024-06-08T13:48:18.255502Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '8b444435'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:18.264871',
#      'end_time': '2024-06-08T13:48:23.727515',
#      'duration': 5.462644,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:18.268102Z',
#      'iopub.execute_input': '2024-06-08T13:48:18.270076Z',
#      'shell.execute_reply': '2024-06-08T13:48:23.722355Z',
#      'iopub.status.idle': '2024-06-08T13:48:23.723962Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': '03ce3abf'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:23.728972',
#      'end_time': '2024-06-08T13:48:23.729902',
#      'duration': 0.00093,
#      'status': 'completed'}},
#    'id': '58b47ff9'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:23.730250',
#      'end_time': '2024-06-08T13:48:23.749395',
#      'duration': 0.019145,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:23.733231Z',
#      'iopub.execute_input': '2024-06-08T13:48:23.733930Z',
#      'iopub.status.idle': '2024-06-08T13:48:23.745695Z',
#      'shell.execute_reply': '2024-06-08T13:48:23.743984Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'e6b66014'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:23.749829',
#      'end_time': '2024-06-08T13:48:23.750285',
#      'duration': 0.000456,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '6a2fe6ca'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:23.750640',
#      'end_time': '2024-06-08T13:48:24.449830',
#      'duration': 0.69919,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:23.752801Z',
#      'iopub.execute_input': '2024-06-08T13:48:23.753258Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.445375Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.446706Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '0ba730ac'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.451234',
#      'end_time': '2024-06-08T13:48:24.494390',
#      'duration': 0.043156,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.453590Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.454508Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.490705Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.491961Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '72653cdf'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.494711',
#      'end_time': '2024-06-08T13:48:24.495050',
#      'duration': 0.000339,
#      'status': 'completed'}},
#    'id': '88bd1334'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.495315',
#      'end_time': '2024-06-08T13:48:24.495604',
#      'duration': 0.000289,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '482cadaf'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.495896',
#      'end_time': '2024-06-08T13:48:24.503698',
#      'duration': 0.007802,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.497249Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.497569Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.500531Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.501193Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'a65a0ffd'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.503920',
#      'end_time': '2024-06-08T13:48:24.514890',
#      'duration': 0.01097,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.505124Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.505394Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.511815Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.512702Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '5f4d6410'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.515134',
#      'end_time': '2024-06-08T13:48:24.515412',
#      'duration': 0.000278,
#      'status': 'completed'}},
#    'id': 'b05f3b3d'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.515643',
#      'end_time': '2024-06-08T13:48:24.528634',
#      'duration': 0.012991,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.516916Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.517197Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.525965Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.524877Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': '7754cb67'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.528946',
#      'end_time': '2024-06-08T13:48:24.529244',
#      'duration': 0.000298,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': 'c3af98b3'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.529460',
#      'end_time': '2024-06-08T13:48:24.540979',
#      'duration': 0.011519,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.530842Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.531138Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.537340Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.538255Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N35a9c24c2ade425d992aa2f89da75d41 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': 'f5b245b7'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.541240',
#      'end_time': '2024-06-08T13:48:24.541492',
#      'duration': 0.000252,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '95412ff4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.541709',
#      'end_time': '2024-06-08T13:48:24.554755',
#      'duration': 0.013046,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.543195Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.543517Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.551029Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.549556Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': 'ab866706'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.556044',
#      'end_time': '2024-06-08T13:48:24.556621',
#      'duration': 0.000577,
#      'status': 'completed'}},
#    'id': '7cc05a08'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.556933',
#      'end_time': '2024-06-08T13:48:24.557455',
#      'duration': 0.000522,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'f58dfbab'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.557771',
#      'end_time': '2024-06-08T13:48:24.573027',
#      'duration': 0.015256,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.560100Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.560995Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.569002Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.567739Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '97648080'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.573311',
#      'end_time': '2024-06-08T13:48:24.597843',
#      'duration': 0.024532,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.575295Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.575830Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.590434Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.592997Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N35a9c24c2ade425d992aa2f89da75d41 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'af793edd'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.598278',
#      'end_time': '2024-06-08T13:48:24.598828',
#      'duration': 0.00055,
#      'status': 'completed'}},
#    'id': '27886f5c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.599210',
#      'end_time': '2024-06-08T13:48:24.620999',
#      'duration': 0.021789,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.601951Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.602980Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.615413Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.617104Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N35a9c24c2ade425d992aa2f89da75d41 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': '208b64bb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.621407',
#      'end_time': '2024-06-08T13:48:24.621922',
#      'duration': 0.000515,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'd6b203cf'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:24.622488',
#      'end_time': '2024-06-08T13:48:24.649806',
#      'duration': 0.027318,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:24.624884Z',
#      'iopub.execute_input': '2024-06-08T13:48:24.626214Z',
#      'shell.execute_reply': '2024-06-08T13:48:24.643325Z',
#      'iopub.status.idle': '2024-06-08T13:48:24.645179Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N35a9c24c2ade425d992aa2f89da75d41 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': 'eb85f126'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T13:48:25.336628',
#    'end_time': '2024-06-08T13:48:32.928741',
#    'duration': 7.592113,
#    'exception': None}},
#  'cells': [{'id': '1074b051',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:26.366187',
#      'end_time': '2024-06-08T13:48:26.403411',
#      'duration': 0.037224,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:26.369838Z',
#      'iopub.execute_input': '2024-06-08T13:48:26.370569Z',
#      'shell.execute_reply': '2024-06-08T13:48:26.395357Z',
#      'iopub.status.idle': '2024-06-08T13:48:26.398069Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:26.405884',
#      'end_time': '2024-06-08T13:48:26.432160',
#      'duration': 0.026276,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:26.409733Z',
#      'iopub.execute_input': '2024-06-08T13:48:26.410485Z',
#      'shell.execute_reply': '2024-06-08T13:48:26.420457Z',
#      'iopub.status.idle': '2024-06-08T13:48:26.423235Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '1dbaf18e'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:26.432846',
#      'end_time': '2024-06-08T13:48:31.521240',
#      'duration': 5.088394,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:26.437481Z',
#      'iopub.execute_input': '2024-06-08T13:48:26.438564Z',
#      'iopub.status.idle': '2024-06-08T13:48:31.519270Z',
#      'shell.execute_reply': '2024-06-08T13:48:31.518344Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '574c4c5f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:31.522339',
#      'end_time': '2024-06-08T13:48:31.532922',
#      'duration': 0.010583,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:31.524115Z',
#      'iopub.execute_input': '2024-06-08T13:48:31.524554Z',
#      'iopub.status.idle': '2024-06-08T13:48:31.530166Z',
#      'shell.execute_reply': '2024-06-08T13:48:31.529089Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '3af15020'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:31.533166',
#      'end_time': '2024-06-08T13:48:31.533499',
#      'duration': 0.000333,
#      'status': 'completed'}},
#    'id': '532c22fa'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:31.533705',
#      'end_time': '2024-06-08T13:48:31.544852',
#      'duration': 0.011147,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:31.535254Z',
#      'iopub.execute_input': '2024-06-08T13:48:31.535647Z',
#      'shell.execute_reply': '2024-06-08T13:48:31.541861Z',
#      'iopub.status.idle': '2024-06-08T13:48:31.542775Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '8200ac54'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:31.545160',
#      'end_time': '2024-06-08T13:48:31.545438',
#      'duration': 0.000278,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': 'da87b758'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:31.545739',
#      'end_time': '2024-06-08T13:48:32.014564',
#      'duration': 0.468825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:31.546989Z',
#      'iopub.execute_input': '2024-06-08T13:48:31.547277Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.011644Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.012601Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': 'ba015f0a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.015320',
#      'end_time': '2024-06-08T13:48:32.230043',
#      'duration': 0.214723,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.017156Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.017938Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.226347Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.227487Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': 'c8e2603b'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.231036',
#      'end_time': '2024-06-08T13:48:32.263950',
#      'duration': 0.032914,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.232752Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.233111Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.259374Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.257942Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '348e924f'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.264411',
#      'end_time': '2024-06-08T13:48:32.264814',
#      'duration': 0.000403,
#      'status': 'completed'}},
#    'id': 'f8448eec'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.265178',
#      'end_time': '2024-06-08T13:48:32.265562',
#      'duration': 0.000384,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'a3b8d87d'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.265935',
#      'end_time': '2024-06-08T13:48:32.276167',
#      'duration': 0.010232,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.267692Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.268247Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.273032Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.271759Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': '92b26aac'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.276428',
#      'end_time': '2024-06-08T13:48:32.290417',
#      'duration': 0.013989,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.277956Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.278277Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.286939Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.287948Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': '83bae288'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.290681',
#      'end_time': '2024-06-08T13:48:32.290956',
#      'duration': 0.000275,
#      'status': 'completed'}},
#    'id': 'f7070600'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.291183',
#      'end_time': '2024-06-08T13:48:32.306187',
#      'duration': 0.015004,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.292662Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.292994Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.302885Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.301714Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': 'a966f625'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.306580',
#      'end_time': '2024-06-08T13:48:32.306857',
#      'duration': 0.000277,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '21337cee'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.307191',
#      'end_time': '2024-06-08T13:48:32.320913',
#      'duration': 0.013722,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.308694Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.309455Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.317268Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.318428Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N502341f9d2f54749994285960adcd9fb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '69dbd515'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.321162',
#      'end_time': '2024-06-08T13:48:32.321428',
#      'duration': 0.000266,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'da0eead7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.321668',
#      'end_time': '2024-06-08T13:48:32.341680',
#      'duration': 0.020012,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.323537Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.324599Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.339245Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.338056Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '7e5dfff6'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.342686',
#      'end_time': '2024-06-08T13:48:32.343401',
#      'duration': 0.000715,
#      'status': 'completed'}},
#    'id': '0d14f043'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.343674',
#      'end_time': '2024-06-08T13:48:32.344376',
#      'duration': 0.000702,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'ed5003e7'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.344742',
#      'end_time': '2024-06-08T13:48:32.356655',
#      'duration': 0.011913,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.346497Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.346971Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.352416Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.351149Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'fb8e9d4a'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.357034',
#      'end_time': '2024-06-08T13:48:32.372934',
#      'duration': 0.0159,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.359214Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.360372Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.368638Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.367421Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N502341f9d2f54749994285960adcd9fb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '83402323'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.373155',
#      'end_time': '2024-06-08T13:48:32.373458',
#      'duration': 0.000303,
#      'status': 'completed'}},
#    'id': '331d5349'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.373662',
#      'end_time': '2024-06-08T13:48:32.387717',
#      'duration': 0.014055,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.375274Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.375956Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.383759Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.382884Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N502341f9d2f54749994285960adcd9fb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '19cdf5cd'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.387994',
#      'end_time': '2024-06-08T13:48:32.388347',
#      'duration': 0.000353,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '78e36e38'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:32.388594',
#      'end_time': '2024-06-08T13:48:32.404031',
#      'duration': 0.015437,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:32.389897Z',
#      'iopub.execute_input': '2024-06-08T13:48:32.390153Z',
#      'shell.execute_reply': '2024-06-08T13:48:32.401342Z',
#      'iopub.status.idle': '2024-06-08T13:48:32.402193Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N502341f9d2f54749994285960adcd9fb (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': 'c74ddde4'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T13:48:33.078916',
#    'end_time': '2024-06-08T13:48:37.715323',
#    'duration': 4.636407,
#    'exception': None}},
#  'cells': [{'id': '92720317',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.319900',
#      'end_time': '2024-06-08T13:48:34.350392',
#      'duration': 0.030492,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.323655Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.324394Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.344945Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.342965Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.352619',
#      'end_time': '2024-06-08T13:48:34.375120',
#      'duration': 0.022501,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.356089Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.356727Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.366644Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.369321Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '626ed241'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.375774',
#      'end_time': '2024-06-08T13:48:34.505421',
#      'duration': 0.129647,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.379200Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.379897Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.502256Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.503028Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '47a4c0c4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.506401',
#      'end_time': '2024-06-08T13:48:34.516352',
#      'duration': 0.009951,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.507919Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.508780Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.513269Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.514103Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': 'dd2d78cc'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.516556',
#      'end_time': '2024-06-08T13:48:34.516817',
#      'duration': 0.000261,
#      'status': 'completed'}},
#    'id': 'd878c906'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.517004',
#      'end_time': '2024-06-08T13:48:34.541074',
#      'duration': 0.02407,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.518290Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.518656Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.537867Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.538680Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '139f1ef4'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.541272',
#      'end_time': '2024-06-08T13:48:34.553039',
#      'duration': 0.011767,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.542539Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.542784Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.549936Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.550799Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:2d3750cf-23cb-443f-9345-3ebdabdbc616 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:2d3750cf-23cb-443f-9345-3ebdabdbc616 .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': 'edfef13a'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.553235',
#      'end_time': '2024-06-08T13:48:34.553478',
#      'duration': 0.000243,
#      'status': 'completed'}},
#    'id': 'd76fbbf6'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.553664',
#      'end_time': '2024-06-08T13:48:34.560655',
#      'duration': 0.006991,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.554773Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.555001Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.558388Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.557633Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '6964de89'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.560852',
#      'end_time': '2024-06-08T13:48:34.561087',
#      'duration': 0.000235,
#      'status': 'completed'}},
#    'id': 'fd9cbf07'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.561273',
#      'end_time': '2024-06-08T13:48:34.568384',
#      'duration': 0.007111,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.562433Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.562671Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.565253Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.566058Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'c1f93dfb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.568653',
#      'end_time': '2024-06-08T13:48:34.568916',
#      'duration': 0.000263,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '678443a5'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.569099',
#      'end_time': '2024-06-08T13:48:34.578920',
#      'duration': 0.009821,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.570221Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.570448Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.577147Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.576458Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'e99d4805'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.579108',
#      'end_time': '2024-06-08T13:48:34.579385',
#      'duration': 0.000277,
#      'status': 'completed'}},
#    'id': 'd501cfc2'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.579621',
#      'end_time': '2024-06-08T13:48:34.588178',
#      'duration': 0.008557,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.580632Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.580865Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.585725Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.586362Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '7b810ad1'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.588367',
#      'end_time': '2024-06-08T13:48:34.597930',
#      'duration': 0.009563,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.589400Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.589628Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.595695Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.594819Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '7804d6cc'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.598203',
#      'end_time': '2024-06-08T13:48:34.610736',
#      'duration': 0.012533,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.599312Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.599600Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.609042Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.608421Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '2b6a806b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.611548',
#      'end_time': '2024-06-08T13:48:34.611922',
#      'duration': 0.000374,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '513a9aef'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.612212',
#      'end_time': '2024-06-08T13:48:34.623475',
#      'duration': 0.011263,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.613401Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.613751Z',
#      'shell.execute_reply': '2024-06-08T13:48:34.620497Z',
#      'iopub.status.idle': '2024-06-08T13:48:34.621318Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '2d454d77'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:34.623676',
#      'end_time': '2024-06-08T13:48:37.073254',
#      'duration': 2.449578,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:34.625190Z',
#      'iopub.execute_input': '2024-06-08T13:48:34.625538Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.067155Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.064320Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '81366b4b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.073803',
#      'end_time': '2024-06-08T13:48:37.096269',
#      'duration': 0.022466,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.077954Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.078742Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.090993Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.088638Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': 'ea189a86'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.096822',
#      'end_time': '2024-06-08T13:48:37.097494',
#      'duration': 0.000672,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'caea7610'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.098032',
#      'end_time': '2024-06-08T13:48:37.135342',
#      'duration': 0.03731,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.101148Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.101861Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.127372Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.124457Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'befec9db'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.136014',
#      'end_time': '2024-06-08T13:48:37.136746',
#      'duration': 0.000732,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '3f66cc7c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.139470',
#      'end_time': '2024-06-08T13:48:37.174728',
#      'duration': 0.035258,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.144336Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.145520Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.168543Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.166408Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\ng = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '75a819e1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.175336',
#      'end_time': '2024-06-08T13:48:37.176068',
#      'duration': 0.000732,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': 'c1e82ebd'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.176613',
#      'end_time': '2024-06-08T13:48:37.195443',
#      'duration': 0.01883,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.179798Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.180504Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.188549Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.186310Z'}},
#    'cell_type': 'code',
#    'source': "\n#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': '379dca95'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.196036',
#      'end_time': '2024-06-08T13:48:37.196643',
#      'duration': 0.000607,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': '22cc6f3b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.197136',
#      'end_time': '2024-06-08T13:48:37.237675',
#      'duration': 0.040539,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.200637Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.201356Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.230853Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.228058Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nb77c1588497048458c2c332a23a0930e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '3d7a56fc'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.241160',
#      'end_time': '2024-06-08T13:48:37.242524',
#      'duration': 0.001364,
#      'status': 'completed'}},
#    'id': '856990dc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.243077',
#      'end_time': '2024-06-08T13:48:37.296736',
#      'duration': 0.053659,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.246553Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.247322Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.287511Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.290343Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '495512aa'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.297416',
#      'end_time': '2024-06-08T13:48:37.322292',
#      'duration': 0.024876,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.300653Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.301369Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.313105Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.315722Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': '6e2f1cf5'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:37.322852',
#      'end_time': '2024-06-08T13:48:37.385293',
#      'duration': 0.062441,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:37.326620Z',
#      'iopub.execute_input': '2024-06-08T13:48:37.327393Z',
#      'shell.execute_reply': '2024-06-08T13:48:37.376527Z',
#      'iopub.status.idle': '2024-06-08T13:48:37.379619Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Ne65d73f3995343f48a2d3eec5c61fb8f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '19b1aaa4'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-08T13:48:37.797839',
#    'end_time': '2024-06-08T13:48:42.212090',
#    'duration': 4.414251,
#    'exception': None}},
#  'cells': [{'id': 'e76c242d',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.706060',
#      'end_time': '2024-06-08T13:48:38.737870',
#      'duration': 0.03181,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.709712Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.711723Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.728135Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.731030Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.740563',
#      'end_time': '2024-06-08T13:48:38.767834',
#      'duration': 0.027271,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.744747Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.745587Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.758265Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.761304Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '6bdc722a'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.768514',
#      'end_time': '2024-06-08T13:48:38.910703',
#      'duration': 0.142189,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.772995Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.773755Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.908162Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.908898Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '637ce3a8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.911784',
#      'end_time': '2024-06-08T13:48:38.921240',
#      'duration': 0.009456,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.913372Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.913636Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.918912Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.918039Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '6489902a'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.921519',
#      'end_time': '2024-06-08T13:48:38.921802',
#      'duration': 0.000283,
#      'status': 'completed'}},
#    'id': '727c0f51'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.921986',
#      'end_time': '2024-06-08T13:48:38.946485',
#      'duration': 0.024499,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.923279Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.923528Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.943167Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.944083Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': 'c50d283f'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.946692',
#      'end_time': '2024-06-08T13:48:38.960754',
#      'duration': 0.014062,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.947938Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.948182Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.957537Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.958431Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\nab:PixelRepresentation a tb:Attribute ;\n    tb:attribute "PixelRepresentation" .\n\nab:PositionerMotion a tb:Attribute ;\n    tb:attribute "PositionerMotion" .\n\nab:PositionerPrimaryAngle a tb:Attribute ;\n    tb:at ...
#    'id': 'df21a94b'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.961048',
#      'end_time': '2024-06-08T13:48:38.961273',
#      'duration': 0.000225,
#      'status': 'completed'}},
#    'id': '1baa2b81'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.961532',
#      'end_time': '2024-06-08T13:48:38.969275',
#      'duration': 0.007743,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.962801Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.963065Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.966870Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.965983Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '258dce6b'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.969513',
#      'end_time': '2024-06-08T13:48:38.969784',
#      'duration': 0.000271,
#      'status': 'completed'}},
#    'id': '31a59aba'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.969976',
#      'end_time': '2024-06-08T13:48:38.977212',
#      'duration': 0.007236,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.971293Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.971867Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.975244Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.974478Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': '3c4a747e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.977408',
#      'end_time': '2024-06-08T13:48:38.977667',
#      'duration': 0.000259,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '3880b4c5'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.977832',
#      'end_time': '2024-06-08T13:48:38.987855',
#      'duration': 0.010023,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.978980Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.979229Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.984494Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.985359Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'ad46bc38'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.988058',
#      'end_time': '2024-06-08T13:48:38.988305',
#      'duration': 0.000247,
#      'status': 'completed'}},
#    'id': 'f0cd292a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.988496',
#      'end_time': '2024-06-08T13:48:38.998659',
#      'duration': 0.010163,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.989644Z',
#      'iopub.execute_input': '2024-06-08T13:48:38.990230Z',
#      'shell.execute_reply': '2024-06-08T13:48:38.995527Z',
#      'iopub.status.idle': '2024-06-08T13:48:38.996333Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'f2cf9ce0'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:38.998879',
#      'end_time': '2024-06-08T13:48:39.011801',
#      'duration': 0.012922,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:38.999976Z',
#      'iopub.execute_input': '2024-06-08T13:48:39.000553Z',
#      'shell.execute_reply': '2024-06-08T13:48:39.009251Z',
#      'iopub.status.idle': '2024-06-08T13:48:39.010016Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '7d087e5d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:39.012714',
#      'end_time': '2024-06-08T13:48:39.013270',
#      'duration': 0.000556,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '0a454630'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:39.013489',
#      'end_time': '2024-06-08T13:48:39.024614',
#      'duration': 0.011125,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:39.015377Z',
#      'iopub.execute_input': '2024-06-08T13:48:39.015844Z',
#      'iopub.status.idle': '2024-06-08T13:48:39.022069Z',
#      'shell.execute_reply': '2024-06-08T13:48:39.021138Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '44a3cb04'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:39.024801',
#      'end_time': '2024-06-08T13:48:41.595417',
#      'duration': 2.570616,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:39.026329Z',
#      'iopub.execute_input': '2024-06-08T13:48:39.027001Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.589845Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.586373Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'f1b02e0e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.596017',
#      'end_time': '2024-06-08T13:48:41.619340',
#      'duration': 0.023323,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.600358Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.601175Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.612189Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.614068Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': 'd874bea8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.619848',
#      'end_time': '2024-06-08T13:48:41.620393',
#      'duration': 0.000545,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '23e0b1d0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.620866',
#      'end_time': '2024-06-08T13:48:41.652583',
#      'duration': 0.031717,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.623969Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.625904Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.647293Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.645100Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '70b6bfd6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.653096',
#      'end_time': '2024-06-08T13:48:41.653711',
#      'duration': 0.000615,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '4e9ebe44'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.655908',
#      'end_time': '2024-06-08T13:48:41.679874',
#      'duration': 0.023966,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.659782Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.660492Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.667757Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.671099Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '9b315617'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.680517',
#      'end_time': '2024-06-08T13:48:41.681298',
#      'duration': 0.000781,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '7194a145'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.682082',
#      'end_time': '2024-06-08T13:48:41.701022',
#      'duration': 0.01894,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.685360Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.687274Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.692546Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.694830Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '811980e7'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.701621',
#      'end_time': '2024-06-08T13:48:41.702368',
#      'duration': 0.000747,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'db7dab8a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.703059',
#      'end_time': '2024-06-08T13:48:41.754750',
#      'duration': 0.051691,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.706804Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.708936Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.745557Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.743016Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc8187d15c7f94ccea21d920874ce7d8e (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': '929da4eb'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.757157',
#      'end_time': '2024-06-08T13:48:41.758079',
#      'duration': 0.000922,
#      'status': 'completed'}},
#    'id': '33026f5b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.758659',
#      'end_time': '2024-06-08T13:48:41.831351',
#      'duration': 0.072692,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.763531Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.764954Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.819265Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.821822Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'a117e6b5'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.831919',
#      'end_time': '2024-06-08T13:48:41.857885',
#      'duration': 0.025966,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.835286Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.836648Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.853129Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.851209Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': '903a1393'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T13:48:41.858169',
#      'end_time': '2024-06-08T13:48:41.889697',
#      'duration': 0.031528,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T13:48:41.860035Z',
#      'iopub.execute_input': '2024-06-08T13:48:41.860406Z',
#      'shell.execute_reply': '2024-06-08T13:48:41.885816Z',
#      'iopub.status.idle': '2024-06-08T13:48:41.886991Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N57123b90e7b449a69eb5c03e36120d80 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': 'c1a90745'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 85d46d02-dbcf-403d-ae00-7c68383e8896
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 3cd82bd4-f997-4c79-83a3-24c9dcdc3410
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 609bd27c-05e1-4b9f-84c6-d638837b4531
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
