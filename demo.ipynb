# %%
import os

# %%
base_dir = os.getcwd()

# %%
import rdflib
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # POPULATE FEDERATED LAYER

# %% [markdown]
# ![title](GD.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',None, parameters={
        'folder': 'FederatedComputationalGovernance',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/22 [00:00<?, ?cell/s]
# {'cells': [{'id': '1900424e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:28.919570',
#      'end_time': '2024-06-09T12:08:28.946273',
#      'duration': 0.026703,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:28.922845Z',
#      'iopub.execute_input': '2024-06-09T12:08:28.924635Z',
#      'iopub.status.idle': '2024-06-09T12:08:28.941019Z',
#      'shell.execute_reply': '2024-06-09T12:08:28.938837Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "FederatedComputationalGovernance"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.222229Z',
#      'start_time': '2024-05-25T11:05:13.206743Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:28.949507',
#      'end_time': '2024-06-09T12:08:28.971210',
#      'duration': 0.021703,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:28.953237Z',
#      'iopub.execute_input': '2024-06-09T12:08:28.955447Z',
#      'iopub.status.idle': '2024-06-09T12:08:28.966890Z',
#      'shell.execute_reply': '2024-06-09T12:08:28.963535Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'execution_count': 2,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:28.971576',
#      'end_time': '2024-06-09T12:08:28.971939',
#      'duration': 0.000363,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.247908Z',
#      'start_time': '2024-05-25T11:05:13.236642Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:28.972258',
#      'end_time': '2024-06-09T12:08:29.034624',
#      'duration': 0.062366,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:28.974431Z',
#      'iopub.execute_input': '2024-06-09T12:08:28.974881Z',
#      'shell.execute_reply': '2024-06-09T12:08:29.032576Z',
#      'iopub.status.idle': '2024-06-09T12:08:29.033192Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'execution_count': 3,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.271599Z',
#      'start_time': '2024-05-25T11:05:13.249465Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:29.034758',
#      'end_time': '2024-06-09T12:08:29.050269',
#      'duration': 0.015511,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:29.035528Z',
#      'iopub.execute_input': '2024-06-09T12:08:29.035891Z',
#      'iopub.status.idle': '2024-06-09T12:08:29.048359Z',
#      'shell.execute_reply': '2024-06-09T12:08:29.047744Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\n",
#    'id': 'bb71af78cd94ef67',
#    'execution_count': 4,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.275860Z',
#      'start_time': '2024-05-25T11:05:13.273492Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:29.050864',
#      'end_time': '2024-06-09T12:08:29.051347',
#      'duration': 0.000483,
#      'status': 'completed'}},
#    'cell_type': 'code',
#    'source': '\n',
#    'id': '2aec70e9fa87de4d',
#    'execution_count': None,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:29.051550',
#      'end_time': '2024-06-09T12:08:29.051905',
#      'duration': 0.000355,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:13.282671Z',
#      'start_time': '2024-05-25T11:05:13.277473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:29.052034',
#      'end_time': '2024-06-09T12:08:29.059512',
#      'duration': 0.007478,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:29.053180Z',
#      'iopub.execute_input': '2024-06-09T12:08:29.053496Z',
#      'iopub.status.idle': '2024-06-09T12:08:29.057948Z',
#      'shell.execute_reply': '2024-06-09T12:08:29.057275Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'execution_count': 5,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.618074Z',
#      'start_time': '2024-05-25T11:05:13.284784Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:29.059651',
#      'end_time': '2024-06-09T12:08:31.049128',
#      'duration': 1.989477,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:29.060697Z',
#      'iopub.execute_input': '2024-06-09T12:08:29.060982Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.047550Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.046804Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}]},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.049945',
#      'end_time': '2024-06-09T12:08:31.050248',
#      'duration': 0.000303,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Data Products',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.623732Z',
#      'start_time': '2024-05-25T11:05:15.619802Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.050450',
#      'end_time': '2024-06-09T12:08:31.058277',
#      'duration': 0.007827,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.051902Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.052238Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.056322Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.055471Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/data_products.json')",
#    'id': 'ec4292618860beb',
#    'execution_count': 7,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.645143Z',
#      'start_time': '2024-05-25T11:05:15.625895Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.058437',
#      'end_time': '2024-06-09T12:08:31.071345',
#      'duration': 0.012908,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.059533Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.059784Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.069719Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.069069Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'execution_count': 8,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.071510',
#      'end_time': '2024-06-09T12:08:31.071738',
#      'duration': 0.000228,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.657388Z',
#      'start_time': '2024-05-25T11:05:15.646659Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.071886',
#      'end_time': '2024-06-09T12:08:31.077949',
#      'duration': 0.006063,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.072798Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.072996Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.076024Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.075355Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues/p1.json')",
#    'id': '61ffdb64b35b3f7f',
#    'execution_count': 9,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.671069Z',
#      'start_time': '2024-05-25T11:05:15.659473Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.078110',
#      'end_time': '2024-06-09T12:08:31.086225',
#      'duration': 0.008115,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.079079Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.079284Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.084678Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.083988Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, policies)',
#    'id': '6035d517b2daa21f',
#    'execution_count': 10,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.086382',
#      'end_time': '2024-06-09T12:08:31.086616',
#      'duration': 0.000234,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### PolicyCheckers',
#    'id': 'a34bc29e2efdbbff'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.683142Z',
#      'start_time': '2024-05-25T11:05:15.672709Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.086768',
#      'end_time': '2024-06-09T12:08:31.092784',
#      'duration': 0.006016,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.087732Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.088012Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.090396Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.091005Z'}},
#    'cell_type': 'code',
#    'source': 'import os',
#    'id': 'd263c753b7551c92',
#    'execution_count': 11,
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.695650Z',
#      'start_time': '2024-05-25T11:05:15.685334Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.093009',
#      'end_time': '2024-06-09T12:08:31.098246',
#      'duration': 0.005237,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.094213Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.094441Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.096440Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.096897Z'}},
#    'cell_type': 'code',
#    'source': "#for pc in os.listdir('./ComputationalCatalogues/PolicyCheckers'):\n#    g = add_jsonld_instances(g, os.path.join('./ComputationalCatalogues/PolicyCheckers', pc, 'pc.json'))",
#    'id': 'd8e629e47d8d042',
#    'execution_count': 12,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.098464',
#      'end_time': '2024-06-09T12:08:31.098672',
#      'duration': 0.000208,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Implementations',
#    'id': 'e064d3f096fdc7ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.708079Z',
#      'start_time': '2024-05-25T11:05:15.697435Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.098867',
#      'end_time': '2024-06-09T12:08:31.104001',
#      'duration': 0.005134,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.099717Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.099903Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.102629Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.101937Z'}},
#    'cell_type': 'code',
#    'source': "#implementations = './ComputationalCatalogues/implementations.json'\n#g = add_jsonld_instances(g, implementations)",
#    'id': '5e611a2e0af562cc',
#    'execution_count': 13,
#    'outputs': []},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.104213',
#      'end_time': '2024-06-09T12:08:31.104408',
#      'duration': 0.000195,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:05:15.727533Z',
#      'start_time': '2024-05-25T11:05:15.709397Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:31.104603',
#      'end_time': '2024-06-09T12:08:31.118775',
#      'duration': 0.014172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:31.105508Z',
#      'iopub.execute_input': '2024-06-09T12:08:31.105695Z',
#      'shell.execute_reply': '2024-06-09T12:08:31.116736Z',
#      'iopub.status.idle': '2024-06-09T12:08:31.117366Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7218f73566ed4ec982b6b888209b340d (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}]}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'FederatedComputationalGovernance'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T12:08:28.213138',
#    'end_time': '2024-06-09T12:08:31.337582',
#    'duration': 3.124444,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA PRODUCTS REGISTRATION

# %% [markdown]
# ![title](SG.png)

# %% [markdown]
# ### DP1

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/27 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T12:08:31.382245',
#    'end_time': '2024-06-09T12:08:37.027512',
#    'duration': 5.645267,
#    'exception': None}},
#  'cells': [{'id': '39c45e4f',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:32.125175',
#      'end_time': '2024-06-09T12:08:32.157139',
#      'duration': 0.031964,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:32.129025Z',
#      'iopub.execute_input': '2024-06-09T12:08:32.129763Z',
#      'iopub.status.idle': '2024-06-09T12:08:32.151377Z',
#      'shell.execute_reply': '2024-06-09T12:08:32.148818Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:42.681801Z',
#      'start_time': '2024-05-25T11:19:42.678488Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:32.159736',
#      'end_time': '2024-06-09T12:08:32.183544',
#      'duration': 0.023808,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:32.164745Z',
#      'iopub.execute_input': '2024-06-09T12:08:32.165896Z',
#      'shell.execute_reply': '2024-06-09T12:08:32.177751Z',
#      'iopub.status.idle': '2024-06-09T12:08:32.179663Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'outputs': [],
#    'execution_count': 2,
#    'id': '545d613c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:26:08.320026Z',
#      'start_time': '2024-05-26T20:26:08.312095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:32.184067',
#      'end_time': '2024-06-09T12:08:32.198125',
#      'duration': 0.014058,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:32.186514Z',
#      'iopub.execute_input': '2024-06-09T12:08:32.187013Z',
#      'shell.execute_reply': '2024-06-09T12:08:32.192967Z',
#      'iopub.status.idle': '2024-06-09T12:08:32.194487Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 3,
#    'id': '35ac3a72'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pandas\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.294473Z',
#      'start_time': '2024-05-25T11:19:42.776958Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:32.198365',
#      'end_time': '2024-06-09T12:08:36.126725',
#      'duration': 3.92836,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:32.199962Z',
#      'iopub.execute_input': '2024-06-09T12:08:32.200286Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.124466Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.125161Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (2.2.2)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy>=1.23.2 in ./venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 4,
#    'id': 'e815f3d9'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.127398',
#      'end_time': '2024-06-09T12:08:36.127811',
#      'duration': 0.000413,
#      'status': 'completed'}},
#    'id': 'fc056ac7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.317431Z',
#      'start_time': '2024-05-25T11:19:46.302100Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.128010',
#      'end_time': '2024-06-09T12:08:36.137083',
#      'duration': 0.009073,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.129425Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.129788Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.135551Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.135103Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'outputs': [],
#    'execution_count': 5,
#    'id': 'fc2001ab'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.137298',
#      'end_time': '2024-06-09T12:08:36.137500',
#      'duration': 0.000202,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '6c65e9c3'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.336196Z',
#      'start_time': '2024-05-25T11:19:46.320632Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.137682',
#      'end_time': '2024-06-09T12:08:36.615472',
#      'duration': 0.47779,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.138709Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.138922Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.613373Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.613960Z'}},
#    'outputs': [],
#    'execution_count': 6,
#    'id': '6c911770'},
#   {'cell_type': 'code',
#    'source': "data_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv')\ndf = pd.read_csv(data_path)\ndf.info()",
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.362430Z',
#      'start_time': '2024-05-25T11:19:46.338745Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.616044',
#      'end_time': '2024-06-09T12:08:36.633354',
#      'duration': 0.01731,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.617343Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.617953Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.631494Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.630772Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 671 entries, 0 to 670\nData columns (total 12 columns):\n #   Column                              Non-Null Count  Dtype  \n---  ------                              --------------  -----  \n 0   ID                                  671 non-null    object \n 1   Gender                              671 non-null    object \n 2   Age_at_scan_years                   671 non-null    float64\n 3   Survival_from_surgery_days_UPDATED  671 non-null    object \n 4   Survival_Status                     671 non-null    object \n 5   Survival_Censor                     671 non-null    object \n 6   IDH1                                671 non-null    object \n 7   MGMT                                671 non-null    object \n 8   KPS                                 671 non-null    object \n 9   GTR_over90percent                   671 non-null    object \n 10  Time_since_baseline_preop           671 non-null    object \n 11  PsP_TP_score                        60 non-null     float64\ndtypes: float64(2), object(10)\nmemory usage: 63.0+ KB\n"}],
#    'execution_count': 7,
#    'id': '50d658c2'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.633564',
#      'end_time': '2024-06-09T12:08:36.633782',
#      'duration': 0.000218,
#      'status': 'completed'}},
#    'id': '2bc3435e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.633965',
#      'end_time': '2024-06-09T12:08:36.634137',
#      'duration': 0.000172,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': 'b682c631'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.367233Z',
#      'start_time': '2024-05-25T11:19:46.363754Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.634325',
#      'end_time': '2024-06-09T12:08:36.640471',
#      'duration': 0.006146,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.635286Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.635494Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.637842Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.638569Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'outputs': [],
#    'execution_count': 8,
#    'id': 'c4394c64'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.382799Z',
#      'start_time': '2024-05-25T11:19:46.369388Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.640620',
#      'end_time': '2024-06-09T12:08:36.648832',
#      'duration': 0.008212,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.641577Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.641764Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.647261Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.646508Z'}},
#    'outputs': [],
#    'execution_count': 9,
#    'id': '709ff6fe'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.649045',
#      'end_time': '2024-06-09T12:08:36.649248',
#      'duration': 0.000203,
#      'status': 'completed'}},
#    'id': '33204c3b'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = meta_dp.name.values[0]\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.398074Z',
#      'start_time': '2024-05-25T11:19:46.384761Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.649432',
#      'end_time': '2024-06-09T12:08:36.657184',
#      'duration': 0.007752,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.650285Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.650484Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.655389Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.655916Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'UPENN-GBM_clinical_info_v2'"},
#      'execution_count': 10}],
#    'execution_count': 10,
#    'id': 'e7b02fbc'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.657336',
#      'end_time': '2024-06-09T12:08:36.657542',
#      'duration': 0.000206,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '6daedd97'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.412989Z',
#      'start_time': '2024-05-25T11:19:46.399635Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.657671',
#      'end_time': '2024-06-09T12:08:36.665174',
#      'duration': 0.007503,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.658473Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.658648Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.662851Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.663434Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7de873a5e3a5495a92a6049a66f6d02b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11,
#    'id': 'c2a5b1e6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.665319',
#      'end_time': '2024-06-09T12:08:36.665508',
#      'duration': 0.000189,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': '422177dc'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.426993Z',
#      'start_time': '2024-05-25T11:19:46.414955Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.665644',
#      'end_time': '2024-06-09T12:08:36.672449',
#      'duration': 0.006805,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.666454Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.666671Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.670152Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.670719Z'}},
#    'cell_type': 'code',
#    'source': 'for column in df.columns:\n    # Create RDF triple for Attribute\n    schema.add((abox[column], RDF.type, tbox.Attribute))\n    # Create RDF triple for Attribute\n    schema.add((abox[dataset_name], tbox.hasAttribute, abox[column]))\n    # rdf for the dataproperty\n    schema.add((abox[column], tbox.attribute, Literal(column)))\n\n\n',
#    'outputs': [],
#    'execution_count': 12,
#    'id': '907c5237'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.672602',
#      'end_time': '2024-06-09T12:08:36.672783',
#      'duration': 0.000181,
#      'status': 'completed'}},
#    'id': 'd8359695'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.672919',
#      'end_time': '2024-06-09T12:08:36.673082',
#      'duration': 0.000163,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': '6d9c5820'},
#   {'cell_type': 'code',
#    'source': 'format = meta_dp.format.values[0]\nformat',
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.442243Z',
#      'start_time': '2024-05-25T11:19:46.430177Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.673217',
#      'end_time': '2024-06-09T12:08:36.679925',
#      'duration': 0.006708,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.673984Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.674157Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.677473Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.678189Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'application/csv'"},
#      'execution_count': 13}],
#    'execution_count': 13,
#    'id': '65617154'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Tabular, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Tabular, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Tabular))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.457529Z',
#      'start_time': '2024-05-25T11:19:46.445683Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.680073',
#      'end_time': '2024-06-09T12:08:36.686646',
#      'duration': 0.006573,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.680920Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.681199Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.685013Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.685448Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7de873a5e3a5495a92a6049a66f6d02b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 14}],
#    'execution_count': 14,
#    'id': 'b4bc3f4b'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.686850',
#      'end_time': '2024-06-09T12:08:36.687037',
#      'duration': 0.000187,
#      'status': 'completed'}},
#    'id': '88f35873'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:19:46.473638Z',
#      'start_time': '2024-05-25T11:19:46.459268Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.687222',
#      'end_time': '2024-06-09T12:08:36.694544',
#      'duration': 0.007322,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.688112Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.688296Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.692753Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.693272Z'}},
#    'cell_type': 'code',
#    'source': '#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA1))\n\n\n#TYPE\n\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA1, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7de873a5e3a5495a92a6049a66f6d02b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'execution_count': 15,
#    'id': 'dc262719'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.694743',
#      'end_time': '2024-06-09T12:08:36.694943',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': '72f93ab0'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP1.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:19:46.494923Z',
#      'start_time': '2024-05-25T11:19:46.475386Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:36.695122',
#      'end_time': '2024-06-09T12:08:36.705803',
#      'duration': 0.010681,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:36.695922Z',
#      'iopub.execute_input': '2024-06-09T12:08:36.696100Z',
#      'iopub.status.idle': '2024-06-09T12:08:36.704126Z',
#      'shell.execute_reply': '2024-06-09T12:08:36.703546Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N7de873a5e3a5495a92a6049a66f6d02b (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'execution_count': 16,
#    'id': '618386ed'}]}

# %% [markdown]
# ## DP2

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Registration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyOKBj7CgNIl65qYTal2GaVV'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Registration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/federate_dp2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T12:08:37.098625',
#    'end_time': '2024-06-09T12:08:42.498661',
#    'duration': 5.400036,
#    'exception': None}},
#  'cells': [{'id': '3114fad8',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:37.835749',
#      'end_time': '2024-06-09T12:08:37.867148',
#      'duration': 0.031399,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:37.839432Z',
#      'iopub.execute_input': '2024-06-09T12:08:37.840168Z',
#      'shell.execute_reply': '2024-06-09T12:08:37.859023Z',
#      'iopub.status.idle': '2024-06-09T12:08:37.861767Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Registration"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'cWn3_A9-Oyl1',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548463306,
#      'user_tz': -120,
#      'elapsed': 28007,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '13874c0a-42b9-4827-b970-6f080299d48e',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:41.110893Z',
#      'start_time': '2024-05-25T11:33:41.107068Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:37.869595',
#      'end_time': '2024-06-09T12:08:37.894117',
#      'duration': 0.024522,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:37.873424Z',
#      'iopub.execute_input': '2024-06-09T12:08:37.874194Z',
#      'iopub.status.idle': '2024-06-09T12:08:37.888174Z',
#      'shell.execute_reply': '2024-06-09T12:08:37.885098Z'}},
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '7d770bf8'},
#   {'cell_type': 'code',
#    'source': '!pip install rdflib\n!pip install pydicom\nfrom rdflib import *\nfrom hashlib import sha256',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'KsSMsFdRgCPO',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548471588,
#      'user_tz': -120,
#      'elapsed': 8294,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '7d5690b9-197e-4fd7-cd78-127805c7aa1f',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.453375Z',
#      'start_time': '2024-05-25T11:33:41.205708Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:37.894777',
#      'end_time': '2024-06-09T12:08:41.558924',
#      'duration': 3.664147,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:37.898191Z',
#      'iopub.execute_input': '2024-06-09T12:08:37.900311Z',
#      'shell.execute_reply': '2024-06-09T12:08:41.556785Z',
#      'iopub.status.idle': '2024-06-09T12:08:41.557461Z'}},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in ./venv/lib/python3.11/site-packages (7.0.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in ./venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '54586e4f'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-26T20:27:06.048498Z',
#      'start_time': '2024-05-26T20:27:06.038731Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.559690',
#      'end_time': '2024-06-09T12:08:41.566989',
#      'duration': 0.007299,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:41.561319Z',
#      'iopub.execute_input': '2024-06-09T12:08:41.561637Z',
#      'shell.execute_reply': '2024-06-09T12:08:41.564600Z',
#      'iopub.status.idle': '2024-06-09T12:08:41.565477Z'}},
#    'cell_type': 'code',
#    'source': 'import uuid\n\ndef generate_unique_uri(base_uri):\n    unique_identifier = str(uuid.uuid4())\n    return URIRef(f"{base_uri}{unique_identifier}")',
#    'outputs': [],
#    'execution_count': 4,
#    'id': '0edc27dd'},
#   {'cell_type': 'markdown',
#    'source': '# Create Source Graph',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.567134',
#      'end_time': '2024-06-09T12:08:41.567357',
#      'duration': 0.000223,
#      'status': 'completed'}},
#    'id': '1dc8433c'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.461161Z',
#      'start_time': '2024-05-25T11:33:46.455720Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.567494',
#      'end_time': '2024-06-09T12:08:41.574260',
#      'duration': 0.006766,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:41.568567Z',
#      'iopub.execute_input': '2024-06-09T12:08:41.569164Z',
#      'shell.execute_reply': '2024-06-09T12:08:41.572513Z',
#      'iopub.status.idle': '2024-06-09T12:08:41.572952Z'}},
#    'cell_type': 'code',
#    'source': "schema = Graph()\nschema.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nschema.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 5,
#    'outputs': [],
#    'id': '0afd7f46'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.574405',
#      'end_time': '2024-06-09T12:08:41.574629',
#      'duration': 0.000224,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Load Data',
#    'id': '7a14ce61'},
#   {'cell_type': 'code',
#    'source': 'import pandas as pd',
#    'metadata': {'id': '4CmhFn87Pvf0',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548473752,
#      'user_tz': -120,
#      'elapsed': 431,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.474875Z',
#      'start_time': '2024-05-25T11:33:46.463255Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.574767',
#      'end_time': '2024-06-09T12:08:41.923155',
#      'duration': 0.348388,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:41.575619Z',
#      'iopub.execute_input': '2024-06-09T12:08:41.575802Z',
#      'shell.execute_reply': '2024-06-09T12:08:41.920991Z',
#      'iopub.status.idle': '2024-06-09T12:08:41.921695Z'}},
#    'execution_count': 6,
#    'outputs': [],
#    'id': '094f8def'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.488104Z',
#      'start_time': '2024-05-25T11:33:46.478306Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:41.923725',
#      'end_time': '2024-06-09T12:08:42.082311',
#      'duration': 0.158586,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:41.925061Z',
#      'iopub.execute_input': '2024-06-09T12:08:41.925726Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.080268Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.080890Z'}},
#    'cell_type': 'code',
#    'source': 'import pydicom',
#    'execution_count': 7,
#    'outputs': [],
#    'id': '4bfe568f'},
#   {'cell_type': 'code',
#    'source': 'ds = pydicom.dcmread(os.path.join(base_dir, \'../../DataProductLayer/DataProduct2/Data/0002.DCM\'))\n\n# Print some header information\nprint("Patient\'s Name: ", ds.PatientName)\nprint("Patient ID: ", ds.PatientID)\nprint("Modality: ", ds.Modality)\nprint("Study Date: ", ds.StudyDate)',
#    'metadata': {'id': 'VVzefu5rPTky',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548474258,
#      'user_tz': -120,
#      'elapsed': 512,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.508486Z',
#      'start_time': '2024-05-25T11:33:46.489628Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.083058',
#      'end_time': '2024-06-09T12:08:42.105274',
#      'duration': 0.022216,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.084381Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.084761Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.103958Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.103340Z'}},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Patient's Name:  Rubo DEMO\nPatient ID:  556342B\nModality:  XA\nStudy Date:  19941013\n"}],
#    'id': '97f306ba'},
#   {'cell_type': 'markdown',
#    'source': '## Data Product Profile',
#    'metadata': {'id': 'p1pqIgj1EiRv',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.105431',
#      'end_time': '2024-06-09T12:08:42.105596',
#      'duration': 0.000165,
#      'status': 'completed'}},
#    'id': '2876d2e3'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.105726',
#      'end_time': '2024-06-09T12:08:42.105924',
#      'duration': 0.000198,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### OWNER',
#    'id': '7eec44f0'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.515200Z',
#      'start_time': '2024-05-25T11:33:46.510891Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.106053',
#      'end_time': '2024-06-09T12:08:42.110825',
#      'duration': 0.004772,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.106811Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.106982Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.109604Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.109159Z'}},
#    'cell_type': 'code',
#    'source': "metadata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct/Metadata/explotaiton.csv')",
#    'execution_count': 9,
#    'outputs': [],
#    'id': '1ebe8c3b'},
#   {'cell_type': 'code',
#    'source': 'meta_df = pd.read_csv(metadata_path)\nmeta_dp = meta_df.loc[meta_df[\'name\'] == "UPENN-GBM_clinical_info_v2"]\nowner = meta_dp.owner.values[0]\n',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/', 'height': 81},
#     'id': 'YHMYL5UvGYeu',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548475987,
#      'user_tz': -120,
#      'elapsed': 1033,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a79b883f-d8f3-458a-be16-43dbd82ea0a5',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.560201Z',
#      'start_time': '2024-05-25T11:33:46.516917Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.110977',
#      'end_time': '2024-06-09T12:08:42.118655',
#      'duration': 0.007678,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.111772Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.111941Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.116721Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.117346Z'}},
#    'execution_count': 10,
#    'outputs': [],
#    'id': 'bfb06939'},
#   {'cell_type': 'markdown',
#    'source': '### NAME',
#    'metadata': {'id': 'cOCQNMyWjWai',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.118790',
#      'end_time': '2024-06-09T12:08:42.118966',
#      'duration': 0.000176,
#      'status': 'completed'}},
#    'id': 'b4ec0aad'},
#   {'cell_type': 'code',
#    'source': 'dataset_name = "dicomimage"\ndataset_name',
#    'metadata': {'id': 'SqR_1q33gvQd',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476427,
#      'user_tz': -120,
#      'elapsed': 56,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': '9c5093a3-f31a-49d3-8077-d02c6c4972f2',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.577418Z',
#      'start_time': '2024-05-25T11:33:46.565047Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.119077',
#      'end_time': '2024-06-09T12:08:42.126859',
#      'duration': 0.007782,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.119832Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.120003Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.125016Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.125624Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'dicomimage'"},
#      'execution_count': 11}],
#    'id': '04b7e7b7'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.126992',
#      'end_time': '2024-06-09T12:08:42.127204',
#      'duration': 0.000212,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'add triples',
#    'id': '2695e03e'},
#   {'cell_type': 'code',
#    'source': "# Name\nschema.add((abox[dataset_name], RDF.type, dcat.Dataset))\n#identifier\nidentifier = sha256(dataset_name.encode('utf-8')).hexdigest()\nschema.add((abox[dataset_name],dcterms.identifier, Literal(identifier)))\n#owner\nschema.add((abox[dataset_name], tbox.owner, Literal(owner)))\n\n\n",
#    'metadata': {'id': 'eBWa940rbvZ-',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 54,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.601618Z',
#      'start_time': '2024-05-25T11:33:46.582530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.127372',
#      'end_time': '2024-06-09T12:08:42.134060',
#      'duration': 0.006688,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.128255Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.128441Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.132899Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.132338Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Naa0e4ef87a3d49d6aaf229cc97f94e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': '380fd29f'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.134200',
#      'end_time': '2024-06-09T12:08:42.134429',
#      'duration': 0.000229,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### ATTRIBUTES\n',
#    'id': 'ad664313'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.648611Z',
#      'start_time': '2024-05-25T11:33:46.612095Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.134561',
#      'end_time': '2024-06-09T12:08:42.145138',
#      'duration': 0.010577,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.135339Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.135514Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.143201Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.143785Z'}},
#    'cell_type': 'code',
#    'source': '# Iterate over all attributes\nfor attribute in dir(ds)[:50]:\n    # Check if the attribute starts with a letter\n    # This is to filter out Python built-in attributes\n    if attribute[0].isalpha():\n        # Check if the attribute exists in the DICOM file\n        if hasattr(ds, attribute):\n            # Create RDF triple for Attribute\n            schema.add((abox[attribute], RDF.type, tbox.Attribute))\n            # Create RDF triple for Attribute\n            schema.add((abox[dataset_name], tbox.hasAttribute, abox[attribute]))\n            # rdf for the dataproperty\n            schema.add((abox[attribute], tbox.attribute, Literal(attribute)))\n\n',
#    'execution_count': 13,
#    'outputs': [],
#    'id': '0b0bab3d'},
#   {'cell_type': 'markdown',
#    'source': '## DatasetTypeTemplate',
#    'metadata': {'id': 'adtA5TxYjTR1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.145280',
#      'end_time': '2024-06-09T12:08:42.145449',
#      'duration': 0.000169,
#      'status': 'completed'}},
#    'id': '7071543e'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.145581',
#      'end_time': '2024-06-09T12:08:42.145778',
#      'duration': 0.000197,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Format',
#    'id': 'f63a52d0'},
#   {'cell_type': 'code',
#    'source': "format = 'dicom'",
#    'metadata': {'id': 'fAMZ3dDQk8nv',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476428,
#      'user_tz': -120,
#      'elapsed': 45,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'colab': {'base_uri': 'https://localhost:8080/', 'height': 35},
#     'outputId': 'abc99a38-a334-4d5f-a214-67d122c480b8',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.664083Z',
#      'start_time': '2024-05-25T11:33:46.654613Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.145909',
#      'end_time': '2024-06-09T12:08:42.150582',
#      'duration': 0.004673,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.146700Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.146875Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.148855Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.149329Z'}},
#    'execution_count': 14,
#    'outputs': [],
#    'id': '8d1901b4'},
#   {'cell_type': 'code',
#    'source': "# triple\nschema.add((abox.Image, RDF.type, tbox.DatasetTypeTemplate))\n\n# format\nschema.add((abox.Image, dcterms['format'], Literal(format)))  # Correct usage of the namespace\n\n# addDTT\nschema.add((abox[dataset_name], tbox.hasDTT, abox.Image))\n",
#    'metadata': {'id': 's-TgsXehjVWY',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548476429,
#      'user_tz': -120,
#      'elapsed': 43,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.685786Z',
#      'start_time': '2024-05-25T11:33:46.670145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.150735',
#      'end_time': '2024-06-09T12:08:42.157082',
#      'duration': 0.006347,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.151568Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.151740Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.155325Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.155842Z'}},
#    'execution_count': 15,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Naa0e4ef87a3d49d6aaf229cc97f94e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 15}],
#    'id': '71feedef'},
#   {'cell_type': 'markdown',
#    'source': '### TechnologyAspects',
#    'metadata': {'id': 'i5_QGqixtaQ2',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.157223',
#      'end_time': '2024-06-09T12:08:42.157398',
#      'duration': 0.000175,
#      'status': 'completed'}},
#    'id': '4af308c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T11:33:46.714978Z',
#      'start_time': '2024-05-25T11:33:46.691308Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.157591',
#      'end_time': '2024-06-09T12:08:42.164935',
#      'duration': 0.007344,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.158397Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.158571Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.163322Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.163724Z'}},
#    'cell_type': 'code',
#    'source': "#triple\nschema.add((abox.TA1, RDF.type, tbox.TechnologyAspects))\n\n#  addTA\nschema.add((abox[dataset_name], tbox.hasTA, abox.TA2))\n\n#TYPE\nacces_uri = generate_unique_uri(abox)\n\nschema.add((abox.TA2, tbox.typeAcces, acces_uri))\n\n\nschema.add((acces_uri, RDF.type, tbox.Acces))\nschema.add((acces_uri, RDFS.label, abox.Static))\n\ndata_path = os.path.join(base_dir, '../../DataProductLayer/DataProduct2/Data/0002.DCM')\n# PATH\nschema.add((acces_uri, tbox.path, Literal(data_path)))\n# PATH\n\n",
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Naa0e4ef87a3d49d6aaf229cc97f94e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 16}],
#    'id': '2096a664'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.165074',
#      'end_time': '2024-06-09T12:08:42.165255',
#      'duration': 0.000181,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE SOURCE_GRAPH',
#    'id': 'c62f3f97'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"\nschema.serialize(destination=os.path.join(base_dir, \'Source_Graph_DP2.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '_5GS_wogzBRV',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548492387,
#      'user_tz': -120,
#      'elapsed': 841,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'd69f4992-d842-4240-f331-1ce4bf730343',
#     'ExecuteTime': {'end_time': '2024-05-25T11:33:46.749681Z',
#      'start_time': '2024-05-25T11:33:46.720625Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:42.165373',
#      'end_time': '2024-06-09T12:08:42.176444',
#      'duration': 0.011071,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:42.166187Z',
#      'iopub.execute_input': '2024-06-09T12:08:42.166365Z',
#      'iopub.status.idle': '2024-06-09T12:08:42.175136Z',
#      'shell.execute_reply': '2024-06-09T12:08:42.174370Z'}},
#    'execution_count': 17,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Naa0e4ef87a3d49d6aaf229cc97f94e65 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 17}],
#    'id': '1f52d606'}]}

# %% [markdown]
# ### DP1 INTEGRATION

# %% [markdown]
# ![title](SDM.png)

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP1.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T12:08:42.565954',
#    'end_time': '2024-06-09T12:08:45.494754',
#    'duration': 2.9288,
#    'exception': None}},
#  'cells': [{'id': '0b052c17',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.293168',
#      'end_time': '2024-06-09T12:08:43.322858',
#      'duration': 0.02969,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.297106Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.299348Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.314732Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.317028Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.349247Z',
#      'start_time': '2024-05-25T13:51:03.314976Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.325371',
#      'end_time': '2024-06-09T12:08:43.351028',
#      'duration': 0.025657,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.329494Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.330254Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.341660Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.344651Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '6904cf49'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.536181Z',
#      'start_time': '2024-05-25T13:51:03.525512Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.351610',
#      'end_time': '2024-06-09T12:08:43.414907',
#      'duration': 0.063297,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.354417Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.355941Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.412472Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.413026Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': 'd2776224'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.561098Z',
#      'start_time': '2024-05-25T13:51:03.554167Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.415052',
#      'end_time': '2024-06-09T12:08:43.420825',
#      'duration': 0.005773,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.415999Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.416222Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.419200Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.418673Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': '5eae47f5'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.420980',
#      'end_time': '2024-06-09T12:08:43.421165',
#      'duration': 0.000185,
#      'status': 'completed'}},
#    'id': 'e491faaf'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP1.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.696775Z',
#      'start_time': '2024-05-25T13:51:03.647116Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.421298',
#      'end_time': '2024-06-09T12:08:43.435663',
#      'duration': 0.014365,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.422148Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.422647Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.433338Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.433945Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '40f85d80'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.711011Z',
#      'start_time': '2024-05-25T13:51:03.700133Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.436231',
#      'end_time': '2024-06-09T12:08:43.447848',
#      'duration': 0.011617,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.438197Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.438727Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.445353Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.446022Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:UPENN-GBM_clinical_info_v2 a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "b4f5450e04e5c1669e36df0e37e5e172872e9cce5924c24955222d7f58004afc" ;\n    tb:hasAttribute ab:Age_at_scan_years,\n        ab:GTR_over90percent,\n        ab:Gender,\n        ab:ID,\n        ab:IDH1,\n        ab:KPS,\n        ab:MGMT,\n        ab:PsP_TP_score,\n        ab:Survival_Censor,\n        ab:Survival_Status,\n        ab:Survival_from_surgery_days_UPDATED,\n        ab:Time_since_baseline_preop ;\n    tb:hasDTT ab:Tabular ;\n    tb:hasTA ab:TA1 ;\n    tb:owner "UPENN" .\n\nab:67fc84ae-798c-4c1c-9fe2-64d73980fbce a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct/Data/Explotation/UPENN-GBM_clinical_info_v2.1.csv" .\n\nab:Age_at_scan_years a tb:Attribute ;\n    tb:attribute "Age_at_scan_years" .\n\nab:GTR_over90percent a tb:Attribute ;\n    tb:attribute "GTR_over90percent" .\n\nab:Gender a tb:Attribute ;\n    tb:attribute "Gender" .\n\nab:ID a tb:Attribute ;\n    tb:attribute "ID" .\n\nab:IDH1 a tb:Attribute ;\n    tb:attribute "IDH1" .\n\nab:KPS a tb:Attribute ;\n    tb:attribute "KPS" .\n\nab:MGMT a tb:Attribute ;\n    tb:attribute "MGMT" .\n\nab:PsP_TP_score a tb:Attribute ;\n    tb:attribute "PsP_TP_score" .\n\nab:Survival_Censor a tb:Attribute ;\n    tb:attribute "Survival_Censor" .\n\nab:Survival_Status a tb:Attribute ;\n    tb:attribute "Survival_Status" .\n\nab:Survival_from_surgery_days_UPDATED a tb:Attribute ;\n    tb:attribute "Survival_from_surgery_days_UPDATED" .\n\nab:TA1 a tb:TechnologyAspects ;\n    tb:typeAcces ab:67fc84ae-798c-4c1c-9fe2-64d73980fbce .\n\nab:Tabular a tb:DatasetTypeTemplate ;\n    dcterms:format "application/csv" .\n\nab:Time_since_baseline_preop a tb:Attribute ;\n    tb:attribute "Time_since_baseline_preop" .\n\n\n'}],
#    'id': '672c8012'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.447997',
#      'end_time': '2024-06-09T12:08:43.448219',
#      'duration': 0.000222,
#      'status': 'completed'}},
#    'id': '40996927'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.736137Z',
#      'start_time': '2024-05-25T13:51:03.731723Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.448355',
#      'end_time': '2024-06-09T12:08:43.453900',
#      'duration': 0.005545,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.449290Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.449484Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.452241Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.451680Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '68a1400a'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.454044',
#      'end_time': '2024-06-09T12:08:43.454185',
#      'duration': 0.000141,
#      'status': 'completed'}},
#    'id': 'f1d8d7d6'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'UPENN-GBM_clinical_info_v2'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.758957Z',
#      'start_time': '2024-05-25T13:51:03.753942Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.454314',
#      'end_time': '2024-06-09T12:08:43.459633',
#      'duration': 0.005319,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.455146Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.455323Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.457461Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.458016Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'a79748fb'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.459768',
#      'end_time': '2024-06-09T12:08:43.459968',
#      'duration': 0.0002,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '118ebec2'},
#   {'cell_type': 'code',
#    'source': "\ncontract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))\n\n",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.803876Z',
#      'start_time': '2024-05-25T13:51:03.796978Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.460099',
#      'end_time': '2024-06-09T12:08:43.467640',
#      'duration': 0.007541,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.460915Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.461092Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.465846Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.465157Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': '49bed93e'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.467841',
#      'end_time': '2024-06-09T12:08:43.467997',
#      'duration': 0.000156,
#      'status': 'completed'}},
#    'id': '4be591ed'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:03.849218Z',
#      'start_time': '2024-05-25T13:51:03.840162Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.468171',
#      'end_time': '2024-06-09T12:08:43.474947',
#      'duration': 0.006776,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.468971Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.469190Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.473016Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.473582Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map1, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map1))\n\ncontract.add((abox.map1, tbox.mfrom, abox.ID))\ncontract.add((abox.map1, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': '1ae1674e'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox.map3, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map3))\n\ncontract.add((abox.map3, tbox.mfrom, abox.Age_at_scan_years))\ncontract.add((abox.map3, tbox.mto, abox.Age))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '6lsuA0BOynpC',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 30,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c3d898dd-99d3-4c5a-9ee1-4f7cd855c78c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:03.938627Z',
#      'start_time': '2024-05-25T13:51:03.934703Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.475082',
#      'end_time': '2024-06-09T12:08:43.482310',
#      'duration': 0.007228,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.475879Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.476042Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.480553Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.479966Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': '15e4d462'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:04.007095Z',
#      'start_time': '2024-05-25T13:51:03.994163Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.482452',
#      'end_time': '2024-06-09T12:08:43.493320',
#      'duration': 0.010868,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.483242Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.483410Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.491375Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.491900Z'}},
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'b05a1526'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.493464',
#      'end_time': '2024-06-09T12:08:43.493681',
#      'duration': 0.000217,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '783b1788'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:04.091421Z',
#      'start_time': '2024-05-25T13:51:04.082844Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.493815',
#      'end_time': '2024-06-09T12:08:43.499927',
#      'duration': 0.006112,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.494736Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.494918Z',
#      'iopub.status.idle': '2024-06-09T12:08:43.498736Z',
#      'shell.execute_reply': '2024-06-09T12:08:43.498344Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 13,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'id': '2b6a6b58'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.180559Z',
#      'start_time': '2024-05-25T13:51:04.094181Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:43.500063',
#      'end_time': '2024-06-09T12:08:45.164325',
#      'duration': 1.664262,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:43.500821Z',
#      'iopub.execute_input': '2024-06-09T12:08:43.500993Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.158643Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.155330Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 14,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': 'bd51065e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.204677Z',
#      'start_time': '2024-05-25T13:51:08.190190Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.166592',
#      'end_time': '2024-06-09T12:08:45.194749',
#      'duration': 0.028157,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.171058Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.173210Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.186461Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.189593Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '72ab44c8'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.195149',
#      'end_time': '2024-06-09T12:08:45.195726',
#      'duration': 0.000577,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': 'c8f869ee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.240922Z',
#      'start_time': '2024-05-25T13:51:08.209790Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.196102',
#      'end_time': '2024-06-09T12:08:45.213667',
#      'duration': 0.017565,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.198537Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.198941Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.210148Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.211108Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': 'd373d1fa'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.213858',
#      'end_time': '2024-06-09T12:08:45.214070',
#      'duration': 0.000212,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': 'dcfa7765'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.256659Z',
#      'start_time': '2024-05-25T13:51:08.248930Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.214227',
#      'end_time': '2024-06-09T12:08:45.225707',
#      'duration': 0.01148,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.215376Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.215601Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.223097Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.223760Z'}},
#    'cell_type': 'code',
#    'source': "\np2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\ng = add_jsonld_instances(contract, p2)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': 'df66c2cf'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.225864',
#      'end_time': '2024-06-09T12:08:45.226067',
#      'duration': 0.000203,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '09348414'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.273489Z',
#      'start_time': '2024-05-25T13:51:08.263103Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.226214',
#      'end_time': '2024-06-09T12:08:45.233847',
#      'duration': 0.007633,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.227153Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.227340Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.231449Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.232061Z'}},
#    'cell_type': 'code',
#    'source': "\np3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\ng = add_jsonld_instances(contract, p3)",
#    'execution_count': 18,
#    'outputs': [],
#    'id': '82b873c1'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.233998',
#      'end_time': '2024-06-09T12:08:45.234177',
#      'duration': 0.000179,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'f88fa4c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.306895Z',
#      'start_time': '2024-05-25T13:51:08.279355Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.234346',
#      'end_time': '2024-06-09T12:08:45.244149',
#      'duration': 0.009803,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.235225Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.235411Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.242686Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.242091Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'./SDP1_C.ttl\'), format=rdf_format)',
#    'execution_count': 19,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N8f636915af5045b6b6834d6dc113b26f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 19}],
#    'id': '99e3e4d1'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.244361',
#      'end_time': '2024-06-09T12:08:45.244555',
#      'duration': 0.000194,
#      'status': 'completed'}},
#    'id': '2bd40887'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T13:51:08.398090Z',
#      'start_time': '2024-05-25T13:51:08.314783Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.244736',
#      'end_time': '2024-06-09T12:08:45.256389',
#      'duration': 0.011653,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.245591Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.245773Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.254994Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.254370Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 20,
#    'outputs': [],
#    'id': '2749666c'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.416054Z',
#      'start_time': '2024-05-25T13:51:08.403530Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.256592',
#      'end_time': '2024-06-09T12:08:45.262780',
#      'duration': 0.006188,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.257504Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.257766Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.260862Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.261493Z'}},
#    'execution_count': 21,
#    'outputs': [],
#    'id': 'c9a3356d'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T13:51:08.482184Z',
#      'start_time': '2024-05-25T13:51:08.420633Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:45.262980',
#      'end_time': '2024-06-09T12:08:45.275866',
#      'duration': 0.012886,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:45.263818Z',
#      'iopub.execute_input': '2024-06-09T12:08:45.264247Z',
#      'shell.execute_reply': '2024-06-09T12:08:45.274024Z',
#      'iopub.status.idle': '2024-06-09T12:08:45.274596Z'}},
#    'execution_count': 22,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc4fa02c094ef46d3b2c0cfb92559c2f6 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 22}],
#    'id': '132659ed'}]}

# %% [markdown]
# ## DP2 INTEGRATION

# %%
pm.execute_notebook(
    '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',None, parameters={
        'folder': 'DataPlatformLayer/Integration',
    }
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'nbformat': 4,
#  'nbformat_minor': 5,
#  'metadata': {'colab': {'provenance': [],
#    'authorship_tag': 'ABX9TyNnF92x2yptBfQivng3aQGu'},
#   'kernelspec': {'name': 'python3',
#    'display_name': 'Python 3 (ipykernel)',
#    'language': 'python'},
#   'language_info': {'name': 'python',
#    'version': '3.11.6',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 0,
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': 'DataPlatformLayer/Integration'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Integration/integrateDP2.ipynb',
#    'output_path': None,
#    'start_time': '2024-06-09T12:08:45.540149',
#    'end_time': '2024-06-09T12:08:48.756205',
#    'duration': 3.216056,
#    'exception': None}},
#  'cells': [{'id': 'c918ce12',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.483687',
#      'end_time': '2024-06-09T12:08:46.519253',
#      'duration': 0.035566,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.487404Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.488529Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.514161Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.516182Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "DataPlatformLayer/Integration"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:54.926442Z',
#      'start_time': '2024-05-25T12:05:54.922338Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.520420',
#      'end_time': '2024-06-09T12:08:46.531339',
#      'duration': 0.010919,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.522479Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.523369Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.527465Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.528566Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'execution_count': 2,
#    'outputs': [],
#    'id': '7b9d2663'},
#   {'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'metadata': {'id': 'JVqPKPKqgBsX',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548547861,
#      'user_tz': -120,
#      'elapsed': 423,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.086701Z',
#      'start_time': '2024-05-25T12:05:55.082010Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.531517',
#      'end_time': '2024-06-09T12:08:46.584949',
#      'duration': 0.053432,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.532752Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.533008Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.582917Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.583501Z'}},
#    'execution_count': 3,
#    'outputs': [],
#    'id': '8325a4b7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.107554Z',
#      'start_time': '2024-05-25T12:05:55.102213Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.585079',
#      'end_time': '2024-06-09T12:08:46.590712',
#      'duration': 0.005633,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.585890Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.586065Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.588758Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.589381Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'execution_count': 4,
#    'outputs': [],
#    'id': 'eb01eadb'},
#   {'cell_type': 'markdown',
#    'source': '# Load Schema + Metadata',
#    'metadata': {'id': '-guqsUZpPtD1',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.590843',
#      'end_time': '2024-06-09T12:08:46.591009',
#      'duration': 0.000166,
#      'status': 'completed'}},
#    'id': 'a0059246'},
#   {'cell_type': 'code',
#    'source': "# Load your RDF ontology file\nschema_metadata = Graph()\nschema_metadata.parse(os.path.join(base_dir, '../Registration/Source_Graph_DP2.ttl'))\n",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '-9jnGCPfyCVA',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 625,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': '3915adaf-a38c-4e4a-d0c5-87e4befc0c34',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.194380Z',
#      'start_time': '2024-05-25T12:05:55.173123Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.591129',
#      'end_time': '2024-06-09T12:08:46.610206',
#      'duration': 0.019077,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.592008Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.592364Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.608905Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.608310Z'}},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 5}],
#    'id': '8e6f0e5b'},
#   {'cell_type': 'code',
#    'source': "print(schema_metadata.serialize(format='turtle'))",
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'GfV22oslyibK',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549804,
#      'user_tz': -120,
#      'elapsed': 18,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'a67cafbc-8062-45f0-97bf-c5e02a5a9b05',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.241699Z',
#      'start_time': '2024-05-25T12:05:55.229057Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.610334',
#      'end_time': '2024-06-09T12:08:46.619891',
#      'duration': 0.009557,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.611201Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.611394Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.617997Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.618576Z'}},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '@prefix ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#> .\n@prefix dcterms: <http://purl.org/dc/terms/> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#> .\n\nab:TA1 a tb:TechnologyAspects .\n\nab:dicomimage a <https://www.w3.org/ns/dcat#Dataset> ;\n    dcterms:identifier "35f214530372f7ab83043b98c268f58a4c042c35ccb8ed7d45e7b1911b21a659" ;\n    tb:hasAttribute ab:AccessionNumber,\n        ab:BitsAllocated,\n        ab:BitsStored,\n        ab:Columns,\n        ab:Exposure,\n        ab:FrameIncrementPointer,\n        ab:FrameTime,\n        ab:HighBit,\n        ab:ImageType,\n        ab:InstanceNumber,\n        ab:InstitutionAddress,\n        ab:InstitutionName,\n        ab:KVP,\n        ab:LossyImageCompressionRetired,\n        ab:Manufacturer,\n        ab:MaskSubtractionSequence,\n        ab:Modality,\n        ab:NumberOfFrames,\n        ab:PatientBirthDate,\n        ab:PatientID,\n        ab:PatientName,\n        ab:PatientOrientation,\n        ab:PatientSex,\n        ab:PerformingPhysicianName,\n        ab:PhotometricInterpretation,\n        ab:PixelData,\n        ab:PixelIntensityRelationship,\n        ab:PixelRepresentation,\n        ab:PositionerMotion,\n        ab:PositionerPrimaryAngle,\n        ab:PositionerSecondaryAngle,\n        ab:RWavePointer,\n        ab:RadiationSetting,\n        ab:RecommendedViewingMode,\n        ab:ReferringPhysicianName,\n        ab:Rows,\n        ab:SOPClassUID,\n        ab:SOPInstanceUID,\n        ab:SamplesPerPixel ;\n    tb:hasDTT ab:Image ;\n    tb:hasTA ab:TA2 ;\n    tb:owner "UPENN" .\n\nab:1668ca79-d9e7-4afd-b662-c2b58e67a562 a tb:Acces ;\n    rdfs:label ab:Static ;\n    tb:path "/home/acraf/psr/tfm/Fdatavalidation/DataPlatformLayer/Registration/../../DataProductLayer/DataProduct2/Data/0002.DCM" .\n\nab:AccessionNumber a tb:Attribute ;\n    tb:attribute "AccessionNumber" .\n\nab:BitsAllocated a tb:Attribute ;\n    tb:attribute "BitsAllocated" .\n\nab:BitsStored a tb:Attribute ;\n    tb:attribute "BitsStored" .\n\nab:Columns a tb:Attribute ;\n    tb:attribute "Columns" .\n\nab:Exposure a tb:Attribute ;\n    tb:attribute "Exposure" .\n\nab:FrameIncrementPointer a tb:Attribute ;\n    tb:attribute "FrameIncrementPointer" .\n\nab:FrameTime a tb:Attribute ;\n    tb:attribute "FrameTime" .\n\nab:HighBit a tb:Attribute ;\n    tb:attribute "HighBit" .\n\nab:Image a tb:DatasetTypeTemplate ;\n    dcterms:format "dicom" .\n\nab:ImageType a tb:Attribute ;\n    tb:attribute "ImageType" .\n\nab:InstanceNumber a tb:Attribute ;\n    tb:attribute "InstanceNumber" .\n\nab:InstitutionAddress a tb:Attribute ;\n    tb:attribute "InstitutionAddress" .\n\nab:InstitutionName a tb:Attribute ;\n    tb:attribute "InstitutionName" .\n\nab:KVP a tb:Attribute ;\n    tb:attribute "KVP" .\n\nab:LossyImageCompressionRetired a tb:Attribute ;\n    tb:attribute "LossyImageCompressionRetired" .\n\nab:Manufacturer a tb:Attribute ;\n    tb:attribute "Manufacturer" .\n\nab:MaskSubtractionSequence a tb:Attribute ;\n    tb:attribute "MaskSubtractionSequence" .\n\nab:Modality a tb:Attribute ;\n    tb:attribute "Modality" .\n\nab:NumberOfFrames a tb:Attribute ;\n    tb:attribute "NumberOfFrames" .\n\nab:PatientBirthDate a tb:Attribute ;\n    tb:attribute "PatientBirthDate" .\n\nab:PatientID a tb:Attribute ;\n    tb:attribute "PatientID" .\n\nab:PatientName a tb:Attribute ;\n    tb:attribute "PatientName" .\n\nab:PatientOrientation a tb:Attribute ;\n    tb:attribute "PatientOrientation" .\n\nab:PatientSex a tb:Attribute ;\n    tb:attribute "PatientSex" .\n\nab:PerformingPhysicianName a tb:Attribute ;\n    tb:attribute "PerformingPhysicianName" .\n\nab:PhotometricInterpretation a tb:Attribute ;\n    tb:attribute "PhotometricInterpretation" .\n\nab:PixelData a tb:Attribute ;\n    tb:attribute "PixelData" .\n\nab:PixelIntensityRelationship a tb:Attribute ;\n    tb:attribute "PixelIntensityRelationship" .\n\ ...
#    'id': '974f57bf'},
#   {'cell_type': 'markdown',
#    'source': '## Data Contract',
#    'metadata': {'id': 'Netxl9kumhgA',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.620571',
#      'end_time': '2024-06-09T12:08:46.620937',
#      'duration': 0.000366,
#      'status': 'completed'}},
#    'id': '98a439c8'},
#   {'cell_type': 'code',
#    'source': 'contract = schema_metadata\ncontract.bind(\'dqv\', "http://www.w3.org/ns/dqv#")',
#    'metadata': {'id': 'HVItxxRv4RiT',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548549805,
#      'user_tz': -120,
#      'elapsed': 10,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.321884Z',
#      'start_time': '2024-05-25T12:05:55.317522Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.621146',
#      'end_time': '2024-06-09T12:08:46.629058',
#      'duration': 0.007912,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.622480Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.622915Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.626751Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.625863Z'}},
#    'execution_count': 7,
#    'outputs': [],
#    'id': '1c6a6cac'},
#   {'cell_type': 'markdown',
#    'source': 'Begin manual contract by adding the schema_metadata to the sdm',
#    'metadata': {'id': 'ct7ZR_3sy9G9',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.629299',
#      'end_time': '2024-06-09T12:08:46.629610',
#      'duration': 0.000311,
#      'status': 'completed'}},
#    'id': '290cd0f0'},
#   {'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ndataset_name = 'dicomimage'",
#    'metadata': {'id': '7W1F9r3c4YZF',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713548550196,
#      'user_tz': -120,
#      'elapsed': 400,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.388212Z',
#      'start_time': '2024-05-25T12:05:55.385075Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.629881',
#      'end_time': '2024-06-09T12:08:46.636054',
#      'duration': 0.006173,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.630964Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.631224Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.633936Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.634655Z'}},
#    'execution_count': 8,
#    'outputs': [],
#    'id': 'aeea0c8b'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.636251',
#      'end_time': '2024-06-09T12:08:46.636442',
#      'duration': 0.000191,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Create Contract',
#    'id': '9054b66e'},
#   {'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],RDF.type, tbox.DataContract))\ncontract.add((abox[dataset_name],tbox.hasDC, abox[f'dc_{dataset_name}']))",
#    'metadata': {'id': 'gWt6B5PSysph',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.414271Z',
#      'start_time': '2024-05-25T12:05:55.407780Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.636616',
#      'end_time': '2024-06-09T12:08:46.644607',
#      'duration': 0.007991,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.637453Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.637690Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.643293Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.642564Z'}},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 9}],
#    'id': 'd3b116eb'},
#   {'cell_type': 'markdown',
#    'source': '### Add Mappings',
#    'metadata': {'id': 'vbsM82sryG8b',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.644803',
#      'end_time': '2024-06-09T12:08:46.644993',
#      'duration': 0.00019,
#      'status': 'completed'}},
#    'id': 'e458480a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.450068Z',
#      'start_time': '2024-05-25T12:05:55.444200Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.645170',
#      'end_time': '2024-06-09T12:08:46.652005',
#      'duration': 0.006835,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.645980Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.646157Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.650237Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.650776Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox.map2, RDF.type, tbox.SchemaMapping))\ncontract.add((abox[f'dc_{dataset_name}'],tbox.hasMapping, abox.map2))\n\ncontract.add((abox.map2, tbox.mfrom, abox.PatientID))\ncontract.add((abox.map2, tbox.mto, abox.Subject))\n",
#    'execution_count': 10,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'id': 'c1442f2c'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'metadata': {'id': 'qI8bk_hn1QGq',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533264385,
#      'user_tz': -120,
#      'elapsed': 25,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'c478607c-9fb2-4bb7-f904-fdc2358b7c9f',
#     'colab': {'base_uri': 'https://localhost:8080/'},
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:55.483663Z',
#      'start_time': '2024-05-25T12:05:55.471253Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.652143',
#      'end_time': '2024-06-09T12:08:46.662175',
#      'duration': 0.010032,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.652886Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.653055Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.659813Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.660451Z'}},
#    'execution_count': 11,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'id': 'e42e80cf'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.662373',
#      'end_time': '2024-06-09T12:08:46.662567',
#      'duration': 0.000194,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '### Add Policy',
#    'id': '823bb088'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:55.523326Z',
#      'start_time': '2024-05-25T12:05:55.517244Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.662747',
#      'end_time': '2024-06-09T12:08:46.668659',
#      'duration': 0.005912,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.663548Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.663810Z',
#      'iopub.status.idle': '2024-06-09T12:08:46.667402Z',
#      'shell.execute_reply': '2024-06-09T12:08:46.666883Z'}},
#    'cell_type': 'code',
#    'source': "contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p1))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p2))\n#contract.add((abox[f'dc_{dataset_name}'],tbox.hasPolicy, abox.p3))",
#    'execution_count': 12,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 12}],
#    'id': 'a610041e'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.521782Z',
#      'start_time': '2024-05-25T12:05:55.572231Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:46.668859',
#      'end_time': '2024-06-09T12:08:48.410516',
#      'duration': 1.741657,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:46.669623Z',
#      'iopub.execute_input': '2024-06-09T12:08:46.669828Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.403284Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.400065Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'execution_count': 13,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in ./venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in ./venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.2)\r\nRequirement already satisfied: six in ./venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.0\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'id': '87152ef3'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.530567Z',
#      'start_time': '2024-05-25T12:05:58.524741Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.413514',
#      'end_time': '2024-06-09T12:08:48.442165',
#      'duration': 0.028651,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.418409Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.420509Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.433936Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.436592Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'execution_count': 14,
#    'outputs': [],
#    'id': '41712a26'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.442752',
#      'end_time': '2024-06-09T12:08:48.443394',
#      'duration': 0.000642,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc1',
#    'id': '8822b233'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.565254Z',
#      'start_time': '2024-05-25T12:05:58.532987Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.443888',
#      'end_time': '2024-06-09T12:08:48.464906',
#      'duration': 0.021018,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.447763Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.448523Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.461258Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.462272Z'}},
#    'cell_type': 'code',
#    'source': "p1 = os.path.join(base_dir, '../../FederatedComputationalGovernance/ComputationalCatalogues/p1.json')\ng = add_jsonld_instances(contract, p1)",
#    'execution_count': 15,
#    'outputs': [],
#    'id': '00a8e446'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.465224',
#      'end_time': '2024-06-09T12:08:48.465550',
#      'duration': 0.000326,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'pc2',
#    'id': '75d80ca1'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.571641Z',
#      'start_time': '2024-05-25T12:05:58.568281Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.465761',
#      'end_time': '2024-06-09T12:08:48.472717',
#      'duration': 0.006956,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.467152Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.467428Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.470708Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.469981Z'}},
#    'cell_type': 'code',
#    'source': "#p2 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p2.json'\n#g = add_jsonld_instances(contract, p2)",
#    'execution_count': 16,
#    'outputs': [],
#    'id': '2ba30df6'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.472934',
#      'end_time': '2024-06-09T12:08:48.473241',
#      'duration': 0.000307,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'p3',
#    'id': '97d3b584'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.586850Z',
#      'start_time': '2024-05-25T12:05:58.573469Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.473451',
#      'end_time': '2024-06-09T12:08:48.480871',
#      'duration': 0.00742,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.474943Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.475565Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.478084Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.478974Z'}},
#    'cell_type': 'code',
#    'source': "#p3 = '/home/acraf/psr/tfm/Fdatavalidation/FederatedComputationalGovernance/ComputationalCatalogues/p3.json'\n#g = add_jsonld_instances(contract, p3)",
#    'execution_count': 17,
#    'outputs': [],
#    'id': '6a55b999'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.481208',
#      'end_time': '2024-06-09T12:08:48.481487',
#      'duration': 0.000279,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '',
#    'id': 'abfd922b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.616023Z',
#      'start_time': '2024-05-25T12:05:58.588724Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.481767',
#      'end_time': '2024-06-09T12:08:48.497282',
#      'duration': 0.015515,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.483012Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.483527Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.494618Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.495487Z'}},
#    'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\ncontract.serialize(destination=os.path.join(base_dir, \'SDP2_C.ttl\'), format=rdf_format)',
#    'execution_count': 18,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nee965df5529f46b3bca394270107915f (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 18}],
#    'id': 'eb1d7391'},
#   {'cell_type': 'markdown',
#    'source': '## SEND CONTRACT TO SDM',
#    'metadata': {'id': 'h7efFyJzjKwG',
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.497465',
#      'end_time': '2024-06-09T12:08:48.497746',
#      'duration': 0.000281,
#      'status': 'completed'}},
#    'id': '6cb98cd7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-05-25T12:05:58.653374Z',
#      'start_time': '2024-05-25T12:05:58.617588Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.497895',
#      'end_time': '2024-06-09T12:08:48.512551',
#      'duration': 0.014656,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.498761Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.498962Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.510727Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.511301Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'))",
#    'execution_count': 19,
#    'outputs': [],
#    'id': 'f2b873c9'},
#   {'cell_type': 'code',
#    'source': 'sdm += contract',
#    'metadata': {'id': 'Jz6xGGPqjSd-',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.662501Z',
#      'start_time': '2024-05-25T12:05:58.655680Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.513112',
#      'end_time': '2024-06-09T12:08:48.521159',
#      'duration': 0.008047,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.513933Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.514140Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.518959Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.519552Z'}},
#    'execution_count': 20,
#    'outputs': [],
#    'id': 'a1925c68'},
#   {'cell_type': 'code',
#    'source': 'rdf_format = "turtle"  # Choose your desired RDF serialization format\nsdm.serialize(destination=os.path.join(base_dir, \'../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl\'), format=rdf_format)',
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': '8sS2yESRjYAJ',
#     'executionInfo': {'status': 'ok',
#      'timestamp': 1713533562001,
#      'user_tz': -120,
#      'elapsed': 11,
#      'user': {'displayName': 'Achraf Hmimou',
#       'userId': '15223621851022794490'}},
#     'outputId': 'bebb36df-28cb-438e-b555-ae7eb322bd5c',
#     'ExecuteTime': {'end_time': '2024-05-25T12:05:58.702350Z',
#      'start_time': '2024-05-25T12:05:58.665215Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-09T12:08:48.521289',
#      'end_time': '2024-06-09T12:08:48.538667',
#      'duration': 0.017378,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-09T12:08:48.522124Z',
#      'iopub.execute_input': '2024-06-09T12:08:48.522304Z',
#      'shell.execute_reply': '2024-06-09T12:08:48.536479Z',
#      'iopub.status.idle': '2024-06-09T12:08:48.537073Z'}},
#    'execution_count': 21,
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nd1aa59a7af8e4ae8912aafee52cc7bdf (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 21}],
#    'id': '098399a8'}]}

# %% [markdown]
# # CONTRACT VALIDATION

# %% [markdown]
# ![title](AS.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:DataProduct .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %%
dp = input("SELECT NAME OF DATA PRODUCT: ")

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


datasets = [row.dataset.split("#")[1] for row in qres]

datasets = set(datasets)
datasets
# Out:
# {'UPENN-GBM_clinical_info_v2', 'dicomimage'}

# %% [markdown]
# ## PARSER

# %% [markdown]
# ![title](PC.png)

# %%
for dp in datasets:    
    pm.execute_notebook(
        '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/parser/parser.ipynb',None, parameters={
            'folder': 'SideCar/ValidateContract/parser',
            'dp': dp
        }
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ## TRANSLATOR

# %% [markdown]
# ![title](SCRIPT.png)

# %%
sdm = Graph().parse(os.path.join(base_dir, 'FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
def queryPC(ds):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?p .
        # ?pc tb:hasType ?t .
        # ?ds tb:hasDTT ?t
        FILTER (?ds = ab:{ds})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %%
for ds in datasets:
    pcs = queryPC(ds)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(
            '/home/acraf/psr/tfm/Fdatavalidation/SideCar/ValidateContract/translator/translator.ipynb',None, parameters={
                'folder': 'SideCar/ValidateContract/translator',
                'pc' : pc.split("#")[1]
            }
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0aa9cc92-7aa8-4543-a6bd-ef2f8aa5cca9
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# d84092c5-d445-4b17-b6ca-3a524e04e09a
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# de62e834-2cc2-4153-9879-5401fde0858c
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
