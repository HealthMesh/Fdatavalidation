# %% [markdown]
# # Generate locally an ML model for data provider

# %%
import os
import pandas as pd
import numpy as np
from pycaret.classification import *
from fairlearn.metrics import demographic_parity_difference, demographic_parity_ratio

# %%
import pandas as pd
import numpy as np
import os
from pycaret.classification import *

df = pd.read_csv('/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/UPENN-GBM_clinical_info_v2.1_ML.csv')

df['Survival_from_surgery_days_UPDATED'] = pd.to_numeric(
    df['Survival_from_surgery_days_UPDATED'].replace('Not Available', np.nan), 
    errors='coerce'
)

df = df.dropna(subset=['Survival_from_surgery_days_UPDATED'])

df['target'] = (df['Survival_from_surgery_days_UPDATED'] > 
                df['Survival_from_surgery_days_UPDATED'].median()).astype(int)

clf = setup(data=df, 
           target='target',
           ignore_features=['ID', 'Time_since_baseline_preop', 'PsP_TP_score',
                          'Survival_Censor', 'Survival_Status', 
                          'Survival_from_surgery_days_UPDATED'],
           use_gpu=True)

best_model = compare_models(n_select=1)
test_data = get_config('X_test').copy()
test_data['target'] = get_config('y_test')
predictions = predict_model(best_model, data=test_data)

save_model(best_model, os.path.join('../Data/Explotation', 'model'))
test_data.to_csv(os.path.join('../Data/Explotation','test.csv'), index=False)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# <style type="text/css">
# #T_aa9e6_row11_col1, #T_aa9e6_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aa9e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa9e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aa9e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa9e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa9e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aa9e6_row0_col1" class="data row0 col1" >4984</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa9e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aa9e6_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aa9e6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_aa9e6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aa9e6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_aa9e6_row3_col1" class="data row3 col1" >(644, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aa9e6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_aa9e6_row4_col1" class="data row4 col1" >(644, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aa9e6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_aa9e6_row5_col1" class="data row5 col1" >(450, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aa9e6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_aa9e6_row6_col1" class="data row6 col1" >(194, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aa9e6_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_aa9e6_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aa9e6_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_aa9e6_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aa9e6_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_aa9e6_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aa9e6_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_aa9e6_row10_col1" class="data row10 col1" >90.8%</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aa9e6_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_aa9e6_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aa9e6_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_aa9e6_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aa9e6_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_aa9e6_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aa9e6_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_aa9e6_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aa9e6_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_aa9e6_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aa9e6_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_aa9e6_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aa9e6_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_aa9e6_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aa9e6_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_aa9e6_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aa9e6_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_aa9e6_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_aa9e6_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_aa9e6_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_aa9e6_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_aa9e6_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_aa9e6_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_aa9e6_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_aa9e6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_aa9e6_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_aa9e6_row23_col1" class="data row23 col1" >1512</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              08:58:59
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_25c7a th {
#   text-align: left;
# }
# #T_25c7a_row0_col0, #T_25c7a_row0_col3, #T_25c7a_row1_col0, #T_25c7a_row1_col1, #T_25c7a_row1_col2, #T_25c7a_row1_col3, #T_25c7a_row1_col4, #T_25c7a_row1_col5, #T_25c7a_row1_col6, #T_25c7a_row1_col7, #T_25c7a_row2_col0, #T_25c7a_row2_col1, #T_25c7a_row2_col2, #T_25c7a_row2_col3, #T_25c7a_row2_col4, #T_25c7a_row2_col5, #T_25c7a_row2_col6, #T_25c7a_row2_col7, #T_25c7a_row3_col0, #T_25c7a_row3_col1, #T_25c7a_row3_col2, #T_25c7a_row3_col3, #T_25c7a_row3_col4, #T_25c7a_row3_col5, #T_25c7a_row3_col6, #T_25c7a_row3_col7, #T_25c7a_row4_col0, #T_25c7a_row4_col1, #T_25c7a_row4_col2, #T_25c7a_row4_col3, #T_25c7a_row4_col4, #T_25c7a_row4_col5, #T_25c7a_row4_col6, #T_25c7a_row4_col7, #T_25c7a_row5_col0, #T_25c7a_row5_col1, #T_25c7a_row5_col2, #T_25c